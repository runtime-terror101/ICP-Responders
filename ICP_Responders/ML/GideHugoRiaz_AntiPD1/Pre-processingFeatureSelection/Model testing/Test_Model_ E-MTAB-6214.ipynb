# %% [markdown]
# # Testing the model on new data
#
# DIDN'T USE 12 SAMPLE DATA, NO RESPONSE

# %% [markdown]
# ## Import Libraries

# %%
library('org.Hs.eg.db')
library(caret)
library(GeneAnswers)
# Out:
# Loading required package: AnnotationDbi
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
# ...

# %% [markdown]
# ## Download the data
#
# [Raw Counts](https://www.ebi.ac.uk/gxa/experiments-content/E-MTAB-6214/resources/DifferentialSecondaryDataFiles.RnaSeq/raw-counts)<br>
# [Analytics](https://www.ebi.ac.uk/gxa/experiments-content/E-MTAB-6214/resources/DifferentialSecondaryDataFiles.RnaSeq/analytics)<br>

# %%
system("wget --content-disposition https://www.ebi.ac.uk/gxa/experiments-content/E-MTAB-6214/resources/DifferentialSecondaryDataFiles.RnaSeq/raw-counts")
system("wget --content-disposition https://www.ebi.ac.uk/gxa/experiments-content/E-MTAB-6214/resources/DifferentialSecondaryDataFiles.RnaSeq/analytics")

# %% [markdown]
# ## Read the data

# %%
expression <- t(read.csv("E-MTAB-6214-raw-counts.tsv", check.names=FALSE, sep="	"))
dim(expression)
expression
# Out:
# [1]    14 58735
#            [,1]            [,2]            [,3]            [,4]
# Gene ID    ENSG00000000003 ENSG00000000005 ENSG00000000419 ENSG00000000457
# Gene Name  TSPAN6          TNMD            DPM1            SCYL3
# ERR2228763      0               0               1               6
# ERR2228765      0               0              50              24
# ERR2228761      0               0              84              49
# ERR2228764      0               0              84              19
# ERR2228759      0               0             114              18
# ERR2228760      0               0              54              42
# ERR2228767      0               0              84              35
# ERR2228758      0               0              42             101
# ERR2228756      0               0              49              43
# ERR2228766      0               0              83              20
# ERR2228762      0               0               0               0
# ...

# %%
analytics <- t(read.csv("E-MTAB-6214-analytics.tsv", check.names=FALSE, sep="	"))
dim(analytics)
analytics
# Out:
# [1]     8 58735
#                                                                                 [,1]
# Gene ID                                                                         ENSG00000000003
# Gene Name                                                                       TSPAN6
# 'responder' vs 'non-responder' in 'metastatic melanoma'.p-value                 NA
# 'responder' vs 'non-responder' in 'metastatic melanoma'.log2foldchange           0.0
# 'metastatic melanoma; non-responder' vs 'normal; not applicable'.p-value        NA
# 'metastatic melanoma; non-responder' vs 'normal; not applicable'.log2foldchange  0.0
# 'metastatic melanoma; responder' vs 'normal; not applicable'.p-value            NA
# 'metastatic melanoma; responder' vs 'normal; not applicable'.log2foldchange      0.0
#                                                                                 [,2]
# Gene ID                                                                         ENSG00000000005
# ...

# %%
system("wget --content-disposition https://www.ebi.ac.uk/gxa/experiments-content/E-MTAB-6214/resources/ExperimentDownloadSupplier.RnaSeqDifferential/tsv")

# %%
results <- read.csv("E-MTAB-6214-query-results.tsv", sep="\t")
dim(results)
results
# Out:
# Error in read.table(file = file, header = header, sep = sep, quote = quote, : more columns than column names
# Traceback:
#
# 1. read.csv("E-MTAB-6214-query-results.tsv", sep = "\t")
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. stop("more columns than column names")
