# %% [markdown]
# # Pre-Processing
# 1) Clean data by removing rows with > 50% missing info <br>
# 2) Find the most informative features <br>
# 3) Split the data into test and train

# %%
library(caret)
library(corrplot)
library(biomaRt)
library(GeneAnswers) # used to get gene names from entrez IDs
# Out:
# Loading required package: lattice
#
# Loading required package: ggplot2
#
# corrplot 0.90 loaded
#
# Loading required package: igraph
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Loading required package: RCurl
#
# Loading required package: annotate
#
# Loading required package: AnnotationDbi
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:igraph’:
#
#     normalize, path, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: IRanges
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: XML
#
# Loading required package: RSQLite
#
# Loading required package: MASS
#
#
# Attaching package: ‘MASS’
#
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
#
# The following object is masked from ‘package:biomaRt’:
#
#     select
#
#
# Loading required package: Heatplus
#
# Loading required package: RColorBrewer
#
# Warning message:
# “replacing previous import ‘stats::decompose’ by ‘igraph::decompose’ when loading ‘GeneAnswers’”
# Warning message:
# “replacing previous import ‘stats::spectrum’ by ‘igraph::spectrum’ when loading ‘GeneAnswers’”

# %% [markdown]
# ## Load data
# The first column is expected to be sample ID <br>
# The second column is expected to be response

# %%
setwd("/home/jp/ICP_Responders/FinalTables")
expression <- read.csv("Final_table_response_and_expression.csv", na.strings = '..', stringsAsFactors = F)
names(expression) <- sub("^X", "", names(expression))
expression[ expression == "NA" ] <- NA
expression[,2:ncol(expression)] <- lapply(expression[, 2:ncol(expression)], as.numeric)
expression[50:60, 1:10]
# Out:
#    Patient Response 3920        345611       3929       54210       3716
# 50 31      1                 NA           NA         NA          NA          NA
# 51 32      1                 NA           NA         NA          NA          NA
# 52 33      1                 NA           NA         NA          NA          NA
# 53 34      1        -0.24227274  0.074304976 -0.3511685  0.54428208 -0.15006954
# 54 35      1        -0.48479782  0.159405465  0.4199815 -2.22883720  0.24650857
# 55 36      1         0.74085490  0.003467014  0.3333496 -0.03988917 -0.21346769
# 56 37      1                 NA           NA         NA          NA          NA
# 57 38      1         0.81259519 -0.048404344 -0.2250873 -0.29189077  0.44538081
# 58 39      0                 NA           NA         NA          NA          NA
# 59 4       0         0.14400922 -0.067130938  0.1120551 -0.96429947  0.10440116
# 60 40      1         0.07691239  0.333001919  0.5565036  0.17618231 -0.09816412
#    10454       3557        3556
# 50          NA          NA           NA
# 51          NA          NA           NA
# 52          NA          NA           NA
# 53 -0.07183968  0.20022650 -1.182660036
# 54 -0.38904130  1.82423349 -1.343065827
# 55  0.54476821 -1.69969237  0.483498059
# 56          NA          NA           NA
# 57  0.21789661 -0.08321449  1.567718745
# 58          NA          NA           NA
# 59 -0.74711659  0.30591242 -1.254576697
# 60  0.45014341 -0.28709491  0.002942665

# %% [markdown]
# ## Clean data

# %%
# Check which column has > 50% NA values
countNA <- function(x=NULL,cutOff=NULL){
  output<-FALSE
  perc<-sum(is.na(x))*100/length(x)
  if(perc>cutOff){output<-TRUE}
  output  
}
col_nas <- apply(expression,2,function(x){countNA(x, 50)})
cat("Columns with NAs > 50% = ", sum(col_nas), "\n")
# all columns have <50% NAs

# Check which rows has > 50% NA values
row_nas <- apply(expression,1,function(x){countNA(x, 50)})
cat("Rows with NAs > 50% = ", sum(row_nas), "\n")

# 43 rows have have >50% NAs, removing them
expr_filtered <- expression[-which(row_nas %in% TRUE),]

cat("Dimensions of the filtered dataset = ", dim(expr_filtered))
# Out:
# Columns with NAs > 50% =  0
# Rows with NAs > 50% =  43
# Dimensions of the filtered dataset =  161 676

# %% [markdown]
# ## Look for near zero variance and remove those columns

# %%
nzv <- nearZeroVar(expr_filtered[3:ncol(expr_filtered)], saveMetrics= TRUE)
nzv[which(nzv$zeroVar %in% TRUE), ]

# All features were retained and there was no filtering due to near zero variance
# Out:
#      freqRatio percentUnique zeroVar nzv

# %% [markdown]
# ## Look for correlation and remove highly correlated columns

# %%
# find attributes that are highly corrected (ideally >0.75)
tmp <- expr_filtered
tmp[is.na(tmp)] <- 0
expr_corr <-  cor(tmp[,3:ncol(tmp)]) 
highlyCorrelated <- findCorrelation(expr_corr, cutoff=0.75, names=TRUE, verbose=TRUE)
expr_rmcorr <- expr_filtered[, -which(colnames(expr_filtered) %in% highlyCorrelated)]
# Out:
#  Combination row 18 and column 19 is above the cut-off, value = 0.797
#  	 Flagging column 18
#  Combination row 18 and column 20 is above the cut-off, value = 0.755
#  	 Flagging column 18
#  Combination row 20 and column 22 is above the cut-off, value = 0.832
#  	 Flagging column 22
#  Combination row 20 and column 23 is above the cut-off, value = 0.801
#  	 Flagging column 23
#  Combination row 22 and column 23 is above the cut-off, value = 0.954
#  	 Flagging column 22
#  Combination row 18 and column 24 is above the cut-off, value = 0.768
#  	 Flagging column 18
#  Combination row 19 and column 24 is above the cut-off, value = 0.838
#  	 Flagging column 24
#  Combination row 19 and column 25 is above the cut-off, value = 0.759
#  	 Flagging column 25
#  Combination row 24 and column 25 is above the cut-off, value = 0.929
#  	 Flagging column 25
#  Combination row 16 and column 26 is above the cut-off, value = 0.856
#  	 Flagging column 16
#  Combination row 16 and column 31 is above the cut-off, value = 0.942
#  	 Flagging column 31
#  Combination row 26 and column 31 is above the cut-off, value = 0.772
#  	 Flagging column 31
#  Combination row 16 and column 32 is above the cut-off, value = 0.827
#  	 Flagging column 16
#  Combination row 31 and column 32 is above the cut-off, value = 0.904
#  	 Flagging column 31
#  Combination row 16 and column 36 is above the cut-off, value = 0.867
#  	 Flagging column 36
#  Combination row 26 and column 36 is above the cut-off, value = 0.767
#  	 Flagging column 36
#  Combination row 31 and column 36 is above the cut-off, value = 0.895
#  	 Flagging column 31
#  Combination row 32 and column 36 is above the cut-off, value = 0.785
#  	 Flagging column 36
#  Combination row 18 and column 38 is above the cut-off, value = 0.816
#  	 Flagging column 38
#  Combination row 19 and column 38 is above the cut-off, value = 0.874
#  	 Flagging column 38
#  Combination row 24 and column 38 is above the cut-off, value = 0.883
#  	 Flagging column 38
#  Combination row 25 and column 38 is above the cut-off, value = 0.825
#  	 Flagging column 38
#  Combination row 22 and column 46 is above the cut-off, value = 0.828
#  	 Flagging column 22
#  Combination row 23 and column 46 is above the cut-off, value = 0.81
#  	 Flagging column 23
#  Combination row 19 and column 52 is above the cut-off, value = 0.811
#  	 Flagging column 52
#  Combination row 38 and column 52 is above the cut-off, value = 0.849
#  	 Flagging column 38
#  Combination row 36 and column 57 is above the cut-off, value = 0.753
#  	 Flagging column 36
#  Combination row 16 and column 63 is above the cut-off, value = 0.8
#  	 Flagging column 63
#  Combination row 18 and column 63 is above the cut-off, value = 0.78
#  	 Flagging column 63
#  Combination row 24 and column 63 is above the cut-off, value = 0.82
#  	 Flagging column 63
#  Combination row 25 and column 63 is above the cut-off, value = 0.792
#  	 Flagging column 63
#  Combination row 31 and column 63 is above the cut-off, value = 0.896
#  	 Flagging column 63
#  Combination row 32 and column 63 is above the cut-off, value = 0.878
#  	 Flagging column 63
#  Combination row 36 and column 63 is above the cut-off, value = 0.813
#  	 Flagging column 63
#  Combination row 38 and column 63 is above the cut-off, value = 0.865
#  	 Flagging column 63
#  Combination row 26 and column 64 is above the cut-off, value = 0.844
#  	 Flagging column 26
#  Combination row 26 and column 65 is above the cut-off, value = 0.814
#  	 Flagging column 26
#  Combination row 64 and column 65 is above the cut-off, value = 0.81
#  	 Flagging column 65
#  Combination row 19 and column 66 is above the cut-off, value = 0.897
#  	 Flagging column 66
#  Combination row 24 and column 66 is above the cut-off, value = 0.769
#  	 Flagging column 24
#  Combination row 38 and column 66 is above the cut-off, value = 0.851
#  	 Flagging column 38
#  Combination row 52 and column 66 is above the cut-off, value = 0.783
#  	 Flagging column 52
#  Combination row 16 and column 68 is above the cut-off, value = 0.82
#  	 Flagging column 16
#  Combination row 26 and column 68 is above the cut-off, value = 0.802
#  	 Flagging column 26
#  Combination row 31 and column 68 is above the cut-off, value = 0.782
#  	 Flagging column 31
#  Combination row 48 and column 68 is above the cut-off, value = 0.762
#  	 Flagging column 68
#  Combination row 65 and column 68 is above the cut-off, value = 0.762
#  	 Flagging column 68
#  Combination row 10 and column 70 is above the cut-off, value = 0.784
#  	 Flagging column 10
#  Combination row 16 and column 75 is above the cut-off, value = 0.765
#  	 Flagging column 16
#  Combination row 26 and column 75 is above the cut-off, value = 0.814
#  	 Flagging column 26
#  Combination row 36 and column 75 is above the cut-off, value = 0.777
#  	 Flagging column 36
#  Combination row 68 and column 75 is above the cut-off, value = 0.778
#  	 Flagging column 68
#  Combination row 18 and column 85 is above the cut-off, value = 0.783
#  	 Flagging column 18
#  Combination row 19 and column 85 is above the cut-off, value = 0.818
#  	 Flagging column 85
#  Combination row 24 and column 85 is above the cut-off, value = 0.811
#  	 Flagging column 85
#  Combination row 25 and column 85 is above the cut-off, value = 0.794
#  	 Flagging column 85
#  Combination row 38 and column 85 is above the cut-off, value = 0.822
#  	 Flagging column 38
#  Combination row 52 and column 85 is above the cut-off, value = 0.763
#  	 Flagging column 85
#  Combination row 63 and column 85 is above the cut-off, value = 0.776
#  	 Flagging column 63
#  Combination row 66 and column 85 is above the cut-off, value = 0.784
#  	 Flagging column 85
#  Combination row 26 and column 86 is above the cut-off, value = 0.83
#  	 Flagging column 26
#  Combination row 64 and column 86 is above the cut-off, value = 0.896
#  	 Flagging column 64
#  Combination row 65 and column 86 is above the cut-off, value = 0.779
#  	 Flagging column 65
#  Combination row 32 and column 104 is above the cut-off, value = 0.755
#  	 Flagging column 32
#  Combination row 63 and column 104 is above the cut-off, value = 0.792
#  	 Flagging column 63
#  Combination row 16 and column 111 is above the cut-off, value = 0.815
#  	 Flagging column 16
#  Combination row 31 and column 111 is above the cut-off, value = 0.845
#  	 Flagging column 31
#  Combination row 36 and column 111 is above the cut-off, value = 0.8
#  	 Flagging column 36
#  Combination row 63 and column 111 is above the cut-off, value = 0.751
#  	 Flagging column 63
#  Combination row 24 and column 115 is above the cut-off, value = 0.84
#  	 Flagging column 115
#  Combination row 25 and column 115 is above the cut-off, value = 0.814
#  	 Flagging column 115
#  Combination row 38 and column 115 is above the cut-off, value = 0.789
#  	 Flagging column 38
#  Combination row 63 and column 115 is above the cut-off, value = 0.765
#  	 Flagging column 63
#  Combination row 85 and column 115 is above the cut-off, value = 0.823
#  	 Flagging column 85
#  Combination row 26 and column 124 is above the cut-off, value = 0.793
#  	 Flagging column 26
#  Combination row 64 and column 124 is above the cut-off, value = 0.803
#  	 Flagging column 64
#  Combination row 68 and column 124 is above the cut-off, value = 0.798
#  	 Flagging column 68
#  Combination row 75 and column 124 is above the cut-off, value = 0.83
#  	 Flagging column 75
#  Combination row 86 and column 124 is above the cut-off, value = 0.775
#  	 Flagging column 124
#  Combination row 16 and column 129 is above the cut-off, value = 0.846
#  	 Flagging column 129
#  Combination row 18 and column 129 is above the cut-off, value = 0.788
#  	 Flagging column 129
#  Combination row 26 and column 129 is above the cut-off, value = 0.834
#  	 Flagging column 129
#  Combination row 31 and column 129 is above the cut-off, value = 0.847
#  	 Flagging column 129
#  Combination row 36 and column 129 is above the cut-off, value = 0.824
#  	 Flagging column 129
#  Combination row 38 and column 129 is above the cut-off, value = 0.783
#  	 Flagging column 129
#  Combination row 63 and column 129 is above the cut-off, value = 0.838
#  	 Flagging column 129
#  Combination row 68 and column 129 is above the cut-off, value = 0.765
#  	 Flagging column 129
#  Combination row 126 and column 129 is above the cut-off, value = 0.775
#  	 Flagging column 129
#  Combination row 130 and column 131 is above the cut-off, value = 0.752
#  	 Flagging column 131
#  Combination row 26 and column 140 is above the cut-off, value = 0.811
#  	 Flagging column 26
#  Combination row 16 and column 144 is above the cut-off, value = 0.794
#  	 Flagging column 16
#  Combination row 31 and column 144 is above the cut-off, value = 0.807
#  	 Flagging column 31
#  Combination row 68 and column 144 is above the cut-off, value = 0.799
#  	 Flagging column 68
#  Combination row 16 and column 147 is above the cut-off, value = 0.89
#  	 Flagging column 16
#  Combination row 26 and column 147 is above the cut-off, value = 0.813
#  	 Flagging column 26
#  Combination row 31 and column 147 is above the cut-off, value = 0.866
#  	 Flagging column 31
#  Combination row 36 and column 147 is above the cut-off, value = 0.782
#  	 Flagging column 36
#  Combination row 68 and column 147 is above the cut-off, value = 0.786
#  	 Flagging column 147
#  Combination row 75 and column 147 is above the cut-off, value = 0.751
#  	 Flagging column 147
#  Combination row 111 and column 147 is above the cut-off, value = 0.76
#  	 Flagging column 147
#  Combination row 129 and column 147 is above the cut-off, value = 0.817
#  	 Flagging column 129
#  Combination row 144 and column 147 is above the cut-off, value = 0.813
#  	 Flagging column 147
#  Combination row 22 and column 149 is above the cut-off, value = 0.786
#  	 Flagging column 22
#  Combination row 23 and column 149 is above the cut-off, value = 0.786
#  	 Flagging column 23
#  Combination row 141 and column 152 is above the cut-off, value = 0.77
#  	 Flagging column 141
#  Combination row 63 and column 154 is above the cut-off, value = 0.758
#  	 Flagging column 63
#  Combination row 153 and column 154 is above the cut-off, value = 0.845
#  	 Flagging column 154
#  Combination row 141 and column 155 is above the cut-off, value = 0.789
#  	 Flagging column 141
#  Combination row 18 and column 156 is above the cut-off, value = 0.782
#  	 Flagging column 156
#  Combination row 19 and column 156 is above the cut-off, value = 0.764
#  	 Flagging column 156
#  Combination row 24 and column 156 is above the cut-off, value = 0.834
#  	 Flagging column 156
#  Combination row 25 and column 156 is above the cut-off, value = 0.813
#  	 Flagging column 156
#  Combination row 31 and column 156 is above the cut-off, value = 0.82
#  	 Flagging column 31
#  Combination row 32 and column 156 is above the cut-off, value = 0.791
#  	 Flagging column 156
#  Combination row 36 and column 156 is above the cut-off, value = 0.768
#  	 Flagging column 36
#  Combination row 38 and column 156 is above the cut-off, value = 0.852
#  	 Flagging column 38
#  Combination row 63 and column 156 is above the cut-off, value = 0.856
#  	 Flagging column 63
#  Combination row 85 and column 156 is above the cut-off, value = 0.758
#  	 Flagging column 156
#  Combination row 129 and column 156 is above the cut-off, value = 0.776
#  	 Flagging column 129
#  Combination row 154 and column 156 is above the cut-off, value = 0.801
#  	 Flagging column 156
#  Combination row 38 and column 157 is above the cut-off, value = 0.759
#  	 Flagging column 38
#  Combination row 18 and column 158 is above the cut-off, value = 0.784
#  	 Flagging column 158
#  Combination row 24 and column 158 is above the cut-off, value = 0.821
#  	 Flagging column 158
#  Combination row 25 and column 158 is above the cut-off, value = 0.796
#  	 Flagging column 158
#  Combination row 31 and column 158 is above the cut-off, value = 0.787
#  	 Flagging column 31
#  Combination row 32 and column 158 is above the cut-off, value = 0.753
#  	 Flagging column 158
#  Combination row 38 and column 158 is above the cut-off, value = 0.817
#  	 Flagging column 38
#  Combination row 63 and column 158 is above the cut-off, value = 0.843
#  	 Flagging column 63
#  Combination row 129 and column 158 is above the cut-off, value = 0.776
#  	 Flagging column 129
#  Combination row 154 and column 158 is above the cut-off, value = 0.82
#  	 Flagging column 158
#  Combination row 156 and column 158 is above the cut-off, value = 0.926
#  	 Flagging column 156
#  Combination row 16 and column 159 is above the cut-off, value = 0.793
#  	 Flagging column 16
#  Combination row 26 and column 159 is above the cut-off, value = 0.781
#  	 Flagging column 26
#  Combination row 68 and column 159 is above the cut-off, value = 0.78
#  	 Flagging column 68
#  Combination row 147 and column 159 is above the cut-off, value = 0.782
#  	 Flagging column 147
#  Combination row 31 and column 161 is above the cut-off, value = 0.763
#  	 Flagging column 31
#  Combination row 36 and column 161 is above the cut-off, value = 0.764
#  	 Flagging column 36
#  Combination row 38 and column 161 is above the cut-off, value = 0.752
#  	 Flagging column 38
#  Combination row 63 and column 161 is above the cut-off, value = 0.756
#  	 Flagging column 63
#  Combination row 129 and column 161 is above the cut-off, value = 0.76
#  	 Flagging column 129
#  Combination row 144 and column 161 is above the cut-off, value = 0.75
#  	 Flagging column 161
#  Combination row 147 and column 161 is above the cut-off, value = 0.765
#  	 Flagging column 147
#  Combination row 26 and column 162 is above the cut-off, value = 0.752
#  	 Flagging column 26
#  Combination row 57 and column 162 is above the cut-off, value = 0.796
#  	 Flagging column 57
#  Combination row 64 and column 175 is above the cut-off, value = 0.787
#  	 Flagging column 64
#  Combination row 31 and column 181 is above the cut-off, value = 0.796
#  	 Flagging column 31
#  Combination row 32 and column 181 is above the cut-off, value = 0.777
#  	 Flagging column 32
#  Combination row 36 and column 181 is above the cut-off, value = 0.793
#  	 Flagging column 36
#  Combination row 16 and column 182 is above the cut-off, value = 0.822
#  	 Flagging column 16
#  Combination row 26 and column 182 is above the cut-off, value = 0.773
#  	 Flagging column 26
#  Combination row 31 and column 182 is above the cut-off, value = 0.847
#  	 Flagging column 31
#  Combination row 32 and column 182 is above the cut-off, value = 0.812
#  	 Flagging column 32
#  Combination row 36 and column 182 is above the cut-off, value = 0.761
#  	 Flagging column 36
#  Combination row 63 and column 182 is above the cut-off, value = 0.792
#  	 Flagging column 63
#  Combination row 129 and column 182 is above the cut-off, value = 0.819
#  	 Flagging column 129
#  Combination row 147 and column 182 is above the cut-off, value = 0.78
#  	 Flagging column 182
#  Combination row 161 and column 182 is above the cut-off, value = 0.779
#  	 Flagging column 182
#  Combination row 16 and column 184 is above the cut-off, value = 0.913
#  	 Flagging column 16
#  Combination row 26 and column 184 is above the cut-off, value = 0.803
#  	 Flagging column 184
#  Combination row 31 and column 184 is above the cut-off, value = 0.93
#  	 Flagging column 31
#  Combination row 32 and column 184 is above the cut-off, value = 0.862
#  	 Flagging column 184
#  Combination row 36 and column 184 is above the cut-off, value = 0.846
#  	 Flagging column 36
#  Combination row 57 and column 184 is above the cut-off, value = 0.789
#  	 Flagging column 184
#  Combination row 63 and column 184 is above the cut-off, value = 0.828
#  	 Flagging column 63
#  Combination row 68 and column 184 is above the cut-off, value = 0.758
#  	 Flagging column 184
#  Combination row 111 and column 184 is above the cut-off, value = 0.81
#  	 Flagging column 184
#  Combination row 129 and column 184 is above the cut-off, value = 0.812
#  	 Flagging column 129
#  Combination row 144 and column 184 is above the cut-off, value = 0.761
#  	 Flagging column 184
#  Combination row 147 and column 184 is above the cut-off, value = 0.805
#  	 Flagging column 184
#  Combination row 156 and column 184 is above the cut-off, value = 0.76
#  	 Flagging column 156
#  Combination row 162 and column 184 is above the cut-off, value = 0.804
#  	 Flagging column 184
#  Combination row 181 and column 184 is above the cut-off, value = 0.781
#  	 Flagging column 184
#  Combination row 182 and column 184 is above the cut-off, value = 0.807
#  	 Flagging column 184
#  Combination row 16 and column 187 is above the cut-off, value = 0.829
#  	 Flagging column 16
#  Combination row 31 and column 187 is above the cut-off, value = 0.91
#  	 Flagging column 31
#  Combination row 32 and column 187 is above the cut-off, value = 0.904
#  	 Flagging column 32
#  Combination row 36 and column 187 is above the cut-off, value = 0.793
#  	 Flagging column 36
#  Combination row 63 and column 187 is above the cut-off, value = 0.884
#  	 Flagging column 63
#  Combination row 104 and column 187 is above the cut-off, value = 0.843
#  	 Flagging column 187
#  Combination row 111 and column 187 is above the cut-off, value = 0.775
#  	 Flagging column 187
#  Combination row 156 and column 187 is above the cut-off, value = 0.795
#  	 Flagging column 156
#  Combination row 181 and column 187 is above the cut-off, value = 0.813
#  	 Flagging column 187
#  Combination row 182 and column 187 is above the cut-off, value = 0.803
#  	 Flagging column 182
#  Combination row 184 and column 187 is above the cut-off, value = 0.851
#  	 Flagging column 184
#  Combination row 14 and column 189 is above the cut-off, value = 0.773
#  	 Flagging column 189
#  Combination row 129 and column 189 is above the cut-off, value = 0.758
#  	 Flagging column 129
#  Combination row 16 and column 190 is above the cut-off, value = 0.77
#  	 Flagging column 16
#  Combination row 26 and column 190 is above the cut-off, value = 0.831
#  	 Flagging column 26
#  Combination row 64 and column 190 is above the cut-off, value = 0.854
#  	 Flagging column 190
#  Combination row 75 and column 190 is above the cut-off, value = 0.775
#  	 Flagging column 75
#  Combination row 86 and column 190 is above the cut-off, value = 0.767
#  	 Flagging column 190
#  Combination row 124 and column 190 is above the cut-off, value = 0.769
#  	 Flagging column 190
#  Combination row 147 and column 190 is above the cut-off, value = 0.766
#  	 Flagging column 147
#  Combination row 159 and column 190 is above the cut-off, value = 0.785
#  	 Flagging column 159
#  Combination row 162 and column 190 is above the cut-off, value = 0.75
#  	 Flagging column 190
#  Combination row 175 and column 190 is above the cut-off, value = 0.806
#  	 Flagging column 190
#  Combination row 26 and column 191 is above the cut-off, value = 0.864
#  	 Flagging column 26
#  Combination row 64 and column 191 is above the cut-off, value = 0.879
#  	 Flagging column 191
#  Combination row 65 and column 191 is above the cut-off, value = 0.764
#  	 Flagging column 191
#  Combination row 86 and column 191 is above the cut-off, value = 0.863
#  	 Flagging column 191
#  Combination row 140 and column 191 is above the cut-off, value = 0.794
#  	 Flagging column 140
#  Combination row 159 and column 191 is above the cut-off, value = 0.771
#  	 Flagging column 159
#  Combination row 162 and column 191 is above the cut-off, value = 0.837
#  	 Flagging column 191
#  Combination row 175 and column 191 is above the cut-off, value = 0.801
#  	 Flagging column 191
#  Combination row 190 and column 191 is above the cut-off, value = 0.928
#  	 Flagging column 190
#  Combination row 24 and column 193 is above the cut-off, value = 0.789
#  	 Flagging column 193
#  Combination row 25 and column 193 is above the cut-off, value = 0.809
#  	 Flagging column 193
#  Combination row 38 and column 193 is above the cut-off, value = 0.836
#  	 Flagging column 38
#  Combination row 52 and column 193 is above the cut-off, value = 0.788
#  	 Flagging column 193
#  Combination row 63 and column 193 is above the cut-off, value = 0.765
#  	 Flagging column 63
#  Combination row 115 and column 193 is above the cut-off, value = 0.768
#  	 Flagging column 193
#  Combination row 16 and column 196 is above the cut-off, value = 0.792
#  	 Flagging column 196
#  Combination row 18 and column 196 is above the cut-off, value = 0.766
#  	 Flagging column 196
#  Combination row 31 and column 196 is above the cut-off, value = 0.847
#  	 Flagging column 196
#  Combination row 32 and column 196 is above the cut-off, value = 0.759
#  	 Flagging column 196
#  Combination row 36 and column 196 is above the cut-off, value = 0.842
#  	 Flagging column 196
#  Combination row 38 and column 196 is above the cut-off, value = 0.82
#  	 Flagging column 196
#  Combination row 63 and column 196 is above the cut-off, value = 0.869
#  	 Flagging column 196
#  Combination row 68 and column 196 is above the cut-off, value = 0.756
#  	 Flagging column 196
#  Combination row 129 and column 196 is above the cut-off, value = 0.854
#  	 Flagging column 196
#  Combination row 147 and column 196 is above the cut-off, value = 0.753
#  	 Flagging column 196
#  Combination row 156 and column 196 is above the cut-off, value = 0.804
#  	 Flagging column 196
#  Combination row 158 and column 196 is above the cut-off, value = 0.781
#  	 Flagging column 196
#  Combination row 184 and column 196 is above the cut-off, value = 0.775
#  	 Flagging column 196
#  Combination row 187 and column 196 is above the cut-off, value = 0.753
#  	 Flagging column 196
#  Combination row 16 and column 197 is above the cut-off, value = 0.963
#  	 Flagging column 197
#  Combination row 26 and column 197 is above the cut-off, value = 0.872
#  	 Flagging column 197
#  Combination row 31 and column 197 is above the cut-off, value = 0.952
#  	 Flagging column 197
#  Combination row 32 and column 197 is above the cut-off, value = 0.858
#  	 Flagging column 197
#  Combination row 36 and column 197 is above the cut-off, value = 0.883
#  	 Flagging column 197
#  Combination row 57 and column 197 is above the cut-off, value = 0.771
#  	 Flagging column 197
#  Combination row 63 and column 197 is above the cut-off, value = 0.832
#  	 Flagging column 197
#  Combination row 68 and column 197 is above the cut-off, value = 0.816
#  	 Flagging column 197
#  Combination row 75 and column 197 is above the cut-off, value = 0.785
#  	 Flagging column 197
#  Combination row 111 and column 197 is above the cut-off, value = 0.832
#  	 Flagging column 197
#  Combination row 129 and column 197 is above the cut-off, value = 0.86
#  	 Flagging column 129
#  Combination row 144 and column 197 is above the cut-off, value = 0.799
#  	 Flagging column 197
#  Combination row 147 and column 197 is above the cut-off, value = 0.86
#  	 Flagging column 197
#  Combination row 156 and column 197 is above the cut-off, value = 0.759
#  	 Flagging column 197
#  Combination row 159 and column 197 is above the cut-off, value = 0.763
#  	 Flagging column 197
#  Combination row 181 and column 197 is above the cut-off, value = 0.791
#  	 Flagging column 197
#  Combination row 182 and column 197 is above the cut-off, value = 0.855
#  	 Flagging column 197
#  Combination row 184 and column 197 is above the cut-off, value = 0.944
#  	 Flagging column 197
#  Combination row 187 and column 197 is above the cut-off, value = 0.868
#  	 Flagging column 197
#  Combination row 196 and column 197 is above the cut-off, value = 0.815
#  	 Flagging column 196
#  Combination row 16 and column 199 is above the cut-off, value = 0.756
#  	 Flagging column 16
#  Combination row 31 and column 199 is above the cut-off, value = 0.809
#  	 Flagging column 31
#  Combination row 36 and column 199 is above the cut-off, value = 0.758
#  	 Flagging column 36
#  Combination row 63 and column 199 is above the cut-off, value = 0.825
#  	 Flagging column 63
#  Combination row 129 and column 199 is above the cut-off, value = 0.771
#  	 Flagging column 129
#  Combination row 184 and column 199 is above the cut-off, value = 0.775
#  	 Flagging column 184
#  Combination row 187 and column 199 is above the cut-off, value = 0.755
#  	 Flagging column 199
#  Combination row 196 and column 199 is above the cut-off, value = 0.782
#  	 Flagging column 196
#  Combination row 197 and column 199 is above the cut-off, value = 0.777
#  	 Flagging column 197
#  Combination row 16 and column 202 is above the cut-off, value = 0.904
#  	 Flagging column 16
#  Combination row 26 and column 202 is above the cut-off, value = 0.785
#  	 Flagging column 202
#  Combination row 31 and column 202 is above the cut-off, value = 0.929
#  	 Flagging column 31
#  Combination row 32 and column 202 is above the cut-off, value = 0.892
#  	 Flagging column 202
#  Combination row 36 and column 202 is above the cut-off, value = 0.801
#  	 Flagging column 36
#  Combination row 63 and column 202 is above the cut-off, value = 0.877
#  	 Flagging column 63
#  Combination row 111 and column 202 is above the cut-off, value = 0.797
#  	 Flagging column 202
#  Combination row 129 and column 202 is above the cut-off, value = 0.84
#  	 Flagging column 129
#  Combination row 144 and column 202 is above the cut-off, value = 0.754
#  	 Flagging column 202
#  Combination row 147 and column 202 is above the cut-off, value = 0.842
#  	 Flagging column 202
#  Combination row 156 and column 202 is above the cut-off, value = 0.764
#  	 Flagging column 202
#  Combination row 158 and column 202 is above the cut-off, value = 0.753
#  	 Flagging column 202
#  Combination row 182 and column 202 is above the cut-off, value = 0.874
#  	 Flagging column 202
#  Combination row 184 and column 202 is above the cut-off, value = 0.884
#  	 Flagging column 202
#  Combination row 187 and column 202 is above the cut-off, value = 0.874
#  	 Flagging column 202
#  Combination row 196 and column 202 is above the cut-off, value = 0.808
#  	 Flagging column 196
#  Combination row 197 and column 202 is above the cut-off, value = 0.918
#  	 Flagging column 197
#  Combination row 199 and column 202 is above the cut-off, value = 0.782
#  	 Flagging column 202
#  Combination row 16 and column 203 is above the cut-off, value = 0.908
#  	 Flagging column 203
#  Combination row 26 and column 203 is above the cut-off, value = 0.789
#  	 Flagging column 203
#  Combination row 31 and column 203 is above the cut-off, value = 0.954
#  	 Flagging column 203
#  Combination row 32 and column 203 is above the cut-off, value = 0.882
#  	 Flagging column 203
#  Combination row 36 and column 203 is above the cut-off, value = 0.885
#  	 Flagging column 203
#  Combination row 38 and column 203 is above the cut-off, value = 0.751
#  	 Flagging column 203
#  Combination row 63 and column 203 is above the cut-off, value = 0.899
#  	 Flagging column 203
#  Combination row 68 and column 203 is above the cut-off, value = 0.79
#  	 Flagging column 203
#  Combination row 111 and column 203 is above the cut-off, value = 0.82
#  	 Flagging column 203
#  Combination row 129 and column 203 is above the cut-off, value = 0.871
#  	 Flagging column 129
#  Combination row 144 and column 203 is above the cut-off, value = 0.771
#  	 Flagging column 203
#  Combination row 147 and column 203 is above the cut-off, value = 0.828
#  	 Flagging column 203
#  Combination row 156 and column 203 is above the cut-off, value = 0.815
#  	 Flagging column 203
#  Combination row 158 and column 203 is above the cut-off, value = 0.796
#  	 Flagging column 203
#  Combination row 181 and column 203 is above the cut-off, value = 0.76
#  	 Flagging column 203
#  Combination row 182 and column 203 is above the cut-off, value = 0.818
#  	 Flagging column 203
#  Combination row 184 and column 203 is above the cut-off, value = 0.921
#  	 Flagging column 203
#  Combination row 187 and column 203 is above the cut-off, value = 0.867
#  	 Flagging column 203
#  Combination row 196 and column 203 is above the cut-off, value = 0.905
#  	 Flagging column 196
#  Combination row 197 and column 203 is above the cut-off, value = 0.935
#  	 Flagging column 203
#  Combination row 199 and column 203 is above the cut-off, value = 0.815
#  	 Flagging column 203
#  Combination row 202 and column 203 is above the cut-off, value = 0.907
#  	 Flagging column 203
#  Combination row 16 and column 207 is above the cut-off, value = 0.813
#  	 Flagging column 16
#  Combination row 26 and column 207 is above the cut-off, value = 0.818
#  	 Flagging column 207
#  Combination row 31 and column 207 is above the cut-off, value = 0.791
#  	 Flagging column 31
#  Combination row 36 and column 207 is above the cut-off, value = 0.793
#  	 Flagging column 36
#  Combination row 68 and column 207 is above the cut-off, value = 0.769
#  	 Flagging column 207
#  Combination row 129 and column 207 is above the cut-off, value = 0.851
#  	 Flagging column 129
#  Combination row 184 and column 207 is above the cut-off, value = 0.775
#  	 Flagging column 207
#  Combination row 196 and column 207 is above the cut-off, value = 0.784
#  	 Flagging column 196
#  Combination row 197 and column 207 is above the cut-off, value = 0.815
#  	 Flagging column 197
#  Combination row 202 and column 207 is above the cut-off, value = 0.762
#  	 Flagging column 202
#  Combination row 203 and column 207 is above the cut-off, value = 0.813
#  	 Flagging column 203
#  Combination row 131 and column 208 is above the cut-off, value = 0.88
#  	 Flagging column 131
#  Combination row 19 and column 209 is above the cut-off, value = 0.847
#  	 Flagging column 19
#  Combination row 38 and column 209 is above the cut-off, value = 0.785
#  	 Flagging column 38
#  Combination row 194 and column 209 is above the cut-off, value = 0.86
#  	 Flagging column 209
#  Combination row 31 and column 212 is above the cut-off, value = 0.799
#  	 Flagging column 31
#  Combination row 32 and column 212 is above the cut-off, value = 0.791
#  	 Flagging column 32
#  Combination row 36 and column 212 is above the cut-off, value = 0.755
#  	 Flagging column 36
#  Combination row 63 and column 212 is above the cut-off, value = 0.767
#  	 Flagging column 63
#  Combination row 131 and column 212 is above the cut-off, value = 0.897
#  	 Flagging column 212
#  Combination row 156 and column 212 is above the cut-off, value = 0.767
#  	 Flagging column 156
#  Combination row 158 and column 212 is above the cut-off, value = 0.771
#  	 Flagging column 158
#  Combination row 187 and column 212 is above the cut-off, value = 0.781
#  	 Flagging column 187
#  Combination row 202 and column 212 is above the cut-off, value = 0.753
#  	 Flagging column 202
#  Combination row 203 and column 212 is above the cut-off, value = 0.784
#  	 Flagging column 203
#  Combination row 208 and column 212 is above the cut-off, value = 0.896
#  	 Flagging column 212
#  Combination row 208 and column 213 is above the cut-off, value = 0.765
#  	 Flagging column 213
#  Combination row 212 and column 213 is above the cut-off, value = 0.821
#  	 Flagging column 212
#  Combination row 24 and column 221 is above the cut-off, value = 0.757
#  	 Flagging column 221
#  Combination row 31 and column 221 is above the cut-off, value = 0.75
#  	 Flagging column 221
#  Combination row 36 and column 221 is above the cut-off, value = 0.756
#  	 Flagging column 221
#  Combination row 38 and column 221 is above the cut-off, value = 0.835
#  	 Flagging column 221
#  Combination row 52 and column 221 is above the cut-off, value = 0.768
#  	 Flagging column 221
#  Combination row 63 and column 221 is above the cut-off, value = 0.838
#  	 Flagging column 221
#  Combination row 66 and column 221 is above the cut-off, value = 0.775
#  	 Flagging column 221
#  Combination row 85 and column 221 is above the cut-off, value = 0.757
#  	 Flagging column 221
#  Combination row 115 and column 221 is above the cut-off, value = 0.756
#  	 Flagging column 221
#  Combination row 129 and column 221 is above the cut-off, value = 0.804
#  	 Flagging column 129
#  Combination row 156 and column 221 is above the cut-off, value = 0.795
#  	 Flagging column 221
#  Combination row 158 and column 221 is above the cut-off, value = 0.776
#  	 Flagging column 221
#  Combination row 193 and column 221 is above the cut-off, value = 0.763
#  	 Flagging column 221
#  Combination row 196 and column 221 is above the cut-off, value = 0.865
#  	 Flagging column 196
#  Combination row 202 and column 221 is above the cut-off, value = 0.759
#  	 Flagging column 221
#  Combination row 203 and column 221 is above the cut-off, value = 0.818
#  	 Flagging column 203
#  Combination row 38 and column 232 is above the cut-off, value = 0.769
#  	 Flagging column 38
#  Combination row 221 and column 232 is above the cut-off, value = 0.77
#  	 Flagging column 221
#  Combination row 16 and column 238 is above the cut-off, value = 0.775
#  	 Flagging column 16
#  Combination row 31 and column 238 is above the cut-off, value = 0.777
#  	 Flagging column 31
#  Combination row 32 and column 238 is above the cut-off, value = 0.763
#  	 Flagging column 32
#  Combination row 184 and column 238 is above the cut-off, value = 0.871
#  	 Flagging column 184
#  Combination row 197 and column 238 is above the cut-off, value = 0.833
#  	 Flagging column 197
#  Combination row 202 and column 238 is above the cut-off, value = 0.771
#  	 Flagging column 202
#  Combination row 203 and column 238 is above the cut-off, value = 0.793
#  	 Flagging column 203
#  Combination row 18 and column 239 is above the cut-off, value = 0.779
#  	 Flagging column 239
#  Combination row 36 and column 239 is above the cut-off, value = 0.774
#  	 Flagging column 36
#  Combination row 38 and column 239 is above the cut-off, value = 0.78
#  	 Flagging column 239
#  Combination row 63 and column 239 is above the cut-off, value = 0.792
#  	 Flagging column 63
#  Combination row 129 and column 239 is above the cut-off, value = 0.793
#  	 Flagging column 129
#  Combination row 161 and column 239 is above the cut-off, value = 0.758
#  	 Flagging column 239
#  Combination row 196 and column 239 is above the cut-off, value = 0.832
#  	 Flagging column 196
#  Combination row 203 and column 239 is above the cut-off, value = 0.77
#  	 Flagging column 203
#  Combination row 221 and column 239 is above the cut-off, value = 0.783
#  	 Flagging column 221
#  Combination row 16 and column 243 is above the cut-off, value = 0.87
#  	 Flagging column 243
#  Combination row 18 and column 243 is above the cut-off, value = 0.852
#  	 Flagging column 243
#  Combination row 26 and column 243 is above the cut-off, value = 0.818
#  	 Flagging column 243
#  Combination row 31 and column 243 is above the cut-off, value = 0.876
#  	 Flagging column 243
#  Combination row 36 and column 243 is above the cut-off, value = 0.911
#  	 Flagging column 243
#  Combination row 38 and column 243 is above the cut-off, value = 0.793
#  	 Flagging column 243
#  Combination row 63 and column 243 is above the cut-off, value = 0.834
#  	 Flagging column 243
#  Combination row 68 and column 243 is above the cut-off, value = 0.791
#  	 Flagging column 243
#  Combination row 75 and column 243 is above the cut-off, value = 0.803
#  	 Flagging column 243
#  Combination row 111 and column 243 is above the cut-off, value = 0.771
#  	 Flagging column 243
#  Combination row 129 and column 243 is above the cut-off, value = 0.904
#  	 Flagging column 243
#  Combination row 144 and column 243 is above the cut-off, value = 0.763
#  	 Flagging column 243
#  Combination row 147 and column 243 is above the cut-off, value = 0.823
#  	 Flagging column 243
#  Combination row 156 and column 243 is above the cut-off, value = 0.82
#  	 Flagging column 243
#  Combination row 158 and column 243 is above the cut-off, value = 0.809
#  	 Flagging column 243
#  Combination row 161 and column 243 is above the cut-off, value = 0.768
#  	 Flagging column 243
#  Combination row 182 and column 243 is above the cut-off, value = 0.775
#  	 Flagging column 243
#  Combination row 184 and column 243 is above the cut-off, value = 0.818
#  	 Flagging column 243
#  Combination row 189 and column 243 is above the cut-off, value = 0.786
#  	 Flagging column 243
#  Combination row 196 and column 243 is above the cut-off, value = 0.889
#  	 Flagging column 196
#  Combination row 197 and column 243 is above the cut-off, value = 0.873
#  	 Flagging column 243
#  Combination row 199 and column 243 is above the cut-off, value = 0.77
#  	 Flagging column 243
#  Combination row 202 and column 243 is above the cut-off, value = 0.805
#  	 Flagging column 243
#  Combination row 203 and column 243 is above the cut-off, value = 0.879
#  	 Flagging column 243
#  Combination row 207 and column 243 is above the cut-off, value = 0.859
#  	 Flagging column 243
#  Combination row 221 and column 243 is above the cut-off, value = 0.794
#  	 Flagging column 243
#  Combination row 239 and column 243 is above the cut-off, value = 0.817
#  	 Flagging column 243
#  Combination row 26 and column 244 is above the cut-off, value = 0.839
#  	 Flagging column 26
#  Combination row 64 and column 244 is above the cut-off, value = 0.918
#  	 Flagging column 64
#  Combination row 65 and column 244 is above the cut-off, value = 0.756
#  	 Flagging column 65
#  Combination row 86 and column 244 is above the cut-off, value = 0.879
#  	 Flagging column 244
#  Combination row 124 and column 244 is above the cut-off, value = 0.777
#  	 Flagging column 124
#  Combination row 175 and column 244 is above the cut-off, value = 0.827
#  	 Flagging column 244
#  Combination row 190 and column 244 is above the cut-off, value = 0.897
#  	 Flagging column 190
#  Combination row 191 and column 244 is above the cut-off, value = 0.925
#  	 Flagging column 191
#  Combination row 16 and column 246 is above the cut-off, value = 0.801
#  	 Flagging column 246
#  Combination row 26 and column 246 is above the cut-off, value = 0.781
#  	 Flagging column 246
#  Combination row 31 and column 246 is above the cut-off, value = 0.796
#  	 Flagging column 246
#  Combination row 36 and column 246 is above the cut-off, value = 0.818
#  	 Flagging column 246
#  Combination row 63 and column 246 is above the cut-off, value = 0.781
#  	 Flagging column 246
#  Combination row 68 and column 246 is above the cut-off, value = 0.773
#  	 Flagging column 246
#  Combination row 129 and column 246 is above the cut-off, value = 0.848
#  	 Flagging column 246
#  Combination row 184 and column 246 is above the cut-off, value = 0.754
#  	 Flagging column 246
#  Combination row 189 and column 246 is above the cut-off, value = 0.76
#  	 Flagging column 246
#  Combination row 196 and column 246 is above the cut-off, value = 0.897
#  	 Flagging column 196
#  Combination row 197 and column 246 is above the cut-off, value = 0.825
#  	 Flagging column 246
#  Combination row 199 and column 246 is above the cut-off, value = 0.774
#  	 Flagging column 246
#  Combination row 202 and column 246 is above the cut-off, value = 0.789
#  	 Flagging column 246
#  Combination row 203 and column 246 is above the cut-off, value = 0.863
#  	 Flagging column 246
#  Combination row 204 and column 246 is above the cut-off, value = 0.779
#  	 Flagging column 246
#  Combination row 207 and column 246 is above the cut-off, value = 0.828
#  	 Flagging column 246
#  Combination row 221 and column 246 is above the cut-off, value = 0.836
#  	 Flagging column 246
#  Combination row 239 and column 246 is above the cut-off, value = 0.811
#  	 Flagging column 246
#  Combination row 243 and column 246 is above the cut-off, value = 0.859
#  	 Flagging column 246
#  Combination row 141 and column 249 is above the cut-off, value = 0.754
#  	 Flagging column 249
#  Combination row 155 and column 249 is above the cut-off, value = 0.886
#  	 Flagging column 249
#  Combination row 172 and column 249 is above the cut-off, value = 0.778
#  	 Flagging column 172
#  Combination row 26 and column 264 is above the cut-off, value = 0.753
#  	 Flagging column 26
#  Combination row 57 and column 264 is above the cut-off, value = 0.75
#  	 Flagging column 57
#  Combination row 64 and column 264 is above the cut-off, value = 0.759
#  	 Flagging column 64
#  Combination row 86 and column 264 is above the cut-off, value = 0.762
#  	 Flagging column 264
#  Combination row 162 and column 264 is above the cut-off, value = 0.756
#  	 Flagging column 162
#  Combination row 190 and column 264 is above the cut-off, value = 0.78
#  	 Flagging column 190
#  Combination row 191 and column 264 is above the cut-off, value = 0.845
#  	 Flagging column 191
#  Combination row 244 and column 264 is above the cut-off, value = 0.767
#  	 Flagging column 264
#  Combination row 16 and column 265 is above the cut-off, value = 0.804
#  	 Flagging column 16
#  Combination row 26 and column 265 is above the cut-off, value = 0.802
#  	 Flagging column 26
#  Combination row 57 and column 265 is above the cut-off, value = 0.814
#  	 Flagging column 57
#  Combination row 86 and column 265 is above the cut-off, value = 0.758
#  	 Flagging column 265
#  Combination row 162 and column 265 is above the cut-off, value = 0.941
#  	 Flagging column 265
#  Combination row 184 and column 265 is above the cut-off, value = 0.856
#  	 Flagging column 184
#  Combination row 190 and column 265 is above the cut-off, value = 0.815
#  	 Flagging column 265
#  Combination row 191 and column 265 is above the cut-off, value = 0.865
#  	 Flagging column 265
#  Combination row 197 and column 265 is above the cut-off, value = 0.814
#  	 Flagging column 197
#  Combination row 203 and column 265 is above the cut-off, value = 0.768
#  	 Flagging column 203
#  Combination row 238 and column 265 is above the cut-off, value = 0.764
#  	 Flagging column 238
#  Combination row 264 and column 265 is above the cut-off, value = 0.817
#  	 Flagging column 265
#  Combination row 18 and column 266 is above the cut-off, value = 0.798
#  	 Flagging column 266
#  Combination row 19 and column 266 is above the cut-off, value = 0.751
#  	 Flagging column 266
#  Combination row 24 and column 266 is above the cut-off, value = 0.858
#  	 Flagging column 266
#  Combination row 25 and column 266 is above the cut-off, value = 0.826
#  	 Flagging column 266
#  Combination row 31 and column 266 is above the cut-off, value = 0.802
#  	 Flagging column 31
#  Combination row 32 and column 266 is above the cut-off, value = 0.818
#  	 Flagging column 266
#  Combination row 38 and column 266 is above the cut-off, value = 0.854
#  	 Flagging column 38
#  Combination row 63 and column 266 is above the cut-off, value = 0.877
#  	 Flagging column 63
#  Combination row 85 and column 266 is above the cut-off, value = 0.765
#  	 Flagging column 266
#  Combination row 115 and column 266 is above the cut-off, value = 0.751
#  	 Flagging column 266
#  Combination row 129 and column 266 is above the cut-off, value = 0.794
#  	 Flagging column 129
#  Combination row 154 and column 266 is above the cut-off, value = 0.82
#  	 Flagging column 266
#  Combination row 156 and column 266 is above the cut-off, value = 0.922
#  	 Flagging column 266
#  Combination row 158 and column 266 is above the cut-off, value = 0.927
#  	 Flagging column 266
#  Combination row 187 and column 266 is above the cut-off, value = 0.761
#  	 Flagging column 266
#  Combination row 196 and column 266 is above the cut-off, value = 0.817
#  	 Flagging column 196
#  Combination row 202 and column 266 is above the cut-off, value = 0.778
#  	 Flagging column 202
#  Combination row 203 and column 266 is above the cut-off, value = 0.828
#  	 Flagging column 203
#  Combination row 221 and column 266 is above the cut-off, value = 0.819
#  	 Flagging column 221
#  Combination row 243 and column 266 is above the cut-off, value = 0.812
#  	 Flagging column 243
#  Combination row 16 and column 271 is above the cut-off, value = 0.826
#  	 Flagging column 16
#  Combination row 31 and column 271 is above the cut-off, value = 0.834
#  	 Flagging column 31
#  Combination row 36 and column 271 is above the cut-off, value = 0.831
#  	 Flagging column 36
#  Combination row 184 and column 271 is above the cut-off, value = 0.826
#  	 Flagging column 184
#  Combination row 197 and column 271 is above the cut-off, value = 0.852
#  	 Flagging column 197
#  Combination row 203 and column 271 is above the cut-off, value = 0.83
#  	 Flagging column 203
#  Combination row 243 and column 271 is above the cut-off, value = 0.807
#  	 Flagging column 243
#  Combination row 16 and column 277 is above the cut-off, value = 0.754
#  	 Flagging column 16
#  Combination row 197 and column 277 is above the cut-off, value = 0.76
#  	 Flagging column 197
#  Combination row 203 and column 277 is above the cut-off, value = 0.752
#  	 Flagging column 203
#  Combination row 243 and column 277 is above the cut-off, value = 0.751
#  	 Flagging column 243
#  Combination row 271 and column 277 is above the cut-off, value = 0.774
#  	 Flagging column 271
#  Combination row 277 and column 282 is above the cut-off, value = 0.753
#  	 Flagging column 277
#  Combination row 24 and column 284 is above the cut-off, value = 0.809
#  	 Flagging column 284
#  Combination row 25 and column 284 is above the cut-off, value = 0.796
#  	 Flagging column 284
#  Combination row 31 and column 284 is above the cut-off, value = 0.831
#  	 Flagging column 31
#  Combination row 32 and column 284 is above the cut-off, value = 0.85
#  	 Flagging column 284
#  Combination row 36 and column 284 is above the cut-off, value = 0.776
#  	 Flagging column 36
#  Combination row 38 and column 284 is above the cut-off, value = 0.835
#  	 Flagging column 38
#  Combination row 63 and column 284 is above the cut-off, value = 0.861
#  	 Flagging column 63
#  Combination row 156 and column 284 is above the cut-off, value = 0.798
#  	 Flagging column 156
#  Combination row 158 and column 284 is above the cut-off, value = 0.801
#  	 Flagging column 158
#  Combination row 161 and column 284 is above the cut-off, value = 0.763
#  	 Flagging column 284
#  Combination row 182 and column 284 is above the cut-off, value = 0.77
#  	 Flagging column 284
#  Combination row 187 and column 284 is above the cut-off, value = 0.853
#  	 Flagging column 284
#  Combination row 193 and column 284 is above the cut-off, value = 0.773
#  	 Flagging column 284
#  Combination row 196 and column 284 is above the cut-off, value = 0.793
#  	 Flagging column 196
#  Combination row 202 and column 284 is above the cut-off, value = 0.807
#  	 Flagging column 202
#  Combination row 203 and column 284 is above the cut-off, value = 0.826
#  	 Flagging column 203
#  Combination row 212 and column 284 is above the cut-off, value = 0.766
#  	 Flagging column 284
#  Combination row 221 and column 284 is above the cut-off, value = 0.763
#  	 Flagging column 221
#  Combination row 266 and column 284 is above the cut-off, value = 0.806
#  	 Flagging column 266
#  Combination row 16 and column 291 is above the cut-off, value = 0.809
#  	 Flagging column 16
#  Combination row 31 and column 291 is above the cut-off, value = 0.859
#  	 Flagging column 31
#  Combination row 32 and column 291 is above the cut-off, value = 0.833
#  	 Flagging column 291
#  Combination row 36 and column 291 is above the cut-off, value = 0.785
#  	 Flagging column 36
#  Combination row 63 and column 291 is above the cut-off, value = 0.816
#  	 Flagging column 63
#  Combination row 129 and column 291 is above the cut-off, value = 0.78
#  	 Flagging column 129
#  Combination row 156 and column 291 is above the cut-off, value = 0.755
#  	 Flagging column 291
#  Combination row 182 and column 291 is above the cut-off, value = 0.775
#  	 Flagging column 291
#  Combination row 184 and column 291 is above the cut-off, value = 0.782
#  	 Flagging column 291
#  Combination row 187 and column 291 is above the cut-off, value = 0.803
#  	 Flagging column 291
#  Combination row 196 and column 291 is above the cut-off, value = 0.788
#  	 Flagging column 196
#  Combination row 197 and column 291 is above the cut-off, value = 0.839
#  	 Flagging column 197
#  Combination row 202 and column 291 is above the cut-off, value = 0.839
#  	 Flagging column 202
#  Combination row 203 and column 291 is above the cut-off, value = 0.855
#  	 Flagging column 203
#  Combination row 221 and column 291 is above the cut-off, value = 0.755
#  	 Flagging column 221
# ...
#  	 Flagging column 646
#  Combination row 399 and column 646 is above the cut-off, value = 0.806
#  	 Flagging column 399
#  Combination row 409 and column 646 is above the cut-off, value = 0.844
#  	 Flagging column 409
#  Combination row 417 and column 646 is above the cut-off, value = 0.771
#  	 Flagging column 417
#  Combination row 421 and column 646 is above the cut-off, value = 0.769
#  	 Flagging column 421
#  Combination row 434 and column 646 is above the cut-off, value = 0.769
#  	 Flagging column 434
#  Combination row 435 and column 646 is above the cut-off, value = 0.763
#  	 Flagging column 435
#  Combination row 459 and column 646 is above the cut-off, value = 0.78
#  	 Flagging column 459
#  Combination row 469 and column 646 is above the cut-off, value = 0.796
#  	 Flagging column 469
#  Combination row 470 and column 646 is above the cut-off, value = 0.865
#  	 Flagging column 470
#  Combination row 483 and column 646 is above the cut-off, value = 0.763
#  	 Flagging column 483
#  Combination row 501 and column 646 is above the cut-off, value = 0.863
#  	 Flagging column 501
#  Combination row 511 and column 646 is above the cut-off, value = 0.75
#  	 Flagging column 511
#  Combination row 557 and column 646 is above the cut-off, value = 0.772
#  	 Flagging column 646
#  Combination row 567 and column 646 is above the cut-off, value = 0.802
#  	 Flagging column 567
#  Combination row 569 and column 646 is above the cut-off, value = 0.82
#  	 Flagging column 569
#  Combination row 570 and column 646 is above the cut-off, value = 0.812
#  	 Flagging column 570
#  Combination row 597 and column 646 is above the cut-off, value = 0.783
#  	 Flagging column 597
#  Combination row 603 and column 646 is above the cut-off, value = 0.818
#  	 Flagging column 603
#  Combination row 605 and column 646 is above the cut-off, value = 0.794
#  	 Flagging column 605
#  Combination row 608 and column 646 is above the cut-off, value = 0.832
#  	 Flagging column 608
#  Combination row 38 and column 648 is above the cut-off, value = 0.752
#  	 Flagging column 38
#  Combination row 52 and column 648 is above the cut-off, value = 0.766
#  	 Flagging column 52
#  Combination row 193 and column 648 is above the cut-off, value = 0.796
#  	 Flagging column 193
#  Combination row 326 and column 648 is above the cut-off, value = 0.779
#  	 Flagging column 326
#  Combination row 366 and column 648 is above the cut-off, value = 0.766
#  	 Flagging column 648
#  Combination row 596 and column 648 is above the cut-off, value = 0.804
#  	 Flagging column 596
#  Combination row 16 and column 651 is above the cut-off, value = 0.751
#  	 Flagging column 651
#  Combination row 24 and column 651 is above the cut-off, value = 0.778
#  	 Flagging column 651
#  Combination row 25 and column 651 is above the cut-off, value = 0.799
#  	 Flagging column 651
#  Combination row 31 and column 651 is above the cut-off, value = 0.787
#  	 Flagging column 651
#  Combination row 32 and column 651 is above the cut-off, value = 0.751
#  	 Flagging column 651
#  Combination row 36 and column 651 is above the cut-off, value = 0.828
#  	 Flagging column 651
#  Combination row 38 and column 651 is above the cut-off, value = 0.824
#  	 Flagging column 651
#  Combination row 52 and column 651 is above the cut-off, value = 0.754
#  	 Flagging column 651
#  Combination row 56 and column 651 is above the cut-off, value = 0.753
#  	 Flagging column 651
#  Combination row 63 and column 651 is above the cut-off, value = 0.776
#  	 Flagging column 651
#  Combination row 85 and column 651 is above the cut-off, value = 0.772
#  	 Flagging column 651
#  Combination row 115 and column 651 is above the cut-off, value = 0.784
#  	 Flagging column 651
#  Combination row 129 and column 651 is above the cut-off, value = 0.818
#  	 Flagging column 129
#  Combination row 156 and column 651 is above the cut-off, value = 0.785
#  	 Flagging column 651
#  Combination row 184 and column 651 is above the cut-off, value = 0.752
#  	 Flagging column 651
#  Combination row 193 and column 651 is above the cut-off, value = 0.795
#  	 Flagging column 651
#  Combination row 196 and column 651 is above the cut-off, value = 0.808
#  	 Flagging column 196
#  Combination row 197 and column 651 is above the cut-off, value = 0.784
#  	 Flagging column 651
#  Combination row 203 and column 651 is above the cut-off, value = 0.817
#  	 Flagging column 203
#  Combination row 207 and column 651 is above the cut-off, value = 0.756
#  	 Flagging column 651
#  Combination row 221 and column 651 is above the cut-off, value = 0.842
#  	 Flagging column 221
#  Combination row 232 and column 651 is above the cut-off, value = 0.81
#  	 Flagging column 651
#  Combination row 243 and column 651 is above the cut-off, value = 0.832
#  	 Flagging column 243
#  Combination row 246 and column 651 is above the cut-off, value = 0.803
#  	 Flagging column 246
#  Combination row 266 and column 651 is above the cut-off, value = 0.767
#  	 Flagging column 651
#  Combination row 271 and column 651 is above the cut-off, value = 0.766
#  	 Flagging column 651
#  Combination row 291 and column 651 is above the cut-off, value = 0.762
#  	 Flagging column 651
#  Combination row 296 and column 651 is above the cut-off, value = 0.883
#  	 Flagging column 296
#  Combination row 301 and column 651 is above the cut-off, value = 0.814
#  	 Flagging column 651
#  Combination row 305 and column 651 is above the cut-off, value = 0.843
#  	 Flagging column 651
#  Combination row 326 and column 651 is above the cut-off, value = 0.856
#  	 Flagging column 651
#  Combination row 346 and column 651 is above the cut-off, value = 0.831
#  	 Flagging column 651
#  Combination row 347 and column 651 is above the cut-off, value = 0.755
#  	 Flagging column 651
#  Combination row 371 and column 651 is above the cut-off, value = 0.781
#  	 Flagging column 651
#  Combination row 374 and column 651 is above the cut-off, value = 0.753
#  	 Flagging column 651
#  Combination row 378 and column 651 is above the cut-off, value = 0.76
#  	 Flagging column 651
#  Combination row 399 and column 651 is above the cut-off, value = 0.886
#  	 Flagging column 399
#  Combination row 432 and column 651 is above the cut-off, value = 0.759
#  	 Flagging column 651
#  Combination row 434 and column 651 is above the cut-off, value = 0.792
#  	 Flagging column 651
#  Combination row 435 and column 651 is above the cut-off, value = 0.752
#  	 Flagging column 651
#  Combination row 441 and column 651 is above the cut-off, value = 0.755
#  	 Flagging column 651
#  Combination row 469 and column 651 is above the cut-off, value = 0.87
#  	 Flagging column 469
#  Combination row 470 and column 651 is above the cut-off, value = 0.757
#  	 Flagging column 470
#  Combination row 490 and column 651 is above the cut-off, value = 0.782
#  	 Flagging column 651
#  Combination row 494 and column 651 is above the cut-off, value = 0.8
#  	 Flagging column 651
#  Combination row 511 and column 651 is above the cut-off, value = 0.835
#  	 Flagging column 511
#  Combination row 565 and column 651 is above the cut-off, value = 0.757
#  	 Flagging column 651
#  Combination row 567 and column 651 is above the cut-off, value = 0.772
#  	 Flagging column 651
#  Combination row 570 and column 651 is above the cut-off, value = 0.769
#  	 Flagging column 651
#  Combination row 596 and column 651 is above the cut-off, value = 0.75
#  	 Flagging column 651
#  Combination row 601 and column 651 is above the cut-off, value = 0.799
#  	 Flagging column 651
#  Combination row 608 and column 651 is above the cut-off, value = 0.755
#  	 Flagging column 608
#  Combination row 633 and column 651 is above the cut-off, value = 0.847
#  	 Flagging column 651
#  Combination row 641 and column 651 is above the cut-off, value = 0.8
#  	 Flagging column 651
#  Combination row 642 and column 651 is above the cut-off, value = 0.803
#  	 Flagging column 651
#  Combination row 16 and column 655 is above the cut-off, value = 0.789
#  	 Flagging column 16
#  Combination row 26 and column 655 is above the cut-off, value = 0.784
#  	 Flagging column 26
#  Combination row 68 and column 655 is above the cut-off, value = 0.772
#  	 Flagging column 68
#  Combination row 184 and column 655 is above the cut-off, value = 0.795
#  	 Flagging column 184
#  Combination row 197 and column 655 is above the cut-off, value = 0.796
#  	 Flagging column 197
#  Combination row 203 and column 655 is above the cut-off, value = 0.754
#  	 Flagging column 203
#  Combination row 364 and column 655 is above the cut-off, value = 0.774
#  	 Flagging column 364
#  Combination row 375 and column 655 is above the cut-off, value = 0.838
#  	 Flagging column 375
#  Combination row 377 and column 655 is above the cut-off, value = 0.78
#  	 Flagging column 377
#  Combination row 378 and column 655 is above the cut-off, value = 0.785
#  	 Flagging column 378
#  Combination row 415 and column 655 is above the cut-off, value = 0.806
#  	 Flagging column 415
#  Combination row 421 and column 655 is above the cut-off, value = 0.761
#  	 Flagging column 421
#  Combination row 501 and column 655 is above the cut-off, value = 0.76
#  	 Flagging column 501
#  Combination row 570 and column 655 is above the cut-off, value = 0.778
#  	 Flagging column 570
#  Combination row 492 and column 656 is above the cut-off, value = 0.821
#  	 Flagging column 656
#  Combination row 615 and column 656 is above the cut-off, value = 0.802
#  	 Flagging column 656
#  Combination row 19 and column 665 is above the cut-off, value = 0.792
#  	 Flagging column 665
#  Combination row 24 and column 665 is above the cut-off, value = 0.801
#  	 Flagging column 665
#  Combination row 25 and column 665 is above the cut-off, value = 0.757
#  	 Flagging column 665
#  Combination row 38 and column 665 is above the cut-off, value = 0.82
#  	 Flagging column 38
#  Combination row 63 and column 665 is above the cut-off, value = 0.804
#  	 Flagging column 63
#  Combination row 156 and column 665 is above the cut-off, value = 0.78
#  	 Flagging column 156
#  Combination row 158 and column 665 is above the cut-off, value = 0.791
#  	 Flagging column 158
#  Combination row 161 and column 665 is above the cut-off, value = 0.75
#  	 Flagging column 665
#  Combination row 196 and column 665 is above the cut-off, value = 0.764
#  	 Flagging column 196
#  Combination row 239 and column 665 is above the cut-off, value = 0.751
#  	 Flagging column 239
#  Combination row 266 and column 665 is above the cut-off, value = 0.779
#  	 Flagging column 266
#  Combination row 284 and column 665 is above the cut-off, value = 0.783
#  	 Flagging column 284
#  Combination row 296 and column 665 is above the cut-off, value = 0.767
#  	 Flagging column 296
#  Combination row 305 and column 665 is above the cut-off, value = 0.824
#  	 Flagging column 305
#  Combination row 326 and column 665 is above the cut-off, value = 0.751
#  	 Flagging column 326
#  Combination row 347 and column 665 is above the cut-off, value = 0.781
#  	 Flagging column 347
#  Combination row 371 and column 665 is above the cut-off, value = 0.761
#  	 Flagging column 665
#  Combination row 399 and column 665 is above the cut-off, value = 0.777
#  	 Flagging column 399
#  Combination row 434 and column 665 is above the cut-off, value = 0.78
#  	 Flagging column 434
#  Combination row 441 and column 665 is above the cut-off, value = 0.755
#  	 Flagging column 665
#  Combination row 469 and column 665 is above the cut-off, value = 0.808
#  	 Flagging column 469
#  Combination row 490 and column 665 is above the cut-off, value = 0.817
#  	 Flagging column 490
#  Combination row 516 and column 665 is above the cut-off, value = 0.829
#  	 Flagging column 665
#  Combination row 565 and column 665 is above the cut-off, value = 0.808
#  	 Flagging column 565
#  Combination row 642 and column 665 is above the cut-off, value = 0.814
#  	 Flagging column 642
#  Combination row 492 and column 669 is above the cut-off, value = 0.763
#  	 Flagging column 669
#  Combination row 615 and column 669 is above the cut-off, value = 0.772
#  	 Flagging column 615
#  Combination row 656 and column 669 is above the cut-off, value = 0.788
#  	 Flagging column 656
#  Combination row 16 and column 670 is above the cut-off, value = 0.806
#  	 Flagging column 16
#  Combination row 31 and column 670 is above the cut-off, value = 0.809
#  	 Flagging column 31
#  Combination row 32 and column 670 is above the cut-off, value = 0.755
#  	 Flagging column 670
#  Combination row 63 and column 670 is above the cut-off, value = 0.773
#  	 Flagging column 63
#  Combination row 129 and column 670 is above the cut-off, value = 0.791
#  	 Flagging column 129
#  Combination row 131 and column 670 is above the cut-off, value = 0.796
#  	 Flagging column 670
#  Combination row 147 and column 670 is above the cut-off, value = 0.772
#  	 Flagging column 670
#  Combination row 182 and column 670 is above the cut-off, value = 0.843
#  	 Flagging column 670
#  Combination row 184 and column 670 is above the cut-off, value = 0.75
#  	 Flagging column 184
#  Combination row 187 and column 670 is above the cut-off, value = 0.75
#  	 Flagging column 670
#  Combination row 197 and column 670 is above the cut-off, value = 0.81
#  	 Flagging column 197
#  Combination row 202 and column 670 is above the cut-off, value = 0.855
#  	 Flagging column 202
#  Combination row 203 and column 670 is above the cut-off, value = 0.79
#  	 Flagging column 203
#  Combination row 212 and column 670 is above the cut-off, value = 0.79
#  	 Flagging column 670
#  Combination row 243 and column 670 is above the cut-off, value = 0.756
#  	 Flagging column 243
#  Combination row 291 and column 670 is above the cut-off, value = 0.781
#  	 Flagging column 291
#  Combination row 304 and column 670 is above the cut-off, value = 0.75
#  	 Flagging column 670
#  Combination row 320 and column 670 is above the cut-off, value = 0.757
#  	 Flagging column 670
#  Combination row 338 and column 670 is above the cut-off, value = 0.81
#  	 Flagging column 670
#  Combination row 364 and column 670 is above the cut-off, value = 0.802
#  	 Flagging column 364
#  Combination row 375 and column 670 is above the cut-off, value = 0.769
#  	 Flagging column 375
#  Combination row 377 and column 670 is above the cut-off, value = 0.803
#  	 Flagging column 377
#  Combination row 379 and column 670 is above the cut-off, value = 0.752
#  	 Flagging column 670
#  Combination row 399 and column 670 is above the cut-off, value = 0.795
#  	 Flagging column 399
#  Combination row 402 and column 670 is above the cut-off, value = 0.785
#  	 Flagging column 670
#  Combination row 409 and column 670 is above the cut-off, value = 0.767
#  	 Flagging column 670
#  Combination row 421 and column 670 is above the cut-off, value = 0.767
#  	 Flagging column 421
#  Combination row 459 and column 670 is above the cut-off, value = 0.801
#  	 Flagging column 670
#  Combination row 470 and column 670 is above the cut-off, value = 0.858
#  	 Flagging column 470
#  Combination row 486 and column 670 is above the cut-off, value = 0.75
#  	 Flagging column 670
#  Combination row 501 and column 670 is above the cut-off, value = 0.773
#  	 Flagging column 501
#  Combination row 511 and column 670 is above the cut-off, value = 0.752
#  	 Flagging column 511
#  Combination row 527 and column 670 is above the cut-off, value = 0.761
#  	 Flagging column 670
#  Combination row 539 and column 670 is above the cut-off, value = 0.768
#  	 Flagging column 670
#  Combination row 557 and column 670 is above the cut-off, value = 0.755
#  	 Flagging column 670
#  Combination row 567 and column 670 is above the cut-off, value = 0.799
#  	 Flagging column 567
#  Combination row 569 and column 670 is above the cut-off, value = 0.79
#  	 Flagging column 569
#  Combination row 570 and column 670 is above the cut-off, value = 0.819
#  	 Flagging column 570
#  Combination row 608 and column 670 is above the cut-off, value = 0.779
#  	 Flagging column 608
#  Combination row 646 and column 670 is above the cut-off, value = 0.759
#  	 Flagging column 670

# %% [markdown]
# ## Linear dependencies(not used)
# NOTE: Linear Dependencies were not used because
# 1) A large number of features from columns 157 to 400 were flagged as linearly dependent to columns 1 to 156 <br>
# 2) We will rely on feature importance and the robustness of the model selected to identify the most important features hence linear dependencies can become redundant

# %%
# tmp <- expr_rmcorr[, 3:ncol(expr_rmcorr)]
# tmp[is.na(tmp)] <- 0
# comboInfo <- findLinearCombos(tmp) 
# comboInfo
# rmLnCmb <- colnames(tmp[,comboInfo$remove])
# expr_rmLnCmb <- expr_rmcorr[,-which(colnames(expr_rmcorr) %in% rmLnCmb)]
cat("Started with dimension = ", dim(expression), "\n")
cat("Post 50% NA filtering in rows and columns the dimension is", dim(expr_filtered), "\n")
cat("Post filtering highly correlated columns the dimension is", dim(expr_rmcorr), "\n")
# cat("Post removing linearly dependent columns the dimension is", dim(expr_rmLnCmb))
# Out:
# Started with dimension =  204 676
# Post 50% NA filtering in rows and columns the dimension is 161 676
# Post filtering highly correlated columns the dimension is 161 495

# %% [markdown]
# # Feature Selection

# %% [markdown]
# There are 2 kinds of feature selection: automated and manual
# 1) Automated<br>
# Automatic feature selection methods can be used to build many models with different subsets of a dataset and identify those attributes that are and are not required to build an accurate model.The algorithm is configured to explore all possible subsets of the attributes.Then it selects the optimal number of attributes and the most important attributes. The relevant functions in CARET are: rfeControl and rfe.<br>
#
#
# 2) Manual<br>
# For classification, ROC curve analysis is conducted on each predictor. For two class problems, a series of cutoffs is applied to the predictor data to predict the class. The sensitivity and specificity are computed for each cutoff and the ROC curve is computed. The trapezoidal rule is used to compute the area under the ROC curve. This area is used as the measure of variable importance.The relevant functions in CARET are varImp.<br>
# <br>
#
# Note: [Chen et al, 2020](https://journalofbigdata.springeropen.com/articles/10.1186/s40537-020-00327-4#Sec14) shows that manually selecting the topmost variables using the random forest varImp function is more accurate in identifying relevant features compared to automated methods.

# %%
# input for modeling
mod_inp_mat <- expr_rmcorr[, 2:ncol(expr_rmcorr)]
mod_inp_mat$Response <- as.factor(mod_inp_mat$Response)
mod_inp_mat[is.na(mod_inp_mat)] <- 0
dim(mod_inp_mat)
# Out:
# [1] 161 494

# %% [markdown]
# ## Automated Feature Selection

# %%
feature_size <- c(20, 50, 100, 150, 200, 250, 300, 350, 400, 450)

# %% [markdown]
# ### Random Forest

# %%
rf.control <- rfeControl(functions=rfFuncs, method="repeatedcv", number=10, repeats=3)
system.time(a.rf <- rfe(Response~., data=mod_inp_mat, 
            sizes=feature_size, 
            rfeControl=rf.control))

# list the chosen featuresplot(a.rf, type=c("g", "o"))
rf.pred <- predictors(a.rf)
# plot the results
plot(a.rf, type=c("g", "o"), ylim=c(0,1))
a.rf.results <- a.rf$results
# Out:
#    user  system elapsed
# 159.698   0.020 159.747
# plot without title

# %%
a.temp <- gsub("`", "", rf.pred)
a.temp <- getSymbols(a.temp, 'org.Hs.eg.db')
for (x in (1:250)){
    cat(a.temp[x], "\n")
}
# Out:
# IFNG
# KLRC2
# SLAMF1
# CD276
# CD83
# TAP2
# CD274
# ITGA5
# HRAS
# SSX1
# GTF3C1
# CASP10
# BIRC5
# SLAMF7
# IRAK2
# MME
# ISG20
# KLRF1
# CD34
# IL18RAP
# PDGFRB
# IL2RA
# COG7
# IL7
# ITGB3
# CD244
# IL12RB2
# ICOS
# CXCL11
# COLEC12
# STAT3
# ICAM4
# SERPINB2
# SPP1
# TNFAIP3
# TNF
# SPINK5
# IL11
# CXCL1
# NFKB2
# IL18R1
# CD22
# CFP
# ATG12
# MAPK8
# XCR1
# MAP3K5
# CTLA4
# SBNO2
# IFIT2
# PTGS2
# TNFRSF11B
# TNFSF15
# TNFRSF10C
# HLA-A
# LTK
# MEFV
# CD1D
# NRP1
# STAT5B
# TLR3
# DPP4
# FEZ1
# C2
# CD9
# KLRC1
# CXCR1
# TNFRSF4
# GZMM
# CCL8
# EOMES
# ATF2
# MS4A2
# HPRT1
# TLR2
# ANP32B
# C5
# IL13RA2
# TNFSF14
# PAX5
# MAP2K1
# MICB
# ZNF205
# ABL1
# ST6GAL1
# MYD88
# TBK1
# CCL3
# ATG5
# HLA-DQB1
# TNFSF18
# CASP1
# LRRN3
# JAK2
# ANXA1
# IL17RB
# IL15
# CFB
# PLA2G6
# CCL28
# CCL20
# MASP1
# TREM1
# KLRD1
# TREM2
# CSF1R
# LGALS3
# TFEB
# F12
# CX3CR1
# ULBP2
# CTSH
# CASP3
# ITGB1
# CYFIP2
# BCL2L1
# MAPKAPK2
# NOTCH1
# ITGA2
# SOCS1
# TUBB
# IRF7
# PDGFC
# MX1
# PIK3CD
# TNFRSF12A
# IL16
# ITGAE
# S100B
# BMI1
# TGFB1
# ZNF346
# DMBT1
# CD36
# MARCO
# TNFRSF13C
# KLRG1
# IFI16
# IFNAR2
# DUSP4
# IL1RAP
# ETS1
# IL6ST
# IL13RA1
# CD63
# NFATC4
# CEBPB
# IL23A
# IL17B
# CCL21
# TNFRSF10B
# FLT3LG
# REPS1
# CD70
# CEACAM1
# LILRA5
# ITGB4
# CCL11
# RORA
# PYCARD
# SELE
# TXK
# IL12B
# CD40
# IL17RA
# PPARG
# HSD11B1
# CHIT1
# TFE3
# MFGE8
# APP
# G6PD
# THBD
# ICAM1
# CD81
# MAF
# AKT3
# CD1B
# C1QBP
# CD207
# MR1
# ELK1
# JAM3
# GPATCH3
# TNFSF4
# HLA-C
# PRAME
# EWSR1
# IKBKB
# EGR2
# IGF2R
# TPSAB1
# MAPK11
# C4B
# NOD2
# CCL24
# FN1
# MAPK14
# ATF1
# DNAJC14
# RRAD
# CD28
# SMPD3
# CCL17
# NOS2
# CD1A
# ITGA2B
# JAK1
# NFATC3
# IL1R1
# TNFRSF14
# POLR2A
# PNMA1
# FOXP3
# TNFRSF18
# F13A1
# HAMP
# MAPK3
# CD200
# CCL22
# NLRP3
# IFNGR1
# PPIA
# IKBKG
# RAG1
# THBS1
# CTSW
# ERCC3
# RPS6
# CKLF
# TGFB2
# SMAD3
# SYT17
# AMMECR1L
# EDC3
# IFI27
# CDK1
# LAMP1
# FCGR2A
# BST2
# ZNF143
# ZKSCAN5
# RUNX1
# FPR2
# MAP3K7
# COL3A1
# CYLD
# TICAM2
# CSF1
# PPBP

# %%
# saveRDS(a.rf.results, "a.rf.results.rdf")

# %% [markdown]
# ## Manual Feature Selection

# %%
# define a resampling approach for caret where data is divided into 10 random subsets and prediction is done on 
# 1 using the remaining 9. This approach is repeated thrice
control <- trainControl(method="repeatedcv", number=10, repeats=3)

# %% [markdown]
# ### glmNet
# A generalized linear model (GLM) is a flexible generalization of ordinary linear regression that allows for the response variable to have an error distribution other than the normal distribution. The GLM generalizes linear regression by allowing the linear model to be related to the response variable via a link function and by allowing the magnitude of the variance of each measurement to be a function of its predicted value.

# %%
m.glm <- train(Response~., data=mod_inp_mat, 
                  method="glmnet", 
                  trControl=control,
                  preProcess = c("scale", "center")
                 )

# %%
# estimate variable importance
glm.imp <- varImp(m.glm, scale=TRUE)$importance
rownames(glm.imp) <- gsub("`", "", rownames(glm.imp))
glm.imp$Name <- rownames(glm.imp)
# summarize importance
glm.imp <- glm.imp[order(glm.imp$Overall, decreasing=TRUE),]
colnames(glm.imp) <- c("Score", "Name")
head(glm.imp)
# Out:
#       Score     Name
# 9308  100.00000 9308
# 8807   68.54299 8807
# 57823  65.35478 57823
# 29126  14.39653 29126
# 6504   12.33301 6504
# 3920    0.00000 3920

# %% [markdown]
# ### SVM
# Support vector machines (SVMs) is a representation of different classes in a hyperplane in multidimensional space. The hyperplane is generated in an iterative manner by SVM for error minimization and divide the datasets into classes to find a maximum marginal hyperplane (MMH).This is effective in high dimensional spaces.

# %%
m.svm <- train(Response~., data=mod_inp_mat, 
                  method="svmLinear2", 
                  trControl=control,
                  preProcess = c("scale", "center"))

# %%
# estimate variable importance
svm.imp <- varImp(m.svm, scale=TRUE)$importance
svm.imp$Name <- rownames(svm.imp)
# summarize importance
svm.imp <- svm.imp[order(svm.imp$X0, decreasing=TRUE),]
svm.imp$X0 <- NULL
colnames(svm.imp) <- c("Score", "Name")
head(svm.imp)
# Out:
#       Score     Name
# 6504  100.00000 6504
# 3458   87.24062 3458
# 29126  85.73951 29126
# 57823  85.38631 57823
# 8807   84.76821 8807
# 29851  82.38411 29851

# %% [markdown]
# ### Neural Network

# %%
m.nnet <- train(Response~., data=mod_inp_mat, 
                  method="nnet", 
                  trControl=control,
                  preProcess = c("scale", "center"))
# Out:
# # weights:  496
# initial  value 98.619332
# iter  10 value 73.951144
# iter  20 value 68.877016
# iter  30 value 63.189253
# iter  40 value 63.161798
# iter  50 value 61.095791
# iter  60 value 61.091551
# iter  70 value 58.888806
# iter  80 value 58.298772
# iter  90 value 57.586792
# iter 100 value 57.586036
# final  value 57.586036
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold01.Rep1: size=3, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold01.Rep1: size=5, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 110.905821
# iter  10 value 83.058230
# iter  20 value 65.803386
# iter  30 value 53.063402
# iter  40 value 47.425735
# iter  50 value 41.529764
# iter  60 value 33.485545
# iter  70 value 27.949198
# iter  80 value 22.508644
# iter  90 value 21.205123
# iter 100 value 18.490417
# final  value 18.490417
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold01.Rep1: size=3, decay=1e-01 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold01.Rep1: size=5, decay=1e-01 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 110.100164
# iter  10 value 79.873840
# iter  20 value 77.656679
# iter  30 value 76.157184
# iter  40 value 75.936698
# iter  50 value 74.230108
# iter  60 value 72.392821
# iter  70 value 71.568016
# iter  80 value 67.746497
# iter  90 value 67.741799
# iter 100 value 65.819586
# final  value 65.819586
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold01.Rep1: size=3, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold01.Rep1: size=5, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 102.054950
# iter  10 value 85.028098
# iter  20 value 74.261059
# iter  30 value 71.156623
# iter  40 value 66.232851
# iter  50 value 64.578085
# iter  60 value 61.340132
# iter  70 value 59.284155
# iter  80 value 59.279849
# iter  90 value 59.212296
# iter 100 value 57.951567
# final  value 57.951567
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold02.Rep1: size=3, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold02.Rep1: size=5, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold02.Rep2: size=3, decay=1e-01 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold02.Rep2: size=5, decay=1e-01 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 99.805114
# iter  10 value 71.208858
# iter  20 value 54.127358
# iter  30 value 51.176021
# iter  40 value 47.177918
# iter  50 value 46.692124
# iter  60 value 43.988605
# iter  70 value 43.740507
# iter  80 value 42.074897
# iter  90 value 42.073335
# iter 100 value 42.070643
# final  value 42.070643
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold02.Rep2: size=3, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold02.Rep2: size=5, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 96.702850
# iter  10 value 87.577137
# iter  20 value 78.093165
# iter  30 value 61.344641
# iter  40 value 61.105074
# iter  50 value 59.859719
# iter  60 value 59.818869
# iter  70 value 59.818360
# iter  80 value 59.817994
# iter  90 value 59.817860
# iter 100 value 59.817808
# final  value 59.817808
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold03.Rep2: size=3, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold03.Rep2: size=5, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 105.893845
# iter  10 value 80.043007
# iter  20 value 56.775451
# iter  30 value 50.290765
# iter  40 value 39.315008
# iter  50 value 34.844193
# iter  60 value 33.653986
# iter  70 value 28.382293
# iter  80 value 27.871835
# iter  90 value 27.847737
# iter 100 value 25.471387
# final  value 25.471387
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold03.Rep2: size=3, decay=1e-01 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold03.Rep2: size=5, decay=1e-01 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 96.450078
# iter  10 value 84.063929
# iter  20 value 55.468722
# iter  30 value 51.450152
# iter  40 value 48.393628
# iter  50 value 48.380574
# iter  60 value 48.377156
# iter  70 value 46.952334
# iter  80 value 45.349594
# iter  90 value 45.346831
# iter 100 value 43.764482
# final  value 43.764482
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold03.Rep2: size=3, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold03.Rep2: size=5, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 108.370999
# iter  10 value 78.442725
# iter  20 value 67.633703
# iter  30 value 66.953592
# iter  40 value 65.107169
# iter  50 value 63.894559
# iter  60 value 62.632352
# iter  70 value 60.964218
# iter  80 value 60.621861
# iter  90 value 60.621486
# final  value 60.621377
# converged
# Warning message:
# “model fit failed for Fold04.Rep2: size=3, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold04.Rep2: size=5, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 104.077274
# iter  10 value 81.137092
# iter  20 value 70.453429
# iter  30 value 57.423339
# iter  40 value 49.814012
# iter  50 value 41.026382
# iter  60 value 29.576564
# iter  70 value 27.360194
# iter  80 value 24.380542
# iter  90 value 20.623461
# iter 100 value 16.659287
# final  value 16.659287
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold04.Rep2: size=3, decay=1e-01 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold04.Rep2: size=5, decay=1e-01 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 104.773294
# iter  10 value 90.514676
# iter  20 value 75.894357
# iter  30 value 74.314238
# iter  40 value 74.277371
# iter  50 value 70.950489
# iter  60 value 69.031382
# iter  70 value 67.985756
# iter  80 value 65.944463
# iter  90 value 63.899467
# iter 100 value 63.737950
# final  value 63.737950
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold04.Rep2: size=3, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold04.Rep2: size=5, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 104.661111
# iter  10 value 95.143950
# iter  20 value 87.160563
# iter  30 value 71.702830
# iter  40 value 71.461932
# iter  50 value 71.455803
# iter  60 value 68.706477
# iter  70 value 68.701619
# iter  80 value 66.953534
# iter  90 value 66.952687
# iter 100 value 65.110325
# final  value 65.110325
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold05.Rep2: size=3, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold05.Rep2: size=5, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 110.307052
# iter  10 value 76.488735
# iter  20 value 59.615917
# iter  30 value 47.223761
# iter  40 value 37.099464
# iter  50 value 31.078173
# iter  60 value 29.783098
# iter  70 value 27.245840
# iter  80 value 24.283206
# iter  90 value 24.102304
# iter 100 value 21.813363
# final  value 21.813363
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold05.Rep2: size=3, decay=1e-01 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold05.Rep2: size=5, decay=1e-01 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 97.241810
# iter  10 value 80.329819
# iter  20 value 63.590769
# iter  30 value 53.954111
# iter  40 value 46.970649
# iter  50 value 46.897295
# iter  60 value 43.742409
# iter  70 value 43.678064
# iter  80 value 42.124109
# iter  90 value 42.107359
# iter 100 value 42.105071
# final  value 42.105071
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold05.Rep2: size=3, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold05.Rep2: size=5, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 114.777740
# iter  10 value 86.986062
# iter  20 value 71.311090
# iter  30 value 71.233840
# iter  40 value 69.209037
# iter  50 value 69.200157
# iter  60 value 69.199512
# iter  70 value 68.113780
# iter  80 value 68.096452
# final  value 68.096446
# converged
# Warning message:
# “model fit failed for Fold06.Rep2: size=3, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold06.Rep2: size=5, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 104
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold09.Rep3: size=3, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold09.Rep3: size=5, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 97.757644
# iter  10 value 71.587170
# iter  20 value 66.865847
# iter  30 value 66.349715
# iter  40 value 64.655924
# iter  50 value 63.506315
# iter  60 value 63.504743
# iter  70 value 63.504504
# iter  80 value 63.502654
# iter  90 value 62.315315
# iter 100 value 60.142246
# final  value 60.142246
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold10.Rep3: size=3, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold10.Rep3: size=5, decay=0e+00 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 109.649879
# iter  10 value 89.614855
# iter  20 value 58.969780
# iter  30 value 42.325937
# iter  40 value 33.470004
# iter  50 value 24.343161
# iter  60 value 20.363253
# iter  70 value 14.851641
# iter  80 value 13.332557
# iter  90 value 13.037651
# iter 100 value 12.978057
# final  value 12.978057
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold10.Rep3: size=3, decay=1e-01 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold10.Rep3: size=5, decay=1e-01 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# # weights:  496
# initial  value 101.082085
# iter  10 value 94.145356
# iter  20 value 81.912269
# iter  30 value 79.103041
# iter  40 value 78.523823
# iter  50 value 76.834388
# iter  60 value 75.980457
# iter  70 value 75.977501
# iter  80 value 75.974281
# iter  90 value 75.103942
# iter 100 value 75.098095
# final  value 75.098095
# stopped after 100 iterations
# Warning message:
# “model fit failed for Fold10.Rep3: size=3, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (1486) weights
# ”
# Warning message:
# “model fit failed for Fold10.Rep3: size=5, decay=1e-04 Error in nnet.default(x, y, w, entropy = TRUE, ...) :
#   too many (2476) weights
# ”
# Warning message in nominalTrainWorkflow(x = x, y = y, wts = weights, info = trainInfo, :
# “There were missing values in resampled performance measures.”
# Warning message in train.default(x, y, weights = w, ...):
# “missing values found in aggregated results”
# # weights:  496
# initial  value 107.101606
# iter  10 value 87.191267
# iter  20 value 59.791483
# iter  30 value 55.587665
# iter  40 value 52.939614
# iter  50 value 52.922641
# iter  60 value 52.908138
# iter  70 value 52.893528
# iter  80 value 52.880395
# iter  90 value 50.051325
# iter 100 value 49.503750
# final  value 49.503750
# stopped after 100 iterations

# %%
# estimate variable importance
nnet.imp <- varImp(m.nnet, scale=TRUE)$importance
rownames(nnet.imp) <- gsub("`", "", rownames(nnet.imp))
nnet.imp$Name <- rownames(nnet.imp)
# summarize importance
nnet.imp <- nnet.imp[order(nnet.imp$Overall, decreasing=TRUE),]
colnames(nnet.imp) <- c("Score", "Name")
head(nnet.imp)
# Out:
#       Score     Name
# 948   100.00000 948
# 4058   88.80912 4058
# 3595   85.12959 3595
# 3572   80.01955 3572
# 3568   77.04632 3568
# 54674  75.59823 54674

# %% [markdown]
# ### Gradient Boosting Machines (GBM)

# %%
library(gbm)
m.gbm <- train(Response~., data=mod_inp_mat, 
                  method="gbm", 
                  trControl=control,
                  preProcess = c("scale", "center"))
# Out:
# Loaded gbm 2.1.8
# Iter   TrainDeviance   ValidDeviance   StepSize   Improve
#      1        1.3055            -nan     0.1000    0.0017
#      2        1.2866            -nan     0.1000   -0.0004
#      3        1.2632            -nan     0.1000    0.0010
#      4        1.2462            -nan     0.1000   -0.0012
#      5        1.2271            -nan     0.1000    0.0058
#      6        1.2140            -nan     0.1000   -0.0030
#      7        1.1957            -nan     0.1000   -0.0082
#      8        1.1820            -nan     0.1000   -0.0046
#      9        1.1625            -nan     0.1000    0.0004
#     10        1.1513            -nan     0.1000   -0.0067
#     20        1.0395            -nan     0.1000   -0.0006
#     40        0.8376            -nan     0.1000   -0.0040
#     60        0.6829            -nan     0.1000   -0.0021
#     80        0.5790            -nan     0.1000   -0.0019
#    100        0.4884            -nan     0.1000   -0.0025
#    120        0.4082            -nan     0.1000   -0.0020
#    140        0.3515            -nan     0.1000   -0.0021
#    150        0.3267            -nan     0.1000   -0.0023
#
# Iter   TrainDeviance   ValidDeviance   StepSize   Improve
#      1        1.
#
# Iter   TrainDeviance   ValidDeviance   StepSize   Improve
#      1        1.2889            -nan     0.1000   -0.0065
#      2        1.2436            -nan     0.1000    0.0015
#      3        1.1814            -nan     0.1000    0.0107
#      4        1.1554            -nan     0.1000   -0.0123
#      5        1.1211            -nan     0.1000   -0.0043
#      6        1.0857            -nan     0.1000   -0.0117
#      7        1.0562            -nan     0.1000   -0.0088
#      8        1.0259            -nan     0.1000   -0.0065
#      9        0.9928            -nan     0.1000   -0.0101
#     10        0.9492            -nan     0.1000    0.0074
#     20        0.7078            -nan     0.1000   -0.0103
#     40        0.4296            -nan     0.1000   -0.0021
#     60        0.2699            -nan     0.1000   -0.0007
#     80        0.1663            -nan     0.1000   -0.0009
#    100        0.1106            -nan     0.1000   -0.0003
#    120        0.0705            -nan     0.1000   -0.0003
#    140        0.0463            -nan     0.1000   -0.0005
#    150        0.0380            -nan     0.1000   -0.0002
#
# Iter   TrainDeviance   ValidDeviance   StepSize   Improve
#      1        1.3068            -nan     0.1000    0.0014
#      2        1.2834            -nan     0.1000    0.0033
#      3        1.2647            -nan     0.1000   -0.0001
#      4        1.2497            -nan     0.1000   -0.0000
#      5        1.2328            -nan     0.1000    0.0021
#      6        1.2215            -nan     0.1000   -0.0058
#      7        1.1981            -nan     0.1000    0.0047
#      8        1.1823            -nan     0.1000   -0.0029
#      9        1.1611            -nan     0.1000    0.0080
#     10        1.1547            -nan     0.1000   -0.0048
#     20        1.0340            -nan     0.1000   -0.0045
#     40        0.8635            -nan     0.1000   -0.0017
#     50        0.8014            -nan     0.1000   -0.0013

# %%
# estimate variable importance
gbm.imp <- varImp(m.gbm, scale=TRUE)$importance
rownames(gbm.imp) <- gsub("`", "", rownames(gbm.imp))
gbm.imp$Name <- rownames(gbm.imp)
# summarize importance
gbm.imp <- gbm.imp[order(gbm.imp$Overall, decreasing=TRUE),]
colnames(gbm.imp) <- c("Score", "Name")
head(gbm.imp)
# Out:
#       Score     Name
# 6504  100.00000 6504
# 3574   83.68914 3574
# 81035  81.38157 81035
# 3265   66.49178 3265
# 6756   62.60650 6756
# 57823  61.06449 57823

# %% [markdown]
# ### Partial Least Squares

# %%
m.pls <- train(Response~., data=mod_inp_mat, 
                  method="pls", 
                  trControl=control,
                  preProcess = c("scale", "center"))

# %%
# estimate variable importance
pls.imp <- varImp(m.pls, scale=TRUE)$importance
rownames(pls.imp) <- gsub("`", "", rownames(pls.imp))
pls.imp$Name <- rownames(pls.imp)
# summarize importance
pls.imp <- pls.imp[order(pls.imp$Overall, decreasing=TRUE),]
colnames(pls.imp) <- c("Score", "Name")
head(pls.imp)
# Out:
# Attaching package: ‘pls’
#
#
# The following object is masked from ‘package:corrplot’:
#
#     corrplot
#
#
# The following object is masked from ‘package:caret’:
#
#     R2
#
#
# The following object is masked from ‘package:stats’:
#
#     loadings
#       Score     Name
# 9308  100.00000 9308
# 8807   97.07626 8807
# 57823  96.61980 57823
# 29126  90.68272 29126
# 6504   88.28608 6504
# 7128   86.38491 7128

# %% [markdown]
# ###  Cforest

# %%
m.cforest <- train(Response~., data=mod_inp_mat, 
                  method="cforest", 
                  trControl=control,
                  preProcess = c("scale", "center"))

# %%
# estimate variable importance
cforest.imp <- varImp(m.cforest, scale=TRUE)$importance
rownames(cforest.imp) <- gsub("`", "", rownames(cforest.imp))
cforest.imp$Name <- rownames(cforest.imp)
# summarize importance
cforest.imp <- cforest.imp[order(cforest.imp$Overall, decreasing=TRUE),]
colnames(cforest.imp) <- c("Score", "Name")
head(cforest.imp)
# Out:
#       Score     Name
# 6504  100.00000 6504
# 9308   86.84080 9308
# 57823  74.19434 57823
# 29126  68.71126 29126
# 8807   64.70124 8807
# 7128   62.21503 7128

# %% [markdown]
# ### Linear Discriminant Analysis with Stepwise Feature Selection

# %%
m.stepLDA <- train(Response~., data=mod_inp_mat, 
                  method="stepLDA", 
                  trControl=control,
                  preProcess = c("scale", "center"))
# Out:
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.68429;  in: "`57823`";  variables (1): `57823`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.281
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.68476;  in: "`3574`";  variables (1): `3574`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.262
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67667;  in: "`29126`";  variables (1): `29126`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.345
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.69667;  in: "`29126`";  variables (1): `29126`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.171
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67095;  in: "`843`";  variables (1): `843`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.183
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.66952;  in: "`9308`";  variables (1): `9308`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.199
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67;  in: "`51744`";  variables (1): `51744`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.353
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.6819;  in: "`29126`";  variables (1): `29126`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.141
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67;  in: "`3669`";  variables (1): `3669`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.172
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 144 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.66619;  in: "`8807`";  variables (1): `8807`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.139
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.68952;  in: "`3574`";  variables (1): `3574`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.179
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 144 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.68095;  in: "`57823`";  variables (1): `57823`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.312
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67524;  in: "`3574`";  variables (1): `3574`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.157
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.69095;  in: "`843`";  variables (1): `843`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.179
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67;  in: "`57823`";  variables (1): `57823`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.169
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.68238;  in: "`57823`";  variables (1): `57823`
#
#  hr.elapsed min.elapsed sec.elapsed
#        0.00        0.00       11.38
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67667;  in: "`3669`";  variables (1): `3669`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.116
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67;  in: "`57823`";  variables (1): `57823`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.148
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.66905;  in: "`29126`";  variables (1): `29126`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.184
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.6681;  in: "`2323`";  variables (1): `2323`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.178
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67;  in: "`9308`";  variables (1): `9308`
#
#  hr.elapsed min.elapsed sec.elapsed
#        0.00        0.00       11.33
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67048;  in: "`29126`";  variables (1): `29126`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.163
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.70429;  in: "`3669`";  variables (1): `3669`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.186
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67667;  in: "`7128`";  variables (1): `7128`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.167
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 144 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67333;  in: "`57823`";  variables (1): `57823`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.408
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67714;  in: "`843`";  variables (1): `843`
#
#  hr.elapsed min.elapsed sec.elapsed
#        0.00        0.00       11.12
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.67762;  in: "`57823`";  variables (1): `57823`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.172
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.6919;  in: "`29126`";  variables (1): `29126`
#
#  hr.elapsed min.elapsed sec.elapsed
#         0.0         0.0        11.2
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.66238;  in: "`29126`";  variables (1): `29126`
#
#  hr.elapsed min.elapsed sec.elapsed
#       0.000       0.000      11.186
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 145 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.66238;  in: "`9308`";  variables (1): `9308`
#
#  hr.elapsed min.elapsed sec.elapsed
#        0.00        0.00       11.36
#  `stepwise classification', using 10-fold cross-validated correctness rate of method lda'.
#
# 161 observations of 493 variables in 2 classes; direction: both
#
# stop criterion: improvement less than 5%.
# correctness rate: 0.66434;  in: "`3574`";  variables (1): `3574`
#
#  hr.elapsed min.elapsed sec.elapsed
#        0.00        0.00       11.36

# %%
# estimate variable importance
stepLDA.imp <- varImp(m.stepLDA, scale=TRUE)$importance
rownames(stepLDA.imp) <- gsub("`", "", rownames(stepLDA.imp))
stepLDA.imp$Name <- rownames(stepLDA.imp)
# summarize importance
stepLDA.imp <- stepLDA.imp[order(stepLDA.imp$X0, decreasing=TRUE),]
stepLDA.imp$X0 <- NULL
colnames(stepLDA.imp) <- c("Score", "Name")
head(stepLDA.imp)
# Out:
#       Score     Name
# 6504  100.00000 6504
# 3458   87.24062 3458
# 29126  85.73951 29126
# 57823  85.38631 57823
# 8807   84.76821 8807
# 29851  82.38411 29851

# %% [markdown]
# ### Naive Bayes

# %%
m.nb <- train(Response~., data=mod_inp_mat, 
                  method="naive_bayes", 
                  trControl=control,
                  preProcess = c("scale", "center"))

# %%
# estimate variable importance
nb.imp <- varImp(m.nb, scale=TRUE)$importance
rownames(nb.imp) <- gsub("`", "", rownames(nb.imp))
nb.imp$Name <- rownames(nb.imp)
# summarize importance
nb.imp <- nb.imp[order(nb.imp$X0, decreasing=TRUE),]
nb.imp$X0 <- NULL
colnames(nb.imp) <- c("Score", "Name")
head(nb.imp)
# Out:
#       Score     Name
# 6504  100.00000 6504
# 3458   87.24062 3458
# 29126  85.73951 29126
# 57823  85.38631 57823
# 8807   84.76821 8807
# 29851  82.38411 29851

# %% [markdown]
# ### Rank Analysis

# %%
# getRank adds a rank column to the input matrix according to varImp scores
getRank <- function(tmp=NULL, cname=NULL){
    tmp[,cname] <- rank(-tmp$Score)
    tmp$Score <- NULL
    tmp
}

glm.rank <- getRank(glm.imp, "glm.Rank")
svm.rank <- getRank(svm.imp, "svm.Rank")
nnet.rank <- getRank(nnet.imp, "nnet.Rank")
gbm.rank <- getRank(gbm.imp, "gbm.Rank")
pls.rank <- getRank(pls.imp, "pls.Rank")
cforest.rank <- getRank(cforest.imp, "cforest.Rank")
stepLDA.rank <- getRank(stepLDA.imp, "stepLDA.Rank")
nb.rank <- getRank(nb.imp, "nb.Rank")

all.rank <- Reduce(function(x,y) merge(x,y, by="Name"),list(glm.rank, svm.rank, nnet.rank, gbm.rank,
                                                             pls.rank, cforest.rank, stepLDA.rank, nb.rank))
                   
colnames(all.rank)[1] <- "Gene_ID" 
all.rank$Gene_Name <- getSymbols(all.rank$Gene_ID, 'org.Hs.eg.db')
# all.rank is the merged matrix containing gene IDs as the first column, gene names as the last column and 
# ranks for all the models as intermediate columns

# to find all genes over the threshold
rank.threshold <- 250
rank.clmn <- grep("Rank", colnames(all.rank))
all.rank$Threshold.250 <- apply(all.rank[, rank.clmn], 1, function(x){sum(x<rank.threshold)})
all.rank <- all.rank[order(all.rank$Threshold.250, decreasing=TRUE),]
# Out:
# Loading required package: org.Hs.eg.db

# %%
# to do a wikipathway search
temp_rank <- all.rank[all.rank$Threshold.250 >= 4, "Gene_Name"]
for (x in seq_along(temp_rank)){
    cat(temp_rank[x], "\n")
}
# Out:
# CREB1
# CD274
# CXCL1
# HRAS
# IFNG
# IL7
# TNFRSF11B
# SERPINB2
# PDGFRB
# SLAMF7
# NOD2
# SLAMF1
# SPP1
# TNFAIP3
# COLEC12
# TLR6
# BATF
# ANP32B
# CHIT1
# NLRP3
# TNFRSF13C
# CTLA4
# CTSH
# DUSP6
# EGR2
# ALAS1
# MS4A2
# FYN
# CYFIP2
# PYCARD
# CXCL3
# GTF3C1
# GZMM
# ANXA1
# HLA-A
# HLA-C
# HSD11B1
# ICAM1
# IFI27
# IGF1R
# IGF2R
# APP
# IL2RA
# IL5RA
# IL6ST
# IL12RB2
# IL13RA1
# IL13RA2
# IL15
# IL18
# IRAK2
# IRF4
# ITGA5
# ITGB3
# NFKB2
# NOS2
# CD244
# SPA17
# TREM2
# PPIA
# SMPD3
# MAP2K1
# CCL28
# PSEN2
# PTGS2
# REL
# CFB
# CCL3
# CXCL11
# STAT2
# STAT3
# STAT5B
# TAPBP
# TLR2
# TLR3
# TNF
# TRAF3
# C4B
# TXK
# IL1R2
# CD276
# ATG10
# CASP8
# MARCO
# IL18RAP
# IL18R1
# CD1D
# MAPKAPK2
# CD83
# CD34
# ATG5
# CD36
# TNFSF15
# ADA
# EBI3
# GNLY
# SH2B2
# TXNIP
# LILRA1
# LILRB3
# CLU
# COL3A1
# CTSW
# CYLD
# DMBT1
# TUBB
# FOS
# FPR2
# LAMP3
# XCR1
# CXCL2
# ICOS
# HLA-DQB1
# MR1
# ICAM2
# CFI
# IFIT2
# IFIT1
# IFNGR1
# IKBKB
# IL4R
# IL6R
# CXCR1
# IRF2
# IRF7
# ISG20
# JAK2
# KIR3DL2
# KLRC2
# ARG2
# LAIR2
# LTF
# LTK
# SMAD2
# MAF
# MCAM
# MEFV
# MAP3K5
# CD200
# ATM
# NFATC3
# NFATC4
# NFKB1
# CLEC4A
# IL23A
# CFP
# ABCB1
# LRRN3
# MAPK8
# MAP2K2
# PSMB7
# HAMP
# BAX
# BCL2
# CEACAM1
# CCL21
# CCL22
# CCL24
# SELE
# BMI1
# SSX1
# BST2
# SYK
# MAP3K7
# TAP2
# TBP
# TFRC
# TLR5
# TNFRSF1A
# TPSAB1
# C3
# VCAM1
# ZNF143
# ZNF205
# EOMES
# CASP1
# CASP10
# TNFSF14
# TNFSF10
# TNFRSF18
# TNFRSF10C
# HDAC3
# CCND3
# ATG12
# COG7
# CD22
# CD40
# MAGEC1
# TANK
# KLRG1
# CDKN1A
# NOD1
# IFITM2
# SPINK5
# CD160
# SH2D1B
# ATF2
# CSF1R
# EGR1
# FCGR2A
# FLT3LG
# ZKSCAN5
# ABL1
# GATA3
# IL17B
# LILRA5
# FAS
# IL11
# IL12B
# IL16
# ITGA4
# KLRC1
# KLRD1
# MAGEA1
# MICB
# MX1
# FOXP3
# PIK3CD
# NUP107
# SIGIRR
# TNFRSF17
# CCL17
# CCL23
# TFE3
# TLR4
# C2
# C7
# CXCR4
# REPS1
# RUNX3
# SOCS1
# FADD
# CD84
# TNFSF18
# CD1B
# PNMA1
# CD28
# FEZ1
# CD63
# IL23R
# CX3CR1
# LY96
# BIRC5
# IRGM
# IL6
# ITGB1
# ITGB4
# MME
# CNOT4
# PAX5
# KLRF1
# IL22RA1
# CCL18
# MTMR14
# C1QBP
# DNAJC14
# RUNX1
# CD9
# ENTPD1

# %%
length(temp_rank) # 259 because there are genes with the same rank
# Out:
# [1] 259

# %%
head(all.rank)
# Out:
#     Gene_ID glm.Rank svm.Rank nnet.Rank gbm.Rank pls.Rank cforest.Rank
# 39  1385    249.5    183      147       12       114      20
# 107 29126     4.0      3       91       30         4       4
# 108 2919    249.5     41       20       33        29      23
# 124 3265    249.5     31      158        4        37      10
# 138 3458    249.5      2      103       29        12      11
# 158 3574    249.5     11      131        2        10      73
#     stepLDA.Rank nb.Rank Gene_Name Threshold.250
# 39  183          183     CREB1     8
# 107   3            3     CD274     8
# 108  41           41     CXCL1     8
# 124  31           31     HRAS      8
# 138   2            2     IFNG      8
# 158  11           11     IL7       8

# %% [markdown]
# ### Merge ranks using Borda voting method
# NOT used since the results are very similar to manual ranking method

# %%
# #merge rank using Borda method
# library(votesys)
# data <- all.rank[,2:9]
# transpose <- t(data)
# tmp <- as.matrix(transpose)
# colnames(tmp) <- all.rank$Gene_Name
# # tmp
# vote <- create_vote(tmp, xtype=1)
# res.borda <- borda_method(vote, modified = FALSE)  # Winner is with the lowest score, for modified is FALSE.
# merged.rank<-data.frame(gene=names(res.borda$other_info$count_min),
#                         rank.borda=res.borda$other_info$count_min,
#                         stringsAsFactors=F)

# merged.rank <- merged.rank[order(merged.rank$rank.borda, decreasing=FALSE),]
# head(merged.rank)
# Out:
#         gene    rank.borda
# SLAMF1  SLAMF1   84.0
# SLAMF7  SLAMF7  119.0
# CD274   CD274   142.0
# CD83    CD83    313.0
# IL18RAP IL18RAP 321.0
# TNFAIP3 TNFAIP3 360.5

# %%
# for (x in (1:250)){
#     cat(merged.rank$gene[x], "\n")
# }

# %% [markdown]
# ![Venn for the 3 approaches](https://github.com/runtime-terror101/ICP-Responders/blob/master/ICP_Responders/auto_manual_boruda.png)

# %% [raw]
# TODO:
# find criteria for best size, accuracy
# what are the predictors
# change threshold

# %% [markdown]
# `TODO:` <br>
# Find genes related to antipd1, link to the papers, make list of genes as a vector before pre processing<br>
# Borda method to vote and rank features <br>
# Find common pathways<br>
# Add descriptions for all ml models
#
# set seed<br>

# %% [raw]
# TODO:
# overlap btw 3 and overlap
# pathway enrichment for all 3
# embed images

# %%
save.image()

# %%
# #parameter tuning
# modelLookup('lvq')
# # design the parameter tuning grid
# grid <- expand.grid(size=c(5,10,20,50), k=c(1,2,3,4,5))
# # train the model
# model <- train(Species~., data=iris, method="lvq", trControl=control, tuneGrid=grid)

# %%
# saveRds(tmp, "tmp.rds")
# # load by giving path
# # tmp <- readRds("path")
# # R
