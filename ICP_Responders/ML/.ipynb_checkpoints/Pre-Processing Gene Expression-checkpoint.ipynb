# %% [markdown]
# # Pre-Processing
# 1) Clean data by removing rows with > 50% missing info <br>
# 2) Find the most informative features <br>
# 3) Split the data into test and train

# %%
library(caret)
library(corrplot)
library(biomaRt)

# %% [markdown]
# ## Load data
# The first column is expected to be sample ID <br>
# The second column is expected to be response

# %%
setwd("/home/jp/ICP_Responders/FinalTables")
expression <- read.csv("Final_table_response_and_expression.csv", na.strings = '..', stringsAsFactors = F)
names(expression) <- sub("^X", "", names(expression))
expression[ expression == "NA" ] <- NA
expression[,2:ncol(expression)] <- lapply(expression[, 2:ncol(expression)], as.numeric)
expression[50:60, 1:10]
# Out:
#    Patient Response 3920        345611       3929       54210       3716
# 50 31      1                 NA           NA         NA          NA          NA
# 51 32      1                 NA           NA         NA          NA          NA
# 52 33      1                 NA           NA         NA          NA          NA
# 53 34      1        -0.24227274  0.074304976 -0.3511685  0.54428208 -0.15006954
# 54 35      1        -0.48479782  0.159405465  0.4199815 -2.22883720  0.24650857
# 55 36      1         0.74085490  0.003467014  0.3333496 -0.03988917 -0.21346769
# 56 37      1                 NA           NA         NA          NA          NA
# 57 38      1         0.81259519 -0.048404344 -0.2250873 -0.29189077  0.44538081
# 58 39      0                 NA           NA         NA          NA          NA
# 59 4       0         0.14400922 -0.067130938  0.1120551 -0.96429947  0.10440116
# 60 40      1         0.07691239  0.333001919  0.5565036  0.17618231 -0.09816412
#    10454       3557        3556
# 50          NA          NA           NA
# 51          NA          NA           NA
# 52          NA          NA           NA
# 53 -0.07183968  0.20022650 -1.182660036
# 54 -0.38904130  1.82423349 -1.343065827
# 55  0.54476821 -1.69969237  0.483498059
# 56          NA          NA           NA
# 57  0.21789661 -0.08321449  1.567718745
# 58          NA          NA           NA
# 59 -0.74711659  0.30591242 -1.254576697
# 60  0.45014341 -0.28709491  0.002942665

# %% [markdown]
# ## Clean data

# %%
# Check which column has > 50% NA values
countNA <- function(x=NULL,cutOff=NULL){
  output<-FALSE
  perc<-sum(is.na(x))*100/length(x)
  if(perc>cutOff){output<-TRUE}
  output  
}
col_nas <- apply(expression,2,function(x){countNA(x, 50)})
cat("Columns with NAs > 50% = ", sum(col_nas), "\n")
# all columns have <50% NAs

# Check which rows has > 50% NA values
row_nas <- apply(expression,1,function(x){countNA(x, 50)})
cat("Rows with NAs > 50% = ", sum(row_nas), "\n")

# 43 rows have have >50% NAs, removing them
expr_filtered <- expression[-which(row_nas %in% TRUE),]

cat("Dimensions of the filteres dataset = ", dim(expr_filtered))
# Out:
# Columns with NAs > 50% =  0
# Rows with NAs > 50% =  43
# Dimensions of the filteres dataset =  161 676

# %% [markdown]
# ## Look for near zero variance and remove those columns

# %%
nzv <- nearZeroVar(expr_filtered[3:ncol(expr_filtered)], saveMetrics= TRUE)
nzv[which(nzv$zeroVar %in% TRUE), ]

# All features were retained and there was no filtering due to near zero variance
# Out:
#      freqRatio percentUnique zeroVar nzv

# %% [markdown]
# ## Look for correlation and remove highly correlated columns

# %%
# find attributes that are highly corrected (ideally >0.75)
tmp <- expr_filtered
tmp[is.na(tmp)] <- 0
expr_corr <-  cor(tmp[,3:ncol(tmp)]) 
highlyCorrelated <- findCorrelation(expr_corr, cutoff=0.75, names=TRUE, verbose=TRUE)
expr_rmcorr <- expr_filtered[, -which(colnames(expr_filtered) %in% highlyCorrelated)]
# Out:
#  Combination row 18 and column 19 is above the cut-off, value = 0.797
#  	 Flagging column 18
#  Combination row 18 and column 20 is above the cut-off, value = 0.755
#  	 Flagging column 18
#  Combination row 20 and column 22 is above the cut-off, value = 0.832
#  	 Flagging column 22
#  Combination row 20 and column 23 is above the cut-off, value = 0.801
#  	 Flagging column 23
#  Combination row 22 and column 23 is above the cut-off, value = 0.954
#  	 Flagging column 22
#  Combination row 18 and column 24 is above the cut-off, value = 0.768
#  	 Flagging column 18
#  Combination row 19 and column 24 is above the cut-off, value = 0.838
#  	 Flagging column 24
#  Combination row 19 and column 25 is above the cut-off, value = 0.759
#  	 Flagging column 25
#  Combination row 24 and column 25 is above the cut-off, value = 0.929
#  	 Flagging column 25
#  Combination row 16 and column 26 is above the cut-off, value = 0.856
#  	 Flagging column 16
#  Combination row 16 and column 31 is above the cut-off, value = 0.942
#  	 Flagging column 31
#  Combination row 26 and column 31 is above the cut-off, value = 0.772
#  	 Flagging column 31
#  Combination row 16 and column 32 is above the cut-off, value = 0.827
#  	 Flagging column 16
#  Combination row 31 and column 32 is above the cut-off, value = 0.904
#  	 Flagging column 31
#  Combination row 16 and column 36 is above the cut-off, value = 0.867
#  	 Flagging column 36
#  Combination row 26 and column 36 is above the cut-off, value = 0.767
#  	 Flagging column 36
#  Combination row 31 and column 36 is above the cut-off, value = 0.895
#  	 Flagging column 31
#  Combination row 32 and column 36 is above the cut-off, value = 0.785
#  	 Flagging column 36
#  Combination row 18 and column 38 is above the cut-off, value = 0.816
#  	 Flagging column 38
#  Combination row 19 and column 38 is above the cut-off, value = 0.874
#  	 Flagging column 38
#  Combination row 24 and column 38 is above the cut-off, value = 0.883
#  	 Flagging column 38
#  Combination row 25 and column 38 is above the cut-off, value = 0.825
#  	 Flagging column 38
#  Combination row 22 and column 46 is above the cut-off, value = 0.828
#  	 Flagging column 22
#  Combination row 23 and column 46 is above the cut-off, value = 0.81
#  	 Flagging column 23
#  Combination row 19 and column 52 is above the cut-off, value = 0.811
#  	 Flagging column 52
#  Combination row 38 and column 52 is above the cut-off, value = 0.849
#  	 Flagging column 38
#  Combination row 36 and column 57 is above the cut-off, value = 0.753
#  	 Flagging column 36
#  Combination row 16 and column 63 is above the cut-off, value = 0.8
#  	 Flagging column 63
#  Combination row 18 and column 63 is above the cut-off, value = 0.78
#  	 Flagging column 63
#  Combination row 24 and column 63 is above the cut-off, value = 0.82
#  	 Flagging column 63
#  Combination row 25 and column 63 is above the cut-off, value = 0.792
#  	 Flagging column 63
#  Combination row 31 and column 63 is above the cut-off, value = 0.896
#  	 Flagging column 63
#  Combination row 32 and column 63 is above the cut-off, value = 0.878
#  	 Flagging column 63
#  Combination row 36 and column 63 is above the cut-off, value = 0.813
#  	 Flagging column 63
#  Combination row 38 and column 63 is above the cut-off, value = 0.865
#  	 Flagging column 63
#  Combination row 26 and column 64 is above the cut-off, value = 0.844
#  	 Flagging column 26
#  Combination row 26 and column 65 is above the cut-off, value = 0.814
#  	 Flagging column 26
#  Combination row 64 and column 65 is above the cut-off, value = 0.81
#  	 Flagging column 65
#  Combination row 19 and column 66 is above the cut-off, value = 0.897
#  	 Flagging column 66
#  Combination row 24 and column 66 is above the cut-off, value = 0.769
#  	 Flagging column 24
#  Combination row 38 and column 66 is above the cut-off, value = 0.851
#  	 Flagging column 38
#  Combination row 52 and column 66 is above the cut-off, value = 0.783
#  	 Flagging column 52
#  Combination row 16 and column 68 is above the cut-off, value = 0.82
#  	 Flagging column 16
#  Combination row 26 and column 68 is above the cut-off, value = 0.802
#  	 Flagging column 26
#  Combination row 31 and column 68 is above the cut-off, value = 0.782
#  	 Flagging column 31
#  Combination row 48 and column 68 is above the cut-off, value = 0.762
#  	 Flagging column 68
#  Combination row 65 and column 68 is above the cut-off, value = 0.762
#  	 Flagging column 68
#  Combination row 10 and column 70 is above the cut-off, value = 0.784
#  	 Flagging column 10
#  Combination row 16 and column 75 is above the cut-off, value = 0.765
#  	 Flagging column 16
#  Combination row 26 and column 75 is above the cut-off, value = 0.814
#  	 Flagging column 26
#  Combination row 36 and column 75 is above the cut-off, value = 0.777
#  	 Flagging column 36
#  Combination row 68 and column 75 is above the cut-off, value = 0.778
#  	 Flagging column 68
#  Combination row 18 and column 85 is above the cut-off, value = 0.783
#  	 Flagging column 18
#  Combination row 19 and column 85 is above the cut-off, value = 0.818
#  	 Flagging column 85
#  Combination row 24 and column 85 is above the cut-off, value = 0.811
#  	 Flagging column 85
#  Combination row 25 and column 85 is above the cut-off, value = 0.794
#  	 Flagging column 85
#  Combination row 38 and column 85 is above the cut-off, value = 0.822
#  	 Flagging column 38
#  Combination row 52 and column 85 is above the cut-off, value = 0.763
#  	 Flagging column 85
#  Combination row 63 and column 85 is above the cut-off, value = 0.776
#  	 Flagging column 63
#  Combination row 66 and column 85 is above the cut-off, value = 0.784
#  	 Flagging column 85
#  Combination row 26 and column 86 is above the cut-off, value = 0.83
#  	 Flagging column 26
#  Combination row 64 and column 86 is above the cut-off, value = 0.896
#  	 Flagging column 64
#  Combination row 65 and column 86 is above the cut-off, value = 0.779
#  	 Flagging column 65
#  Combination row 32 and column 104 is above the cut-off, value = 0.755
#  	 Flagging column 32
#  Combination row 63 and column 104 is above the cut-off, value = 0.792
#  	 Flagging column 63
#  Combination row 16 and column 111 is above the cut-off, value = 0.815
#  	 Flagging column 16
#  Combination row 31 and column 111 is above the cut-off, value = 0.845
#  	 Flagging column 31
#  Combination row 36 and column 111 is above the cut-off, value = 0.8
#  	 Flagging column 36
#  Combination row 63 and column 111 is above the cut-off, value = 0.751
#  	 Flagging column 63
#  Combination row 24 and column 115 is above the cut-off, value = 0.84
#  	 Flagging column 115
#  Combination row 25 and column 115 is above the cut-off, value = 0.814
#  	 Flagging column 115
#  Combination row 38 and column 115 is above the cut-off, value = 0.789
#  	 Flagging column 38
#  Combination row 63 and column 115 is above the cut-off, value = 0.765
#  	 Flagging column 63
#  Combination row 85 and column 115 is above the cut-off, value = 0.823
#  	 Flagging column 85
#  Combination row 26 and column 124 is above the cut-off, value = 0.793
#  	 Flagging column 26
#  Combination row 64 and column 124 is above the cut-off, value = 0.803
#  	 Flagging column 64
#  Combination row 68 and column 124 is above the cut-off, value = 0.798
#  	 Flagging column 68
#  Combination row 75 and column 124 is above the cut-off, value = 0.83
#  	 Flagging column 75
#  Combination row 86 and column 124 is above the cut-off, value = 0.775
#  	 Flagging column 124
#  Combination row 16 and column 129 is above the cut-off, value = 0.846
#  	 Flagging column 129
#  Combination row 18 and column 129 is above the cut-off, value = 0.788
#  	 Flagging column 129
#  Combination row 26 and column 129 is above the cut-off, value = 0.834
#  	 Flagging column 129
#  Combination row 31 and column 129 is above the cut-off, value = 0.847
#  	 Flagging column 129
#  Combination row 36 and column 129 is above the cut-off, value = 0.824
#  	 Flagging column 129
#  Combination row 38 and column 129 is above the cut-off, value = 0.783
#  	 Flagging column 129
#  Combination row 63 and column 129 is above the cut-off, value = 0.838
#  	 Flagging column 129
#  Combination row 68 and column 129 is above the cut-off, value = 0.765
#  	 Flagging column 129
#  Combination row 126 and column 129 is above the cut-off, value = 0.775
#  	 Flagging column 129
#  Combination row 130 and column 131 is above the cut-off, value = 0.752
#  	 Flagging column 131
#  Combination row 26 and column 140 is above the cut-off, value = 0.811
#  	 Flagging column 26
#  Combination row 16 and column 144 is above the cut-off, value = 0.794
#  	 Flagging column 16
#  Combination row 31 and column 144 is above the cut-off, value = 0.807
#  	 Flagging column 31
#  Combination row 68 and column 144 is above the cut-off, value = 0.799
#  	 Flagging column 68
#  Combination row 16 and column 147 is above the cut-off, value = 0.89
#  	 Flagging column 16
#  Combination row 26 and column 147 is above the cut-off, value = 0.813
#  	 Flagging column 26
#  Combination row 31 and column 147 is above the cut-off, value = 0.866
#  	 Flagging column 31
#  Combination row 36 and column 147 is above the cut-off, value = 0.782
#  	 Flagging column 36
#  Combination row 68 and column 147 is above the cut-off, value = 0.786
#  	 Flagging column 147
#  Combination row 75 and column 147 is above the cut-off, value = 0.751
#  	 Flagging column 147
#  Combination row 111 and column 147 is above the cut-off, value = 0.76
#  	 Flagging column 147
#  Combination row 129 and column 147 is above the cut-off, value = 0.817
#  	 Flagging column 129
#  Combination row 144 and column 147 is above the cut-off, value = 0.813
#  	 Flagging column 147
#  Combination row 22 and column 149 is above the cut-off, value = 0.786
#  	 Flagging column 22
#  Combination row 23 and column 149 is above the cut-off, value = 0.786
#  	 Flagging column 23
#  Combination row 141 and column 152 is above the cut-off, value = 0.77
#  	 Flagging column 141
#  Combination row 63 and column 154 is above the cut-off, value = 0.758
#  	 Flagging column 63
#  Combination row 153 and column 154 is above the cut-off, value = 0.845
#  	 Flagging column 154
#  Combination row 141 and column 155 is above the cut-off, value = 0.789
#  	 Flagging column 141
#  Combination row 18 and column 156 is above the cut-off, value = 0.782
#  	 Flagging column 156
#  Combination row 19 and column 156 is above the cut-off, value = 0.764
#  	 Flagging column 156
#  Combination row 24 and column 156 is above the cut-off, value = 0.834
#  	 Flagging column 156
#  Combination row 25 and column 156 is above the cut-off, value = 0.813
#  	 Flagging column 156
#  Combination row 31 and column 156 is above the cut-off, value = 0.82
#  	 Flagging column 31
#  Combination row 32 and column 156 is above the cut-off, value = 0.791
#  	 Flagging column 156
#  Combination row 36 and column 156 is above the cut-off, value = 0.768
#  	 Flagging column 36
#  Combination row 38 and column 156 is above the cut-off, value = 0.852
#  	 Flagging column 38
#  Combination row 63 and column 156 is above the cut-off, value = 0.856
#  	 Flagging column 63
#  Combination row 85 and column 156 is above the cut-off, value = 0.758
#  	 Flagging column 156
#  Combination row 129 and column 156 is above the cut-off, value = 0.776
#  	 Flagging column 129
#  Combination row 154 and column 156 is above the cut-off, value = 0.801
#  	 Flagging column 156
#  Combination row 38 and column 157 is above the cut-off, value = 0.759
#  	 Flagging column 38
#  Combination row 18 and column 158 is above the cut-off, value = 0.784
#  	 Flagging column 158
#  Combination row 24 and column 158 is above the cut-off, value = 0.821
#  	 Flagging column 158
#  Combination row 25 and column 158 is above the cut-off, value = 0.796
#  	 Flagging column 158
#  Combination row 31 and column 158 is above the cut-off, value = 0.787
#  	 Flagging column 31
#  Combination row 32 and column 158 is above the cut-off, value = 0.753
#  	 Flagging column 158
#  Combination row 38 and column 158 is above the cut-off, value = 0.817
#  	 Flagging column 38
#  Combination row 63 and column 158 is above the cut-off, value = 0.843
#  	 Flagging column 63
#  Combination row 129 and column 158 is above the cut-off, value = 0.776
#  	 Flagging column 129
#  Combination row 154 and column 158 is above the cut-off, value = 0.82
#  	 Flagging column 158
#  Combination row 156 and column 158 is above the cut-off, value = 0.926
#  	 Flagging column 156
#  Combination row 16 and column 159 is above the cut-off, value = 0.793
#  	 Flagging column 16
#  Combination row 26 and column 159 is above the cut-off, value = 0.781
#  	 Flagging column 26
#  Combination row 68 and column 159 is above the cut-off, value = 0.78
#  	 Flagging column 68
#  Combination row 147 and column 159 is above the cut-off, value = 0.782
#  	 Flagging column 147
#  Combination row 31 and column 161 is above the cut-off, value = 0.763
#  	 Flagging column 31
#  Combination row 36 and column 161 is above the cut-off, value = 0.764
#  	 Flagging column 36
#  Combination row 38 and column 161 is above the cut-off, value = 0.752
#  	 Flagging column 38
#  Combination row 63 and column 161 is above the cut-off, value = 0.756
#  	 Flagging column 63
#  Combination row 129 and column 161 is above the cut-off, value = 0.76
#  	 Flagging column 129
#  Combination row 144 and column 161 is above the cut-off, value = 0.75
#  	 Flagging column 161
#  Combination row 147 and column 161 is above the cut-off, value = 0.765
#  	 Flagging column 147
#  Combination row 26 and column 162 is above the cut-off, value = 0.752
#  	 Flagging column 26
#  Combination row 57 and column 162 is above the cut-off, value = 0.796
#  	 Flagging column 57
#  Combination row 64 and column 175 is above the cut-off, value = 0.787
#  	 Flagging column 64
#  Combination row 31 and column 181 is above the cut-off, value = 0.796
#  	 Flagging column 31
#  Combination row 32 and column 181 is above the cut-off, value = 0.777
#  	 Flagging column 32
#  Combination row 36 and column 181 is above the cut-off, value = 0.793
#  	 Flagging column 36
#  Combination row 16 and column 182 is above the cut-off, value = 0.822
#  	 Flagging column 16
#  Combination row 26 and column 182 is above the cut-off, value = 0.773
#  	 Flagging column 26
#  Combination row 31 and column 182 is above the cut-off, value = 0.847
#  	 Flagging column 31
#  Combination row 32 and column 182 is above the cut-off, value = 0.812
#  	 Flagging column 32
#  Combination row 36 and column 182 is above the cut-off, value = 0.761
#  	 Flagging column 36
#  Combination row 63 and column 182 is above the cut-off, value = 0.792
#  	 Flagging column 63
#  Combination row 129 and column 182 is above the cut-off, value = 0.819
#  	 Flagging column 129
#  Combination row 147 and column 182 is above the cut-off, value = 0.78
#  	 Flagging column 182
#  Combination row 161 and column 182 is above the cut-off, value = 0.779
#  	 Flagging column 182
#  Combination row 16 and column 184 is above the cut-off, value = 0.913
#  	 Flagging column 16
#  Combination row 26 and column 184 is above the cut-off, value = 0.803
#  	 Flagging column 184
#  Combination row 31 and column 184 is above the cut-off, value = 0.93
#  	 Flagging column 31
#  Combination row 32 and column 184 is above the cut-off, value = 0.862
#  	 Flagging column 184
#  Combination row 36 and column 184 is above the cut-off, value = 0.846
#  	 Flagging column 36
#  Combination row 57 and column 184 is above the cut-off, value = 0.789
#  	 Flagging column 184
#  Combination row 63 and column 184 is above the cut-off, value = 0.828
#  	 Flagging column 63
#  Combination row 68 and column 184 is above the cut-off, value = 0.758
#  	 Flagging column 184
#  Combination row 111 and column 184 is above the cut-off, value = 0.81
#  	 Flagging column 184
#  Combination row 129 and column 184 is above the cut-off, value = 0.812
#  	 Flagging column 129
#  Combination row 144 and column 184 is above the cut-off, value = 0.761
#  	 Flagging column 184
#  Combination row 147 and column 184 is above the cut-off, value = 0.805
#  	 Flagging column 184
#  Combination row 156 and column 184 is above the cut-off, value = 0.76
#  	 Flagging column 156
#  Combination row 162 and column 184 is above the cut-off, value = 0.804
#  	 Flagging column 184
#  Combination row 181 and column 184 is above the cut-off, value = 0.781
#  	 Flagging column 184
#  Combination row 182 and column 184 is above the cut-off, value = 0.807
#  	 Flagging column 184
#  Combination row 16 and column 187 is above the cut-off, value = 0.829
#  	 Flagging column 16
#  Combination row 31 and column 187 is above the cut-off, value = 0.91
#  	 Flagging column 31
#  Combination row 32 and column 187 is above the cut-off, value = 0.904
#  	 Flagging column 32
#  Combination row 36 and column 187 is above the cut-off, value = 0.793
#  	 Flagging column 36
#  Combination row 63 and column 187 is above the cut-off, value = 0.884
#  	 Flagging column 63
#  Combination row 104 and column 187 is above the cut-off, value = 0.843
#  	 Flagging column 187
#  Combination row 111 and column 187 is above the cut-off, value = 0.775
#  	 Flagging column 187
#  Combination row 156 and column 187 is above the cut-off, value = 0.795
#  	 Flagging column 156
#  Combination row 181 and column 187 is above the cut-off, value = 0.813
#  	 Flagging column 187
#  Combination row 182 and column 187 is above the cut-off, value = 0.803
#  	 Flagging column 182
#  Combination row 184 and column 187 is above the cut-off, value = 0.851
#  	 Flagging column 184
#  Combination row 14 and column 189 is above the cut-off, value = 0.773
#  	 Flagging column 189
#  Combination row 129 and column 189 is above the cut-off, value = 0.758
#  	 Flagging column 129
#  Combination row 16 and column 190 is above the cut-off, value = 0.77
#  	 Flagging column 16
#  Combination row 26 and column 190 is above the cut-off, value = 0.831
#  	 Flagging column 26
#  Combination row 64 and column 190 is above the cut-off, value = 0.854
#  	 Flagging column 190
#  Combination row 75 and column 190 is above the cut-off, value = 0.775
#  	 Flagging column 75
#  Combination row 86 and column 190 is above the cut-off, value = 0.767
#  	 Flagging column 190
#  Combination row 124 and column 190 is above the cut-off, value = 0.769
#  	 Flagging column 190
#  Combination row 147 and column 190 is above the cut-off, value = 0.766
#  	 Flagging column 147
#  Combination row 159 and column 190 is above the cut-off, value = 0.785
#  	 Flagging column 159
#  Combination row 162 and column 190 is above the cut-off, value = 0.75
#  	 Flagging column 190
#  Combination row 175 and column 190 is above the cut-off, value = 0.806
#  	 Flagging column 190
#  Combination row 26 and column 191 is above the cut-off, value = 0.864
#  	 Flagging column 26
#  Combination row 64 and column 191 is above the cut-off, value = 0.879
#  	 Flagging column 191
#  Combination row 65 and column 191 is above the cut-off, value = 0.764
#  	 Flagging column 191
#  Combination row 86 and column 191 is above the cut-off, value = 0.863
#  	 Flagging column 191
#  Combination row 140 and column 191 is above the cut-off, value = 0.794
#  	 Flagging column 140
#  Combination row 159 and column 191 is above the cut-off, value = 0.771
#  	 Flagging column 159
#  Combination row 162 and column 191 is above the cut-off, value = 0.837
#  	 Flagging column 191
#  Combination row 175 and column 191 is above the cut-off, value = 0.801
#  	 Flagging column 191
#  Combination row 190 and column 191 is above the cut-off, value = 0.928
#  	 Flagging column 190
#  Combination row 24 and column 193 is above the cut-off, value = 0.789
#  	 Flagging column 193
#  Combination row 25 and column 193 is above the cut-off, value = 0.809
#  	 Flagging column 193
#  Combination row 38 and column 193 is above the cut-off, value = 0.836
#  	 Flagging column 38
#  Combination row 52 and column 193 is above the cut-off, value = 0.788
#  	 Flagging column 193
#  Combination row 63 and column 193 is above the cut-off, value = 0.765
#  	 Flagging column 63
#  Combination row 115 and column 193 is above the cut-off, value = 0.768
#  	 Flagging column 193
#  Combination row 16 and column 196 is above the cut-off, value = 0.792
#  	 Flagging column 196
#  Combination row 18 and column 196 is above the cut-off, value = 0.766
#  	 Flagging column 196
#  Combination row 31 and column 196 is above the cut-off, value = 0.847
#  	 Flagging column 196
#  Combination row 32 and column 196 is above the cut-off, value = 0.759
#  	 Flagging column 196
#  Combination row 36 and column 196 is above the cut-off, value = 0.842
#  	 Flagging column 196
#  Combination row 38 and column 196 is above the cut-off, value = 0.82
#  	 Flagging column 196
#  Combination row 63 and column 196 is above the cut-off, value = 0.869
#  	 Flagging column 196
#  Combination row 68 and column 196 is above the cut-off, value = 0.756
#  	 Flagging column 196
#  Combination row 129 and column 196 is above the cut-off, value = 0.854
#  	 Flagging column 196
#  Combination row 147 and column 196 is above the cut-off, value = 0.753
#  	 Flagging column 196
#  Combination row 156 and column 196 is above the cut-off, value = 0.804
#  	 Flagging column 196
#  Combination row 158 and column 196 is above the cut-off, value = 0.781
#  	 Flagging column 196
#  Combination row 184 and column 196 is above the cut-off, value = 0.775
#  	 Flagging column 196
#  Combination row 187 and column 196 is above the cut-off, value = 0.753
#  	 Flagging column 196
#  Combination row 16 and column 197 is above the cut-off, value = 0.963
#  	 Flagging column 197
#  Combination row 26 and column 197 is above the cut-off, value = 0.872
#  	 Flagging column 197
#  Combination row 31 and column 197 is above the cut-off, value = 0.952
#  	 Flagging column 197
#  Combination row 32 and column 197 is above the cut-off, value = 0.858
#  	 Flagging column 197
#  Combination row 36 and column 197 is above the cut-off, value = 0.883
#  	 Flagging column 197
#  Combination row 57 and column 197 is above the cut-off, value = 0.771
#  	 Flagging column 197
#  Combination row 63 and column 197 is above the cut-off, value = 0.832
#  	 Flagging column 197
#  Combination row 68 and column 197 is above the cut-off, value = 0.816
#  	 Flagging column 197
#  Combination row 75 and column 197 is above the cut-off, value = 0.785
#  	 Flagging column 197
#  Combination row 111 and column 197 is above the cut-off, value = 0.832
#  	 Flagging column 197
#  Combination row 129 and column 197 is above the cut-off, value = 0.86
#  	 Flagging column 129
#  Combination row 144 and column 197 is above the cut-off, value = 0.799
#  	 Flagging column 197
#  Combination row 147 and column 197 is above the cut-off, value = 0.86
#  	 Flagging column 197
#  Combination row 156 and column 197 is above the cut-off, value = 0.759
#  	 Flagging column 197
#  Combination row 159 and column 197 is above the cut-off, value = 0.763
#  	 Flagging column 197
#  Combination row 181 and column 197 is above the cut-off, value = 0.791
#  	 Flagging column 197
#  Combination row 182 and column 197 is above the cut-off, value = 0.855
#  	 Flagging column 197
#  Combination row 184 and column 197 is above the cut-off, value = 0.944
#  	 Flagging column 197
#  Combination row 187 and column 197 is above the cut-off, value = 0.868
#  	 Flagging column 197
#  Combination row 196 and column 197 is above the cut-off, value = 0.815
#  	 Flagging column 196
#  Combination row 16 and column 199 is above the cut-off, value = 0.756
#  	 Flagging column 16
#  Combination row 31 and column 199 is above the cut-off, value = 0.809
#  	 Flagging column 31
#  Combination row 36 and column 199 is above the cut-off, value = 0.758
#  	 Flagging column 36
#  Combination row 63 and column 199 is above the cut-off, value = 0.825
#  	 Flagging column 63
#  Combination row 129 and column 199 is above the cut-off, value = 0.771
#  	 Flagging column 129
#  Combination row 184 and column 199 is above the cut-off, value = 0.775
#  	 Flagging column 184
#  Combination row 187 and column 199 is above the cut-off, value = 0.755
#  	 Flagging column 199
#  Combination row 196 and column 199 is above the cut-off, value = 0.782
#  	 Flagging column 196
#  Combination row 197 and column 199 is above the cut-off, value = 0.777
#  	 Flagging column 197
#  Combination row 16 and column 202 is above the cut-off, value = 0.904
#  	 Flagging column 16
#  Combination row 26 and column 202 is above the cut-off, value = 0.785
#  	 Flagging column 202
#  Combination row 31 and column 202 is above the cut-off, value = 0.929
#  	 Flagging column 31
#  Combination row 32 and column 202 is above the cut-off, value = 0.892
#  	 Flagging column 202
#  Combination row 36 and column 202 is above the cut-off, value = 0.801
#  	 Flagging column 36
#  Combination row 63 and column 202 is above the cut-off, value = 0.877
#  	 Flagging column 63
#  Combination row 111 and column 202 is above the cut-off, value = 0.797
#  	 Flagging column 202
#  Combination row 129 and column 202 is above the cut-off, value = 0.84
#  	 Flagging column 129
#  Combination row 144 and column 202 is above the cut-off, value = 0.754
#  	 Flagging column 202
#  Combination row 147 and column 202 is above the cut-off, value = 0.842
#  	 Flagging column 202
#  Combination row 156 and column 202 is above the cut-off, value = 0.764
#  	 Flagging column 202
#  Combination row 158 and column 202 is above the cut-off, value = 0.753
#  	 Flagging column 202
#  Combination row 182 and column 202 is above the cut-off, value = 0.874
#  	 Flagging column 202
#  Combination row 184 and column 202 is above the cut-off, value = 0.884
#  	 Flagging column 202
#  Combination row 187 and column 202 is above the cut-off, value = 0.874
#  	 Flagging column 202
#  Combination row 196 and column 202 is above the cut-off, value = 0.808
#  	 Flagging column 196
#  Combination row 197 and column 202 is above the cut-off, value = 0.918
#  	 Flagging column 197
#  Combination row 199 and column 202 is above the cut-off, value = 0.782
#  	 Flagging column 202
#  Combination row 16 and column 203 is above the cut-off, value = 0.908
#  	 Flagging column 203
#  Combination row 26 and column 203 is above the cut-off, value = 0.789
#  	 Flagging column 203
#  Combination row 31 and column 203 is above the cut-off, value = 0.954
#  	 Flagging column 203
#  Combination row 32 and column 203 is above the cut-off, value = 0.882
#  	 Flagging column 203
#  Combination row 36 and column 203 is above the cut-off, value = 0.885
#  	 Flagging column 203
#  Combination row 38 and column 203 is above the cut-off, value = 0.751
#  	 Flagging column 203
#  Combination row 63 and column 203 is above the cut-off, value = 0.899
#  	 Flagging column 203
#  Combination row 68 and column 203 is above the cut-off, value = 0.79
#  	 Flagging column 203
#  Combination row 111 and column 203 is above the cut-off, value = 0.82
#  	 Flagging column 203
#  Combination row 129 and column 203 is above the cut-off, value = 0.871
#  	 Flagging column 129
#  Combination row 144 and column 203 is above the cut-off, value = 0.771
#  	 Flagging column 203
#  Combination row 147 and column 203 is above the cut-off, value = 0.828
#  	 Flagging column 203
#  Combination row 156 and column 203 is above the cut-off, value = 0.815
#  	 Flagging column 203
#  Combination row 158 and column 203 is above the cut-off, value = 0.796
#  	 Flagging column 203
#  Combination row 181 and column 203 is above the cut-off, value = 0.76
#  	 Flagging column 203
#  Combination row 182 and column 203 is above the cut-off, value = 0.818
#  	 Flagging column 203
#  Combination row 184 and column 203 is above the cut-off, value = 0.921
#  	 Flagging column 203
#  Combination row 187 and column 203 is above the cut-off, value = 0.867
#  	 Flagging column 203
#  Combination row 196 and column 203 is above the cut-off, value = 0.905
#  	 Flagging column 196
#  Combination row 197 and column 203 is above the cut-off, value = 0.935
#  	 Flagging column 203
#  Combination row 199 and column 203 is above the cut-off, value = 0.815
#  	 Flagging column 203
#  Combination row 202 and column 203 is above the cut-off, value = 0.907
#  	 Flagging column 203
#  Combination row 16 and column 207 is above the cut-off, value = 0.813
#  	 Flagging column 16
#  Combination row 26 and column 207 is above the cut-off, value = 0.818
#  	 Flagging column 207
#  Combination row 31 and column 207 is above the cut-off, value = 0.791
#  	 Flagging column 31
#  Combination row 36 and column 207 is above the cut-off, value = 0.793
#  	 Flagging column 36
#  Combination row 68 and column 207 is above the cut-off, value = 0.769
#  	 Flagging column 207
#  Combination row 129 and column 207 is above the cut-off, value = 0.851
#  	 Flagging column 129
#  Combination row 184 and column 207 is above the cut-off, value = 0.775
#  	 Flagging column 207
#  Combination row 196 and column 207 is above the cut-off, value = 0.784
#  	 Flagging column 196
#  Combination row 197 and column 207 is above the cut-off, value = 0.815
#  	 Flagging column 197
#  Combination row 202 and column 207 is above the cut-off, value = 0.762
#  	 Flagging column 202
#  Combination row 203 and column 207 is above the cut-off, value = 0.813
#  	 Flagging column 203
#  Combination row 131 and column 208 is above the cut-off, value = 0.88
#  	 Flagging column 131
#  Combination row 19 and column 209 is above the cut-off, value = 0.847
#  	 Flagging column 19
#  Combination row 38 and column 209 is above the cut-off, value = 0.785
#  	 Flagging column 38
#  Combination row 194 and column 209 is above the cut-off, value = 0.86
#  	 Flagging column 209
#  Combination row 31 and column 212 is above the cut-off, value = 0.799
#  	 Flagging column 31
#  Combination row 32 and column 212 is above the cut-off, value = 0.791
#  	 Flagging column 32
#  Combination row 36 and column 212 is above the cut-off, value = 0.755
#  	 Flagging column 36
#  Combination row 63 and column 212 is above the cut-off, value = 0.767
#  	 Flagging column 63
#  Combination row 131 and column 212 is above the cut-off, value = 0.897
#  	 Flagging column 212
#  Combination row 156 and column 212 is above the cut-off, value = 0.767
#  	 Flagging column 156
#  Combination row 158 and column 212 is above the cut-off, value = 0.771
#  	 Flagging column 158
#  Combination row 187 and column 212 is above the cut-off, value = 0.781
#  	 Flagging column 187
#  Combination row 202 and column 212 is above the cut-off, value = 0.753
#  	 Flagging column 202
#  Combination row 203 and column 212 is above the cut-off, value = 0.784
#  	 Flagging column 203
#  Combination row 208 and column 212 is above the cut-off, value = 0.896
#  	 Flagging column 212
#  Combination row 208 and column 213 is above the cut-off, value = 0.765
#  	 Flagging column 213
#  Combination row 212 and column 213 is above the cut-off, value = 0.821
#  	 Flagging column 212
#  Combination row 24 and column 221 is above the cut-off, value = 0.757
#  	 Flagging column 221
#  Combination row 31 and column 221 is above the cut-off, value = 0.75
#  	 Flagging column 221
#  Combination row 36 and column 221 is above the cut-off, value = 0.756
#  	 Flagging column 221
#  Combination row 38 and column 221 is above the cut-off, value = 0.835
#  	 Flagging column 221
#  Combination row 52 and column 221 is above the cut-off, value = 0.768
#  	 Flagging column 221
#  Combination row 63 and column 221 is above the cut-off, value = 0.838
#  	 Flagging column 221
#  Combination row 66 and column 221 is above the cut-off, value = 0.775
#  	 Flagging column 221
#  Combination row 85 and column 221 is above the cut-off, value = 0.757
#  	 Flagging column 221
#  Combination row 115 and column 221 is above the cut-off, value = 0.756
#  	 Flagging column 221
#  Combination row 129 and column 221 is above the cut-off, value = 0.804
#  	 Flagging column 129
#  Combination row 156 and column 221 is above the cut-off, value = 0.795
#  	 Flagging column 221
#  Combination row 158 and column 221 is above the cut-off, value = 0.776
#  	 Flagging column 221
#  Combination row 193 and column 221 is above the cut-off, value = 0.763
#  	 Flagging column 221
#  Combination row 196 and column 221 is above the cut-off, value = 0.865
#  	 Flagging column 196
#  Combination row 202 and column 221 is above the cut-off, value = 0.759
#  	 Flagging column 221
#  Combination row 203 and column 221 is above the cut-off, value = 0.818
#  	 Flagging column 203
#  Combination row 38 and column 232 is above the cut-off, value = 0.769
#  	 Flagging column 38
#  Combination row 221 and column 232 is above the cut-off, value = 0.77
#  	 Flagging column 221
#  Combination row 16 and column 238 is above the cut-off, value = 0.775
#  	 Flagging column 16
#  Combination row 31 and column 238 is above the cut-off, value = 0.777
#  	 Flagging column 31
#  Combination row 32 and column 238 is above the cut-off, value = 0.763
#  	 Flagging column 32
#  Combination row 184 and column 238 is above the cut-off, value = 0.871
#  	 Flagging column 184
#  Combination row 197 and column 238 is above the cut-off, value = 0.833
#  	 Flagging column 197
#  Combination row 202 and column 238 is above the cut-off, value = 0.771
#  	 Flagging column 202
#  Combination row 203 and column 238 is above the cut-off, value = 0.793
#  	 Flagging column 203
#  Combination row 18 and column 239 is above the cut-off, value = 0.779
#  	 Flagging column 239
#  Combination row 36 and column 239 is above the cut-off, value = 0.774
#  	 Flagging column 36
#  Combination row 38 and column 239 is above the cut-off, value = 0.78
#  	 Flagging column 239
#  Combination row 63 and column 239 is above the cut-off, value = 0.792
#  	 Flagging column 63
#  Combination row 129 and column 239 is above the cut-off, value = 0.793
#  	 Flagging column 129
#  Combination row 161 and column 239 is above the cut-off, value = 0.758
#  	 Flagging column 239
#  Combination row 196 and column 239 is above the cut-off, value = 0.832
#  	 Flagging column 196
#  Combination row 203 and column 239 is above the cut-off, value = 0.77
#  	 Flagging column 203
#  Combination row 221 and column 239 is above the cut-off, value = 0.783
#  	 Flagging column 221
#  Combination row 16 and column 243 is above the cut-off, value = 0.87
#  	 Flagging column 243
#  Combination row 18 and column 243 is above the cut-off, value = 0.852
#  	 Flagging column 243
#  Combination row 26 and column 243 is above the cut-off, value = 0.818
#  	 Flagging column 243
#  Combination row 31 and column 243 is above the cut-off, value = 0.876
#  	 Flagging column 243
#  Combination row 36 and column 243 is above the cut-off, value = 0.911
#  	 Flagging column 243
#  Combination row 38 and column 243 is above the cut-off, value = 0.793
#  	 Flagging column 243
#  Combination row 63 and column 243 is above the cut-off, value = 0.834
#  	 Flagging column 243
#  Combination row 68 and column 243 is above the cut-off, value = 0.791
#  	 Flagging column 243
#  Combination row 75 and column 243 is above the cut-off, value = 0.803
#  	 Flagging column 243
#  Combination row 111 and column 243 is above the cut-off, value = 0.771
#  	 Flagging column 243
#  Combination row 129 and column 243 is above the cut-off, value = 0.904
#  	 Flagging column 243
#  Combination row 144 and column 243 is above the cut-off, value = 0.763
#  	 Flagging column 243
#  Combination row 147 and column 243 is above the cut-off, value = 0.823
#  	 Flagging column 243
#  Combination row 156 and column 243 is above the cut-off, value = 0.82
#  	 Flagging column 243
#  Combination row 158 and column 243 is above the cut-off, value = 0.809
#  	 Flagging column 243
#  Combination row 161 and column 243 is above the cut-off, value = 0.768
#  	 Flagging column 243
#  Combination row 182 and column 243 is above the cut-off, value = 0.775
#  	 Flagging column 243
#  Combination row 184 and column 243 is above the cut-off, value = 0.818
#  	 Flagging column 243
#  Combination row 189 and column 243 is above the cut-off, value = 0.786
#  	 Flagging column 243
#  Combination row 196 and column 243 is above the cut-off, value = 0.889
#  	 Flagging column 196
#  Combination row 197 and column 243 is above the cut-off, value = 0.873
#  	 Flagging column 243
#  Combination row 199 and column 243 is above the cut-off, value = 0.77
#  	 Flagging column 243
#  Combination row 202 and column 243 is above the cut-off, value = 0.805
#  	 Flagging column 243
#  Combination row 203 and column 243 is above the cut-off, value = 0.879
#  	 Flagging column 243
#  Combination row 207 and column 243 is above the cut-off, value = 0.859
#  	 Flagging column 243
#  Combination row 221 and column 243 is above the cut-off, value = 0.794
#  	 Flagging column 243
#  Combination row 239 and column 243 is above the cut-off, value = 0.817
#  	 Flagging column 243
#  Combination row 26 and column 244 is above the cut-off, value = 0.839
#  	 Flagging column 26
#  Combination row 64 and column 244 is above the cut-off, value = 0.918
#  	 Flagging column 64
#  Combination row 65 and column 244 is above the cut-off, value = 0.756
#  	 Flagging column 65
#  Combination row 86 and column 244 is above the cut-off, value = 0.879
#  	 Flagging column 244
#  Combination row 124 and column 244 is above the cut-off, value = 0.777
#  	 Flagging column 124
#  Combination row 175 and column 244 is above the cut-off, value = 0.827
#  	 Flagging column 244
#  Combination row 190 and column 244 is above the cut-off, value = 0.897
#  	 Flagging column 190
#  Combination row 191 and column 244 is above the cut-off, value = 0.925
#  	 Flagging column 191
#  Combination row 16 and column 246 is above the cut-off, value = 0.801
#  	 Flagging column 246
#  Combination row 26 and column 246 is above the cut-off, value = 0.781
#  	 Flagging column 246
#  Combination row 31 and column 246 is above the cut-off, value = 0.796
#  	 Flagging column 246
#  Combination row 36 and column 246 is above the cut-off, value = 0.818
#  	 Flagging column 246
#  Combination row 63 and column 246 is above the cut-off, value = 0.781
#  	 Flagging column 246
#  Combination row 68 and column 246 is above the cut-off, value = 0.773
#  	 Flagging column 246
#  Combination row 129 and column 246 is above the cut-off, value = 0.848
#  	 Flagging column 246
#  Combination row 184 and column 246 is above the cut-off, value = 0.754
#  	 Flagging column 246
#  Combination row 189 and column 246 is above the cut-off, value = 0.76
#  	 Flagging column 246
#  Combination row 196 and column 246 is above the cut-off, value = 0.897
#  	 Flagging column 196
#  Combination row 197 and column 246 is above the cut-off, value = 0.825
#  	 Flagging column 246
#  Combination row 199 and column 246 is above the cut-off, value = 0.774
#  	 Flagging column 246
#  Combination row 202 and column 246 is above the cut-off, value = 0.789
#  	 Flagging column 246
#  Combination row 203 and column 246 is above the cut-off, value = 0.863
#  	 Flagging column 246
#  Combination row 204 and column 246 is above the cut-off, value = 0.779
#  	 Flagging column 246
#  Combination row 207 and column 246 is above the cut-off, value = 0.828
#  	 Flagging column 246
#  Combination row 221 and column 246 is above the cut-off, value = 0.836
#  	 Flagging column 246
#  Combination row 239 and column 246 is above the cut-off, value = 0.811
#  	 Flagging column 246
#  Combination row 243 and column 246 is above the cut-off, value = 0.859
#  	 Flagging column 246
#  Combination row 141 and column 249 is above the cut-off, value = 0.754
#  	 Flagging column 249
#  Combination row 155 and column 249 is above the cut-off, value = 0.886
#  	 Flagging column 249
#  Combination row 172 and column 249 is above the cut-off, value = 0.778
#  	 Flagging column 172
#  Combination row 26 and column 264 is above the cut-off, value = 0.753
#  	 Flagging column 26
#  Combination row 57 and column 264 is above the cut-off, value = 0.75
#  	 Flagging column 57
#  Combination row 64 and column 264 is above the cut-off, value = 0.759
#  	 Flagging column 64
#  Combination row 86 and column 264 is above the cut-off, value = 0.762
#  	 Flagging column 264
#  Combination row 162 and column 264 is above the cut-off, value = 0.756
#  	 Flagging column 162
#  Combination row 190 and column 264 is above the cut-off, value = 0.78
#  	 Flagging column 190
#  Combination row 191 and column 264 is above the cut-off, value = 0.845
#  	 Flagging column 191
#  Combination row 244 and column 264 is above the cut-off, value = 0.767
#  	 Flagging column 264
#  Combination row 16 and column 265 is above the cut-off, value = 0.804
#  	 Flagging column 16
#  Combination row 26 and column 265 is above the cut-off, value = 0.802
#  	 Flagging column 26
#  Combination row 57 and column 265 is above the cut-off, value = 0.814
#  	 Flagging column 57
#  Combination row 86 and column 265 is above the cut-off, value = 0.758
#  	 Flagging column 265
#  Combination row 162 and column 265 is above the cut-off, value = 0.941
#  	 Flagging column 265
#  Combination row 184 and column 265 is above the cut-off, value = 0.856
#  	 Flagging column 184
#  Combination row 190 and column 265 is above the cut-off, value = 0.815
#  	 Flagging column 265
#  Combination row 191 and column 265 is above the cut-off, value = 0.865
#  	 Flagging column 265
#  Combination row 197 and column 265 is above the cut-off, value = 0.814
#  	 Flagging column 197
#  Combination row 203 and column 265 is above the cut-off, value = 0.768
#  	 Flagging column 203
#  Combination row 238 and column 265 is above the cut-off, value = 0.764
#  	 Flagging column 238
#  Combination row 264 and column 265 is above the cut-off, value = 0.817
#  	 Flagging column 265
#  Combination row 18 and column 266 is above the cut-off, value = 0.798
#  	 Flagging column 266
#  Combination row 19 and column 266 is above the cut-off, value = 0.751
#  	 Flagging column 266
#  Combination row 24 and column 266 is above the cut-off, value = 0.858
#  	 Flagging column 266
#  Combination row 25 and column 266 is above the cut-off, value = 0.826
#  	 Flagging column 266
#  Combination row 31 and column 266 is above the cut-off, value = 0.802
#  	 Flagging column 31
#  Combination row 32 and column 266 is above the cut-off, value = 0.818
#  	 Flagging column 266
#  Combination row 38 and column 266 is above the cut-off, value = 0.854
#  	 Flagging column 38
#  Combination row 63 and column 266 is above the cut-off, value = 0.877
#  	 Flagging column 63
#  Combination row 85 and column 266 is above the cut-off, value = 0.765
#  	 Flagging column 266
#  Combination row 115 and column 266 is above the cut-off, value = 0.751
#  	 Flagging column 266
#  Combination row 129 and column 266 is above the cut-off, value = 0.794
#  	 Flagging column 129
#  Combination row 154 and column 266 is above the cut-off, value = 0.82
#  	 Flagging column 266
#  Combination row 156 and column 266 is above the cut-off, value = 0.922
#  	 Flagging column 266
#  Combination row 158 and column 266 is above the cut-off, value = 0.927
#  	 Flagging column 266
#  Combination row 187 and column 266 is above the cut-off, value = 0.761
#  	 Flagging column 266
#  Combination row 196 and column 266 is above the cut-off, value = 0.817
#  	 Flagging column 196
#  Combination row 202 and column 266 is above the cut-off, value = 0.778
#  	 Flagging column 202
#  Combination row 203 and column 266 is above the cut-off, value = 0.828
#  	 Flagging column 203
#  Combination row 221 and column 266 is above the cut-off, value = 0.819
#  	 Flagging column 221
#  Combination row 243 and column 266 is above the cut-off, value = 0.812
#  	 Flagging column 243
#  Combination row 16 and column 271 is above the cut-off, value = 0.826
#  	 Flagging column 16
#  Combination row 31 and column 271 is above the cut-off, value = 0.834
#  	 Flagging column 31
#  Combination row 36 and column 271 is above the cut-off, value = 0.831
#  	 Flagging column 36
#  Combination row 184 and column 271 is above the cut-off, value = 0.826
#  	 Flagging column 184
#  Combination row 197 and column 271 is above the cut-off, value = 0.852
#  	 Flagging column 197
#  Combination row 203 and column 271 is above the cut-off, value = 0.83
#  	 Flagging column 203
#  Combination row 243 and column 271 is above the cut-off, value = 0.807
#  	 Flagging column 243
#  Combination row 16 and column 277 is above the cut-off, value = 0.754
#  	 Flagging column 16
#  Combination row 197 and column 277 is above the cut-off, value = 0.76
#  	 Flagging column 197
#  Combination row 203 and column 277 is above the cut-off, value = 0.752
#  	 Flagging column 203
#  Combination row 243 and column 277 is above the cut-off, value = 0.751
#  	 Flagging column 243
#  Combination row 271 and column 277 is above the cut-off, value = 0.774
#  	 Flagging column 271
#  Combination row 277 and column 282 is above the cut-off, value = 0.753
#  	 Flagging column 277
#  Combination row 24 and column 284 is above the cut-off, value = 0.809
#  	 Flagging column 284
#  Combination row 25 and column 284 is above the cut-off, value = 0.796
#  	 Flagging column 284
#  Combination row 31 and column 284 is above the cut-off, value = 0.831
#  	 Flagging column 31
#  Combination row 32 and column 284 is above the cut-off, value = 0.85
#  	 Flagging column 284
#  Combination row 36 and column 284 is above the cut-off, value = 0.776
#  	 Flagging column 36
#  Combination row 38 and column 284 is above the cut-off, value = 0.835
#  	 Flagging column 38
#  Combination row 63 and column 284 is above the cut-off, value = 0.861
#  	 Flagging column 63
#  Combination row 156 and column 284 is above the cut-off, value = 0.798
#  	 Flagging column 156
#  Combination row 158 and column 284 is above the cut-off, value = 0.801
#  	 Flagging column 158
#  Combination row 161 and column 284 is above the cut-off, value = 0.763
#  	 Flagging column 284
#  Combination row 182 and column 284 is above the cut-off, value = 0.77
#  	 Flagging column 284
#  Combination row 187 and column 284 is above the cut-off, value = 0.853
#  	 Flagging column 284
#  Combination row 193 and column 284 is above the cut-off, value = 0.773
#  	 Flagging column 284
#  Combination row 196 and column 284 is above the cut-off, value = 0.793
#  	 Flagging column 196
#  Combination row 202 and column 284 is above the cut-off, value = 0.807
#  	 Flagging column 202
#  Combination row 203 and column 284 is above the cut-off, value = 0.826
#  	 Flagging column 203
#  Combination row 212 and column 284 is above the cut-off, value = 0.766
#  	 Flagging column 284
#  Combination row 221 and column 284 is above the cut-off, value = 0.763
#  	 Flagging column 221
#  Combination row 266 and column 284 is above the cut-off, value = 0.806
#  	 Flagging column 266
#  Combination row 16 and column 291 is above the cut-off, value = 0.809
#  	 Flagging column 16
#  Combination row 31 and column 291 is above the cut-off, value = 0.859
#  	 Flagging column 31
#  Combination row 32 and column 291 is above the cut-off, value = 0.833
#  	 Flagging column 291
#  Combination row 36 and column 291 is above the cut-off, value = 0.785
#  	 Flagging column 36
#  Combination row 63 and column 291 is above the cut-off, value = 0.816
#  	 Flagging column 63
#  Combination row 129 and column 291 is above the cut-off, value = 0.78
#  	 Flagging column 129
#  Combination row 156 and column 291 is above the cut-off, value = 0.755
#  	 Flagging column 291
#  Combination row 182 and column 291 is above the cut-off, value = 0.775
#  	 Flagging column 291
#  Combination row 184 and column 291 is above the cut-off, value = 0.782
#  	 Flagging column 291
#  Combination row 187 and column 291 is above the cut-off, value = 0.803
#  	 Flagging column 291
#  Combination row 196 and column 291 is above the cut-off, value = 0.788
#  	 Flagging column 196
#  Combination row 197 and column 291 is above the cut-off, value = 0.839
#  	 Flagging column 197
#  Combination row 202 and column 291 is above the cut-off, value = 0.839
#  	 Flagging column 202
#  Combination row 203 and column 291 is above the cut-off, value = 0.855
#  	 Flagging column 203
#  Combination row 221 and column 291 is above the cut-off, value = 0.755
#  	 Flagging column 221
# ...
#  	 Flagging column 646
#  Combination row 399 and column 646 is above the cut-off, value = 0.806
#  	 Flagging column 399
#  Combination row 409 and column 646 is above the cut-off, value = 0.844
#  	 Flagging column 409
#  Combination row 417 and column 646 is above the cut-off, value = 0.771
#  	 Flagging column 417
#  Combination row 421 and column 646 is above the cut-off, value = 0.769
#  	 Flagging column 421
#  Combination row 434 and column 646 is above the cut-off, value = 0.769
#  	 Flagging column 434
#  Combination row 435 and column 646 is above the cut-off, value = 0.763
#  	 Flagging column 435
#  Combination row 459 and column 646 is above the cut-off, value = 0.78
#  	 Flagging column 459
#  Combination row 469 and column 646 is above the cut-off, value = 0.796
#  	 Flagging column 469
#  Combination row 470 and column 646 is above the cut-off, value = 0.865
#  	 Flagging column 470
#  Combination row 483 and column 646 is above the cut-off, value = 0.763
#  	 Flagging column 483
#  Combination row 501 and column 646 is above the cut-off, value = 0.863
#  	 Flagging column 501
#  Combination row 511 and column 646 is above the cut-off, value = 0.75
#  	 Flagging column 511
#  Combination row 557 and column 646 is above the cut-off, value = 0.772
#  	 Flagging column 646
#  Combination row 567 and column 646 is above the cut-off, value = 0.802
#  	 Flagging column 567
#  Combination row 569 and column 646 is above the cut-off, value = 0.82
#  	 Flagging column 569
#  Combination row 570 and column 646 is above the cut-off, value = 0.812
#  	 Flagging column 570
#  Combination row 597 and column 646 is above the cut-off, value = 0.783
#  	 Flagging column 597
#  Combination row 603 and column 646 is above the cut-off, value = 0.818
#  	 Flagging column 603
#  Combination row 605 and column 646 is above the cut-off, value = 0.794
#  	 Flagging column 605
#  Combination row 608 and column 646 is above the cut-off, value = 0.832
#  	 Flagging column 608
#  Combination row 38 and column 648 is above the cut-off, value = 0.752
#  	 Flagging column 38
#  Combination row 52 and column 648 is above the cut-off, value = 0.766
#  	 Flagging column 52
#  Combination row 193 and column 648 is above the cut-off, value = 0.796
#  	 Flagging column 193
#  Combination row 326 and column 648 is above the cut-off, value = 0.779
#  	 Flagging column 326
#  Combination row 366 and column 648 is above the cut-off, value = 0.766
#  	 Flagging column 648
#  Combination row 596 and column 648 is above the cut-off, value = 0.804
#  	 Flagging column 596
#  Combination row 16 and column 651 is above the cut-off, value = 0.751
#  	 Flagging column 651
#  Combination row 24 and column 651 is above the cut-off, value = 0.778
#  	 Flagging column 651
#  Combination row 25 and column 651 is above the cut-off, value = 0.799
#  	 Flagging column 651
#  Combination row 31 and column 651 is above the cut-off, value = 0.787
#  	 Flagging column 651
#  Combination row 32 and column 651 is above the cut-off, value = 0.751
#  	 Flagging column 651
#  Combination row 36 and column 651 is above the cut-off, value = 0.828
#  	 Flagging column 651
#  Combination row 38 and column 651 is above the cut-off, value = 0.824
#  	 Flagging column 651
#  Combination row 52 and column 651 is above the cut-off, value = 0.754
#  	 Flagging column 651
#  Combination row 56 and column 651 is above the cut-off, value = 0.753
#  	 Flagging column 651
#  Combination row 63 and column 651 is above the cut-off, value = 0.776
#  	 Flagging column 651
#  Combination row 85 and column 651 is above the cut-off, value = 0.772
#  	 Flagging column 651
#  Combination row 115 and column 651 is above the cut-off, value = 0.784
#  	 Flagging column 651
#  Combination row 129 and column 651 is above the cut-off, value = 0.818
#  	 Flagging column 129
#  Combination row 156 and column 651 is above the cut-off, value = 0.785
#  	 Flagging column 651
#  Combination row 184 and column 651 is above the cut-off, value = 0.752
#  	 Flagging column 651
#  Combination row 193 and column 651 is above the cut-off, value = 0.795
#  	 Flagging column 651
#  Combination row 196 and column 651 is above the cut-off, value = 0.808
#  	 Flagging column 196
#  Combination row 197 and column 651 is above the cut-off, value = 0.784
#  	 Flagging column 651
#  Combination row 203 and column 651 is above the cut-off, value = 0.817
#  	 Flagging column 203
#  Combination row 207 and column 651 is above the cut-off, value = 0.756
#  	 Flagging column 651
#  Combination row 221 and column 651 is above the cut-off, value = 0.842
#  	 Flagging column 221
#  Combination row 232 and column 651 is above the cut-off, value = 0.81
#  	 Flagging column 651
#  Combination row 243 and column 651 is above the cut-off, value = 0.832
#  	 Flagging column 243
#  Combination row 246 and column 651 is above the cut-off, value = 0.803
#  	 Flagging column 246
#  Combination row 266 and column 651 is above the cut-off, value = 0.767
#  	 Flagging column 651
#  Combination row 271 and column 651 is above the cut-off, value = 0.766
#  	 Flagging column 651
#  Combination row 291 and column 651 is above the cut-off, value = 0.762
#  	 Flagging column 651
#  Combination row 296 and column 651 is above the cut-off, value = 0.883
#  	 Flagging column 296
#  Combination row 301 and column 651 is above the cut-off, value = 0.814
#  	 Flagging column 651
#  Combination row 305 and column 651 is above the cut-off, value = 0.843
#  	 Flagging column 651
#  Combination row 326 and column 651 is above the cut-off, value = 0.856
#  	 Flagging column 651
#  Combination row 346 and column 651 is above the cut-off, value = 0.831
#  	 Flagging column 651
#  Combination row 347 and column 651 is above the cut-off, value = 0.755
#  	 Flagging column 651
#  Combination row 371 and column 651 is above the cut-off, value = 0.781
#  	 Flagging column 651
#  Combination row 374 and column 651 is above the cut-off, value = 0.753
#  	 Flagging column 651
#  Combination row 378 and column 651 is above the cut-off, value = 0.76
#  	 Flagging column 651
#  Combination row 399 and column 651 is above the cut-off, value = 0.886
#  	 Flagging column 399
#  Combination row 432 and column 651 is above the cut-off, value = 0.759
#  	 Flagging column 651
#  Combination row 434 and column 651 is above the cut-off, value = 0.792
#  	 Flagging column 651
#  Combination row 435 and column 651 is above the cut-off, value = 0.752
#  	 Flagging column 651
#  Combination row 441 and column 651 is above the cut-off, value = 0.755
#  	 Flagging column 651
#  Combination row 469 and column 651 is above the cut-off, value = 0.87
#  	 Flagging column 469
#  Combination row 470 and column 651 is above the cut-off, value = 0.757
#  	 Flagging column 470
#  Combination row 490 and column 651 is above the cut-off, value = 0.782
#  	 Flagging column 651
#  Combination row 494 and column 651 is above the cut-off, value = 0.8
#  	 Flagging column 651
#  Combination row 511 and column 651 is above the cut-off, value = 0.835
#  	 Flagging column 511
#  Combination row 565 and column 651 is above the cut-off, value = 0.757
#  	 Flagging column 651
#  Combination row 567 and column 651 is above the cut-off, value = 0.772
#  	 Flagging column 651
#  Combination row 570 and column 651 is above the cut-off, value = 0.769
#  	 Flagging column 651
#  Combination row 596 and column 651 is above the cut-off, value = 0.75
#  	 Flagging column 651
#  Combination row 601 and column 651 is above the cut-off, value = 0.799
#  	 Flagging column 651
#  Combination row 608 and column 651 is above the cut-off, value = 0.755
#  	 Flagging column 608
#  Combination row 633 and column 651 is above the cut-off, value = 0.847
#  	 Flagging column 651
#  Combination row 641 and column 651 is above the cut-off, value = 0.8
#  	 Flagging column 651
#  Combination row 642 and column 651 is above the cut-off, value = 0.803
#  	 Flagging column 651
#  Combination row 16 and column 655 is above the cut-off, value = 0.789
#  	 Flagging column 16
#  Combination row 26 and column 655 is above the cut-off, value = 0.784
#  	 Flagging column 26
#  Combination row 68 and column 655 is above the cut-off, value = 0.772
#  	 Flagging column 68
#  Combination row 184 and column 655 is above the cut-off, value = 0.795
#  	 Flagging column 184
#  Combination row 197 and column 655 is above the cut-off, value = 0.796
#  	 Flagging column 197
#  Combination row 203 and column 655 is above the cut-off, value = 0.754
#  	 Flagging column 203
#  Combination row 364 and column 655 is above the cut-off, value = 0.774
#  	 Flagging column 364
#  Combination row 375 and column 655 is above the cut-off, value = 0.838
#  	 Flagging column 375
#  Combination row 377 and column 655 is above the cut-off, value = 0.78
#  	 Flagging column 377
#  Combination row 378 and column 655 is above the cut-off, value = 0.785
#  	 Flagging column 378
#  Combination row 415 and column 655 is above the cut-off, value = 0.806
#  	 Flagging column 415
#  Combination row 421 and column 655 is above the cut-off, value = 0.761
#  	 Flagging column 421
#  Combination row 501 and column 655 is above the cut-off, value = 0.76
#  	 Flagging column 501
#  Combination row 570 and column 655 is above the cut-off, value = 0.778
#  	 Flagging column 570
#  Combination row 492 and column 656 is above the cut-off, value = 0.821
#  	 Flagging column 656
#  Combination row 615 and column 656 is above the cut-off, value = 0.802
#  	 Flagging column 656
#  Combination row 19 and column 665 is above the cut-off, value = 0.792
#  	 Flagging column 665
#  Combination row 24 and column 665 is above the cut-off, value = 0.801
#  	 Flagging column 665
#  Combination row 25 and column 665 is above the cut-off, value = 0.757
#  	 Flagging column 665
#  Combination row 38 and column 665 is above the cut-off, value = 0.82
#  	 Flagging column 38
#  Combination row 63 and column 665 is above the cut-off, value = 0.804
#  	 Flagging column 63
#  Combination row 156 and column 665 is above the cut-off, value = 0.78
#  	 Flagging column 156
#  Combination row 158 and column 665 is above the cut-off, value = 0.791
#  	 Flagging column 158
#  Combination row 161 and column 665 is above the cut-off, value = 0.75
#  	 Flagging column 665
#  Combination row 196 and column 665 is above the cut-off, value = 0.764
#  	 Flagging column 196
#  Combination row 239 and column 665 is above the cut-off, value = 0.751
#  	 Flagging column 239
#  Combination row 266 and column 665 is above the cut-off, value = 0.779
#  	 Flagging column 266
#  Combination row 284 and column 665 is above the cut-off, value = 0.783
#  	 Flagging column 284
#  Combination row 296 and column 665 is above the cut-off, value = 0.767
#  	 Flagging column 296
#  Combination row 305 and column 665 is above the cut-off, value = 0.824
#  	 Flagging column 305
#  Combination row 326 and column 665 is above the cut-off, value = 0.751
#  	 Flagging column 326
#  Combination row 347 and column 665 is above the cut-off, value = 0.781
#  	 Flagging column 347
#  Combination row 371 and column 665 is above the cut-off, value = 0.761
#  	 Flagging column 665
#  Combination row 399 and column 665 is above the cut-off, value = 0.777
#  	 Flagging column 399
#  Combination row 434 and column 665 is above the cut-off, value = 0.78
#  	 Flagging column 434
#  Combination row 441 and column 665 is above the cut-off, value = 0.755
#  	 Flagging column 665
#  Combination row 469 and column 665 is above the cut-off, value = 0.808
#  	 Flagging column 469
#  Combination row 490 and column 665 is above the cut-off, value = 0.817
#  	 Flagging column 490
#  Combination row 516 and column 665 is above the cut-off, value = 0.829
#  	 Flagging column 665
#  Combination row 565 and column 665 is above the cut-off, value = 0.808
#  	 Flagging column 565
#  Combination row 642 and column 665 is above the cut-off, value = 0.814
#  	 Flagging column 642
#  Combination row 492 and column 669 is above the cut-off, value = 0.763
#  	 Flagging column 669
#  Combination row 615 and column 669 is above the cut-off, value = 0.772
#  	 Flagging column 615
#  Combination row 656 and column 669 is above the cut-off, value = 0.788
#  	 Flagging column 656
#  Combination row 16 and column 670 is above the cut-off, value = 0.806
#  	 Flagging column 16
#  Combination row 31 and column 670 is above the cut-off, value = 0.809
#  	 Flagging column 31
#  Combination row 32 and column 670 is above the cut-off, value = 0.755
#  	 Flagging column 670
#  Combination row 63 and column 670 is above the cut-off, value = 0.773
#  	 Flagging column 63
#  Combination row 129 and column 670 is above the cut-off, value = 0.791
#  	 Flagging column 129
#  Combination row 131 and column 670 is above the cut-off, value = 0.796
#  	 Flagging column 670
#  Combination row 147 and column 670 is above the cut-off, value = 0.772
#  	 Flagging column 670
#  Combination row 182 and column 670 is above the cut-off, value = 0.843
#  	 Flagging column 670
#  Combination row 184 and column 670 is above the cut-off, value = 0.75
#  	 Flagging column 184
#  Combination row 187 and column 670 is above the cut-off, value = 0.75
#  	 Flagging column 670
#  Combination row 197 and column 670 is above the cut-off, value = 0.81
#  	 Flagging column 197
#  Combination row 202 and column 670 is above the cut-off, value = 0.855
#  	 Flagging column 202
#  Combination row 203 and column 670 is above the cut-off, value = 0.79
#  	 Flagging column 203
#  Combination row 212 and column 670 is above the cut-off, value = 0.79
#  	 Flagging column 670
#  Combination row 243 and column 670 is above the cut-off, value = 0.756
#  	 Flagging column 243
#  Combination row 291 and column 670 is above the cut-off, value = 0.781
#  	 Flagging column 291
#  Combination row 304 and column 670 is above the cut-off, value = 0.75
#  	 Flagging column 670
#  Combination row 320 and column 670 is above the cut-off, value = 0.757
#  	 Flagging column 670
#  Combination row 338 and column 670 is above the cut-off, value = 0.81
#  	 Flagging column 670
#  Combination row 364 and column 670 is above the cut-off, value = 0.802
#  	 Flagging column 364
#  Combination row 375 and column 670 is above the cut-off, value = 0.769
#  	 Flagging column 375
#  Combination row 377 and column 670 is above the cut-off, value = 0.803
#  	 Flagging column 377
#  Combination row 379 and column 670 is above the cut-off, value = 0.752
#  	 Flagging column 670
#  Combination row 399 and column 670 is above the cut-off, value = 0.795
#  	 Flagging column 399
#  Combination row 402 and column 670 is above the cut-off, value = 0.785
#  	 Flagging column 670
#  Combination row 409 and column 670 is above the cut-off, value = 0.767
#  	 Flagging column 670
#  Combination row 421 and column 670 is above the cut-off, value = 0.767
#  	 Flagging column 421
#  Combination row 459 and column 670 is above the cut-off, value = 0.801
#  	 Flagging column 670
#  Combination row 470 and column 670 is above the cut-off, value = 0.858
#  	 Flagging column 470
#  Combination row 486 and column 670 is above the cut-off, value = 0.75
#  	 Flagging column 670
#  Combination row 501 and column 670 is above the cut-off, value = 0.773
#  	 Flagging column 501
#  Combination row 511 and column 670 is above the cut-off, value = 0.752
#  	 Flagging column 511
#  Combination row 527 and column 670 is above the cut-off, value = 0.761
#  	 Flagging column 670
#  Combination row 539 and column 670 is above the cut-off, value = 0.768
#  	 Flagging column 670
#  Combination row 557 and column 670 is above the cut-off, value = 0.755
#  	 Flagging column 670
#  Combination row 567 and column 670 is above the cut-off, value = 0.799
#  	 Flagging column 567
#  Combination row 569 and column 670 is above the cut-off, value = 0.79
#  	 Flagging column 569
#  Combination row 570 and column 670 is above the cut-off, value = 0.819
#  	 Flagging column 570
#  Combination row 608 and column 670 is above the cut-off, value = 0.779
#  	 Flagging column 608
#  Combination row 646 and column 670 is above the cut-off, value = 0.759
#  	 Flagging column 670

# %% [markdown]
# ## Look for linear dependencies
# The function findLinearCombos uses the QR decomposition of a matrix to enumerate sets of linear combinations (if they exist).
# QR decomposition is a decomposition of a matrix A into a product A = QR of an orthogonal matrix Q and an upper triangular matrix R. QR decomposition is the basis for a particular eigenvalue algorithm, the QR algorithm.

# %%
tmp <- expr_rmcorr[, 3:ncol(expr_rmcorr)]
tmp[is.na(tmp)] <- 0
comboInfo <- findLinearCombos(tmp) 
rmLnCmb <- colnames(tmp[,comboInfo$remove])
expr_rmLnCmb <- expr_rmcorr[,-which(colnames(expr_rmcorr) %in% rmLnCmb)]
cat("Started with dimension = ", dim(expression), "\n")
cat("Post 50% NA filtering in rows and columns the dimension is", dim(expr_filtered), "\n")
cat("Post filtering highly correlated columns the dimension is", dim(expr_rmcorr), "\n")
cat("Post removing linearly dependent columns the dimension is", dim(expr_rmLnCmb))
# Out:
# Started with dimension =  204 676
# Post 50% NA filtering in rows and columns the dimension is 161 676
# Post filtering highly correlated columns the dimension is 161 495
# Post removing linearly dependent columns the dimension is 161 158

# %% [markdown]
# # Feature Selection

# %% [markdown]
# `How does var imp work, significance?`<br>
# For classification, ROC curve analysis is conducted on each predictor. For two class problems, a series of cutoffs is applied to the predictor data to predict the class. The sensitivity and specificity are computed for each cutoff and the ROC curve is computed. The trapezoidal rule is used to compute the area under the ROC curve. This area is used as the measure of variable importance.

# %%
# define a resampling approach for caret where data is divided into 8 random subsets and prediction is done on 
# 1 using the remaining 7. This approach is repeated thrice
control <- trainControl(method="repeatedcv", number=8, repeats=3)
mod_inp_mat <- expr_rmLnCmb[, 2:ncol(expr_rmLnCmb)]
mod_inp_mat$Response <- as.factor(mod_inp_mat$Response)

# %% [markdown]
# ## glmNet

# %%
m.glm <- train(Response~., data=mod_inp_mat, 
                  method="glmnet", 
                  trControl=control,
                  preProcess = c("scale", "center"),
                  na.action = na.omit
                 )

# %%
# estimate variable importance
glm.imp <- varImp(m.glm, scale=TRUE)$importance
rownames(glm.imp) <- gsub("`", "", rownames(glm.imp))
glm.imp$Name <- rownames(glm.imp)
# summarize importance
glm.imp <- glm.imp[order(glm.imp$Overall, decreasing=TRUE),]
# glm.imp <- glm.imp[1:50, ]
head(glm.imp)
# Out:
#       Overall   Name
# 2919  100.00000 2919
# 54209  98.63124 54209
# 6374   95.00456 6374
# 1191   89.85806 1191
# 4772   75.65299 4772
# 3673   67.93972 3673

# %% [markdown]
# ## Random Forest
# A Random Forest is an ensemble technique capable of performing both regression and classification tasks with the use of multiple decision trees and a technique called Bootstrap and Aggregation, commonly known as bagging. The basic idea behind this is to combine multiple decision trees in determining the final output rather than relying on individual decision trees.

# %%
m.rf <- train(Response~., data=mod_inp_mat, 
              method="rf", 
              trControl=control,
              preProcess = c("scale", "center"),
              na.action = na.omit)

# %%
# estimate variable importance
rf.imp <- varImp(m.rf, scale=TRUE)$importance
rownames(rf.imp) <- gsub("`", "", rownames(rf.imp))
rf.imp$Name <- rownames(rf.imp)
# summarize importance
rf.imp <- rf.imp[order(rf.imp$Overall, decreasing=TRUE),]
# rf.imp <- rf.imp[1:50, ]
head(rf.imp)
# Out:
#       Overall   Name
# 6504  100.00000 6504
# 3458   99.96209 3458
# 91949  54.09034 91949
# 51348  53.38179 51348
# 29851  50.98084 29851
# 3556   50.17056 3556

# %% [markdown]
# ## SVM
# Support vector machines (SVMs) are a set of supervised learning methods used for classification, regression and outliers detection.
#
# It's advantageous in this case because:<br>
# 1) Effective in high dimensional spaces. <br>
# 2) Still effective in cases where number of dimensions is greater than the number of samples.

# %%
m.svm <- train(Response~., data=mod_inp_mat, 
                  method="svmLinear2", 
                  trControl=control,
                  preProcess = c("scale", "center"),
                  na.action = na.omit
                 )

# %%
# estimate variable importance
svm.imp <- varImp(m.svm, scale=TRUE)$importance
svm.imp$Name <- rownames(svm.imp)
# summarize importance
svm.imp <- svm.imp[order(svm.imp$X0, decreasing=TRUE),]
# svm.imp <- svm.imp[1:50, ]
head(svm.imp)
# Out:
#       X0        X1        Name
# 6504  100.00000 100.00000 6504
# 3458   87.24062  87.24062 3458
# 29851  82.38411  82.38411 29851
# 7128   78.05740  78.05740 7128
# 4210   72.75938  72.75938 4210
# 1493   71.39073  71.39073 1493

# %% [markdown]
# ## Multi layer perceptron (Neural Network)
# A multilayer perceptron is a class of feedforward artificial neural network.

# %%
modelLookup('mlp')
# Out:
#   model parameter label         forReg forClass probModel
# 1 mlp   size      #Hidden Units TRUE   TRUE     TRUE

# %%
m.mlp <- train(Response~., data=mod_inp_mat, 
                  method="mlp", 
                  trControl=control,
                  preProcess = c("scale", "center"),
                  na.action = na.omit
                 )

# %%
# estimate variable importance
mlp.imp <- varImp(m.svm, scale=TRUE)$importance
mlp.imp$Name <- rownames(mlp.imp)
# summarize importance
mlp.imp <- mlp.imp[order(mlp.imp$X0, decreasing=TRUE),]
# mlp.imp <- mlp.imp[1:50, ]
head(mlp.imp)
# Out:
#       X0        X1        Name
# 6504  100.00000 100.00000 6504
# 3458   87.24062  87.24062 3458
# 29851  82.38411  82.38411 29851
# 7128   78.05740  78.05740 7128
# 4210   72.75938  72.75938 4210
# 1493   71.39073  71.39073 1493

# %% [markdown]
# ## Neural Network

# %%
m.nnet <- train(Response~., data=mod_inp_mat, 
                  method="nnet", 
                  trControl=control,
                  preProcess = c("scale", "center"),
                  na.action = na.omit
                 )
# Out:
# # weights:  159
# initial  value 101.422294
# iter  10 value 70.226942
# iter  20 value 55.793927
# iter  30 value 53.079476
# iter  40 value 52.195749
# iter  50 value 48.714206
# iter  60 value 46.929791
# iter  70 value 46.925211
# iter  80 value 44.508380
# iter  90 value 44.505498
# iter 100 value 44.503968
# final  value 44.503968
# stopped after 100 iterations
# # weights:  475
# initial  value 126.565336
# iter  10 value 61.506956
# iter  20 value 29.407147
# iter  30 value 16.109846
# iter  40 value 15.466697
# iter  50 value 13.186229
# iter  60 value 13.112128
# iter  70 value 13.076900
# iter  80 value 12.559961
# iter  90 value 12.439714
# iter 100 value 12.294200
# final  value 12.294200
# stopped after 100 iterations
# # weights:  791
# initial  value 92.593236
# iter  10 value 38.724690
# iter  20 value 21.558491
# iter  30 value 17.175724
# iter  40 value 14.917186
# iter  50 value 9.649096
# iter  60 value 6.531684
# iter  70 value 4.385181
# iter  80 value 4.028138
# iter  90 value 3.332541
# iter 100 value 3.301299
# final  value 3.301299
# stopped after 100 iterations
# # weights:  159
# initial  value 105.880082
# iter  10 value 71.176316
# iter  20 value 55.853016
# iter  30 value 45.072277
# iter  40 value 40.164333
# iter  50 value 36.493501
# iter  60 value 29.713662
# iter  70 value 27.197936
# iter  80 value 26.957741
# iter  90 value 26.875557
# iter 100 value 26.869227
# final  value 26.869227
# stopped after 100 iterations
# # weights:  475
# initial  value 109.813601
# iter  10 value 66.891237
# iter  20 value 43.945091
# iter  30 value 29.679909
# iter  40 value 19.865400
# iter  50 value 15.626361
# iter  60 value 15.094726
# iter  70 value 14.697125
# iter  80 value 14.283268
# iter  90 value 14.178559
# iter 100 value 14.020508
# final  value 14.020508
# stopped after 100 iterations
# # weights:  791
# initial  value 118.669041
# iter  10 value 65.631036
# iter  20 value 35.266502
# iter  30 value 22.460957
# iter  40 value 17.287530
# iter  50 value 14.948069
# iter  60 value 13.968019
# iter  70 value 13.447337
# iter  80 value 12.908872
# iter  90 value 12.461527
# iter 100 value 12.290279
# final  value 12.290279
# stopped after 100 iterations
# # weights:  159
# initial  value 93.179771
# iter  10 value 78.971469
# iter  20 value 63.782063
# iter  30 value 60.918879
# iter  40 value 58.385485
# iter  50 value 54.795747
# iter  60 value 52.481513
# iter  70 value 50.530299
# iter  80 value 50.507518
# iter  90 value 50.498669
# iter 100 value 50.476339
# final  value 50.476339
# stopped after 100 iterations
# # weights:  475
# initial  value 93.859188
# iter  10 value 58.767518
# iter  20 value 29.891060
# iter  30 value 25.637856
# iter  40 value 19.160813
# iter  50 value 17.524621
# iter  60 value 17.330568
# iter  70 value 17.117017
# iter  80 value 16.946705
# iter  90 value 16.936364
# iter 100 value 16.681077
# final  value 16.681077
# stopped after 100 iterations
# # weights:  791
# initial  value 100.584365
# iter  10 value 37.989273
# iter  20 value 13.320943
# iter  30 value 11.428493
# iter  40 value 11.355347
# iter  50 value 11.254647
# iter  60 value 10.308309
# iter  70 value 9.967878
# iter  80 value 9.921456
# iter  90 value 8.330205
# iter 100 value 8.313099
# final  value 8.313099
# stopped after 100 iterations
# # weights:  159
# initial  value 99.965596
# iter  10 value 76.862075
# iter  20 value 62.966340
# iter  30 value 54.366165
# iter  40 value 48.938177
# iter  50 value 46.554117
# iter  60 value 46.482372
# iter  70 value 46.478737
# iter  80 value 46.455123
# iter  90 value 43.929663
# iter 100 value 43.926991
# final  value 43.926991
# stopped after 100 iterations
# # weights:  475
# initial  value 97.320161
# iter  10 value 43.298379
# iter  20 value 28.337049
# iter  30 value 25.729357
# iter  40 value 22.672949
# iter  50 value 22.448335
# iter  60 value 22.399477
# iter  70 value 21.739551
# iter  80 value 20.932359
# iter  90 value 20.903050
# iter 100 value 20.712377
# final  value 20.712377
# stopped after 100 iterations
# # weights:  791
# initial  value 100.953248
# iter  10 value 42.012793
# iter  20 value 19.605829
# iter  30 value 18.175355
# iter  40 value 17.684935
# iter  50 value 17.451111
# iter  60 value 17.180035
# iter  70 value 16.661341
# iter  80 value 12.814246
# iter  90 value 12.802095
# iter 100 value 12.745086
# final  value 12.745086
# stopped after 100 iterations
# # weights:  159
# initial  value 108.235479
# iter  10 value 73.833879
# iter  20 value 54.347483
# iter  30 value 48.093673
# iter  40 value 38.590809
# iter  50 value 32.248019
# iter  60 value 29.371335
# iter  70 value 26.789043
# iter  80 value 26.274216
# iter  90 value 26.245355
# iter 100 value 26.245086
# final  value 26.245086
# stopped after 100 iterations
# # weights:  475
# initial  value 110.143990
# iter  10 value 65.340956
# iter  20 value 42.624036
# iter  30 value 21.693586
# iter  40 value 16.407675
# iter  50 value 14.762590
# iter  60 value 14.374514
# iter  70 value 14.128807
# iter  80 value 14.064869
# iter  90 value 13.963870
# iter 100 value 13.907057
# final  value 13.907057
# stopped after 100 iterations
# # weights:  791
# initial  value 111.237743
# iter  10 value 58.647205
# iter  20 value 26.715828
# iter  30 value 16.346688
# iter  40 value 14.435552
# iter  50 value 13.407564
# iter  60 value 13.018783
# iter  70 value 12.724271
# iter  80 value 12.687828
# iter  90 value 12.642354
# iter 100 value 12.570102
# final  value 12.570102
# stopped after 100 iterations
# # weights:  159
# initial  value 94.552228
# iter  10 value 72.287222
# iter  20 value 59.668596
# iter  30 value 54.829311
# iter  40 value 53.010261
# iter  50 value 50.578137
# iter  60 value 50.529194
# iter  70 value 50.522375
# iter  80 value 50.499886
# iter  90 value 49.083102
# iter 100 value 44.084282
# final  value 44.084282
# stopped after 100 iterations
# # weights:  475
# initial  value 124.324652
# iter  10 value 59.044901
# iter  20 value 37.545041
# iter  30 value 34.426207
# iter  40 value 29.944814
# iter  50 value 26.281965
# iter  60 value 25.999393
# iter  70 value 25.944227
# iter  80 value 25.647133
# iter  90 value 25.610777
# iter 100 value 25.345228
# final  value 25.345228
# stopped after 100 iterations
# # weights:  791
# initial  value 103.937298
# iter  10 value 27.108452
# iter  20 value 5.154359
# iter  30 value 1.872024
# iter  40 value 1.815746
# iter  50 value 1.792582
# iter  60 value 1.729779
# iter  70 value 1.703955
# iter  80 value 1.685971
# iter  90 value 1.669385
# iter 100 value 0.780262
# final  value 0.780262
# stopped after 100 iterations
# # weights:  159
# initial  value 100.619478
# iter  10 value 82.175192
# iter  20 value 58.174798
# iter  30 value 52.775403
# iter  40 value 46.414715
# iter  50 value 41.214830
# iter  60 value 40.786961
# iter  70 value 39.644931
# iter  80 value 39.642001
# iter  90 value 39.640754
# iter 100 value 38.061312
# final  value 38.061312
# stopped after 100 iterations
# # weights:  475
# initial  value 94.485744
# iter  10 value 53.254530
# iter  20 value 36.418900
# iter  30 value 34.142909
# iter  40 value 32.708969
# iter  50 value 32.062443
# iter  60 value 30.863364
# iter  70 value 30.028595
# iter  80 value 29.934597
# iter  90 value 29.866023
# iter 100 value 29.745781
# final  value 29.745781
# stopped after 100 iterations
# # weights:  791
# initial  value 129.419939
# iter  10 value 45.330088
# iter  20 value 23.287130
# iter  30 value 10.123846
# iter  40 value 9.407188
# iter  50 value 8.931989
# iter  60 value 8.862572
# iter  70 value 8.853412
# iter  80 value 8.801262
# iter  90 value 8.759356
# iter 100 value 8.749642
# final  value 8.749642
# stopped after 100 iterations
# # weights:  159
# initial  value 96.675096
# iter  10 value 71.929754
# iter  20 value 54.409262
# iter  30 value 41.022692
# iter  40 value 35.526257
# iter  50 value 29.876246
# iter  60 value 25.948341
# iter  70 value 25.428680
# iter  80 value 23.215598
# iter  90 value 22.776270
# iter 100 value 22.761589
# final  value 22.761589
# stopped after 100 iterations
# # weights:  475
# initial  value 116.489773
# iter  10 value 57.262917
# iter  20 value 35.627059
# iter  30 value 20.737406
# iter  40 value 15.717514
# iter  50 value 15.023553
# iter  60 value 14.238200
# iter  70 value 13.957527
# iter  80 value 13.758038
# iter  90 value 13.706019
# iter 100 value 13.667122
# final  value 13.667122
# stopped after 100 iterations
# # weights:  791
# initial  value 123.673860
# iter  10 value 60.066673
# iter  20 value 26.695118
# iter  30 value 18.064056
# iter  40 value 14.742835
# iter  50 value 13.751969
# iter  60 value 13.374052
# iter  70 value 13.271921
# iter  80 value 12.989100
# iter  90 value 12.661124
# iter 100 value 12.476734
# final  value 12.476734
# stopped after 100 iterations
# # weights:  159
# initial  value 112.570197
# iter  10 value 66.180304
# iter  20 value 51.498739
# iter  30 value 48.168693
# iter  40 value 46.617372
# iter  50 value 46.586678
# iter  60 value 46.579089
# iter  70 value 45.055951
# iter  80 value 45.052355
# iter  90 value 40.270770
# iter 100 value 40.232014
# final  value 40.232014
# stopped after 100 iterations
# # weights:  475
# initial  value 115.006020
# iter  10 value 50.790524
# iter  20 value 27.789454
# iter  30 value 20.156770
# iter  40 value 17.701877
# iter  50 value 16.991730
# iter  60 value 16.943347
# iter  70 value 16.621494
# iter  80 value 15.333528
# iter  90 value 14.765434
# iter 100 value 10.436841
# final  value 10.436841
# stopped after 100 iterations
# # weights:  791
# initial  value 102.370024
# iter  10 value 66.708662
# iter  20 value 27.103885
# iter  30 value 17.739423
# iter  40 value 11.400719
# iter  50 value 9.026958
# iter  60 value 5.087333
# iter  70 value 2.907593
# iter  80 value 2.426065
# iter  90 value 2.389998
# iter 100 value 2.384977
# final  value 2.384977
# stopped after 100 iterations
# # weights:  159
# initial  value 95.244893
# iter  10 value 80.921215
# iter  20 value 53.685388
# iter  30 value 50.196982
# iter  40 value 46.941030
# iter  50 value 45.486907
# iter  60 value 45.476678
# iter  70 value 45.472705
# iter  80 value 45.470953
# iter  90 value 45.470358
# iter 100 value 45.414827
# final  value 45.414827
# stopped after 100 iterations
# # weights:  475
# initial  value 126.279979
# iter  10 value 42.095379
# iter  20 value 28.583557
# iter  30 value 27.489910
# iter  40 value 27.370559
# iter  50 value 26.283049
# iter  60 value 24.707054
# iter  70 value 22.516353
# iter  80 value 22.321932
# iter  90 value 21.584759
# iter 100 value 21.514726
# final  value 21.514726
# stopped after 100 iterations
# # weights:  791
# initial  value 98.498650
# iter  10 value 42.299165
# iter  20 value 19.028606
# iter  30 value 14.383625
# iter  40 value 13.864245
# iter  50 value 13.707439
# iter  60 value 13.556133
# iter  70 value 13.293581
# iter  80 value 9.751519
# iter  90 value 7.415943
# iter 100 value 6.989122
# final  value 6.989122
# stopped after 100 iterations
# # weights:  159
# initial  value 129.171057
# iter  10 value 75.293606
# iter  20 value 59.703233
# iter  30 value 49.118572
# iter  40 value 40.779497
# iter  50 value 32.454142
# iter  60 value 28.839835
# iter  70 value 26.049212
# iter  80 value 25.652663
# iter  90 value 25.615238
# iter 100 value 25.613711
# final  value 25.613711
# stopped after 100 iterations
# # weights:  475
# initial  value 131.725568
# iter  10 value 73.250547
# iter  20 value 36.293339
# iter  30 value 25.169619
# iter  40 value 18.595135
# iter  50 value 15.153904
# iter  60 value 13.846707
# iter  70 value 13.478151
# iter  80 value 13.002209
# iter  90 value 12.931825
# iter 100 value 12.929752
# final  value 12.929752
# stopped after 100 iterations
# # weights:  791
# initial  value 120.668368
# iter  10 value 52.062431
# iter  20 value 30.324679
# iter  30 value 19.637335
# iter  40 value 13.835538
# iter  50 value 12.969493
# iter  60 value 12.599968
# iter  70 value 12.122395
# iter  80 value 12.058530
# iter  90 value 12.035164
# iter 100 value 12.021076
# final  value 12.021076
# stopped after 100 iterations
# # weights:  159
# initial  value 101.726779
# iter  10 value 63.790780
# iter  20 value 46.564791
# iter  30 value 32.763688
# iter  40 value 29.001848
# iter  50 value 24.867470
# iter  60 value 24.764689
# iter  70 value 24.758847
# iter  80 value 24.756787
# iter  90 value 24.755781
# iter 100 value 24.755091
# final  value 24.755091
# stopped after 100 iterations
# # weights:  475
# initial  value 98.452882
# iter  10 value 56.325077
# iter  20 value 31.430154
# iter  30 value 26.617166
# iter  40 value 22.410366
# iter  50 value 21.669861
# iter  60 value 21.474880
# iter  70 value 21.414759
# iter  80 value 21.332460
# iter  90 value 21.298964
# iter 100 value 21.264351
# final  value 21.264351
# stopped after 100 iterations
# # weights:  791
# initial  value 99.130073
# iter  10 value 52.978562
# iter  20 value 32.125128
# iter  30 value 27.295215
# iter  40 value 26.269891
# iter  50 value 26.096063
# iter  60 value 25.905995
# iter  70 value 24.928982
# iter  80 value 24.647597
# iter  90 value 21.298193
# iter 100 value 19.669017
# final  value 19.669017
# stopped after 100 iterations
# # weights:  159
# initial  value 94.913488
# iter  10 value 61.237397
# iter  20 value 59.375859
# iter  30 value 58.596925
# iter  40 value 58.125114
# iter  50 value 58.121484
# iter  60 value 58.120412
# iter  70 value 58.119460
# iter  80 value 56.932307
# iter  90 value 56.852658
# iter 100 value 56.851973
# final  value 56.851973
# stopped after 100 iterations
# # weights:  475
# initial  value 116.712444
# iter  10 value 63.127261
# iter  20 value 38.578426
# iter  30 value 35.089480
# iter  40 value 33.335628
# iter  50 value 30.942577
# iter  60 value 27.376853
# iter  70 value 25.533547
# iter  80 value 25.205001
# iter  90 value 25.069900
# iter 100 value 24.944201
# final  value 24.944201
# stopped after 100 iterations
# # weights:  791
# initial  value 121.934617
# iter  10 value 46.544096
# iter  20 value 26.855253
# iter  30 value 21.193924
# iter  40 value 20.641998
# iter  50 value 19.994647
# iter  60 value 19.814874
# iter  70 value 18.121239
# iter  80 value 15.404650
# iter  90 value 14.981386
# iter 100 value 11.113337
# final  value 11.113337
# stopped after 100 iterations
# # weights:  159
# initial  value 108.421449
# iter  10 value 74.539811
# iter  20 value 52.015148
# iter  30 value 41.362729
# iter  40 value 37.663422
# iter  50 value 31.922836
# iter  60 value 30.240681
# iter  70 value 29.706048
# iter  80 value 28.353142
# iter  90 value 25.485943
# iter 100 value 23.920721
# final  value 23.920721
# stopped after 100 iterations
# # weights:  475
# initial  value 128.502870
# iter  10 value 71.079467
# iter  20 value 43.167472
# iter  30 value 29.635904
# iter  40 value 18.927772
# iter  50 value 16.499666
# iter  60 value 14.540037
# iter  70 value 13.866211
# iter  80 value 13.803040
# iter  90 value 13.238176
# iter 100 value 13.095819
# final  value 13.095819
# stopped after 100 iterations
# # weights:  791
# initial  value 110.772867
# iter  10 value 70.821594
# iter  20 value 37.166228
# iter  30 value 18.760401
# iter  40 value 15.398615
# iter  50 value 14.164647
# iter  60 value 13.651084
# iter  70 value 12.532463
# iter  80 value 12.239252
# iter  90 value 12.153265
# iter 100 value 12.135093
# final  value 12.135093
# stopped after 100 iterations
# # weights:  159
# initial  value 104.573026
# iter  10 value 73.174694
# iter  20 value 54.692402
# iter  30 value 49.839693
# iter  40 value 49.706235
# iter  50 value 49.701724
# iter  60 value 49.699848
# iter  70 value 49.697198
# iter  80 value 49.694543
# iter  90 value 48.751883
# iter 100 value 44.717257
# final  value 44.717257
# stopped after 100 iterations
# # weights:  475
# initial  value 95.666710
# iter  10 value 47.138214
# iter  20 value 30.634362
# iter  30 value 26.546647
# iter  40 value 24.564990
# iter  50 value 23.609551
# iter  60 value 23.355085
# iter  70 value 23.104487
# iter  80 value 23.082864
# iter  90 value 18.868974
# iter 100 value 18.761404
# final  value 18.761404
# stopped after 100 iterations
# # weights:  791
# initial  value 103.511506
# iter  10 value 30.784938
# iter  20 value 17.675719
# iter  30 value 12.318132
# iter  40 value 10.206715
# iter  50 value 8.183316
# iter  60 value 5.958370
# iter  70 value 5.054681
# iter  80 value 4.107734
# iter  90 value 3.683896
# iter 100 value 3.481935
# final  value 3.481935
# stopped after 100 iterations
# # weights:  159
# initial  value 98.831990
# iter  10 value 76.988246
# iter  20 value 55.557526
# iter  30 value 54.120322
# iter  40 value 51.717475
# iter  50 value 51.700202
# iter  60 value 49.141060
# iter  70 value 49.107602
# iter  80 value 49.101342
# iter  90 value 49.098508
# iter 100 value 49.097045
# final  value 49.097045
# stopped after 100 iterations
# # weights:  475
# initial  value 93.486055
# iter  10 value 50.864858
# iter  20 value 41.122957
# iter  30 value 38.414179
# iter  40 value 37.467296
# iter  50 value 35.134027
# iter  60 value 34.525334
# iter  70 value 32.550411
# iter  80 value 31.697363
# iter  90 value 31.103353
# iter 100 value 30.872508
# final  value 30.872508
# stopped after 100 iterations
# # weights:  791
# initial  value 98.207101
# iter  10 value 30.877734
# iter  20 value 10.585569
# iter  30 value 9.307365
# iter  40 value 8.960706
# iter  50 value 7.585376
# iter  60 value 6.671963
# iter  70 value 6.580881
# iter  80 value 6.235640
# iter  90 value 6.061080
# iter 100 value 6.051306
# final  value 6.051306
# stopped after 100 iterations
# # weights:  159
# initial  value 95.306602
# iter  10 value 78.349538
# iter  20 value 55.941065
# iter  30 value 43.240237
# iter  40 value 36.017913
# iter  50 value 32.420946
# iter  60 value 31.725928
# iter  70 value 31.630600
# iter  80 value 31.616293
# iter  90 value 31.615521
# iter 100 value 31.615488
# final  value 31.615488
# stopped after 100 iterations
# # weights:  475
# initial  value 119.794582
# iter  10 value 64.316814
# iter  20 value 39.079022
# iter  30 value 26.906599
# iter  40 value 23.249200
# iter  50 value 18.448113
# iter  60 value 16.222505
# iter  70 value 15.187732
# iter  80 value 15.016026
# iter  90 value 14.865781
# iter 100 value 14.843421
# final  value 14.843421
# stopped after 100 iterations
# # weights:  791
# initial  value 117.898667
# iter  10 value 60.976366
# iter  20 value 28.679910
# iter  30 value 17.322199
# iter  40 value 15.026802
# iter  50 value 13.996508
# iter  60 value 13.525411
# iter  70 value 13.159504
# iter  80 value 12.973356
# iter  90 value 12.913128
# iter 100 value 12.908445
# final  value 12.908445
# stopped after 100 iterations
# # weights:  159
# initial  value 113.371700
# iter  10 value 65.214681
# iter  20 value 56.107798
# iter  30 value 52.160745
# iter  40 value 46.680407
# iter  50 value 46.347120
# iter  60 value 46.338163
# iter  70 value 46.332329
# iter  80 value 46.328534
# iter  90 value 46.323347
# iter 100 value 46.319393
# final  value 46.319393
# stopped after 100 iterations
# # weights:  475
# initial  value 101.402661
# iter  10 value 57.265762
# iter  20 value 30.706907
# iter  30 value 26.763348
# iter  40 value 25.732151
# iter  50 value 24.832676
# iter  60 value 23.523990
# iter  70 value 23.332341
# iter  80 value 23.295628
# iter  90 value 23.225298
# iter 100 value 23.148318
# final  value 23.148318
# stopped after 100 iterations
# # weights:  791
# initial  value 157.240061
# iter  10 value 48.234154
# iter  20 value 20.416828
# iter  30 value 12.982940
# iter  40 value 8.062539
# iter  50 value 7.970922
# iter  60 value 6.911281
# iter  70 value 6.294762
# iter  80 value 6.237117
# iter  90 value 6.227628
# iter 100 value 5.458402
# final  value 5.458402
# stopped after 100 iterations
# # weights:  159
# initial  value 130.525788
# iter  10 value 82.751076
# iter  20 value 66.910476
# iter  30 value 63.493236
# iter  40 value 59.740879
# iter  50 value 51.375908
# iter  60 value 50.678553
# iter  70 value 48.332235
# iter  80 value 45.792872
# iter  90 value 45.748439
# iter 100 value 43.999960
# final  value 43.999960
# stopped after 100 iterations
# # weights:  475
# initial  value 109.240160
# iter  10 value 62.934691
# iter  20 value 35.484772
# iter  30 value 24.842529
# iter  40 value 23.301709
# iter  50 value 22.755916
# iter  60 value 22.433527
# iter  70 value 22.313944
# iter  80 value 21.650307
# iter  90 value 15.962803
# iter 100 value 15.836281
# final  value 15.836281
# stopped after 100 iterations
# # weights:  791
# initial  value 94.756720
# iter  10 value 39.337981
# iter  20 value 21.869925
# iter  30 value 19.405051
# iter  40 value 15.352566
# iter  50 value 12.240305
# iter  60 value 11.140050
# iter  70 value 11.061839
# iter  80 value 10.870698
# iter  90 value 10.659247
# iter 100 value 10.130194
# final  value 10.130194
# stopped after 100 iterations
# # weights:  159
# initial  value 102.500791
# iter  10 value 79.154243
# iter  20 value 61.160566
# iter  30 value 49.992717
# iter  40 value 45.334122
# iter  50 value 40.370968
# iter  60 value 30.963088
# iter  70 value 27.743240
# iter  80 value 25.450559
# iter  90 value 22.634862
# iter 100 value 22.325645
# final  value 22.325645
# stopped after 100 iterations
# # weights:  475
# initial  value 105.562955
# iter  10 value 66.155335
# iter  20 value 39.971484
# iter  30 value 29.005961
# iter  40 value 22.854398
# iter  50 value 19.778900
# iter  60 value 18.805523
# iter  70 value 18.686935
# iter  80 value 17.838253
# iter  90 value 17.692461
# iter 100 value 17.358195
# final  value 17.358195
# stopped after 100 iterations
# # weights:  791
# initial  value 113.188815
# iter  10 value 61.292371
# iter  20 value 34.414486
# iter  30 value 20.157221
# iter  40 value 15.997281
# iter  50 value 14.879936
# iter  60 value 13.650285
# iter  70 value 13.266351
# iter  80 value 13.012302
# iter  90 value 12.903829
# iter 100 value 12.896682
# final  value 12.896682
# stopped after 100 iterations
# # weights:  159
# initial  value 95.354219
# iter  10 value 81.019138
# iter  20 value 68.004105
# iter  30 value 62.217579
# iter  40 value 62.152898
# iter  50 value 60.882885
# iter  60 value 60.877101
# iter  70 value 59.858744
# iter  80 value 56.515197
# iter  90 value 53.958089
# iter 100 value 53.543557
# final  value 53.543557
# stopped after 100 iterations
# # weights:  475
# initial  value 104.657344
# iter  10 value 57.198247
# iter  20 value 41.572862
# iter  30 value 37.039863
# iter  40 value 35.681077
# iter  50 value 34.338602
# iter  60 value 32.918856
# iter  70 value 32.867565
# iter  80 value 31.154166
# iter  90 value 30.770547
# iter 100 value 29.616165
# final  value 29.616165
# stopped after 100 iterations
# # weights:  791
# initial  value 98.532880
# iter  10 value 44.894859
# iter  20 value 18.685046
# iter  30 value 17.215581
# iter  40 value 14.803272
# iter  50 value 14.055189
# iter  60 value 12.906854
# iter  70 value 12.843966
# iter  80 value 10.841506
# iter  90 value 10.344588
# iter 100 value 10.218179
# final  value 10.218179
# stopped after 100 iterations
# # weights:  159
# initial  value 94.348311
# iter  10 value 66.067526
# iter  20 value 54.845476
# iter  30 value 52.814794
# iter  40 value 52.757948
# iter  50 value 47.219474
# iter  60 value 47.212402
# iter  70 value 47.211720
# iter  80 value 47.211553
# final  value 47.211408
# converged
# # weights:  475
# initial  value 98.292796
# iter  10 value 58.073188
# iter  20 value 28.040182
# iter  30 value 19.538246
# iter  40 value 14.687514
# iter  50 value 12.383894
# iter  60 value 11.178561
# iter  70 value 2.898094
# iter  80 value 2.101930
# iter  90 value 1.946772
# iter 100 value 1.913873
# final  value 1.913873
# stopped after 100 iterations
# # weights:  791
# initial  value 94.614322
# iter  10 value 29.508588
# iter  20 value 15.739240
# iter  30 value 14.223591
# iter  40 value 10.390176
# iter  50 value 9.980429
# iter  60 value 8.253246
# iter  70 value 6.219124
# iter  80 value 4.587233
# iter  90 value 4.413339
# iter 100 value 4.118403
# final  value 4.118403
# stopped after 100 iterations
# # weights:  159
# initial  value 106.784330
# iter  10 value 64.292217
# iter  20 value 37.651597
# iter  30 value 30.269060
# iter  40 value 27.170010
# iter  50 value 23.618660
# iter  60 value 22.542498
# iter  70 value 22.210632
# iter  80 value 22.202076
# iter  90 value 22.201872
# final  value 22.201870
# converged
# # weights:  475
# initial  value 110.205456
# iter  10 value 59.368594
# iter  20 value 36.935996
# iter  30 value 22.347494
# iter  40 value 16.042556
# iter  50 value 14.010516
# iter  60 value 13.674057
# iter  70 value 13.481709
# iter  80 value 13.027211
# iter  90 value 12.730489
# iter 100 value 12.327404
# final  value 12.327404
# stopped after 100 iterations
# # weights:  791
# initial  value 109.140110
# iter  10 value 51.519570
# iter  20 value 26.520601
# iter  30 value 15.958006
# iter  40 value 13.426452
# iter  50 value 12.484587
# iter  60 value 12.131507
# iter  70 value 11.684921
# iter  80 value 11.602820
# iter  90 value 11.526567
# iter 100 value 11.499775
# final  value 11.499775
# stopped after 100 iterations
# # weights:  159
# initial  value 97.423275
# iter  10 value 79.878358
# iter  20 value 54.520951
# iter  30 value 50.439397
# iter  40 value 48.837537
# iter  50 value 46.146046
# iter  60 value 44.690402
# iter  70 value 41.783380
# iter  80 value 41.640793
# iter  90 value 41.630622
# iter 100 value 39.829050
# final  value 39.829050
# stopped after 100 iterations
# # weights:  475
# initial  value 98.822529
# iter  10 value 54.449644
# iter  20 value 36.201042
# iter  30 value 28.729968
# iter  40 value 28.281271
# iter  50 value 27.059420
# iter  60 value 26.546281
# iter  70 value 25.964136
# iter  80 value 25.767656
# iter  90 value 25.610163
# iter 100 value 25.601412
# final  value 25.601412
# stopped after 100 iterations
# # weights:  791
# initial  value 110.151171
# iter  10 value 25.681095
# iter  20 value 5.680151
# iter  30 value 2.644090
# iter  40 value 2.334075
# iter  50 value 2.249565
# iter  60 value 2.202059
# iter  70 value 2.159857
# iter  80 value 2.140784
# iter  90 value 2.122651
# iter 100 value 2.101575
# final  value 2.101575
# stopped after 100 iterations
# # weights:  159
# initial  value 93.592342
# iter  10 value 89.425932
# iter  20 value 75.327450
# iter  30 value 71.525244
# iter  40 value 69.270778
# iter  50 value 63.850626
# iter  60 value 60.434712
# iter  70 value 57.189609
# iter  80 value 54.474834
# iter  90 value 37.077804
# iter 100 value 29.448091
# final  value 29.448091
# stopped after 100 iterations
# # weights:  475
# initial  value 112.337127
# iter  10 value 69.615965
# iter  20 value 33.253759
# iter  30 value 24.856909
# iter  40 value 24.062903
# iter  50 value 23.556237
# iter  60 value 23.410845
# iter  70 value 23.353054
# iter  80 value 23.256143
# iter  90 value 23.239140
# iter 100 value 23.212599
# final  value 23.212599
# stopped after 100 iterations
# # weights:  791
# initial  value 95.709797
# iter  10 value 46.816436
# iter  20 value 37.587062
# iter  30 value 36.657910
# iter  40 value 35.645048
# iter  50 value 30.829432
# iter  60 value 26.040526
# iter  70 value 25.922040
# iter  80 value 25.896836
# iter  90 value 25.686626
# iter 100 value 25.234501
# final  value 25.234501
# stopped after 100 iterations
# # weights:  159
# initial  value 110.305530
# iter  10 value 68.848392
# iter  20 value 46.008854
# iter  30 value 39.555818
# iter  40 value 36.288417
# iter  50 value 33.482179
# iter  60 value 32.727729
# iter  70 value 32.647032
# iter  80 value 32.644873
# iter  90 value 32.642795
# iter 100 value 30.508602
# final  value 30.508602
# stopped after 100 iterations
# # weights:  475
# initial  value 101.744874
# iter  10 value 68.746597
# iter  20 value 36.334953
# iter  30 value 25.756733
# iter  40 value 19.858529
# iter  50 value 17.530733
# iter  60 value 16.525628
# iter  70 value 16.258892
# iter  80 value 15.990159
# iter  90 value 15.717715
# iter 100 value 15.683739
# final  value 15.683739
# stopped after 100 iterations
# # weights:  791
# initial  value 112.485456
# iter  10 value 66.393934
# iter  20 value 33.162348
# iter  30 value 21.068388
# iter  40 value 15.784099
# iter  50 value 14.555985
# iter  60 value 13.916230
# iter  70 value 13.528492
# iter  80 value 13.427368
# iter  90 value 13.404763
# iter 100 value 13.385026
# final  value 13.385026
# stopped after 100 iterations
# # weights:  159
# initial  value 97.956446
# iter  10 value 58.178153
# iter  20 value 49.340523
# iter  30 value 47.772140
# iter  40 value 47.740492
# iter  50 value 47.732422
# iter  60 value 47.729885
# iter  70 value 47.727724
# iter  80 value 47.725603
# iter  90 value 47.721814
# iter 100 value 47.720160
# final  value 47.720160
# stopped after 100 iterations
# # weights:  475
# initial  value 102.705467
# iter  10 value 57.511064
# iter  20 value 27.877870
# iter  30 value 23.707261
# iter  40 value 22.198637
# iter  50 value 21.271133
# iter  60 value 20.646996
# iter  70 value 20.236544
# iter  80 value 20.016161
# iter  90 value 18.229492
# iter 100 value 18.110723
# final  value 18.110723
# stopped after 100 iterations
# # weights:  791
# initial  value 96.177827
# iter  10 value 43.287496
# iter  20 value 23.676454
# iter  30 value 19.824140
# iter  40 value 16.203381
# iter  50 value 12.308377
# iter  60 value 11.798049
# iter  70 value 10.250423
# iter  80 value 9.944851
# iter  90 value 9.888435
# iter 100 value 9.801277
# final  value 9.801277
# stopped after 100 iterations
# # weights:  159
# initial  value 112.518000
# iter  10 value 71.644801
# iter  20 value 38.219381
# iter  30 value 35.898124
# iter  40 value 34.355429
# iter  50 value 34.346508
# iter  60 value 32.755152
# iter  70 value 32.748406
# iter  80 value 32.748011
# iter  90 value 32.747484
# iter 100 value 32.744973
# final  value 32.744973
# stopped after 100 iterations
# # weights:  475
# initial  value 91.972905
# iter  10 value 49.957547
# iter  20 value 37.094866
# iter  30 value 32.687189
# iter  40 value 30.453292
# iter  50 value 27.336273
# iter  60 value 25.109218
# iter  70 value 23.666808
# iter  80 value 23.387322
# iter  90 value 23.036046
# iter 100 value 23.015137
# final  value 23.015137
# stopped after 100 iterations
# # weights:  791
# initial  value 103.420478
# iter  10 value 39.401833
# iter  20 value 18.416773
# iter  30 value 11.471077
# iter  40 value 10.982000
# iter  50 value 10.949207
# iter  60 value 10.903776
# iter  70 value 10.324061
# iter  80 value 10.300547
# iter  90 value 10.299755
# iter 100 value 10.299322
# final  value 10.299322
# stopped after 100 iterations
# # weights:  159
# initial  value 95.432736
# iter  10 value 65.040118
# iter  20 value 54.583712
# iter  30 value 47.952515
# iter  40 value 35.172566
# iter  50 value 31.714699
# iter  60 value 31.032527
# iter  70 value 31.018613
# iter  80 value 29.157578
# iter  90 value 28.727234
# iter 100 value 28.688846
# final  value 28.688846
# stopped after 100 iterations
# # weights:  475
# initial  value 109.033847
# iter  10 value 62.063059
# iter  20 value 36.413408
# iter  30 value 22.898940
# iter  40 value 17.970612
# iter  50 value 15.708079
# iter  60 value 15.122615
# iter  70 value 14.866901
# iter  80 value 14.739167
# iter  90 value 14.709498
# iter 100 value 14.702628
# final  value 14.702628
# stopped after 100 iterations
# # weights:  791
# initial  value 143.731037
# iter  10 value 62.578972
# iter  20 value 32.752812
# iter  30 value 18.880932
# iter  40 value 14.925549
# iter  50 value 13.748265
# iter  60 value 13.205117
# iter  70 value 12.874432
# iter  80 value 12.809083
# iter  90 value 12.765131
# iter 100 value 12.659906
# final  value 12.659906
# stopped after 100 iterations
# # weights:  159
# initial  value 94.494313
# iter  10 value 80.167743
# iter  20 value 66.887080
# iter  30 value 63.615407
# iter  40 value 61.454738
# iter  50 value 59.838348
# iter  60 value 59.799464
# iter  70 value 58.513067
# iter  80 value 55.741967
# iter  90 value 55.705368
# iter 100 value 55.702043
# final  value 55.702043
# stopped after 100 iterations
# # weights:  475
# initial  value 93.759421
# iter  10 value 57.018636
# iter  20 value 40.909136
# iter  30 value 30.713131
# iter  40 value 25.364523
# iter  50 value 22.759759
# iter  60 value 21.505473
# iter  70 value 20.360093
# iter  80 value 17.202845
# iter  90 value 16.797498
# iter 100 value 16.788326
# final  value 16.788326
# stopped after 100 iterations
# # weights:  791
# initial  value 110.618209
# iter  10 value 33.081724
# iter  20 value 18.058993
# iter  30 value 14.068771
# iter  40 value 12.043459
# iter  50 value 11.915298
# iter  60 value 11.606267
# iter  70 value 11.000794
# iter  80 value 10.807189
# iter  90 value 10.389781
# iter 100 value 9.901442
# final  value 9.901442
# stopped after 100 iterations
# # weights:  159
# initial  value 96.611502
# iter  10 value 77.731902
# iter  20 value 62.883094
# iter  30 value 62.506846
# iter  40 value 59.366841
# iter  50 value 58.068679
# iter  60 value 58.049768
# iter  70 value 58.045889
# iter  80 value 58.039365
# iter  90 value 53.014561
# iter 100 value 52.992362
# final  value 52.992362
# stopped after 100 iterations
# # weights:  475
# initial  value 94.720403
# iter  10 value 40.224155
# iter  20 value 26.751176
# iter  30 value 21.597881
# iter  40 value 19.599797
# iter  50 value 19.471601
# iter  60 value 19.273795
# iter  70 value 19.015100
# iter  80 value 19.009311
# iter  90 value 18.768140
# iter 100 value 18.492483
# final  value 18.492483
# stopped after 100 iterations
# # weights:  791
# initial  value 139.623787
# iter  10 value 58.193370
# iter  20 value 19.427353
# iter  30 value 7.441579
# iter  40 value 3.084296
# iter  50 value 2.374322
# iter  60 value 2.037501
# iter  70 value 1.814043
# iter  80 value 0.221202
# iter  90 value 0.104370
# iter 100 value 0.074744
# final  value 0.074744
# stopped after 100 iterations
# # weights:  159
# initial  value 102.347115
# iter  10 value 82.851997
# iter  20 value 54.018309
# iter  30 value 46.686189
# iter  40 value 41.544268
# iter  50 value 33.904479
# iter  60 value 26.436041
# iter  70 value 24.523843
# iter  80 value 21.984308
# iter  90 value 21.766032
# iter 100 value 21.757092
# final  value 21.757092
# stopped after 100 iterations
# # weights:  475
# initial  value 102.138005
# iter  10 value 70.810196
# iter  20 value 38.129994
# iter  30 value 26.618893
# iter  40 value 19.599439
# iter  50 value 16.747337
# iter  60 value 15.388237
# iter  70 value 14.622733
# iter  80 value 13.950723
# iter  90 value 13.504910
# iter 100 value 13.360101
# final  value 13.360101
# stopped after 100 iterations
# # weights:  791
# initial  value 108.828873
# iter  10 value 54.066083
# iter  20 value 30.938219
# iter  30 value 17.841456
# iter  40 value 13.801877
# iter  50 value 13.123064
# iter  60 value 12.450849
# iter  70 value 12.271423
# iter  80 value 12.237529
# iter  90 value 12.133402
# iter 100 value 11.954911
# final  value 11.954911
# stopped after 100 iterations
# # weights:  159
# initial  value 95.532751
# iter  10 value 74.026979
# iter  20 value 52.578890
# iter  30 value 48.038642
# iter  40 value 47.999508
# iter  50 value 47.990758
# iter  60 value 47.683555
# iter  70 value 45.090026
# iter  80 value 45.085398
# iter  90 value 43.506799
# iter 100 value 38.585822
# final  value 38.585822
# stopped after 100 iterations
# # weights:  475
# initial  value 114.483957
# iter  10 value 69.899963
# iter  20 value 44.006729
# iter  30 value 26.459770
# iter  40 value 24.166549
# iter  50 value 23.461394
# iter  60 value 22.009342
# iter  70 value 21.940317
# iter  80 value 20.547573
# iter  90 value 19.752427
# iter 100 value 17.766030
# final  value 17.766030
# stopped after 100 iterations
# # weights:  791
# initial  value 113.866501
# iter  10 value 53.442296
# iter  20 value 32.206997
# iter  30 value 26.747553
# iter  40 value 23.372002
# iter  50 value 21.518639
# iter  60 value 21.169953
# iter  70 value 20.749648
# iter  80 value 19.082240
# iter  90 value 18.976527
# iter 100 value 18.931562
# final  value 18.931562
# stopped after 100 iterations
# # weights:  159
# initial  value 124.349930
# iter  10 value 61.256590
# iter  20 value 44.485935
# iter  30 value 44.083507
# iter  40 value 44.075815
# iter  50 value 44.012997
# iter  60 value 42.729494
# iter  70 value 41.228165
# iter  80 value 41.183621
# iter  90 value 41.179863
# iter 100 value 41.178555
# final  value 41.178555
# stopped after 100 iterations
# # weights:  475
# initial  value 103.116209
# iter  10 value 56.891002
# iter  20 value 33.748383
# iter  30 value 26.673968
# iter  40 value 23.298784
# iter  50 value 15.647159
# iter  60 value 12.172003
# iter  70 value 12.036023
# iter  80 value 12.012597
# iter  90 value 11.775150
# iter 100 value 11.774206
# final  value 11.774206
# stopped after 100 iterations
# # weights:  791
# initial  value 105.303651
# iter  10 value 45.299573
# iter  20 value 25.860457
# iter  30 value 23.817325
# iter  40 value 22.647845
# iter  50 value 21.798293
# iter  60 value 19.533903
# iter  70 value 13.925391
# iter  80 value 12.012649
# iter  90 value 9.984201
# iter 100 value 9.888320
# final  value 9.888320
# stopped after 100 iterations
# # weights:  159
# initial  value 115.745633
# iter  10 value 74.810259
# iter  20 value 55.704643
# iter  30 value 45.801123
# iter  40 value 33.945212
# iter  50 value 31.933523
# iter  60 value 26.653211
# iter  70 value 23.640548
# iter  80 value 23.297946
# iter  90 value 23.286669
# iter 100 value 23.286409
# final  value 23.286409
# stopped after 100 iterations
# # weights:  475
# initial  value 110.250225
# iter  10 value 70.426127
# iter  20 value 38.801160
# iter  30 value 25.353670
# iter  40 value 18.591548
# iter  50 value 16.156229
# iter  60 value 14.707597
# iter  70 value 13.829304
# iter  80 value 13.612204
# iter  90 value 13.559176
# iter 100 value 13.557802
# final  value 13.557802
# stopped after 100 iterations
# # weights:  791
# initial  value 173.468504
# iter  10 value 50.169229
# iter  20 value 30.672801
# iter  30 value 16.021309
# iter  40 value 13.562552
# iter  50 value 12.794475
# iter  60 value 12.488024
# iter  70 value 12.375920
# iter  80 value 12.319906
# iter  90 value 12.301223
# iter 100 value 12.212884
# final  value 12.212884
# stopped after 100 iterations
# # weights:  159
# initial  value 121.819424
# iter  10 value 81.913270
# iter  20 value 77.556280
# iter  30 value 66.219726
# iter  40 value 64.508547
# iter  50 value 63.958556
# iter  60 value 63.942638
# iter  70 value 63.921555
# iter  80 value 63.906283
# iter  90 value 63.894289
# iter 100 value 61.903380
# final  value 61.903380
# stopped after 100 iterations
# # weights:  475
# initial  value 95.441791
# iter  10 value 31.425364
# iter  20 value 20.283301
# iter  30 value 17.707184
# iter  40 value 17.176217
# iter  50 value 16.800132
# iter  60 value 16.769119
# iter  70 value 14.571412
# iter  80 value 14.550906
# iter  90 value 14.530810
# iter 100 value 14.493767
# final  value 14.493767
# stopped after 100 iterations
# # weights:  791
# initial  value 97.781340
# iter  10 value 34.731699
# iter  20 value 10.754403
# iter  30 value 4.922063
# iter  40 value 3.033767
# iter  50 value 2.963183
# iter  60 value 2.905346
# iter  70 value 2.615204
# iter  80 value 2.582764
# iter  90 value 2.539057
# iter 100 value 2.517251
# final  value 2.517251
# stopped after 100 iterations
# # weights:  159
# initial  value 106.435654
# iter  10 value 81.352945
# iter  20 value 68.944202
# iter  30 value 67.603332
# iter  40 value 63.464386
# iter  50 value 63.310983
# iter  60 value 61.642591
# iter  70 value 61.631311
# iter  80 value 60.248124
# iter  90 value 57.201205
# iter 100 value 57.189815
# final  value 57.189815
# stopped after 100 iterations
# # weights:  475
# initial  value 93.501761
# iter  10 value 49.795641
# iter  20 value 35.372249
# iter  30 value 33.259785
# iter  40 value 31.832394
# iter  50 value 31.348912
# iter  60 value 30.209009
# iter  70 value 27.126615
# iter  80 value 24.869077
# iter  90 value 24.577055
# iter 100 value 24.412053
# final  value 24.412053
# stopped after 100 iterations
# # weights:  791
# initial  value 132.783015
# iter  10 value 39.824463
# iter  20 value 23.469923
# iter  30 value 12.346794
# iter  40 value 7.079034
# iter  50 value 5.540811
# iter  60 value 4.599057
# iter  70 value 2.774506
# iter  80 value 2.554539
# iter  90 value 2.527126
# iter 100 value 2.518945
# final  value 2.518945
# stopped after 100 iterations
# # weights:  159
# initial  value 97.019220
# iter  10 value 81.827615
# iter  20 value 74.081555
# iter  30 value 62.302217
# iter  40 value 51.176914
# iter  50 value 37.641104
# iter  60 value 33.714149
# iter  70 value 30.969118
# iter  80 value 26.955437
# iter  90 value 26.526920
# iter 100 value 26.493932
# final  value 26.493932
# stopped after 100 iterations
# # weights:  475
# initial  value 108.893634
# iter  10 value 64.336887
# iter  20 value 44.632390
# iter  30 value 32.181419
# iter  40 value 22.682338
# iter  50 value 19.246164
# iter  60 value 17.448989
# iter  70 value 15.348266
# iter  80 value 14.965807
# iter  90 value 14.741854
# iter 100 value 14.429053
# final  value 14.429053
# stopped after 100 iterations
# # weights:  791
# initial  value 115.921872
# iter  10 value 77.188967
# iter  20 value 46.351632
# iter  30 value 28.177975
# iter  40 value 19.604606
# iter  50 value 16.141333
# iter  60 value 15.104423
# iter  70 value 14.851518
# iter  80 value 14.736195
# iter  90 value 14.685321
# iter 100 value 14.668612
# final  value 14.668612
# stopped after 100 iterations
# # weights:  159
# initial  value 119.460008
# iter  10 value 79.692154
# iter  20 value 58.788511
# iter  30 value 53.695350
# iter  40 value 52.150599
# iter  50 value 52.140493
# iter  60 value 52.129158
# iter  70 value 51.422500
# iter  80 value 48.155712
# iter  90 value 48.146149
# iter 100 value 48.140801
# final  value 48.140801
# stopped after 100 iterations
# # weights:  475
# initial  value 124.235206
# iter  10 value 47.750461
# iter  20 value 24.147022
# iter  30 value 12.472301
# iter  40 value 8.364773
# iter  50 value 6.013756
# iter  60 value 5.259395
# iter  70 value 5.202753
# iter  80 value 5.186170
# iter  90 value 5.130099
# iter 100 value 3.275172
# final  value 3.275172
# stopped after 100 iterations
# # weights:  791
# initial  value 96.916525
# iter  10 value 34.359298
# iter  20 value 13.311375
# iter  30 value 11.740943
# iter  40 value 11.123862
# iter  50 value 10.838728
# iter  60 value 10.458832
# iter  70 value 10.297742
# iter  80 value 10.243661
# iter  90 value 10.081604
# iter 100 value 10.069922
# final  value 10.069922
# stopped after 100 iterations
# # weights:  159
# initial  value 96.440254
# iter  10 value 73.223417
# iter  20 value 69.885388
# iter  30 value 63.954042
# iter  40 value 56.120681
# iter  50 value 56.044677
# iter  60 value 56.028392
# iter  70 value 56.025123
# iter  80 value 56.023921
# iter  90 value 56.023458
# iter 100 value 56.023297
# final  value 56.023297
# stopped after 100 iterations
# # weights:  475
# initial  value 110.257819
# iter  10 value 50.510950
# iter  20 value 33.667064
# iter  30 value 29.754171
# iter  40 value 23.416016
# iter  50 value 17.753549
# iter  60 value 16.287150
# iter  70 value 16.212252
# iter  80 value 16.131761
# iter  90 value 16.105488
# iter 100 value 16.036527
# final  value 16.036527
# stopped after 100 iterations
# # weights:  791
# initial  value 100.337049
# iter  10 value 52.535257
# iter  20 value 32.436516
# iter  30 value 27.707377
# iter  40 value 25.566106
# iter  50 value 22.534662
# iter  60 value 22.381861
# iter  70 value 22.085761
# iter  80 value 18.994862
# iter  90 value 16.330707
# iter 100 value 15.842137
# final  value 15.842137
# stopped after 100 iterations
# # weights:  159
# initial  value 121.832326
# iter  10 value 75.706605
# iter  20 value 53.613804
# iter  30 value 43.743012
# iter  40 value 31.863060
# iter  50 value 30.574259
# iter  60 value 28.480575
# iter  70 value 28.109059
# iter  80 value 28.094789
# final  value 28.094690
# converged
# # weights:  475
# initial  value 104.979119
# iter  10 value 53.089728
# iter  20 value 35.405973
# iter  30 value 26.028764
# iter  40 value 18.832096
# iter  50 value 14.952872
# iter  60 value 13.103875
# iter  70 value 12.837045
# iter  80 value 12.772529
# iter  90 value 12.766904
# iter 100 value 12.766208
# final  value 12.766208
# stopped after 100 iterations
# # weights:  791
# initial  value 107.429167
# iter  10 value 56.483488
# iter  20 value 24.677472
# iter  30 value 15.933606
# iter  40 value 13.034476
# iter  50 value 12.553034
# iter  60 value 12.429352
# iter  70 value 12.323423
# iter  80 value 12.253119
# iter  90 value 12.209038
# iter 100 value 12.139031
# final  value 12.139031
# stopped after 100 iterations
# # weights:  159
# initial  value 104.785217
# iter  10 value 63.859143
# iter  20 value 51.677422
# iter  30 value 49.455143
# iter  40 value 49.427801
# iter  50 value 49.412721
# iter  60 value 46.457452
# iter  70 value 44.760643
# iter  80 value 44.730802
# iter  90 value 42.838031
# iter 100 value 40.112335
# final  value 40.112335
# stopped after 100 iterations
# # weights:  475
# initial  value 98.317084
# iter  10 value 66.357142
# iter  20 value 41.757952
# iter  30 value 31.417226
# iter  40 value 29.864747
# iter  50 value 28.514233
# iter  60 value 28.145290
# iter  70 value 27.939231
# iter  80 value 24.611097
# iter  90 value 24.587306
# iter 100 value 24.548632
# final  value 24.548632
# stopped after 100 iterations
# # weights:  791
# initial  value 141.451877
# iter  10 value 38.878472
# iter  20 value 18.333286
# iter  30 value 8.205442
# iter  40 value 6.295134
# iter  50 value 2.827301
# iter  60 value 2.149324
# iter  70 value 2.122828
# iter  80 value 2.018429
# iter  90 value 1.582900
# iter 100 value 1.550313
# final  value 1.550313
# stopped after 100 iterations
# # weights:  159
# initial  value 92.426151
# iter  10 value 69.368482
# iter  20 value 42.111613
# iter  30 value 41.567034
# iter  40 value 39.838746
# iter  50 value 38.046056
# iter  60 value 38.033815
# iter  70 value 36.143227
# iter  80 value 36.141143
# iter  90 value 36.140319
# iter 100 value 36.139411
# final  value 36.139411
# stopped after 100 iterations
# # weights:  475
# initial  value 91.304054
# iter  10 value 42.046157
# iter  20 value 34.714418
# iter  30 value 29.526382
# iter  40 value 22.603466
# iter  50 value 19.648682
# iter  60 value 16.858771
# iter  70 value 15.948300
# iter  80 value 15.192361
# iter  90 value 15.171622
# iter 100 value 15.164756
# final  value 15.164756
# stopped after 100 iterations
# # weights:  791
# initial  value 102.598198
# iter  10 value 33.519232
# iter  20 value 14.914730
# iter  30 value 13.837436
# iter  40 value 10.366865
# iter  50 value 8.380708
# iter  60 value 7.761773
# iter  70 value 5.571559
# iter  80 value 3.569603
# iter  90 value 3.261814
# iter 100 value 3.252552
# final  value 3.252552
# stopped after 100 iterations
# # weights:  159
# initial  value 98.681491
# iter  10 value 73.688501
# iter  20 value 54.447069
# iter  30 value 45.877055
# iter  40 value 37.358878
# iter  50 value 30.518381
# iter  60 value 27.968572
# iter  70 value 23.376757
# iter  80 value 22.712289
# iter  90 value 22.621583
# iter 100 value 22.605130
# final  value 22.605130
# stopped after 100 iterations
# # weights:  475
# initial  value 103.575621
# iter  10 value 58.625393
# iter  20 value 31.109910
# iter  30 value 20.315548
# iter  40 value 15.451621
# iter  50 value 14.549939
# iter  60 value 14.015645
# iter  70 value 13.494284
# iter  80 value 13.401622
# iter  90 value 13.154956
# iter 100 value 13.116931
# final  value 13.116931
# stopped after 100 iterations
# # weights:  791
# initial  value 108.595818
# iter  10 value 44.110645
# iter  20 value 26.554413
# iter  30 value 16.106541
# iter  40 value 13.956128
# iter  50 value 12.758760
# iter  60 value 12.216809
# iter  70 value 12.032065
# iter  80 value 11.992642
# iter  90 value 11.921138
# iter 100 value 11.905213
# final  value 11.905213
# stopped after 100 iterations
# # weights:  159
# initial  value 119.870167
# iter  10 value 67.728393
# iter  20 value 58.194862
# iter  30 value 55.769221
# iter  40 value 55.518261
# iter  50 value 53.071478
# iter  60 value 52.729322
# iter  70 value 51.295730
# iter  80 value 51.243085
# iter  90 value 51.238891
# iter 100 value 51.230978
# final  value 51.230978
# stopped after 100 iterations
# # weights:  475
# initial  value 96.570840
# iter  10 value 70.792855
# iter  20 value 46.923293
# iter  30 value 43.408289
# iter  40 value 37.135091
# iter  50 value 35.668375
# iter  60 value 34.425108
# iter  70 value 34.402142
# iter  80 value 33.786986
# iter  90 value 33.552544
# iter 100 value 33.106281
# final  value 33.106281
# stopped after 100 iterations
# # weights:  791
# initial  value 97.566879
# iter  10 value 29.839377
# iter  20 value 15.461477
# iter  30 value 14.124263
# iter  40 value 11.225165
# iter  50 value 10.701588
# iter  60 value 10.584653
# iter  70 value 8.776315
# iter  80 value 5.640867
# iter  90 value 2.834430
# iter 100 value 2.160366
# final  value 2.160366
# stopped after 100 iterations
# # weights:  159
# initial  value 96.579827
# iter  10 value 78.697257
# iter  20 value 59.214575
# iter  30 value 55.529177
# iter  40 value 52.720073
# iter  50 value 51.697059
# iter  60 value 51.692991
# iter  70 value 51.690597
# iter  80 value 50.254382
# iter  90 value 50.240610
# iter 100 value 50.240044
# final  value 50.240044
# stopped after 100 iterations
# # weights:  475
# initial  value 117.355561
# iter  10 value 48.025304
# iter  20 value 34.520540
# iter  30 value 29.336589
# iter  40 value 27.665303
# iter  50 value 24.681903
# iter  60 value 24.528413
# iter  70 value 24.283196
# iter  80 value 23.848171
# iter  90 value 23.701883
# iter 100 value 23.688565
# final  value 23.688565
# stopped after 100 iterations
# # weights:  791
# initial  value 104.914214
# iter  10 value 38.839110
# iter  20 value 12.635964
# iter  30 value 6.747169
# iter  40 value 5.807793
# iter  50 value 5.331740
# iter  60 value 4.776815
# iter  70 value 4.669132
# iter  80 value 4.647612
# iter  90 value 4.641649
# iter 100 value 4.639945
# final  value 4.639945
# stopped after 100 iterations
# # weights:  159
# initial  value 95.549677
# iter  10 value 63.910394
# iter  20 value 54.112547
# iter  30 value 46.908332
# iter  40 value 40.954370
# iter  50 value 37.101220
# iter  60 value 34.678780
# iter  70 value 34.268025
# iter  80 value 34.191354
# iter  90 value 34.131594
# iter 100 value 34.107433
# final  value 34.107433
# stopped after 100 iterations
# # weights:  475
# initial  value 107.342388
# iter  10 value 63.332726
# iter  20 value 38.198598
# iter  30 value 25.025335
# iter  40 value 21.162601
# iter  50 value 19.745442
# iter  60 value 18.239057
# iter  70 value 16.775761
# iter  80 value 14.063049
# iter  90 value 13.721207
# iter 100 value 13.706029
# ...
# iter  40 value 8.085481
# iter  50 value 4.698884
# iter  60 value 2.336715
# iter  70 value 0.588850
# iter  80 value 0.480223
# iter  90 value 0.471082
# iter 100 value 0.429845
# final  value 0.429845
# stopped after 100 iterations
# # weights:  159
# initial  value 110.354886
# iter  10 value 67.347905
# iter  20 value 56.448342
# iter  30 value 55.679905
# iter  40 value 54.188690
# iter  50 value 54.162890
# iter  60 value 54.160945
# iter  70 value 52.611854
# iter  80 value 52.584796
# iter  90 value 50.389165
# iter 100 value 50.375064
# final  value 50.375064
# stopped after 100 iterations
# # weights:  475
# initial  value 104.168154
# iter  10 value 48.356096
# iter  20 value 31.023436
# iter  30 value 26.341429
# iter  40 value 25.292799
# iter  50 value 24.854116
# iter  60 value 24.048264
# iter  70 value 23.854551
# iter  80 value 23.234299
# iter  90 value 21.701445
# iter 100 value 18.834723
# final  value 18.834723
# stopped after 100 iterations
# # weights:  791
# initial  value 99.081210
# iter  10 value 39.455267
# iter  20 value 18.992796
# iter  30 value 13.003319
# iter  40 value 10.585284
# iter  50 value 9.283194
# iter  60 value 8.886463
# iter  70 value 8.632484
# iter  80 value 8.329248
# iter  90 value 8.310517
# iter 100 value 8.306968
# final  value 8.306968
# stopped after 100 iterations
# # weights:  159
# initial  value 96.970944
# iter  10 value 76.948226
# iter  20 value 57.198685
# iter  30 value 44.250824
# iter  40 value 32.540790
# iter  50 value 26.958556
# iter  60 value 25.398052
# iter  70 value 21.511067
# iter  80 value 21.324638
# iter  90 value 21.311284
# iter 100 value 21.310226
# final  value 21.310226
# stopped after 100 iterations
# # weights:  475
# initial  value 114.247677
# iter  10 value 78.192682
# iter  20 value 48.206104
# iter  30 value 29.876155
# iter  40 value 20.576829
# iter  50 value 15.817388
# iter  60 value 13.108231
# iter  70 value 12.431643
# iter  80 value 11.973450
# iter  90 value 11.933428
# iter 100 value 11.928726
# final  value 11.928726
# stopped after 100 iterations
# # weights:  791
# initial  value 114.338904
# iter  10 value 60.580823
# iter  20 value 25.901426
# iter  30 value 16.015375
# iter  40 value 13.415850
# iter  50 value 12.562106
# iter  60 value 11.846530
# iter  70 value 11.764743
# iter  80 value 11.746804
# iter  90 value 11.687678
# iter 100 value 11.680772
# final  value 11.680772
# stopped after 100 iterations
# # weights:  159
# initial  value 93.574781
# iter  10 value 66.169061
# iter  20 value 49.454159
# iter  30 value 42.554220
# iter  40 value 37.160819
# iter  50 value 36.222785
# iter  60 value 34.224859
# iter  70 value 34.200357
# iter  80 value 34.197550
# iter  90 value 34.194591
# iter 100 value 34.192629
# final  value 34.192629
# stopped after 100 iterations
# # weights:  475
# initial  value 94.656077
# iter  10 value 35.254923
# iter  20 value 20.757806
# iter  30 value 11.922156
# iter  40 value 9.937308
# iter  50 value 9.567656
# iter  60 value 9.187864
# iter  70 value 8.961023
# iter  80 value 8.952414
# iter  90 value 8.498966
# iter 100 value 8.491674
# final  value 8.491674
# stopped after 100 iterations
# # weights:  791
# initial  value 97.044308
# iter  10 value 52.827155
# iter  20 value 25.780388
# iter  30 value 22.881430
# iter  40 value 18.765315
# iter  50 value 17.586637
# iter  60 value 16.388932
# iter  70 value 16.062259
# iter  80 value 13.589471
# iter  90 value 12.318753
# iter 100 value 9.838565
# final  value 9.838565
# stopped after 100 iterations
# # weights:  159
# initial  value 93.899587
# iter  10 value 70.686899
# iter  20 value 61.385905
# iter  30 value 58.695638
# iter  40 value 56.454624
# iter  50 value 54.307880
# iter  60 value 54.176227
# iter  70 value 54.173577
# iter  80 value 54.172025
# iter  90 value 51.872042
# iter 100 value 51.757263
# final  value 51.757263
# stopped after 100 iterations
# # weights:  475
# initial  value 135.376156
# iter  10 value 68.955355
# iter  20 value 45.353002
# iter  30 value 40.152379
# iter  40 value 32.205035
# iter  50 value 31.427991
# iter  60 value 27.370848
# iter  70 value 26.798454
# iter  80 value 26.776718
# iter  90 value 26.758560
# iter 100 value 26.754032
# final  value 26.754032
# stopped after 100 iterations
# # weights:  791
# initial  value 96.711325
# iter  10 value 44.870540
# iter  20 value 21.726816
# iter  30 value 17.244306
# iter  40 value 14.671800
# iter  50 value 14.316824
# iter  60 value 14.202643
# iter  70 value 12.901351
# iter  80 value 12.693984
# iter  90 value 12.680554
# iter 100 value 12.679164
# final  value 12.679164
# stopped after 100 iterations
# # weights:  159
# initial  value 103.263001
# iter  10 value 77.516965
# iter  20 value 64.740306
# iter  30 value 55.546360
# iter  40 value 47.677189
# iter  50 value 39.820449
# iter  60 value 34.910013
# iter  70 value 33.114705
# iter  80 value 32.125584
# iter  90 value 28.865229
# iter 100 value 26.869099
# final  value 26.869099
# stopped after 100 iterations
# # weights:  475
# initial  value 105.536779
# iter  10 value 65.274509
# iter  20 value 36.506540
# iter  30 value 27.701260
# iter  40 value 23.997134
# iter  50 value 17.818187
# iter  60 value 16.231693
# iter  70 value 15.619039
# iter  80 value 15.238844
# iter  90 value 14.596537
# iter 100 value 14.478068
# final  value 14.478068
# stopped after 100 iterations
# # weights:  791
# initial  value 109.264146
# iter  10 value 55.396761
# iter  20 value 30.076399
# iter  30 value 19.229407
# iter  40 value 15.257698
# iter  50 value 13.739344
# iter  60 value 13.053465
# iter  70 value 12.828030
# iter  80 value 12.672853
# iter  90 value 12.553883
# iter 100 value 12.487843
# final  value 12.487843
# stopped after 100 iterations
# # weights:  159
# initial  value 97.445544
# iter  10 value 85.650122
# iter  20 value 59.098668
# iter  30 value 45.902898
# iter  40 value 44.649121
# iter  50 value 44.610306
# iter  60 value 44.604523
# iter  70 value 44.599219
# iter  80 value 44.593279
# iter  90 value 44.586622
# iter 100 value 44.583664
# final  value 44.583664
# stopped after 100 iterations
# # weights:  475
# initial  value 94.738475
# iter  10 value 74.458215
# iter  20 value 24.798479
# iter  30 value 18.534183
# iter  40 value 14.008066
# iter  50 value 8.213714
# iter  60 value 7.964210
# iter  70 value 7.603880
# iter  80 value 7.237761
# iter  90 value 7.217349
# iter 100 value 4.037916
# final  value 4.037916
# stopped after 100 iterations
# # weights:  791
# initial  value 103.966798
# iter  10 value 55.264596
# iter  20 value 19.750858
# iter  30 value 14.329708
# iter  40 value 9.742590
# iter  50 value 9.122207
# iter  60 value 8.757808
# iter  70 value 8.600001
# iter  80 value 8.555179
# iter  90 value 8.526519
# iter 100 value 8.514805
# final  value 8.514805
# stopped after 100 iterations
# # weights:  159
# initial  value 121.535381
# iter  10 value 70.579228
# iter  20 value 62.065701
# iter  30 value 59.000476
# iter  40 value 58.922160
# iter  50 value 58.914457
# iter  60 value 58.911098
# iter  70 value 57.337784
# iter  80 value 57.054759
# iter  90 value 55.481323
# iter 100 value 53.433397
# final  value 53.433397
# stopped after 100 iterations
# # weights:  475
# initial  value 103.276720
# iter  10 value 45.425419
# iter  20 value 19.425080
# iter  30 value 16.034796
# iter  40 value 15.586463
# iter  50 value 12.811051
# iter  60 value 11.715175
# iter  70 value 11.387014
# iter  80 value 11.376059
# iter  90 value 11.034718
# iter 100 value 9.705954
# final  value 9.705954
# stopped after 100 iterations
# # weights:  791
# initial  value 92.660840
# iter  10 value 48.821935
# iter  20 value 12.799789
# iter  30 value 5.513373
# iter  40 value 3.428813
# iter  50 value 2.908532
# iter  60 value 2.890491
# iter  70 value 2.882306
# iter  80 value 2.524704
# iter  90 value 2.509753
# iter 100 value 2.453458
# final  value 2.453458
# stopped after 100 iterations
# # weights:  159
# initial  value 100.425845
# iter  10 value 78.999923
# iter  20 value 61.637919
# iter  30 value 44.202003
# iter  40 value 34.916331
# iter  50 value 30.142388
# iter  60 value 28.874891
# iter  70 value 28.699743
# iter  80 value 28.694658
# iter  90 value 28.694236
# final  value 28.694223
# converged
# # weights:  475
# initial  value 154.261999
# iter  10 value 67.297791
# iter  20 value 37.836291
# iter  30 value 24.470614
# iter  40 value 17.923864
# iter  50 value 15.453482
# iter  60 value 14.875828
# iter  70 value 14.828596
# iter  80 value 14.813714
# iter  90 value 14.501284
# iter 100 value 14.298439
# final  value 14.298439
# stopped after 100 iterations
# # weights:  791
# initial  value 113.612579
# iter  10 value 61.893790
# iter  20 value 28.953912
# iter  30 value 17.225701
# iter  40 value 14.535353
# iter  50 value 13.868921
# iter  60 value 13.574090
# iter  70 value 13.492001
# iter  80 value 13.442239
# iter  90 value 13.403840
# iter 100 value 13.387317
# final  value 13.387317
# stopped after 100 iterations
# # weights:  159
# initial  value 93.958230
# iter  10 value 66.645285
# iter  20 value 54.893841
# iter  30 value 51.300543
# iter  40 value 48.922214
# iter  50 value 45.102252
# iter  60 value 44.542972
# iter  70 value 44.534829
# iter  80 value 44.531074
# iter  90 value 44.526515
# iter 100 value 44.522350
# final  value 44.522350
# stopped after 100 iterations
# # weights:  475
# initial  value 103.821245
# iter  10 value 41.193580
# iter  20 value 27.291099
# iter  30 value 20.893437
# iter  40 value 19.040102
# iter  50 value 18.344460
# iter  60 value 17.168762
# iter  70 value 16.697007
# iter  80 value 14.424182
# iter  90 value 14.380607
# iter 100 value 13.856452
# final  value 13.856452
# stopped after 100 iterations
# # weights:  791
# initial  value 97.735388
# iter  10 value 41.711221
# iter  20 value 16.363060
# iter  30 value 7.990124
# iter  40 value 7.680292
# iter  50 value 6.108155
# iter  60 value 5.899328
# iter  70 value 5.759581
# iter  80 value 5.695781
# iter  90 value 2.644752
# iter 100 value 2.405357
# final  value 2.405357
# stopped after 100 iterations
# # weights:  159
# initial  value 94.778842
# iter  10 value 71.493095
# iter  20 value 59.692208
# iter  30 value 54.553262
# iter  40 value 54.350424
# iter  50 value 53.152397
# iter  60 value 51.907092
# iter  70 value 51.770082
# iter  80 value 49.306654
# iter  90 value 49.155817
# iter 100 value 47.965811
# final  value 47.965811
# stopped after 100 iterations
# # weights:  475
# initial  value 107.950067
# iter  10 value 56.446924
# iter  20 value 32.369312
# iter  30 value 21.447796
# iter  40 value 13.696258
# iter  50 value 11.811147
# iter  60 value 9.708431
# iter  70 value 8.340107
# iter  80 value 8.313672
# iter  90 value 6.591688
# iter 100 value 6.542401
# final  value 6.542401
# stopped after 100 iterations
# # weights:  791
# initial  value 96.459233
# iter  10 value 25.041811
# iter  20 value 10.586139
# iter  30 value 3.222600
# iter  40 value 1.586548
# iter  50 value 1.408317
# iter  60 value 0.060162
# iter  70 value 0.039065
# iter  80 value 0.029124
# iter  90 value 0.012971
# iter 100 value 0.005144
# final  value 0.005144
# stopped after 100 iterations
# # weights:  159
# initial  value 109.340114
# iter  10 value 69.394215
# iter  20 value 54.348503
# iter  30 value 44.516038
# iter  40 value 36.012919
# iter  50 value 29.361110
# iter  60 value 28.051740
# iter  70 value 25.537533
# iter  80 value 24.188740
# iter  90 value 21.831829
# iter 100 value 21.680716
# final  value 21.680716
# stopped after 100 iterations
# # weights:  475
# initial  value 102.080109
# iter  10 value 74.791244
# iter  20 value 42.656354
# iter  30 value 27.024321
# iter  40 value 18.360328
# iter  50 value 15.984314
# iter  60 value 14.602966
# iter  70 value 13.857417
# iter  80 value 13.509450
# iter  90 value 13.177384
# iter 100 value 13.099310
# final  value 13.099310
# stopped after 100 iterations
# # weights:  791
# initial  value 114.222835
# iter  10 value 50.759120
# iter  20 value 25.409844
# iter  30 value 16.530249
# iter  40 value 13.502469
# iter  50 value 12.328610
# iter  60 value 12.093942
# iter  70 value 11.960268
# iter  80 value 11.946421
# iter  90 value 11.941614
# iter 100 value 11.939602
# final  value 11.939602
# stopped after 100 iterations
# # weights:  159
# initial  value 104.189048
# iter  10 value 67.882723
# iter  20 value 45.020303
# iter  30 value 44.600447
# iter  40 value 44.586549
# iter  50 value 44.581560
# iter  60 value 41.857809
# iter  70 value 41.637082
# iter  80 value 41.617162
# iter  90 value 39.923760
# iter 100 value 39.920038
# final  value 39.920038
# stopped after 100 iterations
# # weights:  475
# initial  value 104.845090
# iter  10 value 65.502267
# iter  20 value 36.356066
# iter  30 value 30.511653
# iter  40 value 25.119360
# iter  50 value 22.621914
# iter  60 value 21.705990
# iter  70 value 19.630732
# iter  80 value 19.280713
# iter  90 value 19.252805
# iter 100 value 19.132438
# final  value 19.132438
# stopped after 100 iterations
# # weights:  791
# initial  value 98.184580
# iter  10 value 47.100825
# iter  20 value 29.361705
# iter  30 value 25.310406
# iter  40 value 24.251663
# iter  50 value 23.064527
# iter  60 value 22.471801
# iter  70 value 18.436242
# iter  80 value 17.882676
# iter  90 value 17.199323
# iter 100 value 16.994909
# final  value 16.994909
# stopped after 100 iterations
# # weights:  159
# initial  value 101.684245
# iter  10 value 71.023453
# iter  20 value 51.386438
# iter  30 value 47.552001
# iter  40 value 44.769929
# iter  50 value 42.819399
# iter  60 value 40.201112
# iter  70 value 40.059159
# iter  80 value 38.101185
# iter  90 value 38.095654
# iter 100 value 35.537942
# final  value 35.537942
# stopped after 100 iterations
# # weights:  475
# initial  value 96.003420
# iter  10 value 51.940117
# iter  20 value 38.823398
# iter  30 value 38.509680
# iter  40 value 38.369110
# iter  50 value 37.137058
# iter  60 value 34.096444
# iter  70 value 33.197575
# iter  80 value 33.062708
# iter  90 value 30.337619
# iter 100 value 29.587485
# final  value 29.587485
# stopped after 100 iterations
# # weights:  791
# initial  value 101.881883
# iter  10 value 50.873204
# iter  20 value 23.874118
# iter  30 value 17.980181
# iter  40 value 17.151467
# iter  50 value 14.113435
# iter  60 value 11.922084
# iter  70 value 11.789156
# iter  80 value 11.722562
# iter  90 value 11.471024
# iter 100 value 11.415157
# final  value 11.415157
# stopped after 100 iterations
# # weights:  159
# initial  value 107.038685
# iter  10 value 64.702263
# iter  20 value 54.069880
# iter  30 value 46.306789
# iter  40 value 40.024097
# iter  50 value 34.184079
# iter  60 value 32.025024
# iter  70 value 30.804990
# iter  80 value 26.167377
# iter  90 value 25.923620
# iter 100 value 25.916535
# final  value 25.916535
# stopped after 100 iterations
# # weights:  475
# initial  value 106.354691
# iter  10 value 56.470610
# iter  20 value 31.756555
# iter  30 value 22.775029
# iter  40 value 17.837687
# iter  50 value 15.468447
# iter  60 value 14.952673
# iter  70 value 14.308967
# iter  80 value 13.945569
# iter  90 value 13.598002
# iter 100 value 13.541306
# final  value 13.541306
# stopped after 100 iterations
# # weights:  791
# initial  value 110.888849
# iter  10 value 59.192231
# iter  20 value 33.663479
# iter  30 value 17.736720
# iter  40 value 14.057958
# iter  50 value 12.984365
# iter  60 value 12.605265
# iter  70 value 12.410648
# iter  80 value 12.372563
# iter  90 value 12.336554
# iter 100 value 12.327496
# final  value 12.327496
# stopped after 100 iterations
# # weights:  159
# initial  value 103.551338
# iter  10 value 73.297367
# iter  20 value 50.793690
# iter  30 value 50.617021
# iter  40 value 50.608277
# iter  50 value 50.604700
# iter  60 value 50.599412
# iter  70 value 50.595638
# iter  80 value 50.592723
# iter  90 value 50.589972
# iter 100 value 50.565954
# final  value 50.565954
# stopped after 100 iterations
# # weights:  475
# initial  value 141.109083
# iter  10 value 61.747280
# iter  20 value 31.680601
# iter  30 value 26.594821
# iter  40 value 25.910569
# iter  50 value 24.245936
# iter  60 value 21.936996
# iter  70 value 19.665113
# iter  80 value 19.336074
# iter  90 value 19.205531
# iter 100 value 19.122970
# final  value 19.122970
# stopped after 100 iterations
# # weights:  791
# initial  value 102.215130
# iter  10 value 48.395850
# iter  20 value 19.260391
# iter  30 value 9.192770
# iter  40 value 5.332738
# iter  50 value 4.453416
# iter  60 value 4.103023
# iter  70 value 4.084011
# iter  80 value 4.066291
# iter  90 value 4.041541
# iter 100 value 2.233342
# final  value 2.233342
# stopped after 100 iterations
# # weights:  791
# initial  value 134.547997
# iter  10 value 43.639642
# iter  20 value 30.633502
# iter  30 value 27.762430
# iter  40 value 27.252468
# iter  50 value 25.854221
# iter  60 value 25.489146
# iter  70 value 25.030594
# iter  80 value 24.906472
# iter  90 value 24.637772
# iter 100 value 24.380113
# final  value 24.380113
# stopped after 100 iterations

# %%
# estimate variable importance
nnet.imp <- varImp(m.nnet, scale=TRUE)$importance
rownames(nnet.imp) <- gsub("`", "", rownames(nnet.imp))
nnet.imp$Name <- rownames(nnet.imp)
# summarize importance
nnet.imp <- nnet.imp[order(nnet.imp$Overall, decreasing=TRUE),]
# nnet.imp <- nnet.imp[1:50, ]
head(nnet.imp)
# Out:
#      Overall   Name
# 2919 100.00000 2919
# 6504  94.66473 6504
# 4210  89.79198 4210
# 1191  87.23374 1191
# 7177  83.78756 7177
# 6373  83.57008 6373

# %% [markdown]
# # Compare feature ranks

# %%
a <- subset(rf.imp, select = c(1))
b <- subset(glm.imp, select = c(1))
c <- subset(svm.imp, select = c(1))
d <- subset(nnet.imp, select = c(1))

colnames(a) <- c("Score.rf")
colnames(b) <- c("Score.glm")
colnames(c) <- c("Score.svm")
colnames(d) <- c("Score.nnet")

a$Gene_ID <- rownames(a)
b$Gene_ID <- rownames(b)
c$Gene_ID <- rownames(c)
d$Gene_ID <- rownames(d)

rownames(a) <- NULL
rownames(b) <- NULL
rownames(c) <- NULL
rownames(d) <- NULL

# dim(a)
# dim(b)
# dim(c)
# dim(d)


mergedScore<- Reduce(function(x,y) merge(x,y,by='Gene_ID'), list(a,b,c,d))
mergedScore
# Out:
#     Gene_ID   Score.rf  Score.glm   Score.svm  Score.nnet
# 1   100       25.597884  0.000000   32.3178808  3.388405
# 2   100133941 15.504812 11.861100    7.2406181 48.785784
# 3   100507436 12.005619 42.179470   10.9933775 14.289771
# 4   10148     37.420157 30.568105   39.0286976 52.872124
# 5   10344      5.707342  5.570492   19.6909492 36.585877
# 6   10454     15.308079 15.976189   12.2295806 23.356448
# 7   1051      17.415079  0.000000    9.3156733 46.731868
# 8   10581     21.252106 31.477486   20.9713024 51.394570
# 9   10849     20.284086 13.612360   14.3929360 40.785526
# 10  11005     48.499785  0.000000   32.5386313 32.401290
# 11  114548    21.600122  0.000000   48.3885210 45.867492
# 12  114609    12.689186  0.000000    0.0000000 23.749559
# 13  117157    22.701990 41.355986   27.0640177 42.803798
# 14  1191      32.149330 89.858061   28.9624724 87.233743
# 15  1215       2.504772  0.000000    4.7682119 37.187339
# 16  1281      29.200345 49.988802   28.2560706 48.109527
# 17  146433    29.316659  0.000000    3.2229581 13.628088
# 18  1493      46.548204  0.000000   71.3907285 42.464209
# 19  1755      12.971081  4.238881   31.6997792 66.166180
# 20  1846      23.751788 16.710919   16.8653422 32.834028
# 21  1848      42.222558 23.155968   29.0507726 49.305662
# 22  1958      44.297780  3.431090   25.2538631 35.463697
# 23  1959      24.644518  7.915312   46.1810155 37.646235
# 24  1991      25.202340 14.020847    0.8830022 13.919695
# 25  2150      18.549826  0.000000    1.0596026 14.621553
# 26  2162      33.217209  0.000000    4.9448124 34.898147
# 27  25        36.075339  0.000000   41.7660044 56.807154
# 28  2534      23.077046  0.000000   35.7615894 62.380050
# 29  25904     21.808981  0.000000    5.2980132 34.581496
# 30  2821      15.270313  0.000000    0.3973510 40.305733
# ⋮   ⋮         ⋮         ⋮           ⋮          ⋮
# 127 7128      36.056952 11.54797011 78.057395  47.39388
# 128 717       25.708061  0.00000000 52.891832  57.73632
# 129 7177      26.773881 40.24601080 23.885210  83.78756
# 130 718        2.317804  0.00000000 33.421634  37.58325
# 131 7187      19.069690 17.35771964 53.421634  64.01404
# 132 7412      18.499185  0.18307112 40.971302  18.35721
# 133 7702       5.408463 37.28797555 25.253863  55.97714
# 134 79089     37.760143  0.00639259  9.536424  31.17940
# 135 79882      6.406017  0.00000000  4.635762  57.03785
# 136 8287      12.928257 36.23312313  6.799117  16.14048
# 137 83607      7.334918 19.29093185  7.947020  35.49797
# 138 85021     21.813256  0.00000000 34.172185  39.34131
# 139 8519      17.701079  0.00000000  7.947020  28.32559
# 140 85406     18.522528  0.00000000 23.929360  29.46134
# 141 8600      23.382273 24.36017897 12.759382  23.92876
# 142 8763       7.421807  0.00000000  8.741722  26.92342
# 143 8767      23.165758 22.94501974 19.867550  26.34526
# 144 8792      20.453351  0.00000000  4.768212  36.26791
# 145 8794      46.655040  0.00000000 53.245033  38.21459
# 146 8795      12.152647  0.00000000 18.807947  26.79708
# 147 8832       9.511001  9.19253753 34.481236  34.67553
# 148 909       19.361453  0.00000000 14.834437  59.57824
# 149 91949     54.090338 65.87073947 33.642384  58.46126
# 150 933       39.507064  0.00000000 28.035320  29.99631
# 151 940       24.716207 31.42080480 53.068433  40.05207
# 152 945       10.894472 45.33947773  9.448124  39.72301
# 153 947       27.228907  0.00000000 45.827815  71.68488
# 154 9636       3.121039 54.64903588  4.282561  63.39962
# 155 9638      25.342951  0.00000000 32.715232  28.32002
# 156 9947      14.225261  0.00000000 23.929360  54.91239

# %%
corr <- cor(mergedScore[,2:5])
heatmap(corr, main="Heatmap", margin=c(15,15))
# Out:
# Plot with title “Heatmap”

# %%
corrplot(corr, method="color")
# Out:
# Plot with title “”

# %% [markdown]
# ## Taking only the top 50 features

# %%
rf_50 <- a$Gene_ID[1:50]
glm_50 <- b$Gene_ID[1:50]
svm_50 <- c$Gene_ID[1:50]
nnet_50 <- d$Gene_ID[1:50]

# %%
library(GeneAnswers)
gene_names_rf_50 <- getSymbols(rf_50, 'org.Hs.eg.db')
gene_names_glm_50 <- getSymbols(glm_50, 'org.Hs.eg.db')
gene_names_svm_50 <- getSymbols(svm_50, 'org.Hs.eg.db')
gene_names_nnet_50 <- getSymbols(nnet_50, 'org.Hs.eg.db')

# for (x in 1:50) {
#   print(gene_names_nnet_50[[x]])
# }

# gene_names_rf_50
# gene_names_glm_50
# gene_names_svm_50
# gene_names_nnet_50
# Out:
# [1] "CXCL1"
# [1] "SLAMF1"
# [1] "MEFV"
# [1] "CLU"
# [1] "TPSAB1"
# [1] "CXCL11"
# [1] "LGALS3"
# [1] "SYT17"
# [1] "CCL28"
# [1] "BMI1"
# [1] "CD34"
# [1] "CXCL5"
# [1] "LRRN3"
# [1] "CARD9"
# [1] "HSD11B1"
# [1] "DMBT1"
# [1] "IL1RAP"
# [1] "IL5RA"
# [1] "EPCAM"
# [1] "TRAF3"
# [1] "TREM1"
# [1] "ISG15"
# [1] "TNF"
# [1] "FYN"
# [1] "TCF7"
# [1] "CD1A"
# [1] "COG7"
# [1] "C2"
# [1] "BCL2L1"
# [1] "ZC3H14"
# [1] "BIRC5"
# [1] "ABL1"
# [1] "TNFRSF11B"
# [1] "ZNF143"
# [1] "ATG16L1"
# [1] "MAGEC1"
# [1] "MR1"
# [1] "EBI3"
# [1] "CCL8"
# [1] "IFITM2"
# [1] "PSMB7"
# [1] "NOL7"
# [1] "IFNG"
# [1] "MAVS"
# [1] "ITGA2"
# [1] "TAP2"
# [1] "DUSP6"
# [1] "ITGA2B"
# [1] "CD24"
# [1] "COL3A1"
#        6504        3458       91949       51348       29851        3556
#    "SLAMF1"      "IFNG"      "COG7"     "KLRF1"      "ICOS"    "IL1RAP"
#        3383        4210       11005        8794        1493        7124
#     "ICAM1"      "MEFV"    "SPINK5" "TNFRSF10C"     "CTLA4"       "TNF"
#        1958        5079        1848        6891        6756         933
#      "EGR1"      "PAX5"     "DUSP6"      "TAP2"      "SSX1"      "CD22"
#         332        4982       54209       79089        6892       10148
#     "BIRC5" "TNFRSF11B"     "TREM2"     "TMUB2"     "TAPBP"      "EBI3"
#        4179        3119       50489        3673          25        7128
#      "CD46"  "HLA-DQB1"     "CD207"     "ITGA2"      "ABL1"   "TNFAIP3"
#         558        4615        3290        4311        3140        6355
#       "AXL"     "MYD88"   "HSD11B1"       "MME"       "MR1"      "CCL8"
#        2162        3716        3559       54674        1191         596
#     "F13A1"      "JAK1"     "IL2RA"     "LRRN3"       "CLU"      "BCL2"
#        5648        6932        3958       56658        3676      146433
#     "MASP1"      "TCF7"    "LGALS3"    "TRIM39"     "ITGA4"      "IL34"
#       55054        1281
#   "ATG16L1"    "COL3A1"
#        2919       54209        6374        1191        4772        3673
#     "CXCL1"     "TREM2"     "CXCL5"       "CLU"    "NFATC1"     "ITGA2"
#        6097       91949        7040       56477        3674        4773
#      "RORC"      "COG7"     "TGFB1"     "CCL28"    "ITGA2B"    "NFATC2"
#        9636        1281        4684       51295        4775         945
#     "ISG15"    "COL3A1"     "NCAM1"     "ECSIT"    "NFATC3"      "CD33"
#         684   100507436      117157        3383        7177       54210
#      "BST2"      "MICA"    "SH2D1B"     "ICAM1"    "TPSAB1"     "TREM1"
#        3568        3552        3589        7702        8287        4311
#     "IL5RA"      "IL1A"      "IL11"    "ZNF143"     "USP9Y"       "MME"
#       55750       10581         940        3251       10148       54674
#       "AGK"    "IFITM2"      "CD28"     "HPRT1"      "EBI3"     "LRRN3"
#        5079       51760        6279        4982        3672         648
#      "PAX5"     "SYT17"    "S100A8" "TNFRSF11B"     "ITGA1"      "BMI1"
#        8600        3559        3140        1848        6373        8767
#   "TNFSF11"     "IL2RA"       "MR1"     "DUSP6"    "CXCL11"     "RIPK2"
#        4100        5648
#    "MAGEA1"     "MASP1"
#        6504        3458       29851        7128        4210        1493
#    "SLAMF1"      "IFNG"      "ICOS"   "TNFAIP3"      "MEFV"     "CTLA4"
#        6373        3559        6891        2829        4982        7124
#    "CXCL11"     "IL2RA"      "TAP2"      "XCR1" "TNFRSF11B"       "TNF"
#        2919        3119        3383        7187        8794         940
#     "CXCL1"  "HLA-DQB1"     "ICAM1"     "TRAF3" "TNFRSF10C"      "CD28"
#         717        6892       51348      114548        3589        3290
#        "C2"     "TAPBP"     "KLRF1"     "NLRP3"      "IL11"   "HSD11B1"
#        1959         947        6756         684          25        7412
#      "EGR2"      "CD34"      "SSX1"      "BST2"      "ABL1"     "VCAM1"
#       54674      345611        3140        3676       10148         596
#     "LRRN3"      "IRGM"       "MR1"     "ITGA4"      "EBI3"      "BCL2"
#         648        3459        2534        3566        8832       85021
#      "BMI1"    "IFNGR1"       "FYN"      "IL4R"      "CD84"     "REPS1"
#        5695       91949       56477         718        9638       11005
#     "PSMB7"      "COG7"     "CCL28"        "C3"      "FEZ1"    "SPINK5"
#         100        3662
#       "ADA"      "IRF4"
#        2919        6504        4210        1191        7177        6373
#     "CXCL1"    "SLAMF1"      "MEFV"       "CLU"    "TPSAB1"    "CXCL11"
#        3958       51760       56477         648         947        6374
#    "LGALS3"     "SYT17"     "CCL28"      "BMI1"      "CD34"     "CXCL5"
#       54674       64170        3290        1755        3556        3568
#     "LRRN3"     "CARD9"   "HSD11B1"     "DMBT1"    "IL1RAP"     "IL5RA"
#        4072        7187       54210        9636        7124        2534
#     "EPCAM"     "TRAF3"     "TREM1"     "ISG15"       "TNF"       "FYN"
#        6932         909       91949         717         598       79882
#      "TCF7"      "CD1A"      "COG7"        "C2"    "BCL2L1"    "ZC3H14"
#         332          25        4982        7702       55054        9947
#     "BIRC5"      "ABL1" "TNFRSF11B"    "ZNF143"   "ATG16L1"    "MAGEC1"
#        3140       10148        6355       10581        5695       51406
#       "MR1"      "EBI3"      "CCL8"    "IFITM2"     "PSMB7"      "NOL7"
#        3458       57506        3673        6891        1848        3674
#      "IFNG"      "MAVS"     "ITGA2"      "TAP2"     "DUSP6"    "ITGA2B"
#   100133941        1281
#      "CD24"    "COL3A1"

# %% [raw]
# `Venn Diagram Results`
#
#
# Names	total	elements
# glm nnet rf svm	4	MR1
# 		EBI3
# 		LRRN3
# 		COG7
# glm rf svm	2	ICAM1
# 		IL2RA
# glm nnet rf	4	DUSP6
# 		COL3A1
# 		CLU
# 		ITGA2
# nnet rf svm	7	IFNG
# 		MEFV
# 		TNF
# 		TAP2
# 		ABL1
# 		SLAMF1
# 		HSD11B1
# glm nnet svm	5	CXCL1
# 		TNFRSF11B
# 		CXCL11
# 		BMI1
# 		CCL28
# glm rf	4	PAX5
# 		TREM2
# 		MASP1
# 		MME
# rf svm	11	TNFAIP3
# 		BCL2
# 		TNFRSF10C
# 		TAPBP
# 		HLA-DQB1
# 		ICOS
# 		CTLA4
# 		SPINK5
# 		SSX1
# 		KLRF1
# 		ITGA4
# nnet rf	6	LGALS3
# 		CCL8
# 		IL1RAP
# 		BIRC5
# 		ATG16L1
# 		TCF7
# glm svm	3	CD28
# 		IL11
# 		BST2
# glm nnet	9	ZNF143
# 		TPSAB1
# 		SYT17
# 		TREM1
# 		IL5RA
# 		ISG15
# 		CXCL5
# 		ITGA2B
# 		IFITM2
# nnet svm	5	CD34
# 		C2
# 		PSMB7
# 		TRAF3
# 		FYN
# rf	12	CD207
# 		TRIM39
# 		CD22
# 		IL34
# 		CD46
# 		TMUB2
# 		EGR1
# 		MYD88
# 		AXL
# 		TNFRSF11B"
# 		F13A1
# 		JAK1
# glm	19	ITGA1
# 		CD33
# 		ECSIT
# 		USP9Y
# 		NFATC3
# 		NFATC1
# 		RORC
# 		AGK
# 		TNFSF11
# 		NFATC2
# 		RIPK2
# 		TGFB1
# 		MICA
# 		IL1A
# 		SH2D1B
# 		HPRT1
# 		MAGEA1
# 		S100A8
# 		NCAM1
# svm	13	IRF4
# 		IL4R
# 		VCAM1
# 		ADA
# 		IFNGR1
# 		FEZ1
# 		EGR2
# 		REPS1
# 		XCR1
# 		IRGM
# 		CD84
# 		NLRP3
# 		C3
# nnet	10	MAVS
# 		NOL7
# 		ZC3H14
# 		CARD9
# 		CD1A
# 		MAGEC1
# 		EPCAM
# 		DMBT1
# 		BCL2L1
# 		CD24

# %% [markdown]
# `TODO:` <br>
# Change gene IDs to names in original table to avoid later calculation <br>
# Find overlap for top 20 and top 100 similar to 50
# Find common pathways
#
# set seed<br>
# mlp or nnet?

# %%
# #parameter tuning
# modelLookup('lvq')
# # design the parameter tuning grid
# grid <- expand.grid(size=c(5,10,20,50), k=c(1,2,3,4,5))
# # train the model
# model <- train(Species~., data=iris, method="lvq", trControl=control, tuneGrid=grid)

# %%
# saveRds(tmp, "tmp.rds")
# # load by giving path
# # tmp <- readRds("path")
# # R
