# %% [markdown]
# # Pre-Processing
# 1) Clean data by removing rows with > 50% missing info <br>
# 2) Find the most informative features <br>
# 3) Split the data into test and train

# %%
library(caret)
# Out:
# Loading required package: lattice
#
# Loading required package: ggplot2

# %% [markdown]
# ## Load data
# The first column is expected to be sample ID <br>
# The second column is expected to be response

# %%
setwd("/home/jp/ICP_Responders/FinalTables")
expression <- read.csv("Final_table_response_and_expression.csv", na.strings = '..', stringsAsFactors = F)
names(expression) <- sub("^X", "", names(expression))
expression[ expression == "NA" ] <- NA
expression[,2:ncol(expression)] <- lapply(expression[, 2:ncol(expression)], as.numeric)
expression[50:60, 1:10]
# Out:
#    Patient Response 3920        345611       3929       54210       3716
# 50 31      1                 NA           NA         NA          NA          NA
# 51 32      1                 NA           NA         NA          NA          NA
# 52 33      1                 NA           NA         NA          NA          NA
# 53 34      1        -0.24227274  0.074304976 -0.3511685  0.54428208 -0.15006954
# 54 35      1        -0.48479782  0.159405465  0.4199815 -2.22883720  0.24650857
# 55 36      1         0.74085490  0.003467014  0.3333496 -0.03988917 -0.21346769
# 56 37      1                 NA           NA         NA          NA          NA
# 57 38      1         0.81259519 -0.048404344 -0.2250873 -0.29189077  0.44538081
# 58 39      0                 NA           NA         NA          NA          NA
# 59 4       0         0.14400922 -0.067130938  0.1120551 -0.96429947  0.10440116
# 60 40      1         0.07691239  0.333001919  0.5565036  0.17618231 -0.09816412
#    10454       3557        3556
# 50          NA          NA           NA
# 51          NA          NA           NA
# 52          NA          NA           NA
# 53 -0.07183968  0.20022650 -1.182660036
# 54 -0.38904130  1.82423349 -1.343065827
# 55  0.54476821 -1.69969237  0.483498059
# 56          NA          NA           NA
# 57  0.21789661 -0.08321449  1.567718745
# 58          NA          NA           NA
# 59 -0.74711659  0.30591242 -1.254576697
# 60  0.45014341 -0.28709491  0.002942665

# %% [markdown]
# ## Clean data

# %%
# Check which column has > 50% NA values
countNA <- function(x=NULL,cutOff=NULL){
  output<-FALSE
  perc<-sum(is.na(x))*100/length(x)
  if(perc>cutOff){output<-TRUE}
  output  
}
col_nas <- apply(expression,2,function(x){countNA(x, 50)})
cat("Columns with NAs > 50% = ", sum(col_nas), "\n")
# all columns have <50% NAs

# Check which rows has > 50% NA values
row_nas <- apply(expression,1,function(x){countNA(x, 50)})
cat("Rows with NAs > 50% = ", sum(row_nas), "\n")

# 43 rows have have >50% NAs, removing them
expr_filtered <- expression[-which(row_nas %in% TRUE),]

cat("Dimensions of the filteres dataset = ", dim(expr_filtered))
# Out:
# Columns with NAs > 50% =  0
# Rows with NAs > 50% =  43
# Dimensions of the filteres dataset =  161 676

# %% [markdown]
# ## Look for near zero variance and remove those columns

# %%
nzv <- nearZeroVar(expr_filtered[3:ncol(expr_filtered)], saveMetrics= TRUE)
nzv[which(nzv$zeroVar %in% TRUE), ]

# All features were retained and there was no filtering due to near zero variance
# Out:
#      freqRatio percentUnique zeroVar nzv

# %% [markdown]
# ## Look for correlation and remove highly correlated columns

# %%
# find attributes that are highly corrected (ideally >0.75)
tmp <- expr_filtered
tmp[is.na(tmp)] <- 0
expr_corr <-  cor(tmp[,3:ncol(tmp)]) 
highlyCorrelated <- findCorrelation(expr_corr, cutoff=0.75, names=TRUE, verbose=TRUE)
expr_rmcorr <- expr_filtered[, -which(colnames(expr_filtered) %in% highlyCorrelated)]
# Out:
#  Combination row 18 and column 19 is above the cut-off, value = 0.797
#  	 Flagging column 18
#  Combination row 18 and column 20 is above the cut-off, value = 0.755
#  	 Flagging column 18
#  Combination row 20 and column 22 is above the cut-off, value = 0.832
#  	 Flagging column 22
#  Combination row 20 and column 23 is above the cut-off, value = 0.801
#  	 Flagging column 23
#  Combination row 22 and column 23 is above the cut-off, value = 0.954
#  	 Flagging column 22
#  Combination row 18 and column 24 is above the cut-off, value = 0.768
#  	 Flagging column 18
#  Combination row 19 and column 24 is above the cut-off, value = 0.838
#  	 Flagging column 24
#  Combination row 19 and column 25 is above the cut-off, value = 0.759
#  	 Flagging column 25
#  Combination row 24 and column 25 is above the cut-off, value = 0.929
#  	 Flagging column 25
#  Combination row 16 and column 26 is above the cut-off, value = 0.856
#  	 Flagging column 16
#  Combination row 16 and column 31 is above the cut-off, value = 0.942
#  	 Flagging column 31
#  Combination row 26 and column 31 is above the cut-off, value = 0.772
#  	 Flagging column 31
#  Combination row 16 and column 32 is above the cut-off, value = 0.827
#  	 Flagging column 16
#  Combination row 31 and column 32 is above the cut-off, value = 0.904
#  	 Flagging column 31
#  Combination row 16 and column 36 is above the cut-off, value = 0.867
#  	 Flagging column 36
#  Combination row 26 and column 36 is above the cut-off, value = 0.767
#  	 Flagging column 36
#  Combination row 31 and column 36 is above the cut-off, value = 0.895
#  	 Flagging column 31
#  Combination row 32 and column 36 is above the cut-off, value = 0.785
#  	 Flagging column 36
#  Combination row 18 and column 38 is above the cut-off, value = 0.816
#  	 Flagging column 38
#  Combination row 19 and column 38 is above the cut-off, value = 0.874
#  	 Flagging column 38
#  Combination row 24 and column 38 is above the cut-off, value = 0.883
#  	 Flagging column 38
#  Combination row 25 and column 38 is above the cut-off, value = 0.825
#  	 Flagging column 38
#  Combination row 22 and column 46 is above the cut-off, value = 0.828
#  	 Flagging column 22
#  Combination row 23 and column 46 is above the cut-off, value = 0.81
#  	 Flagging column 23
#  Combination row 19 and column 52 is above the cut-off, value = 0.811
#  	 Flagging column 52
#  Combination row 38 and column 52 is above the cut-off, value = 0.849
#  	 Flagging column 38
#  Combination row 36 and column 57 is above the cut-off, value = 0.753
#  	 Flagging column 36
#  Combination row 16 and column 63 is above the cut-off, value = 0.8
#  	 Flagging column 63
#  Combination row 18 and column 63 is above the cut-off, value = 0.78
#  	 Flagging column 63
#  Combination row 24 and column 63 is above the cut-off, value = 0.82
#  	 Flagging column 63
#  Combination row 25 and column 63 is above the cut-off, value = 0.792
#  	 Flagging column 63
#  Combination row 31 and column 63 is above the cut-off, value = 0.896
#  	 Flagging column 63
#  Combination row 32 and column 63 is above the cut-off, value = 0.878
#  	 Flagging column 63
#  Combination row 36 and column 63 is above the cut-off, value = 0.813
#  	 Flagging column 63
#  Combination row 38 and column 63 is above the cut-off, value = 0.865
#  	 Flagging column 63
#  Combination row 26 and column 64 is above the cut-off, value = 0.844
#  	 Flagging column 26
#  Combination row 26 and column 65 is above the cut-off, value = 0.814
#  	 Flagging column 26
#  Combination row 64 and column 65 is above the cut-off, value = 0.81
#  	 Flagging column 65
#  Combination row 19 and column 66 is above the cut-off, value = 0.897
#  	 Flagging column 66
#  Combination row 24 and column 66 is above the cut-off, value = 0.769
#  	 Flagging column 24
#  Combination row 38 and column 66 is above the cut-off, value = 0.851
#  	 Flagging column 38
#  Combination row 52 and column 66 is above the cut-off, value = 0.783
#  	 Flagging column 52
#  Combination row 16 and column 68 is above the cut-off, value = 0.82
#  	 Flagging column 16
#  Combination row 26 and column 68 is above the cut-off, value = 0.802
#  	 Flagging column 26
#  Combination row 31 and column 68 is above the cut-off, value = 0.782
#  	 Flagging column 31
#  Combination row 48 and column 68 is above the cut-off, value = 0.762
#  	 Flagging column 68
#  Combination row 65 and column 68 is above the cut-off, value = 0.762
#  	 Flagging column 68
#  Combination row 10 and column 70 is above the cut-off, value = 0.784
#  	 Flagging column 10
#  Combination row 16 and column 75 is above the cut-off, value = 0.765
#  	 Flagging column 16
#  Combination row 26 and column 75 is above the cut-off, value = 0.814
#  	 Flagging column 26
#  Combination row 36 and column 75 is above the cut-off, value = 0.777
#  	 Flagging column 36
#  Combination row 68 and column 75 is above the cut-off, value = 0.778
#  	 Flagging column 68
#  Combination row 18 and column 85 is above the cut-off, value = 0.783
#  	 Flagging column 18
#  Combination row 19 and column 85 is above the cut-off, value = 0.818
#  	 Flagging column 85
#  Combination row 24 and column 85 is above the cut-off, value = 0.811
#  	 Flagging column 85
#  Combination row 25 and column 85 is above the cut-off, value = 0.794
#  	 Flagging column 85
#  Combination row 38 and column 85 is above the cut-off, value = 0.822
#  	 Flagging column 38
#  Combination row 52 and column 85 is above the cut-off, value = 0.763
#  	 Flagging column 85
#  Combination row 63 and column 85 is above the cut-off, value = 0.776
#  	 Flagging column 63
#  Combination row 66 and column 85 is above the cut-off, value = 0.784
#  	 Flagging column 85
#  Combination row 26 and column 86 is above the cut-off, value = 0.83
#  	 Flagging column 26
#  Combination row 64 and column 86 is above the cut-off, value = 0.896
#  	 Flagging column 64
#  Combination row 65 and column 86 is above the cut-off, value = 0.779
#  	 Flagging column 65
#  Combination row 32 and column 104 is above the cut-off, value = 0.755
#  	 Flagging column 32
#  Combination row 63 and column 104 is above the cut-off, value = 0.792
#  	 Flagging column 63
#  Combination row 16 and column 111 is above the cut-off, value = 0.815
#  	 Flagging column 16
#  Combination row 31 and column 111 is above the cut-off, value = 0.845
#  	 Flagging column 31
#  Combination row 36 and column 111 is above the cut-off, value = 0.8
#  	 Flagging column 36
#  Combination row 63 and column 111 is above the cut-off, value = 0.751
#  	 Flagging column 63
#  Combination row 24 and column 115 is above the cut-off, value = 0.84
#  	 Flagging column 115
#  Combination row 25 and column 115 is above the cut-off, value = 0.814
#  	 Flagging column 115
#  Combination row 38 and column 115 is above the cut-off, value = 0.789
#  	 Flagging column 38
#  Combination row 63 and column 115 is above the cut-off, value = 0.765
#  	 Flagging column 63
#  Combination row 85 and column 115 is above the cut-off, value = 0.823
#  	 Flagging column 85
#  Combination row 26 and column 124 is above the cut-off, value = 0.793
#  	 Flagging column 26
#  Combination row 64 and column 124 is above the cut-off, value = 0.803
#  	 Flagging column 64
#  Combination row 68 and column 124 is above the cut-off, value = 0.798
#  	 Flagging column 68
#  Combination row 75 and column 124 is above the cut-off, value = 0.83
#  	 Flagging column 75
#  Combination row 86 and column 124 is above the cut-off, value = 0.775
#  	 Flagging column 124
#  Combination row 16 and column 129 is above the cut-off, value = 0.846
#  	 Flagging column 129
#  Combination row 18 and column 129 is above the cut-off, value = 0.788
#  	 Flagging column 129
#  Combination row 26 and column 129 is above the cut-off, value = 0.834
#  	 Flagging column 129
#  Combination row 31 and column 129 is above the cut-off, value = 0.847
#  	 Flagging column 129
#  Combination row 36 and column 129 is above the cut-off, value = 0.824
#  	 Flagging column 129
#  Combination row 38 and column 129 is above the cut-off, value = 0.783
#  	 Flagging column 129
#  Combination row 63 and column 129 is above the cut-off, value = 0.838
#  	 Flagging column 129
#  Combination row 68 and column 129 is above the cut-off, value = 0.765
#  	 Flagging column 129
#  Combination row 126 and column 129 is above the cut-off, value = 0.775
#  	 Flagging column 129
#  Combination row 130 and column 131 is above the cut-off, value = 0.752
#  	 Flagging column 131
#  Combination row 26 and column 140 is above the cut-off, value = 0.811
#  	 Flagging column 26
#  Combination row 16 and column 144 is above the cut-off, value = 0.794
#  	 Flagging column 16
#  Combination row 31 and column 144 is above the cut-off, value = 0.807
#  	 Flagging column 31
#  Combination row 68 and column 144 is above the cut-off, value = 0.799
#  	 Flagging column 68
#  Combination row 16 and column 147 is above the cut-off, value = 0.89
#  	 Flagging column 16
#  Combination row 26 and column 147 is above the cut-off, value = 0.813
#  	 Flagging column 26
#  Combination row 31 and column 147 is above the cut-off, value = 0.866
#  	 Flagging column 31
#  Combination row 36 and column 147 is above the cut-off, value = 0.782
#  	 Flagging column 36
#  Combination row 68 and column 147 is above the cut-off, value = 0.786
#  	 Flagging column 147
#  Combination row 75 and column 147 is above the cut-off, value = 0.751
#  	 Flagging column 147
#  Combination row 111 and column 147 is above the cut-off, value = 0.76
#  	 Flagging column 147
#  Combination row 129 and column 147 is above the cut-off, value = 0.817
#  	 Flagging column 129
#  Combination row 144 and column 147 is above the cut-off, value = 0.813
#  	 Flagging column 147
#  Combination row 22 and column 149 is above the cut-off, value = 0.786
#  	 Flagging column 22
#  Combination row 23 and column 149 is above the cut-off, value = 0.786
#  	 Flagging column 23
#  Combination row 141 and column 152 is above the cut-off, value = 0.77
#  	 Flagging column 141
#  Combination row 63 and column 154 is above the cut-off, value = 0.758
#  	 Flagging column 63
#  Combination row 153 and column 154 is above the cut-off, value = 0.845
#  	 Flagging column 154
#  Combination row 141 and column 155 is above the cut-off, value = 0.789
#  	 Flagging column 141
#  Combination row 18 and column 156 is above the cut-off, value = 0.782
#  	 Flagging column 156
#  Combination row 19 and column 156 is above the cut-off, value = 0.764
#  	 Flagging column 156
#  Combination row 24 and column 156 is above the cut-off, value = 0.834
#  	 Flagging column 156
#  Combination row 25 and column 156 is above the cut-off, value = 0.813
#  	 Flagging column 156
#  Combination row 31 and column 156 is above the cut-off, value = 0.82
#  	 Flagging column 31
#  Combination row 32 and column 156 is above the cut-off, value = 0.791
#  	 Flagging column 156
#  Combination row 36 and column 156 is above the cut-off, value = 0.768
#  	 Flagging column 36
#  Combination row 38 and column 156 is above the cut-off, value = 0.852
#  	 Flagging column 38
#  Combination row 63 and column 156 is above the cut-off, value = 0.856
#  	 Flagging column 63
#  Combination row 85 and column 156 is above the cut-off, value = 0.758
#  	 Flagging column 156
#  Combination row 129 and column 156 is above the cut-off, value = 0.776
#  	 Flagging column 129
#  Combination row 154 and column 156 is above the cut-off, value = 0.801
#  	 Flagging column 156
#  Combination row 38 and column 157 is above the cut-off, value = 0.759
#  	 Flagging column 38
#  Combination row 18 and column 158 is above the cut-off, value = 0.784
#  	 Flagging column 158
#  Combination row 24 and column 158 is above the cut-off, value = 0.821
#  	 Flagging column 158
#  Combination row 25 and column 158 is above the cut-off, value = 0.796
#  	 Flagging column 158
#  Combination row 31 and column 158 is above the cut-off, value = 0.787
#  	 Flagging column 31
#  Combination row 32 and column 158 is above the cut-off, value = 0.753
#  	 Flagging column 158
#  Combination row 38 and column 158 is above the cut-off, value = 0.817
#  	 Flagging column 38
#  Combination row 63 and column 158 is above the cut-off, value = 0.843
#  	 Flagging column 63
#  Combination row 129 and column 158 is above the cut-off, value = 0.776
#  	 Flagging column 129
#  Combination row 154 and column 158 is above the cut-off, value = 0.82
#  	 Flagging column 158
#  Combination row 156 and column 158 is above the cut-off, value = 0.926
#  	 Flagging column 156
#  Combination row 16 and column 159 is above the cut-off, value = 0.793
#  	 Flagging column 16
#  Combination row 26 and column 159 is above the cut-off, value = 0.781
#  	 Flagging column 26
#  Combination row 68 and column 159 is above the cut-off, value = 0.78
#  	 Flagging column 68
#  Combination row 147 and column 159 is above the cut-off, value = 0.782
#  	 Flagging column 147
#  Combination row 31 and column 161 is above the cut-off, value = 0.763
#  	 Flagging column 31
#  Combination row 36 and column 161 is above the cut-off, value = 0.764
#  	 Flagging column 36
#  Combination row 38 and column 161 is above the cut-off, value = 0.752
#  	 Flagging column 38
#  Combination row 63 and column 161 is above the cut-off, value = 0.756
#  	 Flagging column 63
#  Combination row 129 and column 161 is above the cut-off, value = 0.76
#  	 Flagging column 129
#  Combination row 144 and column 161 is above the cut-off, value = 0.75
#  	 Flagging column 161
#  Combination row 147 and column 161 is above the cut-off, value = 0.765
#  	 Flagging column 147
#  Combination row 26 and column 162 is above the cut-off, value = 0.752
#  	 Flagging column 26
#  Combination row 57 and column 162 is above the cut-off, value = 0.796
#  	 Flagging column 57
#  Combination row 64 and column 175 is above the cut-off, value = 0.787
#  	 Flagging column 64
#  Combination row 31 and column 181 is above the cut-off, value = 0.796
#  	 Flagging column 31
#  Combination row 32 and column 181 is above the cut-off, value = 0.777
#  	 Flagging column 32
#  Combination row 36 and column 181 is above the cut-off, value = 0.793
#  	 Flagging column 36
#  Combination row 16 and column 182 is above the cut-off, value = 0.822
#  	 Flagging column 16
#  Combination row 26 and column 182 is above the cut-off, value = 0.773
#  	 Flagging column 26
#  Combination row 31 and column 182 is above the cut-off, value = 0.847
#  	 Flagging column 31
#  Combination row 32 and column 182 is above the cut-off, value = 0.812
#  	 Flagging column 32
#  Combination row 36 and column 182 is above the cut-off, value = 0.761
#  	 Flagging column 36
#  Combination row 63 and column 182 is above the cut-off, value = 0.792
#  	 Flagging column 63
#  Combination row 129 and column 182 is above the cut-off, value = 0.819
#  	 Flagging column 129
#  Combination row 147 and column 182 is above the cut-off, value = 0.78
#  	 Flagging column 182
#  Combination row 161 and column 182 is above the cut-off, value = 0.779
#  	 Flagging column 182
#  Combination row 16 and column 184 is above the cut-off, value = 0.913
#  	 Flagging column 16
#  Combination row 26 and column 184 is above the cut-off, value = 0.803
#  	 Flagging column 184
#  Combination row 31 and column 184 is above the cut-off, value = 0.93
#  	 Flagging column 31
#  Combination row 32 and column 184 is above the cut-off, value = 0.862
#  	 Flagging column 184
#  Combination row 36 and column 184 is above the cut-off, value = 0.846
#  	 Flagging column 36
#  Combination row 57 and column 184 is above the cut-off, value = 0.789
#  	 Flagging column 184
#  Combination row 63 and column 184 is above the cut-off, value = 0.828
#  	 Flagging column 63
#  Combination row 68 and column 184 is above the cut-off, value = 0.758
#  	 Flagging column 184
#  Combination row 111 and column 184 is above the cut-off, value = 0.81
#  	 Flagging column 184
#  Combination row 129 and column 184 is above the cut-off, value = 0.812
#  	 Flagging column 129
#  Combination row 144 and column 184 is above the cut-off, value = 0.761
#  	 Flagging column 184
#  Combination row 147 and column 184 is above the cut-off, value = 0.805
#  	 Flagging column 184
#  Combination row 156 and column 184 is above the cut-off, value = 0.76
#  	 Flagging column 156
#  Combination row 162 and column 184 is above the cut-off, value = 0.804
#  	 Flagging column 184
#  Combination row 181 and column 184 is above the cut-off, value = 0.781
#  	 Flagging column 184
#  Combination row 182 and column 184 is above the cut-off, value = 0.807
#  	 Flagging column 184
#  Combination row 16 and column 187 is above the cut-off, value = 0.829
#  	 Flagging column 16
#  Combination row 31 and column 187 is above the cut-off, value = 0.91
#  	 Flagging column 31
#  Combination row 32 and column 187 is above the cut-off, value = 0.904
#  	 Flagging column 32
#  Combination row 36 and column 187 is above the cut-off, value = 0.793
#  	 Flagging column 36
#  Combination row 63 and column 187 is above the cut-off, value = 0.884
#  	 Flagging column 63
#  Combination row 104 and column 187 is above the cut-off, value = 0.843
#  	 Flagging column 187
#  Combination row 111 and column 187 is above the cut-off, value = 0.775
#  	 Flagging column 187
#  Combination row 156 and column 187 is above the cut-off, value = 0.795
#  	 Flagging column 156
#  Combination row 181 and column 187 is above the cut-off, value = 0.813
#  	 Flagging column 187
#  Combination row 182 and column 187 is above the cut-off, value = 0.803
#  	 Flagging column 182
#  Combination row 184 and column 187 is above the cut-off, value = 0.851
#  	 Flagging column 184
#  Combination row 14 and column 189 is above the cut-off, value = 0.773
#  	 Flagging column 189
#  Combination row 129 and column 189 is above the cut-off, value = 0.758
#  	 Flagging column 129
#  Combination row 16 and column 190 is above the cut-off, value = 0.77
#  	 Flagging column 16
#  Combination row 26 and column 190 is above the cut-off, value = 0.831
#  	 Flagging column 26
#  Combination row 64 and column 190 is above the cut-off, value = 0.854
#  	 Flagging column 190
#  Combination row 75 and column 190 is above the cut-off, value = 0.775
#  	 Flagging column 75
#  Combination row 86 and column 190 is above the cut-off, value = 0.767
#  	 Flagging column 190
#  Combination row 124 and column 190 is above the cut-off, value = 0.769
#  	 Flagging column 190
#  Combination row 147 and column 190 is above the cut-off, value = 0.766
#  	 Flagging column 147
#  Combination row 159 and column 190 is above the cut-off, value = 0.785
#  	 Flagging column 159
#  Combination row 162 and column 190 is above the cut-off, value = 0.75
#  	 Flagging column 190
#  Combination row 175 and column 190 is above the cut-off, value = 0.806
#  	 Flagging column 190
#  Combination row 26 and column 191 is above the cut-off, value = 0.864
#  	 Flagging column 26
#  Combination row 64 and column 191 is above the cut-off, value = 0.879
#  	 Flagging column 191
#  Combination row 65 and column 191 is above the cut-off, value = 0.764
#  	 Flagging column 191
#  Combination row 86 and column 191 is above the cut-off, value = 0.863
#  	 Flagging column 191
#  Combination row 140 and column 191 is above the cut-off, value = 0.794
#  	 Flagging column 140
#  Combination row 159 and column 191 is above the cut-off, value = 0.771
#  	 Flagging column 159
#  Combination row 162 and column 191 is above the cut-off, value = 0.837
#  	 Flagging column 191
#  Combination row 175 and column 191 is above the cut-off, value = 0.801
#  	 Flagging column 191
#  Combination row 190 and column 191 is above the cut-off, value = 0.928
#  	 Flagging column 190
#  Combination row 24 and column 193 is above the cut-off, value = 0.789
#  	 Flagging column 193
#  Combination row 25 and column 193 is above the cut-off, value = 0.809
#  	 Flagging column 193
#  Combination row 38 and column 193 is above the cut-off, value = 0.836
#  	 Flagging column 38
#  Combination row 52 and column 193 is above the cut-off, value = 0.788
#  	 Flagging column 193
#  Combination row 63 and column 193 is above the cut-off, value = 0.765
#  	 Flagging column 63
#  Combination row 115 and column 193 is above the cut-off, value = 0.768
#  	 Flagging column 193
#  Combination row 16 and column 196 is above the cut-off, value = 0.792
#  	 Flagging column 196
#  Combination row 18 and column 196 is above the cut-off, value = 0.766
#  	 Flagging column 196
#  Combination row 31 and column 196 is above the cut-off, value = 0.847
#  	 Flagging column 196
#  Combination row 32 and column 196 is above the cut-off, value = 0.759
#  	 Flagging column 196
#  Combination row 36 and column 196 is above the cut-off, value = 0.842
#  	 Flagging column 196
#  Combination row 38 and column 196 is above the cut-off, value = 0.82
#  	 Flagging column 196
#  Combination row 63 and column 196 is above the cut-off, value = 0.869
#  	 Flagging column 196
#  Combination row 68 and column 196 is above the cut-off, value = 0.756
#  	 Flagging column 196
#  Combination row 129 and column 196 is above the cut-off, value = 0.854
#  	 Flagging column 196
#  Combination row 147 and column 196 is above the cut-off, value = 0.753
#  	 Flagging column 196
#  Combination row 156 and column 196 is above the cut-off, value = 0.804
#  	 Flagging column 196
#  Combination row 158 and column 196 is above the cut-off, value = 0.781
#  	 Flagging column 196
#  Combination row 184 and column 196 is above the cut-off, value = 0.775
#  	 Flagging column 196
#  Combination row 187 and column 196 is above the cut-off, value = 0.753
#  	 Flagging column 196
#  Combination row 16 and column 197 is above the cut-off, value = 0.963
#  	 Flagging column 197
#  Combination row 26 and column 197 is above the cut-off, value = 0.872
#  	 Flagging column 197
#  Combination row 31 and column 197 is above the cut-off, value = 0.952
#  	 Flagging column 197
#  Combination row 32 and column 197 is above the cut-off, value = 0.858
#  	 Flagging column 197
#  Combination row 36 and column 197 is above the cut-off, value = 0.883
#  	 Flagging column 197
#  Combination row 57 and column 197 is above the cut-off, value = 0.771
#  	 Flagging column 197
#  Combination row 63 and column 197 is above the cut-off, value = 0.832
#  	 Flagging column 197
#  Combination row 68 and column 197 is above the cut-off, value = 0.816
#  	 Flagging column 197
#  Combination row 75 and column 197 is above the cut-off, value = 0.785
#  	 Flagging column 197
#  Combination row 111 and column 197 is above the cut-off, value = 0.832
#  	 Flagging column 197
#  Combination row 129 and column 197 is above the cut-off, value = 0.86
#  	 Flagging column 129
#  Combination row 144 and column 197 is above the cut-off, value = 0.799
#  	 Flagging column 197
#  Combination row 147 and column 197 is above the cut-off, value = 0.86
#  	 Flagging column 197
#  Combination row 156 and column 197 is above the cut-off, value = 0.759
#  	 Flagging column 197
#  Combination row 159 and column 197 is above the cut-off, value = 0.763
#  	 Flagging column 197
#  Combination row 181 and column 197 is above the cut-off, value = 0.791
#  	 Flagging column 197
#  Combination row 182 and column 197 is above the cut-off, value = 0.855
#  	 Flagging column 197
#  Combination row 184 and column 197 is above the cut-off, value = 0.944
#  	 Flagging column 197
#  Combination row 187 and column 197 is above the cut-off, value = 0.868
#  	 Flagging column 197
#  Combination row 196 and column 197 is above the cut-off, value = 0.815
#  	 Flagging column 196
#  Combination row 16 and column 199 is above the cut-off, value = 0.756
#  	 Flagging column 16
#  Combination row 31 and column 199 is above the cut-off, value = 0.809
#  	 Flagging column 31
#  Combination row 36 and column 199 is above the cut-off, value = 0.758
#  	 Flagging column 36
#  Combination row 63 and column 199 is above the cut-off, value = 0.825
#  	 Flagging column 63
#  Combination row 129 and column 199 is above the cut-off, value = 0.771
#  	 Flagging column 129
#  Combination row 184 and column 199 is above the cut-off, value = 0.775
#  	 Flagging column 184
#  Combination row 187 and column 199 is above the cut-off, value = 0.755
#  	 Flagging column 199
#  Combination row 196 and column 199 is above the cut-off, value = 0.782
#  	 Flagging column 196
#  Combination row 197 and column 199 is above the cut-off, value = 0.777
#  	 Flagging column 197
#  Combination row 16 and column 202 is above the cut-off, value = 0.904
#  	 Flagging column 16
#  Combination row 26 and column 202 is above the cut-off, value = 0.785
#  	 Flagging column 202
#  Combination row 31 and column 202 is above the cut-off, value = 0.929
#  	 Flagging column 31
#  Combination row 32 and column 202 is above the cut-off, value = 0.892
#  	 Flagging column 202
#  Combination row 36 and column 202 is above the cut-off, value = 0.801
#  	 Flagging column 36
#  Combination row 63 and column 202 is above the cut-off, value = 0.877
#  	 Flagging column 63
#  Combination row 111 and column 202 is above the cut-off, value = 0.797
#  	 Flagging column 202
#  Combination row 129 and column 202 is above the cut-off, value = 0.84
#  	 Flagging column 129
#  Combination row 144 and column 202 is above the cut-off, value = 0.754
#  	 Flagging column 202
#  Combination row 147 and column 202 is above the cut-off, value = 0.842
#  	 Flagging column 202
#  Combination row 156 and column 202 is above the cut-off, value = 0.764
#  	 Flagging column 202
#  Combination row 158 and column 202 is above the cut-off, value = 0.753
#  	 Flagging column 202
#  Combination row 182 and column 202 is above the cut-off, value = 0.874
#  	 Flagging column 202
#  Combination row 184 and column 202 is above the cut-off, value = 0.884
#  	 Flagging column 202
#  Combination row 187 and column 202 is above the cut-off, value = 0.874
#  	 Flagging column 202
#  Combination row 196 and column 202 is above the cut-off, value = 0.808
#  	 Flagging column 196
#  Combination row 197 and column 202 is above the cut-off, value = 0.918
#  	 Flagging column 197
#  Combination row 199 and column 202 is above the cut-off, value = 0.782
#  	 Flagging column 202
#  Combination row 16 and column 203 is above the cut-off, value = 0.908
#  	 Flagging column 203
#  Combination row 26 and column 203 is above the cut-off, value = 0.789
#  	 Flagging column 203
#  Combination row 31 and column 203 is above the cut-off, value = 0.954
#  	 Flagging column 203
#  Combination row 32 and column 203 is above the cut-off, value = 0.882
#  	 Flagging column 203
#  Combination row 36 and column 203 is above the cut-off, value = 0.885
#  	 Flagging column 203
#  Combination row 38 and column 203 is above the cut-off, value = 0.751
#  	 Flagging column 203
#  Combination row 63 and column 203 is above the cut-off, value = 0.899
#  	 Flagging column 203
#  Combination row 68 and column 203 is above the cut-off, value = 0.79
#  	 Flagging column 203
#  Combination row 111 and column 203 is above the cut-off, value = 0.82
#  	 Flagging column 203
#  Combination row 129 and column 203 is above the cut-off, value = 0.871
#  	 Flagging column 129
#  Combination row 144 and column 203 is above the cut-off, value = 0.771
#  	 Flagging column 203
#  Combination row 147 and column 203 is above the cut-off, value = 0.828
#  	 Flagging column 203
#  Combination row 156 and column 203 is above the cut-off, value = 0.815
#  	 Flagging column 203
#  Combination row 158 and column 203 is above the cut-off, value = 0.796
#  	 Flagging column 203
#  Combination row 181 and column 203 is above the cut-off, value = 0.76
#  	 Flagging column 203
#  Combination row 182 and column 203 is above the cut-off, value = 0.818
#  	 Flagging column 203
#  Combination row 184 and column 203 is above the cut-off, value = 0.921
#  	 Flagging column 203
#  Combination row 187 and column 203 is above the cut-off, value = 0.867
#  	 Flagging column 203
#  Combination row 196 and column 203 is above the cut-off, value = 0.905
#  	 Flagging column 196
#  Combination row 197 and column 203 is above the cut-off, value = 0.935
#  	 Flagging column 203
#  Combination row 199 and column 203 is above the cut-off, value = 0.815
#  	 Flagging column 203
#  Combination row 202 and column 203 is above the cut-off, value = 0.907
#  	 Flagging column 203
#  Combination row 16 and column 207 is above the cut-off, value = 0.813
#  	 Flagging column 16
#  Combination row 26 and column 207 is above the cut-off, value = 0.818
#  	 Flagging column 207
#  Combination row 31 and column 207 is above the cut-off, value = 0.791
#  	 Flagging column 31
#  Combination row 36 and column 207 is above the cut-off, value = 0.793
#  	 Flagging column 36
#  Combination row 68 and column 207 is above the cut-off, value = 0.769
#  	 Flagging column 207
#  Combination row 129 and column 207 is above the cut-off, value = 0.851
#  	 Flagging column 129
#  Combination row 184 and column 207 is above the cut-off, value = 0.775
#  	 Flagging column 207
#  Combination row 196 and column 207 is above the cut-off, value = 0.784
#  	 Flagging column 196
#  Combination row 197 and column 207 is above the cut-off, value = 0.815
#  	 Flagging column 197
#  Combination row 202 and column 207 is above the cut-off, value = 0.762
#  	 Flagging column 202
#  Combination row 203 and column 207 is above the cut-off, value = 0.813
#  	 Flagging column 203
#  Combination row 131 and column 208 is above the cut-off, value = 0.88
#  	 Flagging column 131
#  Combination row 19 and column 209 is above the cut-off, value = 0.847
#  	 Flagging column 19
#  Combination row 38 and column 209 is above the cut-off, value = 0.785
#  	 Flagging column 38
#  Combination row 194 and column 209 is above the cut-off, value = 0.86
#  	 Flagging column 209
#  Combination row 31 and column 212 is above the cut-off, value = 0.799
#  	 Flagging column 31
#  Combination row 32 and column 212 is above the cut-off, value = 0.791
#  	 Flagging column 32
#  Combination row 36 and column 212 is above the cut-off, value = 0.755
#  	 Flagging column 36
#  Combination row 63 and column 212 is above the cut-off, value = 0.767
#  	 Flagging column 63
#  Combination row 131 and column 212 is above the cut-off, value = 0.897
#  	 Flagging column 212
#  Combination row 156 and column 212 is above the cut-off, value = 0.767
#  	 Flagging column 156
#  Combination row 158 and column 212 is above the cut-off, value = 0.771
#  	 Flagging column 158
#  Combination row 187 and column 212 is above the cut-off, value = 0.781
#  	 Flagging column 187
#  Combination row 202 and column 212 is above the cut-off, value = 0.753
#  	 Flagging column 202
#  Combination row 203 and column 212 is above the cut-off, value = 0.784
#  	 Flagging column 203
#  Combination row 208 and column 212 is above the cut-off, value = 0.896
#  	 Flagging column 212
#  Combination row 208 and column 213 is above the cut-off, value = 0.765
#  	 Flagging column 213
#  Combination row 212 and column 213 is above the cut-off, value = 0.821
#  	 Flagging column 212
#  Combination row 24 and column 221 is above the cut-off, value = 0.757
#  	 Flagging column 221
#  Combination row 31 and column 221 is above the cut-off, value = 0.75
#  	 Flagging column 221
#  Combination row 36 and column 221 is above the cut-off, value = 0.756
#  	 Flagging column 221
#  Combination row 38 and column 221 is above the cut-off, value = 0.835
#  	 Flagging column 221
#  Combination row 52 and column 221 is above the cut-off, value = 0.768
#  	 Flagging column 221
#  Combination row 63 and column 221 is above the cut-off, value = 0.838
#  	 Flagging column 221
#  Combination row 66 and column 221 is above the cut-off, value = 0.775
#  	 Flagging column 221
#  Combination row 85 and column 221 is above the cut-off, value = 0.757
#  	 Flagging column 221
#  Combination row 115 and column 221 is above the cut-off, value = 0.756
#  	 Flagging column 221
#  Combination row 129 and column 221 is above the cut-off, value = 0.804
#  	 Flagging column 129
#  Combination row 156 and column 221 is above the cut-off, value = 0.795
#  	 Flagging column 221
#  Combination row 158 and column 221 is above the cut-off, value = 0.776
#  	 Flagging column 221
#  Combination row 193 and column 221 is above the cut-off, value = 0.763
#  	 Flagging column 221
#  Combination row 196 and column 221 is above the cut-off, value = 0.865
#  	 Flagging column 196
#  Combination row 202 and column 221 is above the cut-off, value = 0.759
#  	 Flagging column 221
#  Combination row 203 and column 221 is above the cut-off, value = 0.818
#  	 Flagging column 203
#  Combination row 38 and column 232 is above the cut-off, value = 0.769
#  	 Flagging column 38
#  Combination row 221 and column 232 is above the cut-off, value = 0.77
#  	 Flagging column 221
#  Combination row 16 and column 238 is above the cut-off, value = 0.775
#  	 Flagging column 16
#  Combination row 31 and column 238 is above the cut-off, value = 0.777
#  	 Flagging column 31
#  Combination row 32 and column 238 is above the cut-off, value = 0.763
#  	 Flagging column 32
#  Combination row 184 and column 238 is above the cut-off, value = 0.871
#  	 Flagging column 184
#  Combination row 197 and column 238 is above the cut-off, value = 0.833
#  	 Flagging column 197
#  Combination row 202 and column 238 is above the cut-off, value = 0.771
#  	 Flagging column 202
#  Combination row 203 and column 238 is above the cut-off, value = 0.793
#  	 Flagging column 203
#  Combination row 18 and column 239 is above the cut-off, value = 0.779
#  	 Flagging column 239
#  Combination row 36 and column 239 is above the cut-off, value = 0.774
#  	 Flagging column 36
#  Combination row 38 and column 239 is above the cut-off, value = 0.78
#  	 Flagging column 239
#  Combination row 63 and column 239 is above the cut-off, value = 0.792
#  	 Flagging column 63
#  Combination row 129 and column 239 is above the cut-off, value = 0.793
#  	 Flagging column 129
#  Combination row 161 and column 239 is above the cut-off, value = 0.758
#  	 Flagging column 239
#  Combination row 196 and column 239 is above the cut-off, value = 0.832
#  	 Flagging column 196
#  Combination row 203 and column 239 is above the cut-off, value = 0.77
#  	 Flagging column 203
#  Combination row 221 and column 239 is above the cut-off, value = 0.783
#  	 Flagging column 221
#  Combination row 16 and column 243 is above the cut-off, value = 0.87
#  	 Flagging column 243
#  Combination row 18 and column 243 is above the cut-off, value = 0.852
#  	 Flagging column 243
#  Combination row 26 and column 243 is above the cut-off, value = 0.818
#  	 Flagging column 243
#  Combination row 31 and column 243 is above the cut-off, value = 0.876
#  	 Flagging column 243
#  Combination row 36 and column 243 is above the cut-off, value = 0.911
#  	 Flagging column 243
#  Combination row 38 and column 243 is above the cut-off, value = 0.793
#  	 Flagging column 243
#  Combination row 63 and column 243 is above the cut-off, value = 0.834
#  	 Flagging column 243
#  Combination row 68 and column 243 is above the cut-off, value = 0.791
#  	 Flagging column 243
#  Combination row 75 and column 243 is above the cut-off, value = 0.803
#  	 Flagging column 243
#  Combination row 111 and column 243 is above the cut-off, value = 0.771
#  	 Flagging column 243
#  Combination row 129 and column 243 is above the cut-off, value = 0.904
#  	 Flagging column 243
#  Combination row 144 and column 243 is above the cut-off, value = 0.763
#  	 Flagging column 243
#  Combination row 147 and column 243 is above the cut-off, value = 0.823
#  	 Flagging column 243
#  Combination row 156 and column 243 is above the cut-off, value = 0.82
#  	 Flagging column 243
#  Combination row 158 and column 243 is above the cut-off, value = 0.809
#  	 Flagging column 243
#  Combination row 161 and column 243 is above the cut-off, value = 0.768
#  	 Flagging column 243
#  Combination row 182 and column 243 is above the cut-off, value = 0.775
#  	 Flagging column 243
#  Combination row 184 and column 243 is above the cut-off, value = 0.818
#  	 Flagging column 243
#  Combination row 189 and column 243 is above the cut-off, value = 0.786
#  	 Flagging column 243
#  Combination row 196 and column 243 is above the cut-off, value = 0.889
#  	 Flagging column 196
#  Combination row 197 and column 243 is above the cut-off, value = 0.873
#  	 Flagging column 243
#  Combination row 199 and column 243 is above the cut-off, value = 0.77
#  	 Flagging column 243
#  Combination row 202 and column 243 is above the cut-off, value = 0.805
#  	 Flagging column 243
#  Combination row 203 and column 243 is above the cut-off, value = 0.879
#  	 Flagging column 243
#  Combination row 207 and column 243 is above the cut-off, value = 0.859
#  	 Flagging column 243
#  Combination row 221 and column 243 is above the cut-off, value = 0.794
#  	 Flagging column 243
#  Combination row 239 and column 243 is above the cut-off, value = 0.817
#  	 Flagging column 243
#  Combination row 26 and column 244 is above the cut-off, value = 0.839
#  	 Flagging column 26
#  Combination row 64 and column 244 is above the cut-off, value = 0.918
#  	 Flagging column 64
#  Combination row 65 and column 244 is above the cut-off, value = 0.756
#  	 Flagging column 65
#  Combination row 86 and column 244 is above the cut-off, value = 0.879
#  	 Flagging column 244
#  Combination row 124 and column 244 is above the cut-off, value = 0.777
#  	 Flagging column 124
#  Combination row 175 and column 244 is above the cut-off, value = 0.827
#  	 Flagging column 244
#  Combination row 190 and column 244 is above the cut-off, value = 0.897
#  	 Flagging column 190
#  Combination row 191 and column 244 is above the cut-off, value = 0.925
#  	 Flagging column 191
#  Combination row 16 and column 246 is above the cut-off, value = 0.801
#  	 Flagging column 246
#  Combination row 26 and column 246 is above the cut-off, value = 0.781
#  	 Flagging column 246
#  Combination row 31 and column 246 is above the cut-off, value = 0.796
#  	 Flagging column 246
#  Combination row 36 and column 246 is above the cut-off, value = 0.818
#  	 Flagging column 246
#  Combination row 63 and column 246 is above the cut-off, value = 0.781
#  	 Flagging column 246
#  Combination row 68 and column 246 is above the cut-off, value = 0.773
#  	 Flagging column 246
#  Combination row 129 and column 246 is above the cut-off, value = 0.848
#  	 Flagging column 246
#  Combination row 184 and column 246 is above the cut-off, value = 0.754
#  	 Flagging column 246
#  Combination row 189 and column 246 is above the cut-off, value = 0.76
#  	 Flagging column 246
#  Combination row 196 and column 246 is above the cut-off, value = 0.897
#  	 Flagging column 196
#  Combination row 197 and column 246 is above the cut-off, value = 0.825
#  	 Flagging column 246
#  Combination row 199 and column 246 is above the cut-off, value = 0.774
#  	 Flagging column 246
#  Combination row 202 and column 246 is above the cut-off, value = 0.789
#  	 Flagging column 246
#  Combination row 203 and column 246 is above the cut-off, value = 0.863
#  	 Flagging column 246
#  Combination row 204 and column 246 is above the cut-off, value = 0.779
#  	 Flagging column 246
#  Combination row 207 and column 246 is above the cut-off, value = 0.828
#  	 Flagging column 246
#  Combination row 221 and column 246 is above the cut-off, value = 0.836
#  	 Flagging column 246
#  Combination row 239 and column 246 is above the cut-off, value = 0.811
#  	 Flagging column 246
#  Combination row 243 and column 246 is above the cut-off, value = 0.859
#  	 Flagging column 246
#  Combination row 141 and column 249 is above the cut-off, value = 0.754
#  	 Flagging column 249
#  Combination row 155 and column 249 is above the cut-off, value = 0.886
#  	 Flagging column 249
#  Combination row 172 and column 249 is above the cut-off, value = 0.778
#  	 Flagging column 172
#  Combination row 26 and column 264 is above the cut-off, value = 0.753
#  	 Flagging column 26
#  Combination row 57 and column 264 is above the cut-off, value = 0.75
#  	 Flagging column 57
#  Combination row 64 and column 264 is above the cut-off, value = 0.759
#  	 Flagging column 64
#  Combination row 86 and column 264 is above the cut-off, value = 0.762
#  	 Flagging column 264
#  Combination row 162 and column 264 is above the cut-off, value = 0.756
#  	 Flagging column 162
#  Combination row 190 and column 264 is above the cut-off, value = 0.78
#  	 Flagging column 190
#  Combination row 191 and column 264 is above the cut-off, value = 0.845
#  	 Flagging column 191
#  Combination row 244 and column 264 is above the cut-off, value = 0.767
#  	 Flagging column 264
#  Combination row 16 and column 265 is above the cut-off, value = 0.804
#  	 Flagging column 16
#  Combination row 26 and column 265 is above the cut-off, value = 0.802
#  	 Flagging column 26
#  Combination row 57 and column 265 is above the cut-off, value = 0.814
#  	 Flagging column 57
#  Combination row 86 and column 265 is above the cut-off, value = 0.758
#  	 Flagging column 265
#  Combination row 162 and column 265 is above the cut-off, value = 0.941
#  	 Flagging column 265
#  Combination row 184 and column 265 is above the cut-off, value = 0.856
#  	 Flagging column 184
#  Combination row 190 and column 265 is above the cut-off, value = 0.815
#  	 Flagging column 265
#  Combination row 191 and column 265 is above the cut-off, value = 0.865
#  	 Flagging column 265
#  Combination row 197 and column 265 is above the cut-off, value = 0.814
#  	 Flagging column 197
#  Combination row 203 and column 265 is above the cut-off, value = 0.768
#  	 Flagging column 203
#  Combination row 238 and column 265 is above the cut-off, value = 0.764
#  	 Flagging column 238
#  Combination row 264 and column 265 is above the cut-off, value = 0.817
#  	 Flagging column 265
#  Combination row 18 and column 266 is above the cut-off, value = 0.798
#  	 Flagging column 266
#  Combination row 19 and column 266 is above the cut-off, value = 0.751
#  	 Flagging column 266
#  Combination row 24 and column 266 is above the cut-off, value = 0.858
#  	 Flagging column 266
#  Combination row 25 and column 266 is above the cut-off, value = 0.826
#  	 Flagging column 266
#  Combination row 31 and column 266 is above the cut-off, value = 0.802
#  	 Flagging column 31
#  Combination row 32 and column 266 is above the cut-off, value = 0.818
#  	 Flagging column 266
#  Combination row 38 and column 266 is above the cut-off, value = 0.854
#  	 Flagging column 38
#  Combination row 63 and column 266 is above the cut-off, value = 0.877
#  	 Flagging column 63
#  Combination row 85 and column 266 is above the cut-off, value = 0.765
#  	 Flagging column 266
#  Combination row 115 and column 266 is above the cut-off, value = 0.751
#  	 Flagging column 266
#  Combination row 129 and column 266 is above the cut-off, value = 0.794
#  	 Flagging column 129
#  Combination row 154 and column 266 is above the cut-off, value = 0.82
#  	 Flagging column 266
#  Combination row 156 and column 266 is above the cut-off, value = 0.922
#  	 Flagging column 266
#  Combination row 158 and column 266 is above the cut-off, value = 0.927
#  	 Flagging column 266
#  Combination row 187 and column 266 is above the cut-off, value = 0.761
#  	 Flagging column 266
#  Combination row 196 and column 266 is above the cut-off, value = 0.817
#  	 Flagging column 196
#  Combination row 202 and column 266 is above the cut-off, value = 0.778
#  	 Flagging column 202
#  Combination row 203 and column 266 is above the cut-off, value = 0.828
#  	 Flagging column 203
#  Combination row 221 and column 266 is above the cut-off, value = 0.819
#  	 Flagging column 221
#  Combination row 243 and column 266 is above the cut-off, value = 0.812
#  	 Flagging column 243
#  Combination row 16 and column 271 is above the cut-off, value = 0.826
#  	 Flagging column 16
#  Combination row 31 and column 271 is above the cut-off, value = 0.834
#  	 Flagging column 31
#  Combination row 36 and column 271 is above the cut-off, value = 0.831
#  	 Flagging column 36
#  Combination row 184 and column 271 is above the cut-off, value = 0.826
#  	 Flagging column 184
#  Combination row 197 and column 271 is above the cut-off, value = 0.852
#  	 Flagging column 197
#  Combination row 203 and column 271 is above the cut-off, value = 0.83
#  	 Flagging column 203
#  Combination row 243 and column 271 is above the cut-off, value = 0.807
#  	 Flagging column 243
#  Combination row 16 and column 277 is above the cut-off, value = 0.754
#  	 Flagging column 16
#  Combination row 197 and column 277 is above the cut-off, value = 0.76
#  	 Flagging column 197
#  Combination row 203 and column 277 is above the cut-off, value = 0.752
#  	 Flagging column 203
#  Combination row 243 and column 277 is above the cut-off, value = 0.751
#  	 Flagging column 243
#  Combination row 271 and column 277 is above the cut-off, value = 0.774
#  	 Flagging column 271
#  Combination row 277 and column 282 is above the cut-off, value = 0.753
#  	 Flagging column 277
#  Combination row 24 and column 284 is above the cut-off, value = 0.809
#  	 Flagging column 284
#  Combination row 25 and column 284 is above the cut-off, value = 0.796
#  	 Flagging column 284
#  Combination row 31 and column 284 is above the cut-off, value = 0.831
#  	 Flagging column 31
#  Combination row 32 and column 284 is above the cut-off, value = 0.85
#  	 Flagging column 284
#  Combination row 36 and column 284 is above the cut-off, value = 0.776
#  	 Flagging column 36
#  Combination row 38 and column 284 is above the cut-off, value = 0.835
#  	 Flagging column 38
#  Combination row 63 and column 284 is above the cut-off, value = 0.861
#  	 Flagging column 63
#  Combination row 156 and column 284 is above the cut-off, value = 0.798
#  	 Flagging column 156
#  Combination row 158 and column 284 is above the cut-off, value = 0.801
#  	 Flagging column 158
#  Combination row 161 and column 284 is above the cut-off, value = 0.763
#  	 Flagging column 284
#  Combination row 182 and column 284 is above the cut-off, value = 0.77
#  	 Flagging column 284
#  Combination row 187 and column 284 is above the cut-off, value = 0.853
#  	 Flagging column 284
#  Combination row 193 and column 284 is above the cut-off, value = 0.773
#  	 Flagging column 284
#  Combination row 196 and column 284 is above the cut-off, value = 0.793
#  	 Flagging column 196
#  Combination row 202 and column 284 is above the cut-off, value = 0.807
#  	 Flagging column 202
#  Combination row 203 and column 284 is above the cut-off, value = 0.826
#  	 Flagging column 203
#  Combination row 212 and column 284 is above the cut-off, value = 0.766
#  	 Flagging column 284
#  Combination row 221 and column 284 is above the cut-off, value = 0.763
#  	 Flagging column 221
#  Combination row 266 and column 284 is above the cut-off, value = 0.806
#  	 Flagging column 266
#  Combination row 16 and column 291 is above the cut-off, value = 0.809
#  	 Flagging column 16
#  Combination row 31 and column 291 is above the cut-off, value = 0.859
#  	 Flagging column 31
#  Combination row 32 and column 291 is above the cut-off, value = 0.833
#  	 Flagging column 291
#  Combination row 36 and column 291 is above the cut-off, value = 0.785
#  	 Flagging column 36
#  Combination row 63 and column 291 is above the cut-off, value = 0.816
#  	 Flagging column 63
#  Combination row 129 and column 291 is above the cut-off, value = 0.78
#  	 Flagging column 129
#  Combination row 156 and column 291 is above the cut-off, value = 0.755
#  	 Flagging column 291
#  Combination row 182 and column 291 is above the cut-off, value = 0.775
#  	 Flagging column 291
#  Combination row 184 and column 291 is above the cut-off, value = 0.782
#  	 Flagging column 291
#  Combination row 187 and column 291 is above the cut-off, value = 0.803
#  	 Flagging column 291
#  Combination row 196 and column 291 is above the cut-off, value = 0.788
#  	 Flagging column 196
#  Combination row 197 and column 291 is above the cut-off, value = 0.839
#  	 Flagging column 197
#  Combination row 202 and column 291 is above the cut-off, value = 0.839
#  	 Flagging column 202
#  Combination row 203 and column 291 is above the cut-off, value = 0.855
#  	 Flagging column 203
#  Combination row 221 and column 291 is above the cut-off, value = 0.755
#  	 Flagging column 221
# ...
#  	 Flagging column 646
#  Combination row 399 and column 646 is above the cut-off, value = 0.806
#  	 Flagging column 399
#  Combination row 409 and column 646 is above the cut-off, value = 0.844
#  	 Flagging column 409
#  Combination row 417 and column 646 is above the cut-off, value = 0.771
#  	 Flagging column 417
#  Combination row 421 and column 646 is above the cut-off, value = 0.769
#  	 Flagging column 421
#  Combination row 434 and column 646 is above the cut-off, value = 0.769
#  	 Flagging column 434
#  Combination row 435 and column 646 is above the cut-off, value = 0.763
#  	 Flagging column 435
#  Combination row 459 and column 646 is above the cut-off, value = 0.78
#  	 Flagging column 459
#  Combination row 469 and column 646 is above the cut-off, value = 0.796
#  	 Flagging column 469
#  Combination row 470 and column 646 is above the cut-off, value = 0.865
#  	 Flagging column 470
#  Combination row 483 and column 646 is above the cut-off, value = 0.763
#  	 Flagging column 483
#  Combination row 501 and column 646 is above the cut-off, value = 0.863
#  	 Flagging column 501
#  Combination row 511 and column 646 is above the cut-off, value = 0.75
#  	 Flagging column 511
#  Combination row 557 and column 646 is above the cut-off, value = 0.772
#  	 Flagging column 646
#  Combination row 567 and column 646 is above the cut-off, value = 0.802
#  	 Flagging column 567
#  Combination row 569 and column 646 is above the cut-off, value = 0.82
#  	 Flagging column 569
#  Combination row 570 and column 646 is above the cut-off, value = 0.812
#  	 Flagging column 570
#  Combination row 597 and column 646 is above the cut-off, value = 0.783
#  	 Flagging column 597
#  Combination row 603 and column 646 is above the cut-off, value = 0.818
#  	 Flagging column 603
#  Combination row 605 and column 646 is above the cut-off, value = 0.794
#  	 Flagging column 605
#  Combination row 608 and column 646 is above the cut-off, value = 0.832
#  	 Flagging column 608
#  Combination row 38 and column 648 is above the cut-off, value = 0.752
#  	 Flagging column 38
#  Combination row 52 and column 648 is above the cut-off, value = 0.766
#  	 Flagging column 52
#  Combination row 193 and column 648 is above the cut-off, value = 0.796
#  	 Flagging column 193
#  Combination row 326 and column 648 is above the cut-off, value = 0.779
#  	 Flagging column 326
#  Combination row 366 and column 648 is above the cut-off, value = 0.766
#  	 Flagging column 648
#  Combination row 596 and column 648 is above the cut-off, value = 0.804
#  	 Flagging column 596
#  Combination row 16 and column 651 is above the cut-off, value = 0.751
#  	 Flagging column 651
#  Combination row 24 and column 651 is above the cut-off, value = 0.778
#  	 Flagging column 651
#  Combination row 25 and column 651 is above the cut-off, value = 0.799
#  	 Flagging column 651
#  Combination row 31 and column 651 is above the cut-off, value = 0.787
#  	 Flagging column 651
#  Combination row 32 and column 651 is above the cut-off, value = 0.751
#  	 Flagging column 651
#  Combination row 36 and column 651 is above the cut-off, value = 0.828
#  	 Flagging column 651
#  Combination row 38 and column 651 is above the cut-off, value = 0.824
#  	 Flagging column 651
#  Combination row 52 and column 651 is above the cut-off, value = 0.754
#  	 Flagging column 651
#  Combination row 56 and column 651 is above the cut-off, value = 0.753
#  	 Flagging column 651
#  Combination row 63 and column 651 is above the cut-off, value = 0.776
#  	 Flagging column 651
#  Combination row 85 and column 651 is above the cut-off, value = 0.772
#  	 Flagging column 651
#  Combination row 115 and column 651 is above the cut-off, value = 0.784
#  	 Flagging column 651
#  Combination row 129 and column 651 is above the cut-off, value = 0.818
#  	 Flagging column 129
#  Combination row 156 and column 651 is above the cut-off, value = 0.785
#  	 Flagging column 651
#  Combination row 184 and column 651 is above the cut-off, value = 0.752
#  	 Flagging column 651
#  Combination row 193 and column 651 is above the cut-off, value = 0.795
#  	 Flagging column 651
#  Combination row 196 and column 651 is above the cut-off, value = 0.808
#  	 Flagging column 196
#  Combination row 197 and column 651 is above the cut-off, value = 0.784
#  	 Flagging column 651
#  Combination row 203 and column 651 is above the cut-off, value = 0.817
#  	 Flagging column 203
#  Combination row 207 and column 651 is above the cut-off, value = 0.756
#  	 Flagging column 651
#  Combination row 221 and column 651 is above the cut-off, value = 0.842
#  	 Flagging column 221
#  Combination row 232 and column 651 is above the cut-off, value = 0.81
#  	 Flagging column 651
#  Combination row 243 and column 651 is above the cut-off, value = 0.832
#  	 Flagging column 243
#  Combination row 246 and column 651 is above the cut-off, value = 0.803
#  	 Flagging column 246
#  Combination row 266 and column 651 is above the cut-off, value = 0.767
#  	 Flagging column 651
#  Combination row 271 and column 651 is above the cut-off, value = 0.766
#  	 Flagging column 651
#  Combination row 291 and column 651 is above the cut-off, value = 0.762
#  	 Flagging column 651
#  Combination row 296 and column 651 is above the cut-off, value = 0.883
#  	 Flagging column 296
#  Combination row 301 and column 651 is above the cut-off, value = 0.814
#  	 Flagging column 651
#  Combination row 305 and column 651 is above the cut-off, value = 0.843
#  	 Flagging column 651
#  Combination row 326 and column 651 is above the cut-off, value = 0.856
#  	 Flagging column 651
#  Combination row 346 and column 651 is above the cut-off, value = 0.831
#  	 Flagging column 651
#  Combination row 347 and column 651 is above the cut-off, value = 0.755
#  	 Flagging column 651
#  Combination row 371 and column 651 is above the cut-off, value = 0.781
#  	 Flagging column 651
#  Combination row 374 and column 651 is above the cut-off, value = 0.753
#  	 Flagging column 651
#  Combination row 378 and column 651 is above the cut-off, value = 0.76
#  	 Flagging column 651
#  Combination row 399 and column 651 is above the cut-off, value = 0.886
#  	 Flagging column 399
#  Combination row 432 and column 651 is above the cut-off, value = 0.759
#  	 Flagging column 651
#  Combination row 434 and column 651 is above the cut-off, value = 0.792
#  	 Flagging column 651
#  Combination row 435 and column 651 is above the cut-off, value = 0.752
#  	 Flagging column 651
#  Combination row 441 and column 651 is above the cut-off, value = 0.755
#  	 Flagging column 651
#  Combination row 469 and column 651 is above the cut-off, value = 0.87
#  	 Flagging column 469
#  Combination row 470 and column 651 is above the cut-off, value = 0.757
#  	 Flagging column 470
#  Combination row 490 and column 651 is above the cut-off, value = 0.782
#  	 Flagging column 651
#  Combination row 494 and column 651 is above the cut-off, value = 0.8
#  	 Flagging column 651
#  Combination row 511 and column 651 is above the cut-off, value = 0.835
#  	 Flagging column 511
#  Combination row 565 and column 651 is above the cut-off, value = 0.757
#  	 Flagging column 651
#  Combination row 567 and column 651 is above the cut-off, value = 0.772
#  	 Flagging column 651
#  Combination row 570 and column 651 is above the cut-off, value = 0.769
#  	 Flagging column 651
#  Combination row 596 and column 651 is above the cut-off, value = 0.75
#  	 Flagging column 651
#  Combination row 601 and column 651 is above the cut-off, value = 0.799
#  	 Flagging column 651
#  Combination row 608 and column 651 is above the cut-off, value = 0.755
#  	 Flagging column 608
#  Combination row 633 and column 651 is above the cut-off, value = 0.847
#  	 Flagging column 651
#  Combination row 641 and column 651 is above the cut-off, value = 0.8
#  	 Flagging column 651
#  Combination row 642 and column 651 is above the cut-off, value = 0.803
#  	 Flagging column 651
#  Combination row 16 and column 655 is above the cut-off, value = 0.789
#  	 Flagging column 16
#  Combination row 26 and column 655 is above the cut-off, value = 0.784
#  	 Flagging column 26
#  Combination row 68 and column 655 is above the cut-off, value = 0.772
#  	 Flagging column 68
#  Combination row 184 and column 655 is above the cut-off, value = 0.795
#  	 Flagging column 184
#  Combination row 197 and column 655 is above the cut-off, value = 0.796
#  	 Flagging column 197
#  Combination row 203 and column 655 is above the cut-off, value = 0.754
#  	 Flagging column 203
#  Combination row 364 and column 655 is above the cut-off, value = 0.774
#  	 Flagging column 364
#  Combination row 375 and column 655 is above the cut-off, value = 0.838
#  	 Flagging column 375
#  Combination row 377 and column 655 is above the cut-off, value = 0.78
#  	 Flagging column 377
#  Combination row 378 and column 655 is above the cut-off, value = 0.785
#  	 Flagging column 378
#  Combination row 415 and column 655 is above the cut-off, value = 0.806
#  	 Flagging column 415
#  Combination row 421 and column 655 is above the cut-off, value = 0.761
#  	 Flagging column 421
#  Combination row 501 and column 655 is above the cut-off, value = 0.76
#  	 Flagging column 501
#  Combination row 570 and column 655 is above the cut-off, value = 0.778
#  	 Flagging column 570
#  Combination row 492 and column 656 is above the cut-off, value = 0.821
#  	 Flagging column 656
#  Combination row 615 and column 656 is above the cut-off, value = 0.802
#  	 Flagging column 656
#  Combination row 19 and column 665 is above the cut-off, value = 0.792
#  	 Flagging column 665
#  Combination row 24 and column 665 is above the cut-off, value = 0.801
#  	 Flagging column 665
#  Combination row 25 and column 665 is above the cut-off, value = 0.757
#  	 Flagging column 665
#  Combination row 38 and column 665 is above the cut-off, value = 0.82
#  	 Flagging column 38
#  Combination row 63 and column 665 is above the cut-off, value = 0.804
#  	 Flagging column 63
#  Combination row 156 and column 665 is above the cut-off, value = 0.78
#  	 Flagging column 156
#  Combination row 158 and column 665 is above the cut-off, value = 0.791
#  	 Flagging column 158
#  Combination row 161 and column 665 is above the cut-off, value = 0.75
#  	 Flagging column 665
#  Combination row 196 and column 665 is above the cut-off, value = 0.764
#  	 Flagging column 196
#  Combination row 239 and column 665 is above the cut-off, value = 0.751
#  	 Flagging column 239
#  Combination row 266 and column 665 is above the cut-off, value = 0.779
#  	 Flagging column 266
#  Combination row 284 and column 665 is above the cut-off, value = 0.783
#  	 Flagging column 284
#  Combination row 296 and column 665 is above the cut-off, value = 0.767
#  	 Flagging column 296
#  Combination row 305 and column 665 is above the cut-off, value = 0.824
#  	 Flagging column 305
#  Combination row 326 and column 665 is above the cut-off, value = 0.751
#  	 Flagging column 326
#  Combination row 347 and column 665 is above the cut-off, value = 0.781
#  	 Flagging column 347
#  Combination row 371 and column 665 is above the cut-off, value = 0.761
#  	 Flagging column 665
#  Combination row 399 and column 665 is above the cut-off, value = 0.777
#  	 Flagging column 399
#  Combination row 434 and column 665 is above the cut-off, value = 0.78
#  	 Flagging column 434
#  Combination row 441 and column 665 is above the cut-off, value = 0.755
#  	 Flagging column 665
#  Combination row 469 and column 665 is above the cut-off, value = 0.808
#  	 Flagging column 469
#  Combination row 490 and column 665 is above the cut-off, value = 0.817
#  	 Flagging column 490
#  Combination row 516 and column 665 is above the cut-off, value = 0.829
#  	 Flagging column 665
#  Combination row 565 and column 665 is above the cut-off, value = 0.808
#  	 Flagging column 565
#  Combination row 642 and column 665 is above the cut-off, value = 0.814
#  	 Flagging column 642
#  Combination row 492 and column 669 is above the cut-off, value = 0.763
#  	 Flagging column 669
#  Combination row 615 and column 669 is above the cut-off, value = 0.772
#  	 Flagging column 615
#  Combination row 656 and column 669 is above the cut-off, value = 0.788
#  	 Flagging column 656
#  Combination row 16 and column 670 is above the cut-off, value = 0.806
#  	 Flagging column 16
#  Combination row 31 and column 670 is above the cut-off, value = 0.809
#  	 Flagging column 31
#  Combination row 32 and column 670 is above the cut-off, value = 0.755
#  	 Flagging column 670
#  Combination row 63 and column 670 is above the cut-off, value = 0.773
#  	 Flagging column 63
#  Combination row 129 and column 670 is above the cut-off, value = 0.791
#  	 Flagging column 129
#  Combination row 131 and column 670 is above the cut-off, value = 0.796
#  	 Flagging column 670
#  Combination row 147 and column 670 is above the cut-off, value = 0.772
#  	 Flagging column 670
#  Combination row 182 and column 670 is above the cut-off, value = 0.843
#  	 Flagging column 670
#  Combination row 184 and column 670 is above the cut-off, value = 0.75
#  	 Flagging column 184
#  Combination row 187 and column 670 is above the cut-off, value = 0.75
#  	 Flagging column 670
#  Combination row 197 and column 670 is above the cut-off, value = 0.81
#  	 Flagging column 197
#  Combination row 202 and column 670 is above the cut-off, value = 0.855
#  	 Flagging column 202
#  Combination row 203 and column 670 is above the cut-off, value = 0.79
#  	 Flagging column 203
#  Combination row 212 and column 670 is above the cut-off, value = 0.79
#  	 Flagging column 670
#  Combination row 243 and column 670 is above the cut-off, value = 0.756
#  	 Flagging column 243
#  Combination row 291 and column 670 is above the cut-off, value = 0.781
#  	 Flagging column 291
#  Combination row 304 and column 670 is above the cut-off, value = 0.75
#  	 Flagging column 670
#  Combination row 320 and column 670 is above the cut-off, value = 0.757
#  	 Flagging column 670
#  Combination row 338 and column 670 is above the cut-off, value = 0.81
#  	 Flagging column 670
#  Combination row 364 and column 670 is above the cut-off, value = 0.802
#  	 Flagging column 364
#  Combination row 375 and column 670 is above the cut-off, value = 0.769
#  	 Flagging column 375
#  Combination row 377 and column 670 is above the cut-off, value = 0.803
#  	 Flagging column 377
#  Combination row 379 and column 670 is above the cut-off, value = 0.752
#  	 Flagging column 670
#  Combination row 399 and column 670 is above the cut-off, value = 0.795
#  	 Flagging column 399
#  Combination row 402 and column 670 is above the cut-off, value = 0.785
#  	 Flagging column 670
#  Combination row 409 and column 670 is above the cut-off, value = 0.767
#  	 Flagging column 670
#  Combination row 421 and column 670 is above the cut-off, value = 0.767
#  	 Flagging column 421
#  Combination row 459 and column 670 is above the cut-off, value = 0.801
#  	 Flagging column 670
#  Combination row 470 and column 670 is above the cut-off, value = 0.858
#  	 Flagging column 470
#  Combination row 486 and column 670 is above the cut-off, value = 0.75
#  	 Flagging column 670
#  Combination row 501 and column 670 is above the cut-off, value = 0.773
#  	 Flagging column 501
#  Combination row 511 and column 670 is above the cut-off, value = 0.752
#  	 Flagging column 511
#  Combination row 527 and column 670 is above the cut-off, value = 0.761
#  	 Flagging column 670
#  Combination row 539 and column 670 is above the cut-off, value = 0.768
#  	 Flagging column 670
#  Combination row 557 and column 670 is above the cut-off, value = 0.755
#  	 Flagging column 670
#  Combination row 567 and column 670 is above the cut-off, value = 0.799
#  	 Flagging column 567
#  Combination row 569 and column 670 is above the cut-off, value = 0.79
#  	 Flagging column 569
#  Combination row 570 and column 670 is above the cut-off, value = 0.819
#  	 Flagging column 570
#  Combination row 608 and column 670 is above the cut-off, value = 0.779
#  	 Flagging column 608
#  Combination row 646 and column 670 is above the cut-off, value = 0.759
#  	 Flagging column 670

# %% [markdown]
# ## Look for linear dependencies
# The function findLinearCombos uses the QR decomposition of a matrix to enumerate sets of linear combinations (if they exist).
# QR decomposition is a decomposition of a matrix A into a product A = QR of an orthogonal matrix Q and an upper triangular matrix R. QR decomposition is the basis for a particular eigenvalue algorithm, the QR algorithm.

# %%
tmp <- expr_rmcorr[, 3:ncol(expr_rmcorr)]
tmp[is.na(tmp)] <- 0
comboInfo <- findLinearCombos(tmp) 
rmLnCmb <- colnames(tmp[,comboInfo$remove])
expr_rmLnCmb <- expr_rmcorr[,-which(colnames(expr_rmcorr) %in% rmLnCmb)]
cat("Started with dimension = ", dim(expression), "\n")
cat("Post 50% NA filtering in rows and columns the dimension is", dim(expr_filtered), "\n")
cat("Post filtering highly correlated columns the dimension is", dim(expr_rmcorr), "\n")
cat("Post removing linearly dependent columns the dimension is", dim(expr_rmLnCmb))
# Out:
# Started with dimension =  204 676
# Post 50% NA filtering in rows and columns the dimension is 161 676
# Post filtering highly correlated columns the dimension is 161 495
# Post removing linearly dependent columns the dimension is 161 158

# %% [markdown]
# # Feature Selection

# %% [markdown]
# `How does var imp work, significance?`<br>
# The varImp function tracks the changes in model statistics, such as the generalized cross-validation, for each predictor and accumulates the reduction in the statistic when each predictor’s feature is added to the model. This total reduction is used as the variable importance measure.

# %%
# define a resampling approach for caret where data is divided into 8 random subsets and prediction is done on 
# 1 using the remaining 7. This approach is repeated thrice
control <- trainControl(method="repeatedcv", number=8, repeats=3)
mod_inp_mat <- expr_rmLnCmb[, 2:ncol(expr_rmLnCmb)]
mod_inp_mat$Response <- as.factor(mod_inp_mat$Response)

# %% [markdown]
# ## glmNet

# %%
m.glm <- train(Response~., data=mod_inp_mat, 
                  method="glmnet", 
                  trControl=control,
                  preProcess = c("scale", "center"),
                  na.action = na.omit
                 )

# %%
# estimate variable importance
glm.imp <- varImp(m.glm, scale=TRUE)$importance
glm.imp$Name <- rownames(glm.imp)
# summarize importance
glm.imp <- glm.imp[order(glm.imp$Overall, decreasing=TRUE),]
glm.imp <- rownames(glm.imp[1:50, ])
glm.imp
# Out:
#  [1] "`2919`"   "`9636`"   "`54674`"  "`7128`"   "`6374`"   "`56477`"
#  [7] "`4982`"   "`4210`"   "`947`"    "`648`"    "`3458`"   "`64170`"
# [13] "`29851`"  "`4100`"   "`4615`"   "`1848`"   "`6504`"   "`7177`"
# [19] "`6373`"   "`54210`"  "`3673`"   "`6097`"   "`7042`"   "`7187`"
# [25] "`8794`"   "`6891`"   "`7702`"   "`4772`"   "`5648`"   "`3662`"
# [31] "`1191`"   "`7124`"   "`7040`"   "`3958`"   "`4775`"   "`4311`"
# [37] "`598`"    "`3920`"   "`345611`" "`3716`"   "`10454`"  "`3557`"
# [43] "`3556`"   "`3554`"   "`3552`"   "`3551`"   "`3251`"   "`3559`"
# [49] "`10581`"  "`348`"

# %% [markdown]
# ## Random Forest
# A Random Forest is an ensemble technique capable of performing both regression and classification tasks with the use of multiple decision trees and a technique called Bootstrap and Aggregation, commonly known as bagging. The basic idea behind this is to combine multiple decision trees in determining the final output rather than relying on individual decision trees.

# %%
m.rf <- train(Response~., data=mod_inp_mat, 
              method="rf", 
              trControl=control,
              preProcess = c("scale", "center"),
              na.action = na.omit)

# %%
# estimate variable importance
rf.imp <- varImp(m.rf, scale=TRUE)$importance
rf.imp$Name <- rownames(rf.imp)
# summarize importance
rf.imp <- rf.imp[order(rf.imp$Overall, decreasing=TRUE),]
rf.imp <- rownames(rf.imp[1:50, ])
rf.imp
# Out:
#  [1] "`91949`" "`6504`"  "`3458`"  "`4210`"  "`6891`"  "`6756`"  "`51348`"
#  [8] "`1493`"  "`8795`"  "`2919`"  "`8794`"  "`5079`"  "`3554`"  "`933`"
# [15] "`332`"   "`947`"   "`9638`"  "`3551`"  "`3589`"  "`4772`"  "`6373`"
# [22] "`7124`"  "`2829`"  "`7187`"  "`717`"   "`684`"   "`51760`" "`10454`"
# [29] "`3383`"  "`8287`"  "`54674`" "`3559`"  "`3556`"  "`51295`" "`3557`"
# [36] "`4982`"  "`1281`"  "`3119`"  "`54210`" "`648`"   "`7128`"  "`3662`"
# [43] "`55054`" "`1848`"  "`29851`" "`3459`"  "`3569`"  "`4773`"  "`1755`"
# [50] "`5648`"

# %% [raw]
# Get top features
# Find common features
#
# Get gene names
# Find pathways

# %%
# saveRds(tmp, "tmp.rds")
# # load by giving path
# # tmp <- readRds("path")
# # R

# %%
# #parameter tuning
# modelLookup('lvq')
# # design the parameter tuning grid
# grid <- expand.grid(size=c(5,10,20,50), k=c(1,2,3,4,5))
# # train the model
# model <- train(Species~., data=iris, method="lvq", trControl=control, tuneGrid=grid)

# %% [markdown]
# > install.packages("logicFS") <br>
# Warning message:  <br>
# package ‘logicFS’ is not available (for R version 3.5.1)<br>
# >

# %% [markdown]
# ## SVM
# Support vector machines (SVMs) are a set of supervised learning methods used for classification, regression and outliers detection.
#
# It's advantageous in this case because:<br>
# 1) Effective in high dimensional spaces. <br>
# 2) Still effective in cases where number of dimensions is greater than the number of samples.

# %%
m.svm <- train(Response~., data=mod_inp_mat, 
                  method="svmLinear2", 
                  trControl=control,
                  preProcess = c("scale", "center"),
                  na.action = na.omit
                 )

# %%
# estimate variable importance
svm.imp <- varImp(m.svm, scale=TRUE)$importance
svm.imp$Name <- rownames(svm.imp)
# summarize importance
svm.imp <- svm.imp[order(svm.imp$X0, decreasing=TRUE),]
svm.imp <- rownames(svm.imp[1:50, ])
svm.imp
# Out:
#  [1] "6504"   "3458"   "29851"  "7128"   "4210"   "1493"   "6373"   "3559"
#  [9] "6891"   "2829"   "4982"   "7124"   "2919"   "3119"   "3383"   "7187"
# [17] "8794"   "940"    "717"    "6892"   "51348"  "114548" "3589"   "3290"
# [25] "1959"   "947"    "6756"   "684"    "25"     "7412"   "54674"  "345611"
# [33] "3140"   "3676"   "10148"  "596"    "648"    "3459"   "2534"   "3566"
# [41] "8832"   "85021"  "5695"   "91949"  "56477"  "718"    "9638"   "11005"
# [49] "100"    "3662"

# %% [markdown]
# ## Multi layer perceptron (Neural Network)
# A multilayer perceptron is a class of feedforward artificial neural network.

# %%
modelLookup('mlp')
# Out:
#   model parameter label         forReg forClass probModel
# 1 mlp   size      #Hidden Units TRUE   TRUE     TRUE

# %%
m.mlp <- train(Response~., data=mod_inp_mat, 
                  method="mlp", 
                  trControl=control,
                  preProcess = c("scale", "center"),
                  na.action = na.omit
                 )

# %%
# estimate variable importance
mlp.imp <- varImp(m.svm, scale=TRUE)$importance
mlp.imp$Name <- rownames(mlp.imp)
# summarize importance
mlp.imp <- mlp.imp[order(mlp.imp$X0, decreasing=TRUE),]
mlp.imp <- rownames(mlp.imp[1:50, ])
mlp.imp
# Out:
#  [1] "6504"   "3458"   "29851"  "7128"   "4210"   "1493"   "6373"   "3559"
#  [9] "6891"   "2829"   "4982"   "7124"   "2919"   "3119"   "3383"   "7187"
# [17] "8794"   "940"    "717"    "6892"   "51348"  "114548" "3589"   "3290"
# [25] "1959"   "947"    "6756"   "684"    "25"     "7412"   "54674"  "345611"
# [33] "3140"   "3676"   "10148"  "596"    "648"    "3459"   "2534"   "3566"
# [41] "8832"   "85021"  "5695"   "91949"  "56477"  "718"    "9638"   "11005"
# [49] "100"    "3662"

# %% [markdown]
# ## Neural Network

# %%
m.nnet <- train(Response~., data=mod_inp_mat, 
                  method="nnet", 
                  trControl=control,
                  preProcess = c("scale", "center"),
                  na.action = na.omit
                 )
# Out:
# # weights:  159
# initial  value 95.018419
# iter  10 value 63.450613
# iter  20 value 55.362210
# iter  30 value 54.811746
# iter  40 value 54.784273
# iter  50 value 54.782387
# iter  60 value 53.449217
# iter  70 value 53.421895
# iter  80 value 53.421666
# iter  90 value 53.421486
# iter 100 value 53.421371
# final  value 53.421371
# stopped after 100 iterations
# # weights:  475
# initial  value 98.360074
# iter  10 value 55.101432
# iter  20 value 32.549303
# iter  30 value 29.720695
# iter  40 value 28.032600
# iter  50 value 26.857895
# iter  60 value 26.757538
# iter  70 value 26.753626
# iter  80 value 26.729862
# iter  90 value 26.666932
# iter 100 value 26.659335
# final  value 26.659335
# stopped after 100 iterations
# # weights:  791
# initial  value 94.815386
# iter  10 value 34.310623
# iter  20 value 21.161808
# iter  30 value 16.190901
# iter  40 value 16.136986
# iter  50 value 11.464234
# iter  60 value 10.850612
# iter  70 value 10.834082
# iter  80 value 10.828786
# iter  90 value 10.596809
# iter 100 value 10.592185
# final  value 10.592185
# stopped after 100 iterations
# # weights:  159
# initial  value 102.594699
# iter  10 value 81.915359
# iter  20 value 61.894695
# iter  30 value 49.080402
# iter  40 value 43.005741
# iter  50 value 37.430935
# iter  60 value 32.529377
# iter  70 value 31.313737
# iter  80 value 28.613042
# iter  90 value 26.096376
# iter 100 value 21.947160
# final  value 21.947160
# stopped after 100 iterations
# # weights:  475
# initial  value 102.156311
# iter  10 value 56.514767
# iter  20 value 31.916739
# iter  30 value 21.152414
# iter  40 value 15.507591
# iter  50 value 13.547461
# iter  60 value 13.168281
# iter  70 value 13.077053
# iter  80 value 13.048865
# iter  90 value 13.032941
# iter 100 value 13.022947
# final  value 13.022947
# stopped after 100 iterations
# # weights:  791
# initial  value 110.894533
# iter  10 value 44.087719
# iter  20 value 25.735143
# iter  30 value 15.821224
# iter  40 value 13.101982
# iter  50 value 12.349366
# iter  60 value 12.048907
# iter  70 value 11.896402
# iter  80 value 11.797090
# iter  90 value 11.730758
# iter 100 value 11.649122
# final  value 11.649122
# stopped after 100 iterations
# # weights:  159
# initial  value 96.202677
# iter  10 value 72.274934
# iter  20 value 51.737235
# iter  30 value 41.188457
# iter  40 value 37.842692
# iter  50 value 34.397608
# iter  60 value 25.425456
# iter  70 value 21.925391
# iter  80 value 19.593349
# iter  90 value 19.585395
# iter 100 value 19.581595
# final  value 19.581595
# stopped after 100 iterations
# # weights:  475
# initial  value 93.785507
# iter  10 value 32.260554
# iter  20 value 27.436543
# iter  30 value 26.857094
# iter  40 value 26.495702
# iter  50 value 21.710304
# iter  60 value 21.026703
# iter  70 value 19.984137
# iter  80 value 18.926580
# iter  90 value 18.910380
# iter 100 value 17.497576
# final  value 17.497576
# stopped after 100 iterations
# # weights:  791
# initial  value 150.938543
# iter  10 value 55.467528
# iter  20 value 21.474716
# iter  30 value 10.008983
# iter  40 value 8.493055
# iter  50 value 8.177969
# iter  60 value 8.144887
# iter  70 value 8.131207
# iter  80 value 6.555632
# iter  90 value 5.867459
# iter 100 value 5.683095
# final  value 5.683095
# stopped after 100 iterations
# # weights:  159
# initial  value 101.352194
# iter  10 value 81.111967
# iter  20 value 52.986687
# iter  30 value 49.384763
# iter  40 value 49.175529
# iter  50 value 44.817562
# iter  60 value 44.798597
# iter  70 value 41.844948
# iter  80 value 41.586253
# iter  90 value 41.582758
# iter 100 value 41.581384
# final  value 41.581384
# stopped after 100 iterations
# # weights:  475
# initial  value 96.459152
# iter  10 value 61.610826
# iter  20 value 37.523442
# iter  30 value 27.265319
# iter  40 value 24.093555
# iter  50 value 23.079442
# iter  60 value 23.044596
# iter  70 value 23.018685
# iter  80 value 22.956296
# iter  90 value 22.917870
# iter 100 value 22.911333
# final  value 22.911333
# stopped after 100 iterations
# # weights:  791
# initial  value 101.313946
# iter  10 value 59.074221
# iter  20 value 30.960747
# iter  30 value 22.925018
# iter  40 value 17.974190
# iter  50 value 17.418473
# iter  60 value 12.386718
# iter  70 value 10.750459
# iter  80 value 10.634474
# iter  90 value 5.473682
# iter 100 value 4.757543
# final  value 4.757543
# stopped after 100 iterations
# # weights:  159
# initial  value 96.957018
# iter  10 value 74.213999
# iter  20 value 55.282966
# iter  30 value 46.204638
# iter  40 value 38.937622
# iter  50 value 36.658946
# iter  60 value 34.249523
# iter  70 value 31.991995
# iter  80 value 29.640113
# iter  90 value 29.514458
# iter 100 value 29.513845
# final  value 29.513845
# stopped after 100 iterations
# # weights:  475
# initial  value 103.757806
# iter  10 value 66.144366
# iter  20 value 39.544746
# iter  30 value 27.657338
# iter  40 value 18.226302
# iter  50 value 15.424789
# iter  60 value 14.964012
# iter  70 value 14.128525
# iter  80 value 13.993198
# iter  90 value 13.989458
# iter 100 value 13.989416
# final  value 13.989416
# stopped after 100 iterations
# # weights:  791
# initial  value 139.062797
# iter  10 value 59.204472
# iter  20 value 31.263911
# iter  30 value 20.314982
# iter  40 value 14.996782
# iter  50 value 13.338131
# iter  60 value 12.682405
# iter  70 value 12.314416
# iter  80 value 12.238876
# iter  90 value 12.187963
# iter 100 value 12.184573
# final  value 12.184573
# stopped after 100 iterations
# # weights:  159
# initial  value 106.845633
# iter  10 value 81.967317
# iter  20 value 46.886984
# iter  30 value 34.647970
# iter  40 value 34.272916
# iter  50 value 34.249797
# iter  60 value 34.246125
# iter  70 value 34.241865
# iter  80 value 34.239485
# iter  90 value 34.237074
# iter 100 value 34.234989
# final  value 34.234989
# stopped after 100 iterations
# # weights:  475
# initial  value 96.474669
# iter  10 value 55.436980
# iter  20 value 39.460166
# iter  30 value 38.656447
# iter  40 value 37.823217
# iter  50 value 37.518926
# iter  60 value 35.555221
# iter  70 value 34.951480
# iter  80 value 34.677611
# iter  90 value 34.444072
# iter 100 value 32.471722
# final  value 32.471722
# stopped after 100 iterations
# # weights:  791
# initial  value 98.820669
# iter  10 value 47.272669
# iter  20 value 16.658886
# iter  30 value 10.954481
# iter  40 value 9.122229
# iter  50 value 7.374451
# iter  60 value 7.190199
# iter  70 value 7.090645
# iter  80 value 2.588613
# iter  90 value 2.273181
# iter 100 value 1.696632
# final  value 1.696632
# stopped after 100 iterations
# # weights:  159
# initial  value 97.167442
# iter  10 value 78.288344
# iter  20 value 65.422039
# iter  30 value 53.589049
# iter  40 value 50.496291
# iter  50 value 48.100456
# iter  60 value 48.090228
# iter  70 value 48.088075
# iter  80 value 48.087185
# iter  90 value 48.086985
# iter 100 value 46.384960
# final  value 46.384960
# stopped after 100 iterations
# # weights:  475
# initial  value 98.953972
# iter  10 value 50.177423
# iter  20 value 34.465112
# iter  30 value 20.300095
# iter  40 value 18.682782
# iter  50 value 16.826196
# iter  60 value 16.695920
# iter  70 value 15.294650
# iter  80 value 15.056827
# iter  90 value 14.657612
# iter 100 value 14.192367
# final  value 14.192367
# stopped after 100 iterations
# # weights:  791
# initial  value 100.714600
# iter  10 value 46.723346
# iter  20 value 24.732836
# iter  30 value 16.771044
# iter  40 value 15.873240
# iter  50 value 15.481816
# iter  60 value 15.245416
# iter  70 value 15.229716
# iter  80 value 14.592682
# iter  90 value 14.459772
# iter 100 value 14.444279
# final  value 14.444279
# stopped after 100 iterations
# # weights:  159
# initial  value 96.422459
# iter  10 value 75.142113
# iter  20 value 54.585425
# iter  30 value 44.532010
# iter  40 value 40.839154
# iter  50 value 35.040138
# iter  60 value 32.534817
# iter  70 value 32.120702
# iter  80 value 32.087205
# iter  90 value 29.218734
# iter 100 value 29.051568
# final  value 29.051568
# stopped after 100 iterations
# # weights:  475
# initial  value 109.592050
# iter  10 value 61.598037
# iter  20 value 38.166476
# iter  30 value 25.592671
# iter  40 value 20.095941
# iter  50 value 16.833127
# iter  60 value 14.417610
# iter  70 value 14.234207
# iter  80 value 14.189169
# iter  90 value 14.035419
# iter 100 value 13.843729
# final  value 13.843729
# stopped after 100 iterations
# # weights:  791
# initial  value 111.344806
# iter  10 value 67.916272
# iter  20 value 34.869235
# iter  30 value 21.660161
# iter  40 value 18.634402
# iter  50 value 16.198066
# iter  60 value 14.333848
# iter  70 value 13.557661
# iter  80 value 13.210395
# iter  90 value 13.099972
# iter 100 value 13.071056
# final  value 13.071056
# stopped after 100 iterations
# # weights:  159
# initial  value 107.021166
# iter  10 value 73.799450
# iter  20 value 58.081162
# iter  30 value 55.771323
# iter  40 value 54.340466
# iter  50 value 54.324492
# iter  60 value 54.318973
# iter  70 value 54.316796
# iter  80 value 54.314675
# iter  90 value 52.754328
# iter 100 value 52.747673
# final  value 52.747673
# stopped after 100 iterations
# # weights:  475
# initial  value 117.847503
# iter  10 value 59.656782
# iter  20 value 45.155357
# iter  30 value 40.165955
# iter  40 value 38.586022
# iter  50 value 25.654228
# iter  60 value 21.975308
# iter  70 value 21.128261
# iter  80 value 17.317086
# iter  90 value 13.062719
# iter 100 value 13.011687
# final  value 13.011687
# stopped after 100 iterations
# # weights:  791
# initial  value 92.075283
# iter  10 value 34.411580
# iter  20 value 12.005811
# iter  30 value 3.699898
# iter  40 value 2.858746
# iter  50 value 2.806531
# iter  60 value 2.794081
# iter  70 value 2.779499
# iter  80 value 2.632917
# iter  90 value 2.185587
# iter 100 value 2.171043
# final  value 2.171043
# stopped after 100 iterations
# # weights:  159
# initial  value 95.207038
# iter  10 value 86.328856
# iter  20 value 57.668225
# iter  30 value 56.685389
# iter  40 value 54.365703
# iter  50 value 50.371143
# iter  60 value 47.252039
# iter  70 value 44.525453
# iter  80 value 44.480601
# iter  90 value 44.473890
# iter 100 value 44.469745
# final  value 44.469745
# stopped after 100 iterations
# # weights:  475
# initial  value 103.726815
# iter  10 value 51.336267
# iter  20 value 35.125066
# iter  30 value 29.425282
# iter  40 value 26.331765
# iter  50 value 26.115272
# iter  60 value 26.073212
# iter  70 value 24.330619
# iter  80 value 24.280743
# iter  90 value 23.867201
# iter 100 value 21.548695
# final  value 21.548695
# stopped after 100 iterations
# # weights:  791
# initial  value 98.948704
# iter  10 value 57.962556
# iter  20 value 27.048072
# iter  30 value 20.744886
# iter  40 value 19.936104
# iter  50 value 19.335329
# iter  60 value 19.105123
# iter  70 value 18.662780
# iter  80 value 18.548343
# iter  90 value 17.642359
# iter 100 value 17.078798
# final  value 17.078798
# stopped after 100 iterations
# # weights:  159
# initial  value 96.358266
# iter  10 value 70.057346
# iter  20 value 55.602520
# iter  30 value 48.122806
# iter  40 value 43.021754
# iter  50 value 39.161990
# iter  60 value 36.164075
# iter  70 value 34.118915
# iter  80 value 34.078423
# iter  90 value 34.077972
# iter 100 value 34.077963
# final  value 34.077963
# stopped after 100 iterations
# # weights:  475
# initial  value 145.497598
# iter  10 value 63.851945
# iter  20 value 41.773390
# iter  30 value 27.822321
# iter  40 value 19.158950
# iter  50 value 16.774637
# iter  60 value 16.197218
# iter  70 value 16.063329
# iter  80 value 15.864745
# iter  90 value 15.807906
# iter 100 value 15.687585
# final  value 15.687585
# stopped after 100 iterations
# # weights:  791
# initial  value 121.264564
# iter  10 value 76.201360
# iter  20 value 37.721728
# iter  30 value 21.563612
# iter  40 value 16.448492
# iter  50 value 14.885874
# iter  60 value 14.161245
# iter  70 value 13.616757
# iter  80 value 13.360514
# iter  90 value 13.316362
# iter 100 value 13.291033
# final  value 13.291033
# stopped after 100 iterations
# # weights:  159
# initial  value 102.330470
# iter  10 value 85.785108
# iter  20 value 66.007353
# iter  30 value 58.479654
# iter  40 value 52.435747
# iter  50 value 48.099588
# iter  60 value 44.919020
# iter  70 value 44.085945
# iter  80 value 43.265716
# iter  90 value 43.258706
# iter 100 value 43.255603
# final  value 43.255603
# stopped after 100 iterations
# # weights:  475
# initial  value 138.818144
# iter  10 value 50.936599
# iter  20 value 29.990387
# iter  30 value 26.851012
# iter  40 value 24.297858
# iter  50 value 20.962766
# iter  60 value 19.852508
# iter  70 value 18.917817
# iter  80 value 18.329400
# iter  90 value 18.285831
# iter 100 value 18.167753
# final  value 18.167753
# stopped after 100 iterations
# # weights:  791
# initial  value 95.155419
# iter  10 value 45.956328
# iter  20 value 12.182289
# iter  30 value 7.638132
# iter  40 value 6.739435
# iter  50 value 6.330943
# iter  60 value 6.304192
# iter  70 value 6.266446
# iter  80 value 6.245494
# iter  90 value 6.210407
# iter 100 value 5.627031
# final  value 5.627031
# stopped after 100 iterations
# # weights:  159
# initial  value 101.072397
# iter  10 value 57.628521
# iter  20 value 53.258962
# iter  30 value 53.094173
# iter  40 value 50.428624
# iter  50 value 50.242608
# iter  60 value 50.240410
# iter  70 value 50.240118
# final  value 50.239922
# converged
# # weights:  475
# initial  value 96.920987
# iter  10 value 55.074764
# iter  20 value 37.201261
# iter  30 value 33.810659
# iter  40 value 31.538822
# iter  50 value 28.741539
# iter  60 value 27.540028
# iter  70 value 24.748189
# iter  80 value 23.200306
# iter  90 value 22.836171
# iter 100 value 22.776791
# final  value 22.776791
# stopped after 100 iterations
# # weights:  791
# initial  value 98.693571
# iter  10 value 29.717018
# iter  20 value 14.631601
# iter  30 value 11.030165
# iter  40 value 7.893022
# iter  50 value 6.716251
# iter  60 value 6.221807
# iter  70 value 3.745813
# iter  80 value 3.459504
# iter  90 value 3.155672
# iter 100 value 1.919127
# final  value 1.919127
# stopped after 100 iterations
# # weights:  159
# initial  value 127.234383
# iter  10 value 71.106242
# iter  20 value 57.706028
# iter  30 value 53.182728
# iter  40 value 38.238105
# iter  50 value 33.605352
# iter  60 value 29.810234
# iter  70 value 26.966681
# iter  80 value 26.788616
# iter  90 value 26.782704
# iter 100 value 26.782643
# final  value 26.782643
# stopped after 100 iterations
# # weights:  475
# initial  value 103.499639
# iter  10 value 70.330031
# iter  20 value 39.427790
# iter  30 value 24.118109
# iter  40 value 17.173295
# iter  50 value 14.970180
# iter  60 value 13.764366
# iter  70 value 13.557788
# iter  80 value 13.461449
# iter  90 value 13.437700
# iter 100 value 13.432389
# final  value 13.432389
# stopped after 100 iterations
# # weights:  791
# initial  value 113.878141
# iter  10 value 70.314379
# iter  20 value 35.897573
# iter  30 value 19.668418
# iter  40 value 14.884556
# iter  50 value 13.547862
# iter  60 value 12.752373
# iter  70 value 12.580205
# iter  80 value 12.513303
# iter  90 value 12.471459
# iter 100 value 12.414397
# final  value 12.414397
# stopped after 100 iterations
# # weights:  159
# initial  value 95.390165
# iter  10 value 56.950528
# iter  20 value 43.712014
# iter  30 value 41.298158
# iter  40 value 41.076093
# iter  50 value 41.071753
# iter  60 value 41.069832
# iter  70 value 41.068653
# iter  80 value 41.068141
# iter  90 value 41.067594
# iter 100 value 41.067048
# final  value 41.067048
# stopped after 100 iterations
# # weights:  475
# initial  value 92.439248
# iter  10 value 46.586782
# iter  20 value 28.679720
# iter  30 value 24.556475
# iter  40 value 22.645414
# iter  50 value 20.503376
# iter  60 value 17.448129
# iter  70 value 16.665347
# iter  80 value 14.458977
# iter  90 value 14.103226
# iter 100 value 13.888726
# final  value 13.888726
# stopped after 100 iterations
# # weights:  791
# initial  value 124.072202
# iter  10 value 31.022596
# iter  20 value 7.713132
# iter  30 value 5.438738
# iter  40 value 5.387502
# iter  50 value 3.628650
# iter  60 value 3.319055
# iter  70 value 3.301846
# iter  80 value 3.253549
# iter  90 value 3.229330
# iter 100 value 2.872995
# final  value 2.872995
# stopped after 100 iterations
# # weights:  159
# initial  value 96.614008
# iter  10 value 84.412884
# iter  20 value 63.134094
# iter  30 value 58.752069
# iter  40 value 58.709195
# iter  50 value 58.707691
# final  value 58.707677
# converged
# # weights:  475
# initial  value 98.317553
# iter  10 value 51.777971
# iter  20 value 33.947378
# iter  30 value 28.871029
# iter  40 value 26.007384
# iter  50 value 25.552409
# iter  60 value 22.020663
# iter  70 value 21.840639
# iter  80 value 21.828224
# iter  90 value 21.726250
# iter 100 value 21.723023
# final  value 21.723023
# stopped after 100 iterations
# # weights:  791
# initial  value 95.800942
# iter  10 value 46.910665
# iter  20 value 15.255878
# iter  30 value 4.051620
# iter  40 value 2.663033
# iter  50 value 1.883337
# iter  60 value 1.425412
# iter  70 value 1.391929
# iter  80 value 0.033147
# iter  90 value 0.003234
# iter 100 value 0.000176
# final  value 0.000176
# stopped after 100 iterations
# # weights:  159
# initial  value 109.913580
# iter  10 value 78.295719
# iter  20 value 62.715724
# iter  30 value 51.603812
# iter  40 value 44.336503
# iter  50 value 38.123231
# iter  60 value 36.955478
# iter  70 value 29.621177
# iter  80 value 26.581163
# iter  90 value 22.885459
# iter 100 value 22.639074
# final  value 22.639074
# stopped after 100 iterations
# # weights:  475
# initial  value 110.845635
# iter  10 value 59.294017
# iter  20 value 35.584573
# iter  30 value 25.214992
# iter  40 value 21.399267
# iter  50 value 20.348129
# iter  60 value 17.076858
# iter  70 value 16.075407
# iter  80 value 15.782539
# iter  90 value 15.731145
# iter 100 value 15.479059
# final  value 15.479059
# stopped after 100 iterations
# # weights:  791
# initial  value 112.760613
# iter  10 value 60.236128
# iter  20 value 28.333736
# iter  30 value 16.354661
# iter  40 value 13.941241
# iter  50 value 12.675005
# iter  60 value 12.224031
# iter  70 value 12.103037
# iter  80 value 12.056159
# iter  90 value 12.041492
# iter 100 value 12.019481
# final  value 12.019481
# stopped after 100 iterations
# # weights:  159
# initial  value 109.387265
# iter  10 value 63.331131
# iter  20 value 54.798282
# iter  30 value 51.548930
# iter  40 value 51.474006
# iter  50 value 49.922399
# iter  60 value 49.901827
# iter  70 value 49.898719
# iter  80 value 48.263613
# iter  90 value 48.255879
# iter 100 value 46.196258
# final  value 46.196258
# stopped after 100 iterations
# # weights:  475
# initial  value 103.230740
# iter  10 value 54.699570
# iter  20 value 35.232156
# iter  30 value 29.604647
# iter  40 value 28.691681
# iter  50 value 28.458979
# iter  60 value 27.139187
# iter  70 value 27.031787
# iter  80 value 26.751232
# iter  90 value 26.734093
# iter 100 value 25.423026
# final  value 25.423026
# stopped after 100 iterations
# # weights:  791
# initial  value 107.558486
# iter  10 value 54.114218
# iter  20 value 22.831684
# iter  30 value 10.810970
# iter  40 value 9.986107
# iter  50 value 9.855244
# iter  60 value 7.313405
# iter  70 value 6.067844
# iter  80 value 5.685699
# iter  90 value 5.649027
# iter 100 value 5.633492
# final  value 5.633492
# stopped after 100 iterations
# # weights:  159
# initial  value 98.506023
# iter  10 value 80.634297
# iter  20 value 72.433683
# iter  30 value 71.526822
# iter  40 value 71.520390
# iter  50 value 71.518025
# iter  60 value 71.517258
# final  value 71.516930
# converged
# # weights:  475
# initial  value 92.976521
# iter  10 value 49.108051
# iter  20 value 29.406629
# iter  30 value 25.817227
# iter  40 value 23.863854
# iter  50 value 23.646293
# iter  60 value 20.838580
# iter  70 value 20.492437
# iter  80 value 19.940134
# iter  90 value 19.918799
# iter 100 value 19.817334
# final  value 19.817334
# stopped after 100 iterations
# # weights:  791
# initial  value 98.115475
# iter  10 value 42.216102
# iter  20 value 25.236513
# iter  30 value 20.457035
# iter  40 value 16.587368
# iter  50 value 15.886138
# iter  60 value 15.795561
# iter  70 value 15.654259
# iter  80 value 15.616475
# iter  90 value 15.581457
# iter 100 value 15.563080
# final  value 15.563080
# stopped after 100 iterations
# # weights:  159
# initial  value 117.532844
# iter  10 value 74.646513
# iter  20 value 58.849596
# iter  30 value 51.452884
# iter  40 value 42.266138
# iter  50 value 29.698751
# iter  60 value 25.480325
# iter  70 value 24.658121
# iter  80 value 24.043614
# iter  90 value 23.354013
# iter 100 value 22.435555
# final  value 22.435555
# stopped after 100 iterations
# # weights:  475
# initial  value 126.673996
# iter  10 value 69.366673
# iter  20 value 39.474931
# iter  30 value 24.283215
# iter  40 value 19.872371
# iter  50 value 18.025743
# iter  60 value 16.711977
# iter  70 value 16.453230
# iter  80 value 16.352564
# iter  90 value 16.333234
# iter 100 value 16.331907
# final  value 16.331907
# stopped after 100 iterations
# # weights:  791
# initial  value 117.585052
# iter  10 value 67.848692
# iter  20 value 40.847114
# iter  30 value 19.942469
# iter  40 value 14.498668
# iter  50 value 13.116915
# iter  60 value 12.389241
# iter  70 value 12.239224
# iter  80 value 12.071609
# iter  90 value 11.848142
# iter 100 value 11.785190
# final  value 11.785190
# stopped after 100 iterations
# # weights:  159
# initial  value 106.049186
# iter  10 value 59.692927
# iter  20 value 54.569896
# iter  30 value 54.224363
# iter  40 value 54.217908
# iter  50 value 54.212722
# iter  60 value 52.790917
# iter  70 value 51.540273
# iter  80 value 46.238179
# iter  90 value 46.180080
# iter 100 value 46.173501
# final  value 46.173501
# stopped after 100 iterations
# # weights:  475
# initial  value 124.484513
# iter  10 value 58.762885
# iter  20 value 34.988573
# iter  30 value 30.876963
# iter  40 value 29.105513
# iter  50 value 28.236063
# iter  60 value 27.236418
# iter  70 value 27.089188
# iter  80 value 26.006632
# iter  90 value 25.834107
# iter 100 value 25.250077
# final  value 25.250077
# stopped after 100 iterations
# # weights:  791
# initial  value 93.833438
# iter  10 value 36.404675
# iter  20 value 17.642154
# iter  30 value 14.152998
# iter  40 value 13.584177
# iter  50 value 12.262042
# iter  60 value 12.166498
# iter  70 value 8.048724
# iter  80 value 7.159398
# iter  90 value 6.526041
# iter 100 value 5.990642
# final  value 5.990642
# stopped after 100 iterations
# # weights:  159
# initial  value 108.846390
# iter  10 value 87.519794
# iter  20 value 66.929174
# iter  30 value 64.020576
# iter  40 value 59.482890
# iter  50 value 57.310911
# iter  60 value 57.279000
# iter  70 value 57.272489
# iter  80 value 57.270711
# iter  90 value 54.599867
# iter 100 value 54.597163
# final  value 54.597163
# stopped after 100 iterations
# # weights:  475
# initial  value 102.632345
# iter  10 value 48.368608
# iter  20 value 31.548068
# iter  30 value 29.547829
# iter  40 value 23.344453
# iter  50 value 21.987039
# iter  60 value 21.578751
# iter  70 value 21.566380
# iter  80 value 21.494477
# iter  90 value 21.161605
# iter 100 value 21.019280
# final  value 21.019280
# stopped after 100 iterations
# # weights:  791
# initial  value 112.978460
# iter  10 value 48.470629
# iter  20 value 19.870654
# iter  30 value 9.006959
# iter  40 value 4.935344
# iter  50 value 4.243477
# iter  60 value 4.167051
# iter  70 value 3.369573
# iter  80 value 2.775075
# iter  90 value 1.913045
# iter 100 value 1.911596
# final  value 1.911596
# stopped after 100 iterations
# # weights:  159
# initial  value 97.253376
# iter  10 value 64.297415
# iter  20 value 50.235433
# iter  30 value 41.203822
# iter  40 value 36.304965
# iter  50 value 31.921498
# iter  60 value 29.583968
# iter  70 value 28.854151
# iter  80 value 28.791406
# iter  90 value 28.788525
# final  value 28.788394
# converged
# # weights:  475
# initial  value 120.275994
# iter  10 value 64.996781
# iter  20 value 39.969586
# iter  30 value 26.763748
# iter  40 value 21.311409
# iter  50 value 16.648517
# iter  60 value 14.820609
# iter  70 value 13.614504
# iter  80 value 13.332080
# iter  90 value 13.032875
# iter 100 value 13.013581
# final  value 13.013581
# stopped after 100 iterations
# # weights:  791
# initial  value 118.023613
# iter  10 value 65.744130
# iter  20 value 32.698671
# iter  30 value 20.950051
# iter  40 value 16.501061
# iter  50 value 14.944465
# iter  60 value 13.881335
# iter  70 value 13.451227
# iter  80 value 13.338889
# iter  90 value 13.320851
# iter 100 value 13.316026
# final  value 13.316026
# stopped after 100 iterations
# # weights:  159
# initial  value 118.811461
# iter  10 value 78.345313
# iter  20 value 66.715426
# iter  30 value 60.887120
# iter  40 value 59.698581
# iter  50 value 57.156298
# iter  60 value 57.147918
# iter  70 value 56.137572
# iter  80 value 53.523134
# iter  90 value 53.438784
# iter 100 value 49.441084
# final  value 49.441084
# stopped after 100 iterations
# # weights:  475
# initial  value 107.405387
# iter  10 value 60.646018
# iter  20 value 38.920871
# iter  30 value 36.546951
# iter  40 value 34.319461
# iter  50 value 33.334324
# iter  60 value 32.512123
# iter  70 value 30.681068
# iter  80 value 29.095048
# iter  90 value 28.888192
# iter 100 value 28.759302
# final  value 28.759302
# stopped after 100 iterations
# # weights:  791
# initial  value 97.658786
# iter  10 value 45.187611
# iter  20 value 22.583070
# iter  30 value 17.912662
# iter  40 value 17.185129
# iter  50 value 17.049342
# iter  60 value 17.016202
# iter  70 value 16.897817
# iter  80 value 16.428960
# iter  90 value 16.325237
# iter 100 value 15.689880
# final  value 15.689880
# stopped after 100 iterations
# # weights:  159
# initial  value 99.036415
# iter  10 value 77.233175
# iter  20 value 62.159348
# iter  30 value 57.709002
# iter  40 value 57.700504
# iter  50 value 55.798369
# iter  60 value 52.295640
# iter  70 value 51.969468
# iter  80 value 51.965670
# iter  90 value 50.374767
# iter 100 value 50.371755
# final  value 50.371755
# stopped after 100 iterations
# # weights:  475
# initial  value 103.128988
# iter  10 value 47.815112
# iter  20 value 25.845854
# iter  30 value 23.435855
# iter  40 value 19.702604
# iter  50 value 13.980541
# iter  60 value 13.829028
# iter  70 value 13.782627
# iter  80 value 13.750327
# iter  90 value 13.748201
# iter 100 value 13.736317
# final  value 13.736317
# stopped after 100 iterations
# # weights:  791
# initial  value 89.348685
# iter  10 value 36.853757
# iter  20 value 9.876348
# iter  30 value 4.515584
# iter  40 value 3.018550
# iter  50 value 2.877574
# iter  60 value 2.870969
# iter  70 value 2.870848
# iter  80 value 2.870827
# final  value 2.870814
# converged
# # weights:  159
# initial  value 127.518787
# iter  10 value 71.703510
# iter  20 value 53.133398
# iter  30 value 42.955435
# iter  40 value 38.518121
# iter  50 value 29.343026
# iter  60 value 22.760796
# iter  70 value 21.205841
# iter  80 value 19.171405
# iter  90 value 18.346210
# iter 100 value 18.202523
# final  value 18.202523
# stopped after 100 iterations
# # weights:  475
# initial  value 108.417338
# iter  10 value 63.949841
# iter  20 value 37.128085
# iter  30 value 24.286016
# iter  40 value 16.526041
# iter  50 value 14.205165
# iter  60 value 13.204037
# iter  70 value 12.912137
# iter  80 value 12.497220
# iter  90 value 12.398725
# iter 100 value 12.386193
# final  value 12.386193
# stopped after 100 iterations
# # weights:  791
# initial  value 149.692428
# iter  10 value 55.942938
# iter  20 value 31.373259
# iter  30 value 17.542807
# iter  40 value 14.203897
# iter  50 value 12.968871
# iter  60 value 11.725598
# iter  70 value 10.899806
# iter  80 value 10.789109
# iter  90 value 10.765440
# iter 100 value 10.758533
# final  value 10.758533
# stopped after 100 iterations
# # weights:  159
# initial  value 92.924481
# iter  10 value 72.385822
# iter  20 value 64.909588
# iter  30 value 57.388135
# iter  40 value 55.766523
# iter  50 value 54.989457
# iter  60 value 54.985634
# iter  70 value 49.806162
# iter  80 value 46.267411
# iter  90 value 46.126316
# iter 100 value 44.699074
# final  value 44.699074
# stopped after 100 iterations
# # weights:  475
# initial  value 122.993737
# iter  10 value 50.803033
# iter  20 value 32.990363
# iter  30 value 25.654250
# iter  40 value 21.432924
# iter  50 value 18.522907
# iter  60 value 16.513071
# iter  70 value 15.545626
# iter  80 value 15.456607
# iter  90 value 15.377047
# iter 100 value 15.354801
# final  value 15.354801
# stopped after 100 iterations
# # weights:  791
# initial  value 122.006671
# iter  10 value 49.387644
# iter  20 value 15.417072
# iter  30 value 13.899761
# iter  40 value 13.814697
# iter  50 value 13.786724
# iter  60 value 12.931585
# iter  70 value 10.835446
# iter  80 value 10.730718
# iter  90 value 8.708903
# iter 100 value 8.493928
# final  value 8.493928
# stopped after 100 iterations
# # weights:  159
# initial  value 128.087464
# iter  10 value 64.912028
# iter  20 value 55.535963
# iter  30 value 51.238426
# iter  40 value 49.232782
# iter  50 value 48.941786
# iter  60 value 44.629346
# iter  70 value 44.605841
# iter  80 value 44.601892
# iter  90 value 44.598391
# iter 100 value 44.596784
# final  value 44.596784
# stopped after 100 iterations
# # weights:  475
# initial  value 113.452295
# iter  10 value 51.372348
# iter  20 value 34.470840
# iter  30 value 28.159122
# iter  40 value 27.479925
# iter  50 value 25.900933
# iter  60 value 25.862769
# iter  70 value 24.224474
# iter  80 value 22.441896
# iter  90 value 22.375545
# iter 100 value 22.371375
# final  value 22.371375
# stopped after 100 iterations
# # weights:  791
# initial  value 97.845787
# iter  10 value 30.102984
# iter  20 value 12.875373
# iter  30 value 9.665818
# iter  40 value 8.958930
# iter  50 value 8.599022
# iter  60 value 8.454819
# iter  70 value 4.541974
# iter  80 value 3.692586
# iter  90 value 2.410814
# iter 100 value 1.921408
# final  value 1.921408
# stopped after 100 iterations
# # weights:  159
# initial  value 106.176405
# iter  10 value 70.987082
# iter  20 value 57.509447
# iter  30 value 39.416962
# iter  40 value 34.660739
# iter  50 value 33.698720
# iter  60 value 31.549849
# iter  70 value 31.478363
# iter  80 value 29.743701
# iter  90 value 29.136319
# iter 100 value 29.065186
# final  value 29.065186
# stopped after 100 iterations
# # weights:  475
# initial  value 101.301450
# iter  10 value 63.049197
# iter  20 value 32.437100
# iter  30 value 21.611171
# iter  40 value 16.637239
# iter  50 value 14.210678
# iter  60 value 13.834854
# iter  70 value 13.401754
# iter  80 value 13.021893
# iter  90 value 12.896034
# iter 100 value 12.890823
# final  value 12.890823
# stopped after 100 iterations
# # weights:  791
# initial  value 111.936184
# iter  10 value 46.456191
# iter  20 value 23.780839
# iter  30 value 15.553042
# iter  40 value 13.764733
# iter  50 value 12.741164
# iter  60 value 12.456716
# iter  70 value 12.321564
# iter  80 value 12.259788
# iter  90 value 12.252108
# iter 100 value 12.248173
# final  value 12.248173
# stopped after 100 iterations
# # weights:  159
# initial  value 105.376479
# iter  10 value 61.904098
# iter  20 value 46.923343
# iter  30 value 27.656609
# iter  40 value 26.535987
# iter  50 value 23.928947
# iter  60 value 23.909265
# iter  70 value 23.901826
# iter  80 value 23.900052
# iter  90 value 23.899234
# iter 100 value 23.898774
# final  value 23.898774
# stopped after 100 iterations
# # weights:  475
# initial  value 107.596019
# iter  10 value 44.851214
# iter  20 value 24.243177
# iter  30 value 19.225787
# iter  40 value 18.969564
# iter  50 value 18.587329
# iter  60 value 18.570412
# iter  70 value 18.556064
# iter  80 value 18.548442
# iter  90 value 18.538169
# iter 100 value 18.528992
# final  value 18.528992
# stopped after 100 iterations
# # weights:  791
# initial  value 95.642149
# iter  10 value 47.725176
# iter  20 value 28.681090
# iter  30 value 26.236341
# iter  40 value 24.937979
# iter  50 value 24.574511
# iter  60 value 24.190466
# iter  70 value 23.486072
# iter  80 value 22.713625
# iter  90 value 22.119255
# iter 100 value 22.088484
# final  value 22.088484
# stopped after 100 iterations
# # weights:  159
# initial  value 93.703989
# iter  10 value 78.883802
# iter  20 value 67.318584
# iter  30 value 64.823069
# iter  40 value 58.516254
# iter  50 value 56.523206
# iter  60 value 55.551219
# iter  70 value 54.191047
# iter  80 value 54.175272
# iter  90 value 54.173336
# iter 100 value 54.117659
# final  value 54.117659
# stopped after 100 iterations
# # weights:  475
# initial  value 95.814138
# iter  10 value 48.481928
# iter  20 value 26.825048
# iter  30 value 19.090075
# iter  40 value 17.427387
# iter  50 value 17.286015
# iter  60 value 17.282624
# iter  70 value 17.170244
# iter  80 value 17.053376
# iter  90 value 17.051293
# iter 100 value 16.930631
# final  value 16.930631
# stopped after 100 iterations
# # weights:  791
# initial  value 113.408533
# iter  10 value 46.350355
# iter  20 value 15.670459
# iter  30 value 9.470459
# iter  40 value 7.129820
# iter  50 value 6.981295
# iter  60 value 6.859286
# iter  70 value 6.758436
# iter  80 value 6.748817
# iter  90 value 6.638416
# iter 100 value 6.621649
# final  value 6.621649
# stopped after 100 iterations
# # weights:  159
# initial  value 120.299647
# iter  10 value 64.412538
# iter  20 value 52.830388
# iter  30 value 42.183144
# iter  40 value 38.258744
# iter  50 value 33.750496
# iter  60 value 30.858988
# iter  70 value 28.765506
# iter  80 value 26.441761
# iter  90 value 26.007674
# iter 100 value 25.996611
# final  value 25.996611
# stopped after 100 iterations
# # weights:  475
# initial  value 151.725698
# iter  10 value 62.124328
# iter  20 value 38.088783
# iter  30 value 28.307494
# iter  40 value 24.491969
# iter  50 value 17.755160
# iter  60 value 15.102853
# iter  70 value 14.281368
# iter  80 value 13.886246
# iter  90 value 13.804527
# iter 100 value 13.797448
# final  value 13.797448
# stopped after 100 iterations
# # weights:  791
# initial  value 119.232330
# iter  10 value 63.096591
# iter  20 value 30.487311
# iter  30 value 20.440021
# iter  40 value 15.263965
# iter  50 value 14.192183
# iter  60 value 13.472915
# iter  70 value 13.192017
# iter  80 value 12.998510
# iter  90 value 12.925291
# iter 100 value 12.855482
# final  value 12.855482
# stopped after 100 iterations
# # weights:  159
# initial  value 110.584550
# iter  10 value 71.310432
# iter  20 value 57.750346
# iter  30 value 46.345907
# iter  40 value 42.943730
# iter  50 value 42.903240
# iter  60 value 39.955245
# iter  70 value 39.937166
# iter  80 value 39.934312
# iter  90 value 38.148708
# iter 100 value 38.135927
# final  value 38.135927
# stopped after 100 iterations
# # weights:  475
# initial  value 124.423414
# iter  10 value 53.054058
# iter  20 value 33.958841
# iter  30 value 24.613674
# iter  40 value 20.617882
# iter  50 value 18.768539
# iter  60 value 17.797265
# iter  70 value 17.608251
# iter  80 value 17.544186
# iter  90 value 17.533261
# iter 100 value 17.528078
# final  value 17.528078
# stopped after 100 iterations
# # weights:  791
# initial  value 99.608553
# iter  10 value 68.414837
# iter  20 value 25.848843
# iter  30 value 14.914777
# iter  40 value 14.665597
# iter  50 value 14.632778
# iter  60 value 14.209108
# iter  70 value 13.412576
# iter  80 value 12.442602
# iter  90 value 12.384278
# iter 100 value 12.361824
# final  value 12.361824
# stopped after 100 iterations
# # weights:  159
# initial  value 105.650116
# iter  10 value 62.555783
# iter  20 value 53.080099
# iter  30 value 51.193618
# iter  40 value 50.548172
# iter  50 value 50.546234
# iter  60 value 50.544325
# iter  70 value 50.543057
# iter  80 value 50.542859
# iter  90 value 50.542448
# iter 100 value 50.542306
# final  value 50.542306
# stopped after 100 iterations
# # weights:  475
# initial  value 114.450672
# iter  10 value 56.711338
# iter  20 value 33.069668
# iter  30 value 27.942286
# iter  40 value 26.533102
# iter  50 value 24.141172
# iter  60 value 22.638787
# iter  70 value 22.137588
# iter  80 value 21.494178
# iter  90 value 21.076494
# iter 100 value 20.780274
# final  value 20.780274
# stopped after 100 iterations
# # weights:  791
# initial  value 103.973785
# iter  10 value 45.272676
# iter  20 value 18.734349
# iter  30 value 12.310725
# iter  40 value 11.975528
# iter  50 value 11.883882
# iter  60 value 8.401021
# iter  70 value 7.582777
# iter  80 value 7.464138
# iter  90 value 7.210399
# iter 100 value 4.421518
# final  value 4.421518
# stopped after 100 iterations
# # weights:  159
# initial  value 97.183663
# iter  10 value 73.375085
# iter  20 value 57.196751
# iter  30 value 48.285139
# iter  40 value 44.236864
# iter  50 value 36.800791
# iter  60 value 30.711559
# iter  70 value 27.431038
# iter  80 value 27.270440
# iter  90 value 27.266265
# final  value 27.266227
# converged
# # weights:  475
# initial  value 137.576923
# iter  10 value 67.074210
# iter  20 value 44.687636
# iter  30 value 28.564471
# iter  40 value 21.584863
# iter  50 value 19.325962
# iter  60 value 18.415037
# iter  70 value 18.068348
# iter  80 value 17.423311
# iter  90 value 17.270167
# iter 100 value 17.143426
# final  value 17.143426
# stopped after 100 iterations
# # weights:  791
# initial  value 110.978606
# iter  10 value 61.351944
# iter  20 value 32.401628
# iter  30 value 20.605891
# iter  40 value 16.398986
# iter  50 value 15.052325
# iter  60 value 14.168057
# iter  70 value 13.466385
# iter  80 value 13.192926
# iter  90 value 13.086079
# iter 100 value 13.028691
# final  value 13.028691
# stopped after 100 iterations
# # weights:  159
# initial  value 98.760026
# iter  10 value 66.057457
# iter  20 value 60.777643
# iter  30 value 59.433850
# iter  40 value 56.831748
# iter  50 value 55.486849
# iter  60 value 55.337522
# iter  70 value 55.321470
# iter  80 value 51.636774
# iter  90 value 49.121142
# iter 100 value 46.596155
# final  value 46.596155
# stopped after 100 iterations
# # weights:  475
# initial  value 95.929825
# iter  10 value 61.650798
# iter  20 value 35.018478
# iter  30 value 31.784804
# iter  40 value 26.183909
# iter  50 value 24.146302
# iter  60 value 24.024476
# iter  70 value 22.144263
# iter  80 value 21.901057
# iter  90 value 21.284851
# iter 100 value 20.959918
# final  value 20.959918
# stopped after 100 iterations
# # weights:  791
# initial  value 99.430370
# iter  10 value 44.836154
# iter  20 value 12.220319
# iter  30 value 4.262269
# iter  40 value 1.904100
# iter  50 value 1.744357
# iter  60 value 1.704241
# iter  70 value 1.697882
# iter  80 value 1.667787
# iter  90 value 1.639929
# iter 100 value 1.600549
# final  value 1.600549
# stopped after 100 iterations
# # weights:  159
# initial  value 119.526031
# iter  10 value 71.859722
# iter  20 value 58.068915
# iter  30 value 46.860523
# iter  40 value 46.559463
# iter  50 value 46.545140
# iter  60 value 46.542228
# iter  70 value 46.541746
# iter  80 value 46.541670
# final  value 46.541640
# converged
# # weights:  475
# initial  value 98.368876
# iter  10 value 37.273653
# iter  20 value 26.613107
# iter  30 value 25.477533
# iter  40 value 24.715882
# iter  50 value 24.237957
# iter  60 value 23.660050
# iter  70 value 23.633525
# iter  80 value 23.499936
# iter  90 value 23.278915
# iter 100 value 23.126189
# final  value 23.126189
# stopped after 100 iterations
# # weights:  791
# initial  value 124.964502
# iter  10 value 43.783294
# iter  20 value 22.617200
# iter  30 value 14.540649
# iter  40 value 14.189071
# iter  50 value 13.928266
# iter  60 value 13.498738
# iter  70 value 8.231407
# iter  80 value 4.077131
# iter  90 value 3.608517
# iter 100 value 3.542767
# final  value 3.542767
# stopped after 100 iterations
# # weights:  159
# initial  value 106.078869
# iter  10 value 71.257942
# iter  20 value 50.898257
# iter  30 value 39.309961
# iter  40 value 33.593140
# iter  50 value 31.427180
# iter  60 value 28.427594
# iter  70 value 27.493098
# iter  80 value 27.326748
# iter  90 value 27.142788
# iter 100 value 25.241468
# final  value 25.241468
# stopped after 100 iterations
# # weights:  475
# initial  value 104.701248
# iter  10 value 73.436987
# iter  20 value 47.667871
# iter  30 value 27.818065
# iter  40 value 20.121378
# iter  50 value 16.453268
# iter  60 value 15.354537
# iter  70 value 14.990510
# iter  80 value 14.705440
# iter  90 value 14.570671
# iter 100 value 14.436704
# final  value 14.436704
# stopped after 100 iterations
# # weights:  791
# initial  value 111.561147
# iter  10 value 52.694004
# iter  20 value 29.898691
# iter  30 value 20.817348
# iter  40 value 15.808014
# iter  50 value 14.857120
# iter  60 value 14.365660
# iter  70 value 14.242967
# iter  80 value 14.059602
# iter  90 value 13.946690
# iter 100 value 13.906558
# final  value 13.906558
# stopped after 100 iterations
# # weights:  159
# initial  value 107.138100
# iter  10 value 72.133513
# iter  20 value 65.309704
# iter  30 value 62.080312
# iter  40 value 57.402303
# iter  50 value 57.273877
# iter  60 value 56.179504
# iter  70 value 56.173397
# iter  80 value 56.168774
# iter  90 value 56.165517
# iter 100 value 56.160878
# final  value 56.160878
# stopped after 100 iterations
# # weights:  475
# initial  value 115.060477
# iter  10 value 54.303803
# iter  20 value 31.771647
# iter  30 value 17.499756
# iter  40 value 13.326356
# iter  50 value 8.823196
# iter  60 value 8.779783
# iter  70 value 8.762877
# iter  80 value 8.747484
# iter  90 value 8.739008
# iter 100 value 8.727921
# final  value 8.727921
# stopped after 100 iterations
# # weights:  791
# initial  value 114.442222
# iter  10 value 38.025432
# iter  20 value 21.949832
# iter  30 value 19.089087
# iter  40 value 16.729010
# iter  50 value 12.387379
# iter  60 value 10.426970
# iter  70 value 7.271935
# iter  80 value 6.972049
# iter  90 value 6.034608
# iter 100 value 4.215464
# final  value 4.215464
# stopped after 100 iterations
# # weights:  159
# initial  value 96.398856
# iter  10 value 62.733831
# iter  20 value 56.137087
# iter  30 value 50.262106
# iter  40 value 47.644803
# iter  50 value 47.623307
# iter  60 value 47.618108
# iter  70 value 47.617187
# iter  80 value 47.616796
# iter  90 value 47.616497
# iter 100 value 47.616227
# final  value 47.616227
# stopped after 100 iterations
# # weights:  475
# initial  value 100.401845
# iter  10 value 58.802409
# iter  20 value 29.981054
# iter  30 value 15.753012
# iter  40 value 14.471520
# iter  50 value 13.838401
# iter  60 value 13.117588
# iter  70 value 9.163845
# iter  80 value 8.151322
# iter  90 value 8.110745
# iter 100 value 7.229684
# final  value 7.229684
# stopped after 100 iterations
# # weights:  791
# initial  value 101.401658
# iter  10 value 52.356047
# iter  20 value 20.191853
# iter  30 value 9.930897
# iter  40 value 8.423674
# iter  50 value 7.839431
# iter  60 value 7.604044
# iter  70 value 6.946979
# iter  80 value 5.314596
# iter  90 value 5.216425
# iter 100 value 5.208333
# final  value 5.208333
# stopped after 100 iterations
# # weights:  159
# initial  value 95.567599
# iter  10 value 72.896586
# iter  20 value 48.641771
# iter  30 value 36.721862
# iter  40 value 31.258250
# iter  50 value 25.667987
# iter  60 value 24.700135
# iter  70 value 24.667352
# iter  80 value 22.289890
# iter  90 value 22.196009
# iter 100 value 22.191543
# final  value 22.191543
# stopped after 100 iterations
# # weights:  475
# initial  value 113.515251
# iter  10 value 56.161103
# iter  20 value 30.044136
# iter  30 value 22.532561
# iter  40 value 17.286559
# iter  50 value 15.625848
# iter  60 value 14.020130
# iter  70 value 13.005092
# iter  80 value 12.869974
# iter  90 value 12.756507
# iter 100 value 12.640642
# final  value 12.640642
# stopped after 100 iterations
# # weights:  791
# initial  value 123.909384
# iter  10 value 55.885299
# iter  20 value 27.144482
# iter  30 value 15.152722
# iter  40 value 12.692927
# iter  50 value 12.214363
# iter  60 value 11.883919
# iter  70 value 11.783391
# iter  80 value 11.662848
# iter  90 value 11.637234
# iter 100 value 11.627483
# final  value 11.627483
# stopped after 100 iterations
# # weights:  159
# initial  value 96.414785
# iter  10 value 66.169387
# iter  20 value 56.393905
# iter  30 value 46.712586
# iter  40 value 46.150390
# iter  50 value 46.136782
# iter  60 value 44.531871
# iter  70 value 44.524384
# iter  80 value 44.519496
# iter  90 value 44.513560
# iter 100 value 42.902051
# final  value 42.902051
# stopped after 100 iterations
# # weights:  475
# initial  value 105.940357
# iter  10 value 30.010124
# iter  20 value 16.409156
# iter  30 value 10.080105
# iter  40 value 7.999900
# iter  50 value 3.553841
# iter  60 value 2.513056
# iter  70 value 2.413828
# iter  80 value 2.389766
# iter  90 value 2.386294
# iter 100 value 2.379584
# final  value 2.379584
# stopped after 100 iterations
# # weights:  791
# initial  value 104.183948
# iter  10 value 15.038955
# iter  20 value 6.711367
# iter  30 value 5.622211
# iter  40 value 5.548432
# iter  50 value 5.493389
# iter  60 value 5.372656
# iter  70 value 5.258846
# iter  80 value 5.242156
# iter  90 value 1.273886
# iter 100 value 0.474777
# final  value 0.474777
# stopped after 100 iterations
# # weights:  159
# initial  value 107.167364
# iter  10 value 67.058835
# iter  20 value 64.033190
# iter  30 value 62.886760
# iter  40 value 62.877080
# iter  50 value 60.776760
# iter  60 value 59.597474
# iter  70 value 59.581056
# iter  80 value 59.580696
# final  value 59.580685
# converged
# # weights:  475
# initial  value 93.783766
# iter  10 value 42.459866
# iter  20 value 35.458219
# iter  30 value 33.812632
# iter  40 value 30.120124
# iter  50 value 26.357527
# iter  60 value 24.922595
# iter  70 value 24.336351
# iter  80 value 24.112991
# iter  90 value 23.877965
# iter 100 value 23.824014
# final  value 23.824014
# stopped after 100 iterations
# # weights:  791
# initial  value 100.261514
# iter  10 value 50.433682
# iter  20 value 27.327009
# iter  30 value 20.491501
# iter  40 value 16.990745
# iter  50 value 16.040248
# iter  60 value 15.331201
# iter  70 value 15.268186
# iter  80 value 14.246984
# iter  90 value 13.877075
# iter 100 value 13.165587
# final  value 13.165587
# stopped after 100 iterations
# # weights:  159
# initial  value 96.339443
# iter  10 value 80.950462
# iter  20 value 64.389216
# iter  30 value 56.304341
# iter  40 value 49.495285
# iter  50 value 45.577813
# iter  60 value 40.176480
# iter  70 value 39.496324
# iter  80 value 37.437257
# iter  90 value 36.128722
# iter 100 value 32.366695
# final  value 32.366695
# stopped after 100 iterations
# # weights:  475
# initial  value 103.418142
# iter  10 value 76.125982
# iter  20 value 56.659417
# iter  30 value 35.841385
# iter  40 value 25.323832
# iter  50 value 20.184846
# iter  60 value 18.775475
# iter  70 value 18.376881
# iter  80 value 18.186876
# iter  90 value 17.806088
# iter 100 value 17.524488
# final  value 17.524488
# stopped after 100 iterations
# # weights:  791
# initial  value 107.887456
# iter  10 value 60.638440
# iter  20 value 31.735414
# iter  30 value 17.045817
# iter  40 value 14.772682
# iter  50 value 13.822763
# iter  60 value 12.865911
# iter  70 value 12.597079
# iter  80 value 12.530493
# iter  90 value 12.485194
# iter 100 value 12.427764
# final  value 12.427764
# stopped after 100 iterations
# # weights:  159
# initial  value 109.008797
# iter  10 value 65.501495
# iter  20 value 59.360343
# iter  30 value 53.153851
# iter  40 value 52.013047
# iter  50 value 51.996728
# iter  60 value 50.534904
# iter  70 value 50.528399
# iter  80 value 50.524105
# iter  90 value 50.520470
# iter 100 value 50.517560
# final  value 50.517560
# stopped after 100 iterations
# # weights:  475
# initial  value 119.811860
# iter  10 value 62.217628
# iter  20 value 38.037461
# iter  30 value 28.226622
# iter  40 value 25.298674
# iter  50 value 25.147361
# iter  60 value 24.952472
# iter  70 value 23.985119
# iter  80 value 23.703636
# iter  90 value 22.438032
# iter 100 value 21.189461
# final  value 21.189461
# stopped after 100 iterations
# # weights:  791
# initial  value 117.863873
# iter  10 value 46.631662
# iter  20 value 15.917643
# iter  30 value 9.143180
# iter  40 value 8.621925
# iter  50 value 8.168689
# iter  60 value 6.840883
# iter  70 value 2.635742
# iter  80 value 1.191177
# iter  90 value 0.276811
# iter 100 value 0.225163
# final  value 0.225163
# stopped after 100 iterations
# # weights:  159
# initial  value 95.913920
# iter  10 value 76.202434
# iter  20 value 59.537781
# iter  30 value 54.159303
# iter  40 value 52.890160
# iter  50 value 51.196288
# iter  60 value 51.188559
# iter  70 value 49.639010
# iter  80 value 49.638300
# iter  90 value 49.637656
# iter 100 value 49.637158
# final  value 49.637158
# stopped after 100 iterations
# # weights:  475
# initial  value 100.804002
# iter  10 value 48.455255
# iter  20 value 33.397480
# iter  30 value 24.176007
# iter  40 value 19.327467
# iter  50 value 14.483816
# iter  60 value 12.594291
# iter  70 value 12.373591
# iter  80 value 10.908432
# iter  90 value 10.901765
# iter 100 value 10.899428
# final  value 10.899428
# stopped after 100 iterations
# # weights:  791
# initial  value 119.995712
# iter  10 value 45.101252
# iter  20 value 25.495055
# iter  30 value 17.738560
# iter  40 value 15.919144
# iter  50 value 15.405750
# iter  60 value 14.810500
# iter  70 value 14.395644
# iter  80 value 13.894491
# iter  90 value 13.217366
# iter 100 value 12.821733
# final  value 12.821733
# stopped after 100 iterations
# # weights:  159
# initial  value 112.549975
# iter  10 value 79.672290
# iter  20 value 62.875909
# iter  30 value 52.268609
# iter  40 value 44.320858
# iter  50 value 41.367124
# iter  60 value 38.358141
# iter  70 value 34.244382
# iter  80 value 31.754416
# iter  90 value 31.579984
# iter 100 value 29.919946
# final  value 29.919946
# stopped after 100 iterations
# # weights:  475
# initial  value 103.829212
# iter  10 value 70.677442
# iter  20 value 46.216124
# iter  30 value 32.068936
# iter  40 value 21.299071
# iter  50 value 16.153365
# iter  60 value 15.226617
# iter  70 value 14.834010
# iter  80 value 14.796623
# iter  90 value 14.764552
# iter 100 value 14.702509
# final  value 14.702509
# stopped after 100 iterations
# # weights:  791
# initial  value 117.389137
# iter  10 value 56.632398
# iter  20 value 29.089881
# iter  30 value 17.056271
# iter  40 value 14.374625
# iter  50 value 13.363358
# iter  60 value 13.051518
# iter  70 value 12.846012
# iter  80 value 12.760172
# iter  90 value 12.720293
# iter 100 value 12.693136
# final  value 12.693136
# stopped after 100 iterations
# # weights:  159
# initial  value 94.402949
# iter  10 value 79.525629
# iter  20 value 58.495063
# ...
# iter  30 value 15.416932
# iter  40 value 11.552649
# iter  50 value 8.239204
# iter  60 value 7.051248
# iter  70 value 6.855575
# iter  80 value 6.178367
# iter  90 value 3.792748
# iter 100 value 3.735968
# final  value 3.735968
# stopped after 100 iterations
# # weights:  159
# initial  value 106.852755
# iter  10 value 66.996495
# iter  20 value 39.183863
# iter  30 value 26.690006
# iter  40 value 26.357033
# iter  50 value 26.330910
# iter  60 value 26.327319
# iter  70 value 26.325162
# iter  80 value 26.324978
# iter  90 value 26.324768
# iter 100 value 26.324747
# final  value 26.324747
# stopped after 100 iterations
# # weights:  475
# initial  value 91.451848
# iter  10 value 50.549975
# iter  20 value 40.755006
# iter  30 value 37.354157
# iter  40 value 36.131443
# iter  50 value 35.451321
# iter  60 value 34.971452
# iter  70 value 34.904785
# iter  80 value 33.945119
# iter  90 value 33.938291
# iter 100 value 33.936716
# final  value 33.936716
# stopped after 100 iterations
# # weights:  791
# initial  value 107.794612
# iter  10 value 35.455775
# iter  20 value 16.849656
# iter  30 value 9.499189
# iter  40 value 6.357182
# iter  50 value 1.110923
# iter  60 value 0.122224
# iter  70 value 0.037064
# iter  80 value 0.014189
# iter  90 value 0.006677
# iter 100 value 0.001949
# final  value 0.001949
# stopped after 100 iterations
# # weights:  159
# initial  value 98.474779
# iter  10 value 80.976300
# iter  20 value 59.599804
# iter  30 value 51.870774
# iter  40 value 47.558356
# iter  50 value 44.326195
# iter  60 value 37.323249
# iter  70 value 28.984014
# iter  80 value 25.900314
# iter  90 value 23.009249
# iter 100 value 22.530233
# final  value 22.530233
# stopped after 100 iterations
# # weights:  475
# initial  value 105.504964
# iter  10 value 71.883906
# iter  20 value 45.577339
# iter  30 value 24.049600
# iter  40 value 17.076311
# iter  50 value 14.823086
# iter  60 value 14.238801
# iter  70 value 14.150666
# iter  80 value 14.019301
# iter  90 value 13.976059
# iter 100 value 13.793321
# final  value 13.793321
# stopped after 100 iterations
# # weights:  791
# initial  value 112.401678
# iter  10 value 60.583442
# iter  20 value 33.115134
# iter  30 value 20.814409
# iter  40 value 14.053482
# iter  50 value 13.002925
# iter  60 value 12.607230
# iter  70 value 12.473115
# iter  80 value 12.360818
# iter  90 value 12.266781
# iter 100 value 12.218290
# final  value 12.218290
# stopped after 100 iterations
# # weights:  159
# initial  value 100.078918
# iter  10 value 73.342146
# iter  20 value 46.565816
# iter  30 value 44.914204
# iter  40 value 43.311440
# iter  50 value 43.299893
# iter  60 value 41.666358
# iter  70 value 41.659971
# iter  80 value 41.653989
# iter  90 value 41.644809
# iter 100 value 41.587885
# final  value 41.587885
# stopped after 100 iterations
# # weights:  475
# initial  value 116.692844
# iter  10 value 53.830028
# iter  20 value 35.432446
# iter  30 value 34.185822
# iter  40 value 32.948790
# iter  50 value 31.623520
# iter  60 value 30.083394
# iter  70 value 26.517730
# iter  80 value 24.835440
# iter  90 value 23.797037
# iter 100 value 23.059524
# final  value 23.059524
# stopped after 100 iterations
# # weights:  791
# initial  value 92.079395
# iter  10 value 37.550654
# iter  20 value 12.782402
# iter  30 value 8.574266
# iter  40 value 6.701022
# iter  50 value 6.628574
# iter  60 value 6.595267
# iter  70 value 6.507598
# iter  80 value 6.207315
# iter  90 value 4.108755
# iter 100 value 4.061318
# final  value 4.061318
# stopped after 100 iterations
# # weights:  159
# initial  value 99.586111
# iter  10 value 67.711377
# iter  20 value 50.830213
# iter  30 value 50.585781
# iter  40 value 50.565822
# iter  50 value 48.558025
# iter  60 value 48.203107
# iter  70 value 48.202549
# final  value 48.202449
# converged
# # weights:  475
# initial  value 96.633526
# iter  10 value 54.541546
# iter  20 value 16.777325
# iter  30 value 10.498749
# iter  40 value 9.745076
# iter  50 value 9.566743
# iter  60 value 9.515441
# iter  70 value 9.169304
# iter  80 value 8.952660
# iter  90 value 8.948045
# iter 100 value 8.834691
# final  value 8.834691
# stopped after 100 iterations
# # weights:  791
# initial  value 96.646165
# iter  10 value 28.640500
# iter  20 value 18.771320
# iter  30 value 13.289418
# iter  40 value 7.800417
# iter  50 value 5.374391
# iter  60 value 4.413320
# iter  70 value 3.477779
# iter  80 value 3.280611
# iter  90 value 3.178516
# iter 100 value 1.494568
# final  value 1.494568
# stopped after 100 iterations
# # weights:  159
# initial  value 98.638857
# iter  10 value 86.949051
# iter  20 value 64.627988
# iter  30 value 48.253415
# iter  40 value 43.722216
# iter  50 value 41.186203
# iter  60 value 37.741168
# iter  70 value 34.997915
# iter  80 value 30.359027
# iter  90 value 29.797252
# iter 100 value 29.778819
# final  value 29.778819
# stopped after 100 iterations
# # weights:  475
# initial  value 105.256308
# iter  10 value 71.601082
# iter  20 value 42.318653
# iter  30 value 30.966328
# iter  40 value 21.034146
# iter  50 value 18.880543
# iter  60 value 17.096665
# iter  70 value 16.302029
# iter  80 value 15.630168
# iter  90 value 15.290500
# iter 100 value 15.034654
# final  value 15.034654
# stopped after 100 iterations
# # weights:  791
# initial  value 121.116906
# iter  10 value 51.291491
# iter  20 value 25.317074
# iter  30 value 16.883888
# iter  40 value 15.197452
# iter  50 value 14.566096
# iter  60 value 14.317223
# iter  70 value 14.098197
# iter  80 value 13.952354
# iter  90 value 13.799796
# iter 100 value 13.638828
# final  value 13.638828
# stopped after 100 iterations
# # weights:  159
# initial  value 110.837346
# iter  10 value 75.916915
# iter  20 value 61.015259
# iter  30 value 60.706309
# iter  40 value 60.695529
# iter  50 value 59.162515
# iter  60 value 57.559324
# iter  70 value 55.634421
# iter  80 value 55.619314
# iter  90 value 53.699308
# iter 100 value 53.645026
# final  value 53.645026
# stopped after 100 iterations
# # weights:  475
# initial  value 97.725249
# iter  10 value 46.102016
# iter  20 value 33.642497
# iter  30 value 32.262461
# iter  40 value 31.749602
# iter  50 value 31.117909
# iter  60 value 24.580187
# iter  70 value 24.277585
# iter  80 value 24.243761
# iter  90 value 22.937572
# iter 100 value 22.536717
# final  value 22.536717
# stopped after 100 iterations
# # weights:  791
# initial  value 97.695284
# iter  10 value 55.119524
# iter  20 value 24.679311
# iter  30 value 14.388667
# iter  40 value 12.920125
# iter  50 value 11.112072
# iter  60 value 10.921888
# iter  70 value 10.844817
# iter  80 value 9.649655
# iter  90 value 9.634569
# iter 100 value 9.343767
# final  value 9.343767
# stopped after 100 iterations
# # weights:  159
# initial  value 93.798466
# iter  10 value 80.658294
# iter  20 value 66.803960
# iter  30 value 64.326401
# iter  40 value 64.247759
# iter  50 value 57.845059
# iter  60 value 56.436115
# iter  70 value 56.430230
# iter  80 value 56.427662
# iter  90 value 56.426445
# iter 100 value 56.425458
# final  value 56.425458
# stopped after 100 iterations
# # weights:  475
# initial  value 100.889538
# iter  10 value 60.565140
# iter  20 value 40.505095
# iter  30 value 37.833782
# iter  40 value 37.071272
# iter  50 value 35.226251
# iter  60 value 35.077293
# iter  70 value 34.483699
# iter  80 value 34.479047
# iter  90 value 34.477507
# iter 100 value 33.839273
# final  value 33.839273
# stopped after 100 iterations
# # weights:  791
# initial  value 107.908176
# iter  10 value 39.647094
# iter  20 value 23.581266
# iter  30 value 15.000924
# iter  40 value 13.577907
# iter  50 value 12.848537
# iter  60 value 12.340333
# iter  70 value 12.231983
# iter  80 value 11.803008
# iter  90 value 11.793414
# iter 100 value 11.597425
# final  value 11.597425
# stopped after 100 iterations
# # weights:  159
# initial  value 95.781537
# iter  10 value 77.523596
# iter  20 value 63.583716
# iter  30 value 48.385617
# iter  40 value 36.416456
# iter  50 value 30.007353
# iter  60 value 28.174404
# iter  70 value 23.497089
# iter  80 value 22.749603
# iter  90 value 22.720464
# iter 100 value 22.719588
# final  value 22.719588
# stopped after 100 iterations
# # weights:  475
# initial  value 110.317479
# iter  10 value 70.903653
# iter  20 value 41.383799
# iter  30 value 27.620177
# iter  40 value 18.262151
# iter  50 value 14.759262
# iter  60 value 13.818473
# iter  70 value 13.469294
# iter  80 value 13.214097
# iter  90 value 13.145317
# iter 100 value 13.112198
# final  value 13.112198
# stopped after 100 iterations
# # weights:  791
# initial  value 106.279998
# iter  10 value 66.029390
# iter  20 value 32.178078
# iter  30 value 19.602770
# iter  40 value 15.104470
# iter  50 value 13.548413
# iter  60 value 13.095986
# iter  70 value 12.770406
# iter  80 value 12.618745
# iter  90 value 12.510582
# iter 100 value 12.475819
# final  value 12.475819
# stopped after 100 iterations
# # weights:  159
# initial  value 93.291351
# iter  10 value 63.186432
# iter  20 value 51.963858
# iter  30 value 48.959570
# iter  40 value 47.725416
# iter  50 value 45.998559
# iter  60 value 44.600464
# iter  70 value 44.586811
# iter  80 value 44.581641
# iter  90 value 41.644341
# iter 100 value 41.640772
# final  value 41.640772
# stopped after 100 iterations
# # weights:  475
# initial  value 112.269900
# iter  10 value 74.316180
# iter  20 value 55.306382
# iter  30 value 41.692714
# iter  40 value 40.037736
# iter  50 value 39.784092
# iter  60 value 37.977018
# iter  70 value 37.739350
# iter  80 value 35.758338
# iter  90 value 35.657232
# iter 100 value 34.158512
# final  value 34.158512
# stopped after 100 iterations
# # weights:  791
# initial  value 144.943977
# iter  10 value 45.533862
# iter  20 value 26.217626
# iter  30 value 24.850373
# iter  40 value 22.969004
# iter  50 value 22.582472
# iter  60 value 21.459615
# iter  70 value 20.961867
# iter  80 value 20.686711
# iter  90 value 19.992488
# iter 100 value 19.015506
# final  value 19.015506
# stopped after 100 iterations
# # weights:  159
# initial  value 104.724520
# iter  10 value 66.586415
# iter  20 value 49.215197
# iter  30 value 47.803273
# iter  40 value 47.755143
# iter  50 value 47.705593
# iter  60 value 46.344410
# iter  70 value 46.238399
# iter  80 value 44.800748
# iter  90 value 44.793226
# iter 100 value 44.791159
# final  value 44.791159
# stopped after 100 iterations
# # weights:  475
# initial  value 99.875187
# iter  10 value 63.442858
# iter  20 value 32.949130
# iter  30 value 25.991890
# iter  40 value 23.910564
# iter  50 value 23.762890
# iter  60 value 20.130788
# iter  70 value 17.487048
# iter  80 value 17.321657
# iter  90 value 16.016222
# iter 100 value 15.896140
# final  value 15.896140
# stopped after 100 iterations
# # weights:  791
# initial  value 98.052736
# iter  10 value 26.974918
# iter  20 value 19.051809
# iter  30 value 16.515840
# iter  40 value 14.835929
# iter  50 value 14.348611
# iter  60 value 10.511103
# iter  70 value 9.853985
# iter  80 value 8.292023
# iter  90 value 5.394811
# iter 100 value 5.082402
# final  value 5.082402
# stopped after 100 iterations
# # weights:  159
# initial  value 95.147705
# iter  10 value 70.827648
# iter  20 value 51.253029
# iter  30 value 41.784565
# iter  40 value 34.198245
# iter  50 value 32.156090
# iter  60 value 29.913417
# iter  70 value 29.900438
# iter  80 value 28.426798
# iter  90 value 27.725939
# iter 100 value 27.713282
# final  value 27.713282
# stopped after 100 iterations
# # weights:  475
# initial  value 102.136419
# iter  10 value 66.675885
# iter  20 value 39.065703
# iter  30 value 23.477989
# iter  40 value 17.698266
# iter  50 value 15.957075
# iter  60 value 14.532162
# iter  70 value 14.238831
# iter  80 value 14.062210
# iter  90 value 13.956638
# iter 100 value 13.867788
# final  value 13.867788
# stopped after 100 iterations
# # weights:  791
# initial  value 111.681457
# iter  10 value 51.728354
# iter  20 value 27.464565
# iter  30 value 18.523174
# iter  40 value 14.241334
# iter  50 value 13.130138
# iter  60 value 12.903396
# iter  70 value 12.719864
# iter  80 value 12.664935
# iter  90 value 12.631565
# iter 100 value 12.616074
# final  value 12.616074
# stopped after 100 iterations
# # weights:  159
# initial  value 102.514234
# iter  10 value 72.337779
# iter  20 value 63.851993
# iter  30 value 62.448002
# iter  40 value 56.861036
# iter  50 value 55.097507
# iter  60 value 52.943907
# iter  70 value 50.383394
# iter  80 value 50.351237
# iter  90 value 50.348347
# iter 100 value 50.345174
# final  value 50.345174
# stopped after 100 iterations
# # weights:  475
# initial  value 97.894540
# iter  10 value 38.485180
# iter  20 value 27.546734
# iter  30 value 27.178686
# iter  40 value 26.337901
# iter  50 value 26.236323
# iter  60 value 26.142726
# iter  70 value 25.951211
# iter  80 value 25.867829
# iter  90 value 25.858886
# iter 100 value 25.796350
# final  value 25.796350
# stopped after 100 iterations
# # weights:  791
# initial  value 93.514044
# iter  10 value 33.071482
# iter  20 value 21.264058
# iter  30 value 15.775928
# iter  40 value 15.115485
# iter  50 value 14.945892
# iter  60 value 6.506716
# iter  70 value 5.535094
# iter  80 value 5.072875
# iter  90 value 5.004015
# iter 100 value 4.984436
# final  value 4.984436
# stopped after 100 iterations
# # weights:  159
# initial  value 104.313004
# iter  10 value 85.639529
# iter  20 value 61.809219
# iter  30 value 59.552218
# iter  40 value 56.056169
# iter  50 value 56.000705
# iter  60 value 54.824794
# iter  70 value 52.276086
# iter  80 value 52.267898
# iter  90 value 50.657786
# iter 100 value 50.653417
# final  value 50.653417
# stopped after 100 iterations
# # weights:  475
# initial  value 123.980403
# iter  10 value 61.295894
# iter  20 value 45.542697
# iter  30 value 26.684358
# iter  40 value 23.051320
# iter  50 value 21.564179
# iter  60 value 18.852280
# iter  70 value 18.422141
# iter  80 value 18.412743
# iter  90 value 17.610115
# iter 100 value 15.334377
# final  value 15.334377
# stopped after 100 iterations
# # weights:  791
# initial  value 108.591115
# iter  10 value 43.069421
# iter  20 value 16.792069
# iter  30 value 10.610411
# iter  40 value 10.025609
# iter  50 value 7.318270
# iter  60 value 5.555822
# iter  70 value 5.405887
# iter  80 value 4.263680
# iter  90 value 1.974428
# iter 100 value 1.940661
# final  value 1.940661
# stopped after 100 iterations
# # weights:  159
# initial  value 129.777547
# iter  10 value 62.084700
# iter  20 value 44.081247
# iter  30 value 29.316776
# iter  40 value 24.684437
# iter  50 value 23.205353
# iter  60 value 21.450495
# iter  70 value 18.385680
# iter  80 value 16.753358
# iter  90 value 16.671652
# iter 100 value 16.669546
# final  value 16.669546
# stopped after 100 iterations
# # weights:  475
# initial  value 104.114373
# iter  10 value 56.457699
# iter  20 value 33.636166
# iter  30 value 24.514458
# iter  40 value 20.744020
# iter  50 value 17.551047
# iter  60 value 16.699325
# iter  70 value 15.760433
# iter  80 value 15.187479
# iter  90 value 15.160053
# iter 100 value 15.159161
# final  value 15.159161
# stopped after 100 iterations
# # weights:  791
# initial  value 110.359704
# iter  10 value 55.483487
# iter  20 value 24.604213
# iter  30 value 15.885492
# iter  40 value 13.238178
# iter  50 value 12.822833
# iter  60 value 12.434848
# iter  70 value 12.372546
# iter  80 value 12.253755
# iter  90 value 12.220172
# iter 100 value 12.083658
# final  value 12.083658
# stopped after 100 iterations
# # weights:  159
# initial  value 95.488485
# iter  10 value 80.944649
# iter  20 value 60.459327
# iter  30 value 50.206062
# iter  40 value 45.404787
# iter  50 value 45.373977
# iter  60 value 45.361619
# iter  70 value 45.348663
# iter  80 value 45.339922
# iter  90 value 45.336312
# iter 100 value 45.333758
# final  value 45.333758
# stopped after 100 iterations
# # weights:  475
# initial  value 100.903286
# iter  10 value 56.920301
# iter  20 value 37.603105
# iter  30 value 24.909624
# iter  40 value 24.171981
# iter  50 value 22.527902
# iter  60 value 20.348379
# iter  70 value 15.010912
# iter  80 value 14.044008
# iter  90 value 13.593803
# iter 100 value 10.821096
# final  value 10.821096
# stopped after 100 iterations
# # weights:  791
# initial  value 101.989300
# iter  10 value 46.193821
# iter  20 value 18.768668
# iter  30 value 4.104995
# iter  40 value 2.539605
# iter  50 value 2.431296
# iter  60 value 0.645938
# iter  70 value 0.546702
# iter  80 value 0.471352
# iter  90 value 0.451892
# iter 100 value 0.432227
# final  value 0.432227
# stopped after 100 iterations
# # weights:  475
# initial  value 129.318874
# iter  10 value 69.872198
# iter  20 value 48.317690
# iter  30 value 30.416234
# iter  40 value 25.585141
# iter  50 value 23.453074
# iter  60 value 21.753838
# iter  70 value 18.253490
# iter  80 value 16.332445
# iter  90 value 16.197034
# iter 100 value 16.145598
# final  value 16.145598
# stopped after 100 iterations

# %%
# estimate variable importance
nnet.imp <- varImp(m.nnet, scale=TRUE)$importance
nnet.imp$Name <- rownames(nnet.imp)
# summarize importance
nnet.imp <- nnet.imp[order(nnet.imp$Overall, decreasing=TRUE),]
nnet.imp <- rownames(nnet.imp[1:50, ])
nnet.imp
# Out:
#  [1] "`2919`"  "`6374`"  "`6097`"  "`3673`"  "`56477`" "`4773`"  "`1191`"
#  [8] "`6373`"  "`4772`"  "`4982`"  "`91949`" "`9636`"  "`54674`" "`7187`"
# [15] "`3552`"  "`3458`"  "`54209`" "`7702`"  "`4775`"  "`50489`" "`684`"
# [22] "`3568`"  "`83607`" "`1958`"  "`7040`"  "`945`"   "`54210`" "`8600`"
# [29] "`1281`"  "`51295`" "`3119`"  "`64170`" "`7177`"  "`6932`"  "`3662`"
# [36] "`6504`"  "`4102`"  "`3140`"  "`4311`"  "`6279`"  "`3146`"  "`10148`"
# [43] "`10581`" "`1051`"  "`3556`"  "`7412`"  "`648`"   "`718`"   "`5580`"
# [50] "`4615`"

# %% [markdown]
# # Compare feature ranks

# %%
a <- rf.imp
colnames(a) <- c("GeneID", "Score.rf")

mergedScore<- Reduce(function(x,y) merge(x,y,by="GeneID"), list(a,b,c,d))
                     
# find  correlations
#
