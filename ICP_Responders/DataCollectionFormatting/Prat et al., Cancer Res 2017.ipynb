# %% [markdown]
# # Formatting data and collating it
# ## Setting working directory

# %%
setwd("/home/jp/ICP_Responders/DataCollectionFormatting/RawData")

# %%
getwd()
# Out:
# [1] "/home/jp/ICP_Responders/DataCollectionFormatting/RawData"

# %% [markdown]
# ## Read Supplementary Data file

# %%
supp <- read.csv("Prat_supp.csv") # TODO: fix this redirection issue!!!

# %%
supp
# Out:
#      Please.turn.JavaScript.on.and.reload.the.page..Checking.your.browser.before.accessing.aacrjournals.org..Please.enable.Cookies.and.reload.the.page..This.process.is.automatic..Your.browser.will.redirect.to.your.requested.content.shortly..Please.allow.up.to.5.seconds..Redirecting..DDoS.protection.by.Cloudflare.Ray.ID..662bd8cb8c324ec1

# %% [markdown]
# ## Clinical

# %%
clinical <- read.csv("Prat2017_PD1_NSCLC-HNSC-Melanoma_Nanostring/ICB.Prat2017_Pembrolizumab-Nivolumab_NSCLC-HNSC-Melanoma.clinical", sep="\t")

# %%
clinical
# Out:
#     PFS        PFS.Event Response RECIST Age Gender Type     ECOG Baseline
# A1   2.7333333 1         1        SD     75  0      HEADNECK 0    0
# A2   2.0000000 1         0        PD     72  0      HEADNECK 1    0
# A3   1.8000000 0         1        SD     57  0      HEADNECK 1    1
# A4  13.5666667 0         1        CR     50  0      HEADNECK 1    1
# A5  12.1666667 0         1        PR     59  0      HEADNECK 1    1
# A6  25.7333333 0         1        CR     57  0      ADENO    1    0
# A7   1.0000000 1         0        PD     59  1      ADENO    1    0
# A8   0.0000000 1         0        PD     55  0      ADENO    1    0
# A9   1.9333333 0         1        SD     79  0      ADENO    1    0
# A10  2.8000000 1         0        PD     46  1      ADENO    1    0
# A11  2.8666667 0         1        SD     62  0      ADENO    1    0
# A12  3.7666667 1         1        SD     72  0      ADENO    0    0
# A13  4.9000000 0         1        PR     46  0      ADENO    0    0
# ...

# %% [markdown]
# ## Self Subtract

# %%
self_subtract <- read.csv("Prat2017_PD1_NSCLC-HNSC-Melanoma_Nanostring/ICB.Prat2017_Pembrolizumab-Nivolumab_NSCLC-HNSC-Melanoma.self_subtract", sep="\t")

# %%
self_subtract
# Out:
#        A3           A4           A5           A16           A17
# 3920   -0.037048998 -0.059521101 -0.016796343 -0.0595211011 -0.0452206283
# 345611 -0.173078748  0.010977016 -0.030998976 -0.0559012473  0.1793229862
# 3929   -0.368857481 -0.013230830 -0.298699051 -0.0663990037 -0.1196162015
# 54210   0.491806112  0.041592866  0.144774172  0.3175602146  0.5597757129
# 4049   -0.120158690 -0.122179233  0.071431882 -0.0001621679 -0.0001621679
# 3716   -0.074566939 -0.017182454 -0.101576738 -0.0247100333  0.0719819491
# 10454  -0.283848357 -0.046850929 -0.039048766 -0.0634922636  0.1055835700
# 3557    0.972517923  0.634771435 -0.041544182 -0.3646418130 -0.2648694812
# 3556    0.043073890  0.043073890 -0.124916585  0.0364847511  0.1850751749
# 3554   -0.154175746  0.133848769 -0.075525342  0.2004899222  0.1817592546
# 3553    0.991616839  0.595538872  0.237458744 -0.1430552971 -0.3064995493
# 3552    0.828378367  0.451169099 -0.114656147 -0.0532812714 -0.1545922354
# ...

# %%
self_subtract <- as.data.frame(t(self_subtract))  # transpose
self_subtract
# Out:
#     3920         345611       3929         54210       4049
# A3  -0.037048998 -0.173078748 -0.368857481  0.49180611 -0.1201586902
# A4  -0.059521101  0.010977016 -0.013230830  0.04159287 -0.1221792328
# A5  -0.016796343 -0.030998976 -0.298699051  0.14477417  0.0714318822
# A16 -0.059521101 -0.055901247 -0.066399004  0.31756021 -0.0001621679
# A17 -0.045220628  0.179322986 -0.119616202  0.55977571 -0.0001621679
# A18 -0.119066638 -0.042179451  0.188758424  0.49761887  0.0050639811
# A19  0.101110613  0.069645138  0.429073226  0.19877988 -0.0914248459
# A20  0.033633526  0.050338865 -0.157213294  0.33586009 -0.0732377963
# A21 -0.045220628 -0.016262640  0.007430542  0.33219951 -0.0080930705
# A22 -0.127627681  0.117930809  0.834049867  0.29014259  0.0443015440
# A23 -0.024132344 -0.009188050 -0.143373975 -0.04198644 -0.0080930705
# A24 -0.248121832 -0.029516967 -0.243702156  0.49761887  0.1454206091
# A25 -0.092224794  0.001913909  0.355295731  0.31866789 -0.0202018378
# ...

# %% [markdown]
# ## Merge
# The number of patients is different in clinical and self subtract
# Guess: No self subtract data for baseline 0

# %%
combined <- merge(clinical,self_subtract,by='row.names',all=TRUE)
colnames(combined)[colnames(combined) == "Row.names"] <- "Patient"
combined
# Out:
#    Patient PFS        PFS.Event Response RECIST Age Gender Type     ECOG
# 1  A1       2.7333333 1         1        SD     75  0      HEADNECK 0
# 2  A10      2.8000000 1         0        PD     46  1      ADENO    1
# 3  A11      2.8666667 0         1        SD     62  0      ADENO    1
# 4  A12      3.7666667 1         1        SD     72  0      ADENO    0
# 5  A13      4.9000000 0         1        PR     46  0      ADENO    0
# 6  A14      3.2000000 1         0        PD     60  1      ADENO    1
# 7  A15      1.8666667 0         1        SD     69  0      ADENO    1
# 8  A16      0.9666667 1         0        PD     44  1      ADENO    1
# 9  A17     12.1000000 0         1        SD     53  0      ADENO    0
# 10 A18      1.4000000 1         0        PD     51  0      ADENO    1
# 11 A19      6.3000000 1         1        PR     52  0      ADENO    0
# 12 A2       2.0000000 1         0        PD     72  0      HEADNECK 1
# ...

# %% [markdown]
# # Writing final tables in file

# %%
setwd("/home/jp/ICP_Responders/DataCollectionFormatting/MergeTables")
getwd()
# Out:
# [1] "/home/jp/ICP_Responders/DataCollectionFormatting/MergeTables"

# %%
write.csv(combined, "Prat.csv", row.names = FALSE)
df <- read.csv("Prat.csv")
df
# Out:
#    Patient PFS        PFS.Event Response RECIST Age Gender Type     ECOG
# 1  A1       2.7333333 1         1        SD     75  0      HEADNECK 0
# 2  A10      2.8000000 1         0        PD     46  1      ADENO    1
# 3  A11      2.8666667 0         1        SD     62  0      ADENO    1
# 4  A12      3.7666667 1         1        SD     72  0      ADENO    0
# 5  A13      4.9000000 0         1        PR     46  0      ADENO    0
# 6  A14      3.2000000 1         0        PD     60  1      ADENO    1
# 7  A15      1.8666667 0         1        SD     69  0      ADENO    1
# 8  A16      0.9666667 1         0        PD     44  1      ADENO    1
# 9  A17     12.1000000 0         1        SD     53  0      ADENO    0
# 10 A18      1.4000000 1         0        PD     51  0      ADENO    1
# 11 A19      6.3000000 1         1        PR     52  0      ADENO    0
# 12 A2       2.0000000 1         0        PD     72  0      HEADNECK 1
# ...
