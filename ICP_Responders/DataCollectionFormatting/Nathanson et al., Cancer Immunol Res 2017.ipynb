# %% [markdown]
# # Formatting data and collating it
# ## Setting working directory

# %%
setwd("/home/jp/ICP_Responders/DataCollectionFormatting/RawData")

# %%
getwd()
# Out:
# [1] "/home/jp/ICP_Responders/DataCollectionFormatting/RawData"

# %% [markdown]
# ## Read Supplementary Data file

# %%
cuff <- read.csv("cufflinks.csv")

# %%
cuff
# Out:
#         tracking_id     class_code nearest_ref_id gene_id
# 1       ENSG00000268020 -          -              ENSG00000268020
# 2       ENSG00000237613 -          -              ENSG00000237613
# 3       ENSG00000186092 -          -              ENSG00000186092
# 4       ENSG00000238009 -          -              ENSG00000238009
# 5       ENSG00000239945 -          -              ENSG00000239945
# 6       ENSG00000233750 -          -              ENSG00000233750
# 7       ENSG00000240361 -          -              ENSG00000240361
# 8       ENSG00000239906 -          -              ENSG00000239906
# 9       ENSG00000237683 -          -              ENSG00000237683
# 10      ENSG00000268903 -          -              ENSG00000268903
# 11      ENSG00000269981 -          -              ENSG00000269981
# 12      ENSG00000228463 -          -              ENSG00000228463
# 13      ENSG00000241670 -          -              ENSG00000241670
# ...

# %% [markdown]
# ## Read Pre
# ### Clinical

# %%
pre_clinical <- read.csv("Nathanson2017_CTLA4_Melanoma_RNASeq_Pre/ICB.Nathanson2017_Ipilimumab_Melanoma_Pre.clinical", sep="\t")

# %%
pre_clinical
# Out:
#   Patient OS  OS.Event Gender Response
# 1 P6126   1.9 0        1      1
# 2 P167    2.7 0        0      1
# 3 P1494   2.0 0        0      1
# 4 P2056   3.9 0        1      1
# 5 P2051   0.8 1        1      0
# 6 P5784   0.5 1        1      0
# 7 P8727   0.4 1        0      0
# 8 P1867   1.5 1        0      0
# 9 P3549   0.5 1        0      0

# %%
row.names(pre_clinical) <- pre_clinical$Patient

# %%
pre_clinical <- pre_clinical[, -1]

# %%
pre_clinical
# Out:
#       OS  OS.Event Gender Response
# P6126 1.9 0        1      1
# P167  2.7 0        0      1
# P1494 2.0 0        0      1
# P2056 3.9 0        1      1
# P2051 0.8 1        1      0
# P5784 0.5 1        1      0
# P8727 0.4 1        0      0
# P1867 1.5 1        0      0
# P3549 0.5 1        0      0

# %% [markdown]
# ### Self Subtract

# %%
pre_self_subtract <- read.csv("Nathanson2017_CTLA4_Melanoma_RNASeq_Pre/ICB.Nathanson2017_Ipilimumab_Melanoma_Pre.self_subtract", sep="\t")
pre_self_subtract
# Out:
#       Entrez    P6126         P167          P1494         P2056
# 1             1  3.670584e-01 -0.1627803379  3.213053e-01  7.812774e-01
# 2        503538  3.525103e-01 -0.6496037563  1.059083e-01  3.582025e-01
# 3         29974 -2.076209e-01  1.6585430266 -2.076209e-01 -2.076209e-01
# 4             2 -1.104980e+00  0.1984735934 -1.141004e+00 -2.599261e-01
# 5        144571 -4.187450e-01 -0.4045754019  7.028402e-01  2.258693e-01
# 6        144568  2.882956e+00 -0.4093105842 -1.784216e-01 -3.799846e-01
# 7     100874108  0.000000e+00  0.0000000000  0.000000e+00  0.000000e+00
# 8     106478979  0.000000e+00  0.0000000000  0.000000e+00  0.000000e+00
# 9             3  9.276853e-03 -0.0428384665 -3.116986e-02 -6.693797e-02
# 10       127550 -1.291667e-02 -0.0129166697  6.744625e-02 -1.291667e-02
# 11        53947 -1.927381e-01 -0.4964318724 -1.470158e+00 -8.006925e-01
# 12        51146 -4.093345e-02 -0.0295351754  1.260012e-01 -7.016869e-04
# ...

# %%
pre_self_subtract <- as.data.frame(t(pre_self_subtract))

# %%
pre_self_subtract.names <- pre_self_subtract[1,]

colnames(pre_self_subtract) <- pre_self_subtract.names

# %%
pre_self_subtract <- pre_self_subtract[-1,]

# %%
pre_self_subtract
# Out:
#       1           503538      29974      2          144571      144568
# P6126  0.36705844  0.35251033 -0.2076209 -1.1049803 -0.41874498  2.8829563
# P167  -0.16278034 -0.64960376  1.6585430  0.1984736 -0.40457540 -0.4093106
# P1494  0.32130534  0.10590832 -0.2076209 -1.1410038  0.70284024 -0.1784216
# P2056  0.78127741  0.35820247 -0.2076209 -0.2599261  0.22586929 -0.3799846
# P2051  0.08832143 -0.05041334 -0.2076209  1.3475256  0.87209962 -0.4100378
# P5784  0.48468667  0.43570776 -0.2076209  0.1462315 -0.46011198 -0.3389105
# P8727 -0.40194010  0.13331933 -0.2076209 -1.5395137 -0.59883273 -0.4034876
# P1867 -2.32851873 -1.59386387 -0.2051966  3.1735489 -0.09406908 -0.3736886
# P3549  0.85058988  0.90823276 -0.2076209 -0.8203558  0.17552504 -0.3891151
#       100874108 106478979 3            127550      ⋯ 11130      7789
# P6126 0         0          0.009276853 -0.01291667 ⋯  0.7899648  0.005957200
# P167  0         0         -0.042838466 -0.01291667 ⋯  0.3230405 -0.348313541
# ...

# %% [markdown]
# ### Merge clinical and self subtract

# %%
pre_combined <- merge(pre_clinical,pre_self_subtract,by='row.names',all=TRUE)
colnames(pre_combined)[colnames(pre_combined) == "Row.names"] <- "Patient"
pre_combined
# Out:
#   Patient OS  OS.Event Gender Response 1           503538      29974
# 1 P1494   2.0 0        0      1         0.32130534  0.10590832 -0.2076209
# 2 P167    2.7 0        0      1        -0.16278034 -0.64960376  1.6585430
# 3 P1867   1.5 1        0      0        -2.32851873 -1.59386387 -0.2051966
# 4 P2051   0.8 1        1      0         0.08832143 -0.05041334 -0.2076209
# 5 P2056   3.9 0        1      1         0.78127741  0.35820247 -0.2076209
# 6 P3549   0.5 1        0      0         0.85058988  0.90823276 -0.2076209
# 7 P5784   0.5 1        1      0         0.48468667  0.43570776 -0.2076209
# 8 P6126   1.9 0        1      1         0.36705844  0.35251033 -0.2076209
# 9 P8727   0.4 1        0      0        -0.40194010  0.13331933 -0.2076209
#   2          144571      ⋯ 11130      7789         158586       79364
# 1 -1.1410038  0.70284024 ⋯ -0.2208769  0.509868186  0.591028026  0.24670976
# 2  0.1984736 -0.40457540 ⋯  0.3230405 -0.348313541 -0.276188591 -0.14024255
# ...

# %% [markdown]
# ## Read Post

# %% [markdown]
# ### Clinical

# %%
post_clinical <- read.csv("Nathanson2017_CTLA4_Melanoma_RNASeq_Post/ICB.Nathanson2017_Ipilimumab_Melanoma_Post.clinical", sep="\t")

# %%
post_clinical
# Out:
#    Patient OS  OS.Event Gender Response
# 1  P4631   0.5 1        0      0
# 2  P9449   0.6 1        1      0
# 3  P9521   2.7 1        0      0
# 4  P9705   1.2 1        1      0
# 5  P1509   4.5 0        1      1
# 6  P7623   4.0 0        0      0
# 7  P9699   4.4 0        0      1
# 8  P346    2.9 1        1      1
# 9  P6336   6.9 0        0      1
# 10 P5038   1.2 1        0      0
# 11 P5118   2.7 1        1      0
# 12 P6494   0.7 1        1      0
# 13 P7357   2.0 1        1      0
# 14 P4949   0.7 1        1      0
# 15 P4810   0.4 1        1      0

# %%
row.names(post_clinical) <- post_clinical$Patient

# %%
post_clinical
# Out:
#       Patient OS  OS.Event Gender Response
# P4631 P4631   0.5 1        0      0
# P9449 P9449   0.6 1        1      0
# P9521 P9521   2.7 1        0      0
# P9705 P9705   1.2 1        1      0
# P1509 P1509   4.5 0        1      1
# P7623 P7623   4.0 0        0      0
# P9699 P9699   4.4 0        0      1
# P346  P346    2.9 1        1      1
# P6336 P6336   6.9 0        0      1
# P5038 P5038   1.2 1        0      0
# P5118 P5118   2.7 1        1      0
# P6494 P6494   0.7 1        1      0
# P7357 P7357   2.0 1        1      0
# P4949 P4949   0.7 1        1      0
# P4810 P4810   0.4 1        1      0

# %%
post_clinical <- post_clinical[, -1]

# %%
post_clinical
# Out:
#       OS  OS.Event Gender Response
# P4631 0.5 1        0      0
# P9449 0.6 1        1      0
# P9521 2.7 1        0      0
# P9705 1.2 1        1      0
# P1509 4.5 0        1      1
# P7623 4.0 0        0      0
# P9699 4.4 0        0      1
# P346  2.9 1        1      1
# P6336 6.9 0        0      1
# P5038 1.2 1        0      0
# P5118 2.7 1        1      0
# P6494 0.7 1        1      0
# P7357 2.0 1        1      0
# P4949 0.7 1        1      0
# P4810 0.4 1        1      0

# %% [markdown]
# ### Self Subtract

# %%
post_self_subtract <- read.csv("Nathanson2017_CTLA4_Melanoma_RNASeq_Post/ICB.Nathanson2017_Ipilimumab_Melanoma_Post.self_subtract", sep="\t")

# %%
post_self_subtract
# Out:
#       Entrez    P4631         P9449         P9521         P9705
# 1             1 -0.704845880   0.4570770556  0.3702409730 -1.0001506002
# 2        503538 -0.260733659   0.0546111036  0.2676178876 -0.4862419794
# 3         29974 -0.007582718   0.0108901380 -0.0104045740 -0.0087555745
# 4             2 -1.241713516  -0.6383287633 -0.9880080319 -0.6054137558
# 5        144571  0.045751084   0.7621368681 -0.6117861356 -0.4901363000
# 6        144568 -0.029239074   0.0265446807 -0.0905207039 -0.0877167487
# 7     100874108  0.000000000   0.0000000000  0.0000000000  0.0000000000
# 8     106478979  0.003423296  -0.0002445211 -0.0002445211 -0.0002445211
# 9             3 -0.045845184   0.0062161541  0.0611914362 -0.0336267146
# 10       127550 -0.022562624   0.0201700114 -0.0225626244 -0.0038660459
# 11        53947 -0.808824487  -0.0694202648 -0.3525693294  0.2210440248
# 12        51146 -0.034124159  -0.0142844893 -0.0216628892  0.0813414983
# ...

# %%
post_self_subtract <- as.data.frame(t(post_self_subtract))  # transpose

# %%
post_self_subtract.names <- post_self_subtract[1,]  # index by patient ID
colnames(post_self_subtract) <- post_self_subtract.names

# %%
post_self_subtract <- post_self_subtract[-1,]

# %%
post_self_subtract
# Out:
#       1          503538      29974        2          144571      144568
# P4631 -0.7048459 -0.26073366 -0.007582718 -1.2417135  0.04575108 -0.029239074
# P9449  0.4570771  0.05461110  0.010890138 -0.6383288  0.76213687  0.026544681
# P9521  0.3702410  0.26761789 -0.010404574 -0.9880080 -0.61178614 -0.090520704
# P9705 -1.0001506 -0.48624198 -0.008755575 -0.6054138 -0.49013630 -0.087716749
# P1509 -0.6767664  0.10756798 -0.010404574  1.0147373  0.53822385 -0.072022259
# P7623 -0.7787619 -1.24566217 -0.010404574  0.8805762 -0.36288231 -0.090520704
# P9699  0.6260886 -0.17291950 -0.010404574  0.4552635 -0.63774827 -0.009050972
# P346   0.3093996 -0.25020447  0.028196275 -1.5271637  0.04950693  0.171431752
# P6336  1.1318837  1.02015062 -0.008221231  3.0290759 -0.02592215 -0.051269107
# P5038  0.3847593  0.49945646 -0.010404574 -1.9939462 -0.68367275 -0.090520704
# P5118 -0.5690439  0.52915526 -0.010404574  2.0224739  0.10176651 -0.090520704
# ...

# %% [markdown]
# ### Merge clinical and self subtract

# %%
post_combined <- merge(post_clinical,post_self_subtract,by='row.names',all=TRUE)
colnames(post_combined)[colnames(post_combined) == "Row.names"] <- "Patient"
post_combined
# Out:
#    Patient OS  OS.Event Gender Response 1          503538      29974
# 1  P1509   4.5 0        1      1        -0.6767664  0.10756798 -0.010404574
# 2  P346    2.9 1        1      1         0.3093996 -0.25020447  0.028196275
# 3  P4631   0.5 1        0      0        -0.7048459 -0.26073366 -0.007582718
# 4  P4810   0.4 1        1      0         0.6962591  0.29587689 -0.010404574
# 5  P4949   0.7 1        1      0         0.4248242 -0.18182480 -0.010026684
# 6  P5038   1.2 1        0      0         0.3847593  0.49945646 -0.010404574
# 7  P5118   2.7 1        1      0        -0.5690439  0.52915526 -0.010404574
# 8  P6336   6.9 0        0      1         1.1318837  1.02015062 -0.008221231
# 9  P6494   0.7 1        1      0        -1.1650045 -0.11623631  0.078736388
# 10 P7357   2.0 1        1      0         0.4940407 -0.06061331 -0.010404574
# 11 P7623   4.0 0        0      0        -0.7787619 -1.24566217 -0.010404574
# ...

# %% [markdown]
# # Writing final tables in file

# %%
setwd("/home/jp/ICP_Responders/DataCollectionFormatting/MergeTables")
getwd()
# Out:
# [1] "/home/jp/ICP_Responders/DataCollectionFormatting/MergeTables"

# %%
write.csv(pre_combined, "Nathanson_pre.csv", row.names = FALSE)
df <- read.csv("Nathanson_pre.csv")
df
# Out:
#   Patient OS  OS.Event Gender Response X1          X503538     X29974
# 1 P1494   2.0 0        0      1         0.32130534  0.10590832 -0.2076209
# 2 P167    2.7 0        0      1        -0.16278034 -0.64960376  1.6585430
# 3 P1867   1.5 1        0      0        -2.32851873 -1.59386387 -0.2051966
# 4 P2051   0.8 1        1      0         0.08832143 -0.05041334 -0.2076209
# 5 P2056   3.9 0        1      1         0.78127741  0.35820247 -0.2076209
# 6 P3549   0.5 1        0      0         0.85058988  0.90823276 -0.2076209
# 7 P5784   0.5 1        1      0         0.48468667  0.43570776 -0.2076209
# 8 P6126   1.9 0        1      1         0.36705844  0.35251033 -0.2076209
# 9 P8727   0.4 1        0      0        -0.40194010  0.13331933 -0.2076209
#   X2         X144571     ⋯ X11130     X7789        X158586      X79364
# 1 -1.1410038  0.70284024 ⋯ -0.2208769  0.509868186  0.591028026  0.24670976
# 2  0.1984736 -0.40457540 ⋯  0.3230405 -0.348313541 -0.276188591 -0.14024255
# ...

# %%
write.csv(post_combined, "Nathanson_post.csv", row.names = FALSE)
df <- read.csv("Nathanson_post.csv")
df
# Out:
#    Patient OS  OS.Event Gender Response X1         X503538     X29974
# 1  P1509   4.5 0        1      1        -0.6767664  0.10756798 -0.010404574
# 2  P346    2.9 1        1      1         0.3093996 -0.25020447  0.028196275
# 3  P4631   0.5 1        0      0        -0.7048459 -0.26073366 -0.007582718
# 4  P4810   0.4 1        1      0         0.6962591  0.29587689 -0.010404574
# 5  P4949   0.7 1        1      0         0.4248242 -0.18182480 -0.010026684
# 6  P5038   1.2 1        0      0         0.3847593  0.49945646 -0.010404574
# 7  P5118   2.7 1        1      0        -0.5690439  0.52915526 -0.010404574
# 8  P6336   6.9 0        0      1         1.1318837  1.02015062 -0.008221231
# 9  P6494   0.7 1        1      0        -1.1650045 -0.11623631  0.078736388
# 10 P7357   2.0 1        1      0         0.4940407 -0.06061331 -0.010404574
# 11 P7623   4.0 0        0      0        -0.7787619 -1.24566217 -0.010404574
# ...
